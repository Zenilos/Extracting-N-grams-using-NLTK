# %% [markdown]
# This note book is based on this post: <br>
#
# https://heartbeat.comet.ml/n-grams-and-how-to-implement-them-with-the-python-nltk-library-1379d0945f43

# %%
from nltk import download
download('stopwords')
download('punkt')
from nltk import word_tokenize
import re
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.util import ngrams 

sentence = "Natural Language Processing using N-grams is incredibly awesome."

def generate_n_grams(sentence, n):
  unigrams = ngrams(sentence.split(), n)
  return [unigram for unigram in unigrams]

# %%
# n = 1
generate_n_grams(sentence, 1)
# Out:
# [('Natural',),
#  ('Language',),
#  ('Processing',),
#  ('using',),
#  ('N-grams',),
#  ('is',),
#  ('incredibly',),
#  ('awesome.',)]

# %%
# n = 2
generate_n_grams(sentence, 2)
# Out:
# [('Natural', 'Language'),
#  ('Language', 'Processing'),
#  ('Processing', 'using'),
#  ('using', 'N-grams'),
#  ('N-grams', 'is'),
#  ('is', 'incredibly'),
#  ('incredibly', 'awesome.')]

# %%
# n = 3
generate_n_grams(sentence, 3)
# Out:
# [('Natural', 'Language', 'Processing'),
#  ('Language', 'Processing', 'using'),
#  ('Processing', 'using', 'N-grams'),
#  ('using', 'N-grams', 'is'),
#  ('N-grams', 'is', 'incredibly'),
#  ('is', 'incredibly', 'awesome.')]

# %%
import pandas as pd
import string #library that contains sets of punctuation
import nltk
from nltk.corpus import stopwords
from collections import defaultdict
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/02- N-grams and How to Implement Them With the Python NLTK Library/Financial_Sentiment.csv")
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5842 entries, 0 to 5841
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sentence   5842 non-null   object
#  1   Sentiment  5842 non-null   object
# dtypes: object(2)
# memory usage: 91.4+ KB
# None
#                                             Sentence Sentiment
# 0  The GeoSolutions technology will leverage Bene...  positive
# 1  $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2  For the last quarter of 2010 , Componenta 's n...  positive
# 3  According to the Finnish-Russian Chamber of Co...   neutral
# 4  The Swedish buyout firm has sold its remaining...   neutral

# %%
data['Sentiment'].unique(), data['Sentiment'].value_counts()
# Out:
# (array(['positive', 'negative', 'neutral'], dtype=object), neutral     3130
#  positive    1852
#  negative     860
#  Name: Sentiment, dtype: int64)

# %%
data.isnull().sum()
# Out:
# Sentence     0
# Sentiment    0
# dtype: int64

# %%
train_set, test_set = train_test_split(data, test_size=0.20, random_state=42)

train_set.shape, test_set.shape

# ((4673, 2), (1169, 2))
# Out:
# ((4673, 2), (1169, 2))

# %%
def generate_ngrams(sentence, ngram=1):
    # first lets convert the senetence into lower case
    sentence_lower = sentence.lower()
    sentence = re.sub(r'[^a-zA-Z0-9\s]', ' ', sentence_lower)
    
    # Remove stopwords, and punctuation
    stop = set(stopwords.words('english') + list(string.punctuation))
    
    # tokenize and display tokenized sentence
    clean_words = [i for i in word_tokenize(sentence) if i not in stop]
    print(f"\n===Tokens:=== \n{clean_words}\n")
    
    # Generate the n-grams of any size
    ngrams = zip(*[clean_words[i:] for i in range(ngram)])
    return [" ".join(ngram) for ngram in ngrams]

# %%
# Generate n-grams of N=4 from the text
text = 'Natural language Processing(NLP) is an awesome task! Learn N-grams today!'
generate_ngrams(text,4)
# Out:
# ===Tokens:===
# ['natural', 'language', 'processing', 'nlp', 'awesome', 'task', 'learn', 'n', 'grams', 'today']
# ['natural language processing nlp',
#  'language processing nlp awesome',
#  'processing nlp awesome task',
#  'nlp awesome task learn',
#  'awesome task learn n',
#  'task learn n grams',
#  'learn n grams today']

# %%
# Initialize a dictionary to store the words together with their counts
positiveWords=defaultdict(int)

# 1. traverse the dataframe pick sentences with positive sentiment
#   1.1. traverse through sentences and pick each word and preprocess 
#        them with the generate_ngrams() functions we created
#       1.1.1 store the words in a defaultdict 
# 2. convert the dictionary into a df

for text in train_set[train_set['Sentiment']=='positive']['Sentence']:
    for word in generate_ngrams(text):
        positiveWords[word]+=1
df_positive = pd.DataFrame(sorted(positiveWords.items(),key=lambda x:x[1],reverse=True))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['contrast', 'company', 'net', 'loss', 'third', 'quarter', '2009', 'contracted', 'eur', '76', 'million', 'eur', '256', 'million', 'corresponding', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finland', 'neste', 'oil', 'awarded', 'chemical', 'industry', 'federation', 'finland', 'innovation', 'award', 'nexbtl', 'technology', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['combining', 'deep', 'domain', 'expertise', 'application', 'service', 'management', 'asm', 'outsourcing', 'service', 'offerings', 'proved', 'winning', 'combination']
#
#
# ===Tokens:===
# ['trx', 'http', 'stks', 'co', '1kkk', 'long', 'setup', 'macd', 'cross']
#
#
# ===Tokens:===
# ['meanwhile', 'electrowatt', 'ekono', 'philippines', 'inc', 'also', 'awarded', 'three', 'year', 'operation', 'maintenance', 'contract', 'fr', 'cement', 'corporation']
#
#
# ===Tokens:===
# ['madison', 'wis', 'feb', '6', 'prnewswire', 'fiskars', 'announces', 'united', 'states', 'patent', 'trademark', 'office', 'granted', 'trademark', 'registration', 'color', 'orange', 'iconic', 'scissor', 'handles']
#
#
# ===Tokens:===
# ['wfm', 'bought', 'little', 'yesterday', 'hoping', 'earnings', 'pop']
#
#
# ===Tokens:===
# ['ragutis', 'controlled', 'finnish', 'brewery', 'reported', '5', '4', 'per', 'cent', 'rise', 'beer', 'sales', '10', '44', 'million', 'litres', 'held', '11', '09', 'per', 'cent', 'market', 'share']
#
#
# ===Tokens:===
# ['addition', 'cramo', 'peab', 'signed', 'exclusive', 'five', 'year', 'rental', 'agreements', 'finland', 'extended', 'existing', 'rental', 'agreements', 'swedish', 'market', 'another', 'five', 'years']
#
#
# ===Tokens:===
# ['combined', 'foreign', 'investments', 'creates', 'interesting', 'opportunities', 'solteq']
#
#
# ===Tokens:===
# ['osur', '33', 'since', '6', '25', 'buy', 'signal', 'resistance', '5', '33', 'expect', '1', 'pullback', '2nd', 'half', 'day', '2', 'break', 'abov', '5', '33', 'continue', 'rally', '4', '5', 'days']
#
#
# ===Tokens:===
# ['federal', 'secretary', 'transport', 'communication', 'mexico', 'awarded', 'poyry', 'mexican', 'partner', 'sintra', 'consulting', 'contract', 'connection', 'buenavista', 'cuautitlan', 'suburban', 'railway']
#
#
# ===Tokens:===
# ['kndi', 'china', 'electriccar', 'maker', 'china', 'car', 'sales', '7', '8', 'also', 'may', 'feed', 'tsla', 'momentum', 'run', 'lately']
#
#
# ===Tokens:===
# ['agreement', 'signed', 'biohit', 'healthcare', 'ltd', 'uk', 'based', 'subsidiary', 'biohit', 'oyj', 'finnish', 'public', 'company', 'develops', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems']
#
#
# ===Tokens:===
# ['third', 'quarter', 'net', 'sales', 'increased', '12', 'year', 'year', 'eur159', '5', '6', 'comparable', 'currency', 'rates', 'growth']
#
#
# ===Tokens:===
# ['finnish', 'vacon', 'signed', 'significant', 'deals', 'norwegian', 'scandinavian', 'electric', 'systems', 'ses', 'supply', 'ac', 'drives']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'bounces', 'back', 'mondi', 'barratt', 'lead']
#
#
# ===Tokens:===
# ['update', 'barclays', 'expects', 'gain', 'settling', 'lehman', 'bros', 'trustee']
#
#
# ===Tokens:===
# ['interest', 'heats', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'co', 'j5jvji9bia']
#
#
# ===Tokens:===
# ['according', 'pkc', 'acquisition', 'would', 'bring', 'significant', 'addition', 'pkc', 'customer', 'base']
#
#
# ===Tokens:===
# ['buffett', 'berkshire', 'builds', 'deere', 'stake', 'dumps', 'exxon']
#
#
# ===Tokens:===
# ['etteplan', 'targets', 'employ', 'least', '20', 'people', 'borl', 'nge']
#
#
# ===Tokens:===
# ['slw', 'weekly', '34', 'calls', '28', '95', '23', 'x', '25', '321', 'volume', 'worth', 'chance', 'jmho', 'http', 'stks', 'co', '1qfg']
#
#
# ===Tokens:===
# ['finnish', 'food', 'industry', 'companies', 'hk', 'ruokatalo', 'atria', 'form', 'joint', 'venture', 'company', 'called', 'l', 'nsi', 'kalkkuna', 'produce', 'turkey', 'meat']
#
#
# ===Tokens:===
# ['sales', 'climbed', '19', '2', 'pct', '1', '002', 'bln', 'eur', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure']
#
#
# ===Tokens:===
# ['continuing', 'operations', 'turned', 'operating', 'loss', 'eur', '0', '1', 'mn', 'slight', 'improvement', 'loss', 'eur', '0', '2', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'leap', 'ftse', '100', 'marks', 'spencer', 'drops']
#
#
# ===Tokens:===
# ['basware', 'corporation', 'stock', 'exchange', 'release', 'august', '31', '2010', '16', '25', 'basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'basware', 'deliver', 'invoice', 'automation', 'solution', 'connectivity', 'services', 'international', 'industrial', 'group']
#
#
# ===Tokens:===
# ['also', 'turned', 'earnings', 'per', 'share', 'eps', 'eur', '0', '08', 'versus', 'loss', 'per', 'share', 'eur', '0', '04']
#
#
# ===Tokens:===
# ['company', 'consolidated', 'operating', 'profit', 'amounted', 'eur', '15', '86', 'mn', 'eur', '4', '14', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['aapl', 'right', 'back', 'buy', 'dips', 'brought', 'cnbc', 'lol']
#
#
# ===Tokens:===
# ['capman', 'partner', 'able', 'develop', 'business', 'continue', 'focus', 'providing', 'quality', 'restaurant', 'services', 'customers', 'says', 'christopher', 'wynne', 'ceo', 'papa', 'john', 'russia']
#
#
# ===Tokens:===
# ['technical', 'indicators', 'stock', 'bullish', 'p', 'gives', 'nok', 'positive', '4', 'stars', '5', 'buy', 'ranking']
#
#
# ===Tokens:===
# ['upm', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', 'efficiency', 'operations', 'improved', 'chief', 'executive', 'jussi', 'pesonen', 'said']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'maker', 'amer', 'sports', 'oyj', 'hel', 'ameas', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '16', '9', 'million', 'usd', '22', '3', 'second', 'quarter', '2010', 'eur', '23', '2', 'million', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['outokumpu', 'chief', 'executive', 'juha', 'rantanen', 'expressed', 'confidence', 'china', 'market']
#
#
# ===Tokens:===
# ['nflx', 'vision', 'short', 'term', 'consolidation', 'movement', 'higher', 'http', 'stks', 'co', 'j05uu']
#
#
# ===Tokens:===
# ['elcoteq', 'elcoteq', 'se', 'leading', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'communications', 'technology', 'field']
#
#
# ===Tokens:===
# ['renovation', 'biggest', 'moulding', 'line', 'orhangazi', 'foundry', 'modern', 'line', 'europe']
#
#
# ===Tokens:===
# ['company', 'established', '3g', 'base', 'station', '17', '000', 'feet', 'foot', 'mount', 'everest', 'enable', 'mountain', 'climbers', '29', '035', 'foot', 'summit', 'surf', 'internet', 'even', 'send', 'videos', 'exploits']
#
#
# ===Tokens:===
# ['spy', 'hang', 'bull', 'hat', 'yet', 'next', 'week', 'pop', 'higher', 'qe3', 'hope', 'back', 'fed', '2', 'day', 'meeting']
#
#
# ===Tokens:===
# ['return', 'investment', '16', '6', 'compared', '15', '8', '2004']
#
#
# ===Tokens:===
# ['finnish', 'investment', 'group', 'panostaja', 'oyj', 'said', 'net', 'profit', 'went', '8', '6', 'mln', 'euro', '11', '4', 'mln', 'fiscal', '2005', '06', 'ended', 'october', '31', '2006', '2', '8', 'mln', 'euro', '3', '7', 'mln', 'period', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['analysts', 'impressed', 'progress', 'tesla', 'flagship', 'factory', 'co', 'spent', '1', '6b', 'upgrades', '15', 'https', 'co', 'sabxcsn8cd', 'tsrandall', 'tsla']
#
#
# ===Tokens:===
# ['london', 'afx', 'shares', 'rautaruukki', 'corp', 'upgraded', 'hold', 'sell', 'abn', 'amro', 'price', 'target', 'raised', '25', '75', 'eur', '14', '5', 'said', 'dealers']
#
#
# ===Tokens:===
# ['narrows', 'eur2', '8', '9', 'mo', '09', '29', 'october', '2009', 'finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'net', 'loss', 'narrowed', 'eur2', '8', 'first', 'nine', 'months', '2009', 'eur35', '6', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['adp', 'news', 'nov', '18', '2008', 'finnish', 'ac', 'drives', 'manufacturer', 'vacon', 'oyj', 'omx', 'vac1v', 'said', 'today', 'set', 'new', 'representative', 'offices', 'romania', 'ukraine', 'serve', 'growing', 'markets', 'eastern', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['finnish', 'aktia', 'group', 'operating', 'profit', 'rose', 'eur', '17', '5', 'mn', 'first', 'quarter', '2010', 'eur', '8', '2', 'mn', 'first', 'quarter', '2009']
#
#
# ===Tokens:===
# ['first', 'nine', 'months', '2010', 'talvivaara', 'net', 'loss', 'narrowed', 'eur', '8', '3', 'million', 'eur', '21', '9', 'million', 'period', '2009']
#
#
# ===Tokens:===
# ['wpp', 'boosts', 'sales', 'despite', 'cautious', 'clients']
#
#
# ===Tokens:===
# ['fb', 'small', 'long', '109', '25', 'via', 'calls']
#
#
# ===Tokens:===
# ['altia', 'operating', 'profit', 'jumped', 'eur', '47', 'million', 'eur', '6', '6', 'million']
#
#
# ===Tokens:===
# ['lnt', 'increases', 'annual', 'dividend', 'target', '1', '80', 'share', '1', '70', 'share']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'kci', 'konecranes', 'said', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'ltd']
#
#
# ===Tokens:===
# ['vaahto', 'pulp', 'paper', 'finnish', 'vaahto', 'group', 'awarded', 'order', 'renovate', 'finnish', 'swedish', 'forest', 'industry', 'company', 'stora', 'enso', 'paperboard', 'machine', 'ingerois', 'board', 'mill', 'finland']
#
#
# ===Tokens:===
# ['buy', 'recommendation', 'reiterated']
#
#
# ===Tokens:===
# ['bristol', 'port', 'company', 'sealed', 'one', 'million', 'pound', 'contract', 'cooper', 'specialised', 'handling', 'supply', 'four', '45', 'tonne', 'customised', 'reach', 'stackers', 'konecranes']
#
#
# ===Tokens:===
# ['h', 'move', 'enhance', 'growth']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'period', 'eur0', '9', 'eur0', '01', 'last', 'year']
#
#
# ===Tokens:===
# ['subscriptions', 'increase', 'cargotec', 'share', 'capital', '36', '780', 'euros']
#
#
# ===Tokens:===
# ['new', 'representation', 'extends', 'comptel', 'global', 'presence', 'total', '18', 'countries', 'serving', '250', 'customers', '80', 'countries', 'worldwide']
#
#
# ===Tokens:===
# ['china', 'finnish', 'kone', 'provides', 'elevators', 'escalators', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'high', 'speed', 'railway', 'section', 'beijing', 'shanghai', '1', '5', 'years', 'time']
#
#
# ===Tokens:===
# ['shares', 'standard', 'chartered', 'stan', 'rose', '1', '2', 'ftse', '100', 'royal', 'bank', 'scotland', 'rbs', 'shares', 'rose', '2', 'barclays', 'shares', 'barc', 'bcs', '1', '7']
#
#
# ===Tokens:===
# ['cargo', 'volume', 'increased', 'approximately', '5']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'retail', 'wholesale', 'group', 'kesko', 'reported', 'net', 'sales', '659', '4', 'mln', 'eur', 'february', 'increase', '10', '8', 'pct', 'year', 'year']
#
#
# ===Tokens:===
# ['lule', 'municipality', 'awarded', 'yit', '2', 'year', 'contract', 'property', 'management', 'one', 'third', 'municipality', 'properties', 'total', 'area', '140', '000', 'sq', 'metres']
#
#
# ===Tokens:===
# ['pre', 'tax', 'profit', 'totaled', 'eur', '397', '4', 'mn', 'eur', '164', '7', 'mn']
#
#
# ===Tokens:===
# ['yhoo', 'break', '5', 'min']
#
#
# ===Tokens:===
# ['today', 'bought', 'mu', 'yhoo', 'vale', 'nbl', 'twtr', 'axp', 'znga', 'https', 'co', 'vt6t5zp2is']
#
#
# ===Tokens:===
# ['kalnapilio', 'tauro', 'grupe', 'kalnapilis', 'tauras', 'group', 'owned', 'denmark', 'royal', 'unibrew', 'raised', 'market', 'share', '25', '2', 'percent', '23', '91', 'percent', 'beer', 'sales', 'nine', 'months', 'jumped', '11', '4', 'percent', '52', '99', 'million', 'liters']
#
#
# ===Tokens:===
# ['mos', 'looking', 'good', '58', '65', 'calls', 'active', 'month', 'weekly']
#
#
# ===Tokens:===
# ['nokian', 'tyre', 'proves', 'high', 'safety', 'excellently', 'important', 'driving', 'qualities', 'stability', 'mark', '1', '4', 'handling', '1', '5', 'braking', 'wet', 'road', '1', '9']
#
#
# ===Tokens:===
# ['several', 'growth', 'initiatives', 'chosen', 'geographic', 'areas', 'already', 'ongoing', 'continued', 'noting', 'lindex', 'opened', 'first', 'store', 'czech', 'republic', 'autumn', 'brno']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'totalled', 'eur', '2', '71', 'mn', 'compared', 'negative', 'eur', '0', '83', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['sppi', 'building', 'rs', 'sweet', 'want', 'break', 'new', '52week', 'earnings', 'growth', 'justifies', 'way', 'higher']
#
#
# ===Tokens:===
# ['according', 'finnish', 'metso', 'minerals', 'value', 'company', 'orders', 'gone', 'eur', '1', '9', 'bn', '12', 'months']
#
#
# ===Tokens:===
# ['return', 'equity', 'stood', '18', '3', 'compared', '15', '4', 'third', 'quarter', '2005']
#
#
# ===Tokens:===
# ['fio', 'stay']
#
#
# ===Tokens:===
# ['intuitiv', 'clne', 'gasoline', 'prices', 'spike', 'california', 'http', 'stks', 'co', 't1boi']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '6', '2009', 'finnish', 'fishing', 'tackle', 'company', 'rapala', 'vmc', 'corp', 'hel', 'rap1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '19', '2', 'million', 'usd', '24', '6', '2008', 'eur', '17', '5', 'million', '2007']
#
#
# ===Tokens:===
# ['warmly', 'welcome', 'michael', 'frei', 'outotec']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'group', 'share', 'price', 'climbs', '1', '5bn', 'special', 'dividend']
#
#
# ===Tokens:===
# ['stora', 'enso', 'third', 'quarter', 'pre', 'tax', 'profit', 'doubled', 'eur', '197mn']
#
#
# ===Tokens:===
# ['kesko', 'agro', 'lietuva', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'kesko', 'group', 'boosted', 'sales', '42', '9', 'percent', '13', '4', 'million', 'euros', 'vat', 'inclusive']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur13', '6', 'net', 'sales', 'increased', 'eur394', '7', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['compass', 'group', 'says', 'positive', 'year', 'ahead']
#
#
# ===Tokens:===
# ['shire', 'ceo', 'steps', 'drive', 'get', 'baxalta', 'board', 'talking']
#
#
# ===Tokens:===
# ['astrazeneca', 'acquires', 'zs', 'pharma', '2', '7', 'billion', 'deal']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '11', '4', 'mn', 'eur', '7', '5', 'mn']
#
#
# ===Tokens:===
# ['net', 'interest', 'income', 'eur', '152', '2', 'mn', 'eur', '101', '0', 'mn', '2008']
#
#
# ===Tokens:===
# ['president', 'ceo', 'mika', 'vehvil', 'inen', 'says', 'positive', 'signs', 'first', 'foremost', 'emerging', 'outside', 'finland']
#
#
# ===Tokens:===
# ['fb', 'slight', 'green', 'may', 'runner', 'later']
#
#
# ===Tokens:===
# ['contract', 'signed', 'august', 'papua', 'new', 'guinea', 'based', 'lihir', 'gold', 'ltd', 'asx', 'lgl']
#
#
# ===Tokens:===
# ['stora', 'enso', 'norske', 'skog', 'real', 'upm', 'kymmene', 'credit', 'suisse', 'first', 'boston', 'cfsb', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'nordic', 'forestry', 'groups']
#
#
# ===Tokens:===
# ['pleased', 'welcome', 'tapeks', 'noma', 'cramo', 'group']
#
#
# ===Tokens:===
# ['berkshire', 'applies', 'boost', 'wells', 'fargo', 'stake', '10', 'percent']
#
#
# ===Tokens:===
# ['outotec', 'oyj', 'press', 'release', 'december', '4', '2009', '10', '30', 'outotec', 'establishes', 'new', 'subsidiary', 'kolkata', 'outotec', 'established', 'subsidiary', 'india', 'order', 'better', 'serve', 'indian', 'customers', 'increase', 'business', 'growing', 'indian', 'market']
#
#
# ===Tokens:===
# ['amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'company']
#
#
# ===Tokens:===
# ['honored', 'acknowledged', 'commitment', 'industry', 'especially', 'asia', 'pacific']
#
#
# ===Tokens:===
# ['navteq', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'north', 'american', 'vehicles', 'may', 'leader', 'turn', 'turn', 'navigation', 'data', 'offered', 'services', 'onstar', 'north', 'america', 'said', 'analyst', 'phil', 'magney', 'telematics', 'research', 'group', 'minnetonka', 'minn']
#
#
# ===Tokens:===
# ['gsk', 'joins', 'china', 'trade', 'push', 'uk', 'trumpets', 'healthcare', 'deals']
#
#
# ===Tokens:===
# ['value', 'firm', 'forestry', 'holdings', 'increased', 'sek', '3', '6', 'bn']
#
#
# ===Tokens:===
# ['hammerson', 'jv', 'partner', 'secure', 'ownership', 'ireland', 'dundrum', 'quick', 'facts']
#
#
# ===Tokens:===
# ['2009', 'fiskars', 'cash', 'flow', 'operating', 'activities', 'amounted', 'eur121m', 'eur97m', 'previous', 'year']
#
#
# ===Tokens:===
# ['long', 'vvus', 'shares', 'call', 'option', 'w', 'expiration', 'umm', 'today', 'hitting', 'hod']
#
#
# ===Tokens:===
# ['chime', 'communications', 'set', 'acquired', 'wpp', 'providence']
#
#
# ===Tokens:===
# ['asdfllc', 'nice', 'pop', 'today', 'told', 'ya', 'would', 'green', 'haha', 'funny', 'bring', 'actually', 'working', 'story', 'nok', 'moment']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'company', 'elcoteq', 'signing', 'cooperation', 'agreement', 'japanese', 'mobile', 'phone', 'manufacturer', 'bypasses', 'elcoteq', 'tallinn', 'says', 'jan', 'kotka', 'ceo', 'elcoteq', 'tallinn']
#
#
# ===Tokens:===
# ['based', 'upon', 'unique', 'fiber', 'expertise', 'innovative', 'approach', 'company', 'strong', 'market', 'position', 'several', 'business', 'areas', 'operates']
#
#
# ===Tokens:===
# ['company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market']
#
#
# ===Tokens:===
# ['developers', 'project', 'predict', 'completed', 'april', '2009', 'skanssi', 'attract', '4', '5', 'million', 'visitors', 'annually']
#
#
# ===Tokens:===
# ['ftse', '100', 'flat', 'standard', 'chartered', 'leads', 'risers']
#
#
# ===Tokens:===
# ['manavigator', 'september', '7', '2010', 'kemira', 'unveils', 'indian', 'jv', 'ivrcl', 'finnish', 'chemicals', 'group', 'kemira', 'hel', 'kra1v', 'tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'india', 'local', 'construction', 'firm', 'ivrcl', 'infrastructure', 'projects', 'ltd', 'bom', '530773']
#
#
# ===Tokens:===
# ['according', 'finnish', 'aktia', 'bank', 'managing', 'director', 'jussi', 'laitinen', 'bank', 'aim', 'triple', 'number', 'customers', 'finland', 'next', 'five', 'years']
#
#
# ===Tokens:===
# ['finland', 'nokian', 'tyres', 'kazakhstan', 'ordabasy', 'corporation', 'signed', 'agreement', 'build', 'plant', 'astana', 'produce', 'car', 'tires', 'ordabasy', 'chairman', 'dinmukhamet', 'idrisov', 'said', 'press', 'conference']
#
#
# ===Tokens:===
# ['danske', 'bank', 'danske', 'dc', 'jumped', '3', '7', 'percent', '133', '4', 'kroner', 'rebounding', 'yesterday', '3', '5', 'percent', 'slide']
#
#
# ===Tokens:===
# ['vessel', 'order', 'help', 'aspo', 'secure', 'long', 'term', 'competitiveness', 'fleet', 'terms', 'technology', 'pricing']
#
#
# ===Tokens:===
# ['enb', 'ca', 'head', 'shoulders', 'bullish', 'reversal', 'setup', 'breakout', 'oil', 'gas', 'pipleline', 'stock', 'uso']
#
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastic', 'products', 'maker', 'suominen', 'corporation', 'said', 'net', 'loss', 'narrowed', '1', '6', 'mln', 'euro', '2', '0', 'mln', 'first', 'nine', 'months', '2006', '2', '16', 'mln', 'euro', '2', '7', 'mln', 'period', '2005']
#
#
# ===Tokens:===
# ['upside', 'moves', 'volatile', 'mining', 'sector', 'sending', 'anglo', 'american', 'plc', 'aal', '6', '8', '4', '30', 'pm', 'london', 'time']
#
#
# ===Tokens:===
# ['rad', 'would', 'consider', 'opportunity', 'add', 'position', 'company', 'right', 'track', 'still', 'improving', 'sales']
#
#
# ===Tokens:===
# ['ocn', 'stuff', 'looking', 'add', 'shares', 'get', 'new', 'high', 'breakout']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'net', 'profit', 'rose', '26', '1', 'mln', 'euro', '35', '9', 'mln', 'first', 'quarter', '2007', '5', '3', 'mln', 'euro', '7', '3', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['rapala', 'estimates', 'net', 'sales', '2008', 'increase', '8', '0', 'pct', '12', 'pct', 'assuming', '2007', 'exchange', 'rates']
#
#
# ===Tokens:===
# ['free', 'ha', 'heeeeeere', 'comes', 'pump', 'glad', 'picked', '9k', 'end', 'day', 'get', 'ready', 'bull', 'ride']
#
#
# ===Tokens:===
# ['eps', 'grew', '0', '04', 'eur', '0', '02', 'eur']
#
#
# ===Tokens:===
# ['held', 'recent', 'double', 'bottom', 'buy', 'point', '56', '57', 'almost', 'penny', 'today', 'wmt', 'http', 'chart', 'ly', '6nosp5q']
#
#
# ===Tokens:===
# ['astrazeneca', 'shares', 'climb', '3', 'drug', 'maker', 'ups', 'profits', 'forecasts']
#
#
# ===Tokens:===
# ['group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets']
#
#
# ===Tokens:===
# ['companiescar', 'insurer', 'hastings', 'group', 'driving', '180m', 'ipo']
#
#
# ===Tokens:===
# ['vrtx', 'early', 'technical', 'buy', 'signal', 'confirmation', '86', 'needs', 'fundam', 'incentive', 'https', 'co', 'quysrqfo2x']
#
#
# ===Tokens:===
# ['systeemitiimi', 'sales', 'project', 'resources', 'also', 'strengthened', 'director', 'paul', 'skogberg', 'said']
#
#
# ===Tokens:===
# ['accordance', 'strategy', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'south', 'africa', 'october']
#
#
# ===Tokens:===
# ['metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'china', 'lee', 'man', 'paper', 'co']
#
#
# ===Tokens:===
# ['poyry', 'recognized', 'one', 'world', 'leading', 'advisors', 'global', 'forestry', 'industry']
#
#
# ===Tokens:===
# ['skf', '6', 'april', '2010', 'alandsbanken', 'given', 'buy', 'recommendation', 'swedish', 'industrial', 'company', 'skf', 'ab', 'sto', 'skf', 'b', 'share', 'price', 'target', 'sek150']
#
#
# ===Tokens:===
# ['investments', 'operational', 'changes', 'enable', 'additional', 'optimisation', 'working', 'hours', 'thereby', 'cost', 'savings', '7', '9']
#
#
# ===Tokens:===
# ['finnish', 'software', 'developer', 'basware', 'oyj', 'said', 'november', '30', '2006', 'u', 'subsidiary', 'basware', 'inc', 'order', 'provide', 'software', 'contract', 'lifecycle', 'management', 'unnamed', 'u', 'medical', 'technology', 'company']
#
#
# ===Tokens:===
# ['repair', 'maintenance', 'business', 'accounted', 'net', 'sales', 'eur', '645', '3', 'mn', 'eur', '563', '6', 'mn']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'increased', '2', 'eur', '1', '050', '7', 'mn', 'eur', '1', '027', '0', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['stock', 'trading', 'maps', '50', 'day', 'map', 'sek72', '983', 'higher', '200', 'day', 'map', 'sek70', '283', 'bullish', 'indicator']
#
#
# ===Tokens:===
# ['luv', 'continues', 'consolidate', 'previous', 'break', 'area']
#
#
# ===Tokens:===
# ['recommendable', 'nokian', 'z', 'g2', 'according', 'adac', 'judgement', 'latest', 'summer', 'tyre', 'test', 'german', 'automobile', 'association', 'adac']
#
#
# ===Tokens:===
# ['economic', 'occupancy', 'rate', 'sponda', 'property', 'portfolio', 'rose', '91', '2', '88', '8', '2006']
#
#
# ===Tokens:===
# ['leipurin', 'growing', 'rapidly', 'internationalizing', 'group']
#
#
# ===Tokens:===
# ['2008', 'deal', 'likely', 'bring', 'savings', 'eur', '20mn', '25mn']
#
#
# ===Tokens:===
# ['cargotec', 'germany', 'gmbh', 'awarded', 'contract', 'stadtverwaltung', 'mainz', 'chassis', 'bodies', 'open', 'procedure']
#
#
# ===Tokens:===
# ['exports', 'accounted', '65', '4', 'net', 'sales', 'representing', 'time', 'record', 'company']
#
#
# ===Tokens:===
# ['previously', 'eb', 'delivered', 'custom', 'solution', 'lg', 'electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators']
#
#
# ===Tokens:===
# ['marimekko', 'group', 'full', 'year', 'net', 'sales', 'estimated', 'increase', '10']
#
#
# ===Tokens:===
# ['terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', 'chief', 'executive', 'veli', 'matti', 'mattila', 'said']
#
#
# ===Tokens:===
# ['profit', 'taking', 'aapl', 'morning', 'pressure', 'stock', 'still', 'bullish', 'aapl']
#
#
# ===Tokens:===
# ['passenger', 'related', 'revenue', 'rose', '5', '1', 'eur', '460', '8', 'mn', 'eur', '438', '5', 'mn', '2009']
#
#
# ===Tokens:===
# ['end', 'review', 'period', 'nordic', 'aluminium', 'order', 'book', 'stood', 'eur', '8', '77', 'mn', 'compared', 'eur', '7', '04', '2005']
#
#
# ===Tokens:===
# ['tesco', 'closes', 'new', 'chairman', 'dixons', 'carphone', 'john', 'allan', 'frame']
#
#
# ===Tokens:===
# ['takeover', 'cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'latvian', 'market']
#
#
# ===Tokens:===
# ['cencorp', 'estimates', 'net', 'sales', 'last', 'quarter', 'earlier', 'stated', 'eur4', '3', 'eur5', '0', 'operating', 'profit', 'ebit', 'estimated', 'positive']
#
#
# ===Tokens:===
# ['teliasonera', 'said', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', 'nepal', 'population']
#
#
# ===Tokens:===
# ['amazon', 'declares', 'best', 'ever', 'black', 'friday', 'cyber', 'monday', 'kindle', 'family', 'http', 'stks', 'co', 'cetw', 'via', 'engadget', 'amzn']
#
#
# ===Tokens:===
# ['rdc', 'rowan', 'expands', 'share', 'repurchase', 'program', '150', 'million']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', '2010', 'seen', 'grown', 'eur598', '3', 'eur582', '3', '2009']
#
#
# ===Tokens:===
# ['clothing', 'chain', 'sepp', 'l', 'net', 'sales', 'increased', '7', '0', 'eur', '30', '8', 'mn']
#
#
# ===Tokens:===
# ['ilmn', 'piper', 'jeffries', 'raises', 'pt', 'remain', 'long']
#
#
# ===Tokens:===
# ['dxcm', 'making', 'higher', 'highs', 'higher', 'lows', 'consolidates', 'past', 'several', 'weeks', '26', '70', 'time', 'high', '2006']
#
#
# ===Tokens:===
# ['mr', 'lee', 'said', 'hoped', 'neste', 'move', 'pave', 'way', 'collaboration', 'projects', 'two', 'countries']
#
#
# ===Tokens:===
# ['addition', 'fireplace', 'exports', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'sales', 'three', 'month', 'period', 'increased', 'respectively', 'eur0', '3', 'eur13', '1', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['also', 'bringing', 'right', 'kind', 'people', 'upgrade', 'human', 'resources']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '27', '8', 'mn', 'eur', '17', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['endp', 'saw', 'large', 'order', 'one', 'last', 'week', 'someone', 'also', 'accumulating', 'may', 'jun', '35', 'calls', 'today']
#
#
# ===Tokens:===
# ['commencing', 'construction', 'works', 'pearl', 'plaza', 'significant', 'step', 'russian', 'projects']
#
#
# ===Tokens:===
# ['raisio', 'divisions', 'recorded', 'operating', 'profit']
#
#
# ===Tokens:===
# ['meanwhile', 'nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout']
#
#
# ===Tokens:===
# ['glaxo', 'viiv', 'healthcare', 'signs', 'china', 'manufacturing', 'deal', 'desano']
#
#
# ===Tokens:===
# ['bot', 'amzn', '600', 'weekly', 'calls', '5', '93']
#
#
# ===Tokens:===
# ['finnish', 'lifting', 'equipment', 'maker', 'kone', 'oyj', 'said', 'october', '4', '2007', 'order', 'worth', '15', 'mln', 'euro', '21', '2', 'mln', 'deliver', 'total', '53', 'custom', 'designed', 'elevators', 'norwegian', 'shipbuilder', 'aker', 'yards', 'asa']
#
#
# ===Tokens:===
# ['standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'itella']
#
#
# ===Tokens:===
# ['refining', 'margin', 'year', '13', '39', 'bbl', 'compared', '10', '46', 'bbl', 'prior', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '103', '4', 'mn', 'eur', '23', '2', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['kraft', 'heinz', 'merger', 'came', 'together', 'speedy', '10', 'weeks']
#
#
# ===Tokens:===
# ['net', 'sales', 'vegetable', 'oil', 'business', 'rose', 'eur', '10', '6', 'mn', 'eur', '10', '1', 'mn']
#
#
# ===Tokens:===
# ['company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'eur', '67', '1', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'surged', 'eur21m', 'eur106', '000']
#
#
# ===Tokens:===
# ['bilfinger', 'industrial', 'services', 'win', '100m', 'bp', 'contract', 'extension']
#
#
# ===Tokens:===
# ['would', 'invest', 'physical', 'infrastructure', 'would', 'also', 'provide', 'know', 'managing', 'developing', 'science', 'technology', 'parks', 'said', 'sunrise', 'valley', 'director', 'andrius', 'bagdonas']
#
#
# ===Tokens:===
# ['rationalization', 'operations', 'seeks', 'achieve', 'eur', '1', 'million', 'yearly', 'savings', 'second', 'quarter', 'current', 'financial', 'year']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'outperforms', 'europe', 'royal', 'mail', 'tesco', 'rise']
#
#
# ===Tokens:===
# ['profit', 'period', 'eur', '5', '9', 'mn', 'eur', '1', '3', 'mn']
#
#
# ===Tokens:===
# ['cision', 'says', 'sale', 'return', 'u', 'k', 'operation', 'profitability']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'higher', '0', '48', '0', '37', 'year', 'ahead', 'market', 'consensus', '0', '40', 'eur']
#
#
# ===Tokens:===
# ['ebit', 'margin', '1', '4', '5', '1']
#
#
# ===Tokens:===
# ['ruukki', 'forecast', '15', '20', 'annual', 'sales', 'growth', 'positive', 'pretax', 'result', '2010']
#
#
# ===Tokens:===
# ['acquiring', 'rcp', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company']
#
#
# ===Tokens:===
# ['4', 'beaten', 'internet', 'companies', 'may', 'ripe', 'takeover', 'target', 'twitter', 'twtr', 'linkedin', 'lnkd', 'yahoo', 'yhoo', 'groupon', 'grpn']
#
#
# ===Tokens:===
# ['sonc', 'amazing', 'run', 'since', 'middle', 'march', 'obvious', 'quality', 'tastiness', 'burgers', 'factored', 'price', 'advance']
#
#
# ===Tokens:===
# ['activision', 'blizzard', 'media', 'networks', 'announces', 'record', 'esports', 'viewership', 'https', 'co', '729biqlbtk', 'atvi', 'partnered', 'hdsi', '9', 'tournament']
#
#
# ===Tokens:===
# ['dara', 'breaking']
#
#
# ===Tokens:===
# ['supermarket', 'stocks', 'rally', 'tesco', 'plans', 'axe', 'non', 'core', 'uk', 'assets', 'tsco', 'https', 'co', 'bmvhcrwrea']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '4', '7', 'mn', 'eur', '4', '6', 'mn']
#
#
# ===Tokens:===
# ['strategic', 'cooperation', 'rentakran', 'brings', 'us', 'new', 'customers', 'already', 'working', 'relationships', 'authorities', 'new', 'territories', 'said', 'jarmo', 'laasanen', 'senior', 'manager', 'cramo']
#
#
# ===Tokens:===
# ['kitd', 'looking', 'oversold', 'bounce']
#
#
# ===Tokens:===
# ['wft', 'closng', 'higher']
#
#
# ===Tokens:===
# ['kauko', 'telko', 'ltd', 'press', 'release', '19', '06', '2007', '14', '00', '1', '1', 'telko', 'group', 'kauko', 'telko', 'expanding', 'strategic', 'partnership', 'bp', 'industrial', 'lubricants', 'services', 'bp', 'ils', 'acquiring', 'total', 'ownership', 'bp', 'swedish', 'retail', 'company', 'molub', 'alloy', 'ab']
#
#
# ===Tokens:===
# ['eln', 'longs', 'congrats', 'another', 'hod']
#
#
# ===Tokens:===
# ['solutions', 'used', 'upgrading', 'networks', 'russian', 'mso', '37', 'different', 'cities', 'russia']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '9', '2009', 'finnish', 'computer', 'services', 'company', 'proha', 'oyj', 'hel', 'art1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '113', '000', 'usd', '146', '000', '2008', 'eur', '1', '2', 'million', '2007']
#
#
# ===Tokens:===
# ['major', 'breweries', 'increased', 'domestic', 'beer', 'sales', '4', '5', 'per', 'cent', 'last', 'year', '256', '88', 'million', 'litres', '245', '92', 'million', 'litres', '2004']
#
#
# ===Tokens:===
# ['shopping', 'center', 'opened', 'st', 'petersburg', 'russia', 'november', '2010', 'turn', 'cash', 'flow', 'finnish', 'department', 'store', 'chain', 'stockmann', 'russian', 'operations', 'positive', 'first', 'time', '2011']
#
#
# ===Tokens:===
# ['company', 'also', 'estimates', 'already', 'carried', 'investments', 'lead', 'increase', 'net', 'sales', '2010', '2009', 'reached', 'eur', '141', '7', 'million']
#
#
# ===Tokens:===
# ['poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'latin', 'america']
#
#
# ===Tokens:===
# ['stx', 'long', 'play', 'another', 'consistent', 'profit', 'zone', 'check', 'https', 'co', 'dqfuzozylh', 'https', 'co', 'ggne4ayzqn']
#
#
# ===Tokens:===
# ['combine', 'renew', 'contents', 'functionality', 'current', 'systems', 'funding', 'online', 'service', 'well', 'maintenance']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '6', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['daily', 'mail', 'owner', 'considering', 'yahoo', 'bid', 'yhoo', '2', '05', 'https', 'co', 'extzr1riyp']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'seen', 'eur', '0', '56', 'eur', '0', '38']
#
#
# ===Tokens:===
# ['went', 'long', 'ilmn']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'awarded', 'contract', 'rebuild', 'sabah', 'forest', 'industries', 'sfi', 'pulp', 'mill', 'sabah', 'malaysia']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '1', '2008', 'finnish', 'consulting', 'engineering', 'company', 'poyry', 'oyj', 'omx', 'poy1v', 'said', 'today', 'awarded', 'eur', '5', '2', 'million', 'usd', '7', '4', 'extension', 'existing', 'consultancy', 'engineering', 'contract', 'venezuel']
#
#
# ===Tokens:===
# ['finnish', 'kci', 'konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'delivered', '2007']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'release', 'february', '11', '2011', 'at8', '45', 'esl', 'shipping', 'ltd', 'part', 'aspo', 'group', 'signed', 'new', 'long', 'term', 'contract', 'rautaruukki', 'corporation', 'marine', 'transport', 'raw', 'materials', 'baltic', 'sea']
#
#
# ===Tokens:===
# ['long', 'pcln']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'management', 'software', 'solutions', 'provider', 'ixonos', 'oyj', 'hel', 'xns1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '3', '5', 'million', 'usd', '4', '5', '2008', 'eur', '3', '1', 'million', '2007']
#
#
# ===Tokens:===
# ['stock', 'rose', 'second', 'day', 'wednesday', 'bringing', 'two', 'day', 'rise', 'gbx12', '0', '2', '0']
#
#
# ===Tokens:===
# ['new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties']
#
#
# ===Tokens:===
# ['handelsbanken', 'ranked', 'local', 'cooperative', 'banks', 'aktia', 'customer', 'loyalty', 'time', 'however']
#
#
# ===Tokens:===
# ['fedday', 'looking', 'sharp', 'move', 'equities', 'aapl', 'hd', 'low', 'fb', 'seeing', 'uvxy', 'tvix', 'getting', 'hammered', 'even', 'though', 'market']
#
#
# ===Tokens:===
# ['operating', 'profit', 'grain', 'trading', 'increased', 'eur', '2', '0', 'mn', 'eur', '1', '4', 'mn', '2005']
#
#
# ===Tokens:===
# ['section', 'regional', 'news', 'demand', 'finnair', 'asian', 'traffic', 'measured', 'passenger', 'kilometers', '34', '9', 'august', 'compare', 'last', 'year']
#
#
# ===Tokens:===
# ['nflx', '3', 'lows']
#
#
# ===Tokens:===
# ['geosolutions', 'technology', 'leverage', 'benefon', 'gps', 'solutions', 'providing', 'location', 'based', 'search', 'technology', 'communities', 'platform', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model']
#
#
# ===Tokens:===
# ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa']
#
#
# ===Tokens:===
# ['15', 'december', '2010', 'finnish', 'german', 'telecoms', 'equipment', 'maker', 'nokia', 'siemens', 'networks', 'said', 'today', 'contract', 'upgrade', 'radio', 'network', 'home', 'based', 'telecommunications', 'company', 'elisa', 'oyj', 'hel', 'eli1v']
#
#
# ===Tokens:===
# ['zurich', 'insurance', 'considering', 'offer', 'uk', 'rival', 'rsa', 'insurance']
#
#
# ===Tokens:===
# ['full', '2010', 'company', 'expects', 'net', 'sales', 'operating', 'result', 'improve', 'previous', 'year', 'saying', 'positive', 'operating', 'result', 'amount', 'depend', 'order', 'intake', 'end', 'summer']
#
#
# ===Tokens:===
# ['looking', 'strong', 'bounce', 'spy', 'lunchtime', 'rally', 'coming', 'dia', 'iwm', 'qqq', 'aa', 'fb']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur', '36', 'million', 'eur', '27', 'million']
#
#
# ===Tokens:===
# ['company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230', '000', 'tonnes', 'copper']
#
#
# ===Tokens:===
# ['long', 'position', 'gol', 'updating', 'http', 'stks', 'co', 'fdmm']
#
#
# ===Tokens:===
# ['transaction', 'also', 'rationalize', 'pulp', 'paper', 'industry', 'related', 'solutions']
#
#
# ===Tokens:===
# ['neste', 'oil', 'corp', 'signed', 'long', 'term', 'procurement', 'contracts', 'honkajoki', 'oy', 'findest', 'protein', 'oy', 'owned', 'finnish', 'food', 'manufacturers', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'neste', '200', '000', 'b', 'cd', 'porvoo', 'finland', 'refinery']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur3', '1', 'net', 'sales', 'increased', 'eur61', '5', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['finnish', 'aldata', 'solution', 'signed', 'contract', 'supply', 'g', 'l', 'system', 'two', 'french', 'retail', 'chains']
#
#
# ===Tokens:===
# ['reached', 'agreement', 'union', 'flights', 'continue', 'normal', 'finnair', 'spokesman', 'usko', 'maatta', 'said']
#
#
# ===Tokens:===
# ['real', 'sales', 'expected', 'increased', '4', 'year', 'year', 'eur609m', 'second', 'quarter', '2010']
#
#
# ===Tokens:===
# ['australia', 'clears', 'ab', 'inbev', '100', 'billion', 'sabmiller', 'buyout', 'plan']
#
#
# ===Tokens:===
# ['far', 'mr', 'galvan', 'able', 'avoid', 'laying', 'workers']
#
#
# ===Tokens:===
# ['abb', 'deutsche', 'bank', 'upgraded', 'recommendation', 'swiss', 'swedish', 'engineering', 'group', 'abb', 'ltd', 'buy', 'hold']
#
#
# ===Tokens:===
# ['slowly', 'adding', 'fio', 'got', 'ta', 'careful', 'one', 'biggest', 'winners', '2012']
#
#
# ===Tokens:===
# ['see', '200', 'day', 'sma', 'big', 'hurdle', 'good', 'base', 'building', 'nflx', 'https', 'co', 'imkygo2cyc']
#
#
# ===Tokens:===
# ['news', 'feedschroders', 'books', 'solid', 'earnings', 'growth', 'several', 'board', 'changes']
#
#
# ===Tokens:===
# ['astrazeneca', 'weighing', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug']
#
#
# ===Tokens:===
# ['thanks', 'wide', 'contact', 'network', 'good', 'knowledge', 'market', 'business', 'environment', 'give', 'great', 'contribution', 'development', 'indian', 'operations', 'tells', 'incap', 'president', 'ceo', 'juhani', 'hanninen']
#
#
# ===Tokens:===
# ['design', 'team', 'long', 'admired', 'marimekko', 'vivid', 'patterns', 'colors']
#
#
# ===Tokens:===
# ['much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'finland', 'canada']
#
#
# ===Tokens:===
# ['arm', 'royalties', 'accelerate', 'smartphone', 'market', 'regains', 'strength']
#
#
# ===Tokens:===
# ['following', 'transaction', 'lundbeck', 'worldwide', 'rights', 'nalmefene', 'excluding', 'north', 'america', 'mexico', 'turkey', 'south', 'korea']
#
#
# ===Tokens:===
# ['fb', '110', '20', 'starting', 'show', 'relative', 'strength', 'signs', 'potential', 'b', 'daily']
#
#
# ===Tokens:===
# ['piper', 'upgrades', 'symantec', 'improving', 'renewal', 'rates', 'enterprise', 'growth', 'symc']
#
#
# ===Tokens:===
# ['district', 'court', 'helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005']
#
#
# ===Tokens:===
# ['china', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', 'also', 'strengthen', 'capability', 'offer', 'industry', 'leading', 'products', 'customers', 'china']
#
#
# ===Tokens:===
# ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'co', 'xk6lz3ui3k']
#
#
# ===Tokens:===
# ['adobe', 'receives', 'new', 'rating', 'top', 'analyst', 'adbe', 'https', 'co', 'ljnxpevhzn']
#
#
# ===Tokens:===
# ['assignment', 'strengthens', 'poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry']
#
#
# ===Tokens:===
# ['finnish', 'outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'ozk', 'kardzhali', 'zinc', 'smelter', 'bulgaria']
#
#
# ===Tokens:===
# ['london', 'open', 'taylor', 'wimpey', 'ashtead', 'drive', 'markets', 'higher', 'barclays', 'falls']
#
#
# ===Tokens:===
# ['es', 'f', 'nice', 'little', 'cup', 'handle', 'shaping', '15', 'minute', 'end', 'day', 'spy', 'spx', 'favours', 'good', 'day', 'index', 'see', 'gap', 'open']
#
#
# ===Tokens:===
# ['finland', 'insurance', 'company', 'pohjola', 'finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', 'traffic', 'safety']
#
#
# ===Tokens:===
# ['soapstone', 'deposits', 'medvezhyegorsk', 'area', 'expected', 'increase', 'tulikivi', 'current', 'reserves', 'considerably']
#
#
# ===Tokens:===
# ['q1', '10', '19', 'april', '2010', 'finnish', 'forest', 'machinery', 'equipment', 'maker', 'ponsse', 'oyj', 'hel', 'pon1v', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'eur6', '3', 'first', 'quarter', '2010', 'eur9', '6', 'loss', 'year', 'earlier']
#
#
# ===Tokens:===
# ['isrg', 'pt', 'raised', '700', '640', 'leerink', 'keeps', 'outperform', 'rated']
#
#
# ===Tokens:===
# ['q1', '2010', '18', 'may', '2010', 'finnish', 'electrical', 'components', 'maker', 'salcomp', 'oy', 'hel', 'sal1v', 'said', 'today', 'turned', 'net', 'profit', 'eur1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'eur2m', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['purchase', 'agreement', '7', '200', 'tons', 'gasoline', 'delivery', 'hamina', 'terminal', 'finland', 'signed', 'neste', 'oil', 'oyj', 'average', 'platts', 'index', 'september', 'plus', 'eight', 'us', 'dollars', 'per', 'month']
#
#
# ===Tokens:===
# ['added', 'bbby', 'jimcramer', 'wrong', 'one', 'still', 'profitable', 'merchant', 'profitable', 'stores']
#
#
# ===Tokens:===
# ['reporting', 'period', 'biotie', 'north', 'american', 'licensing', 'partner', 'somaxon', 'pharmaceuticals', 'announced', 'positive', 'results', 'nalmefene', 'pilot', 'phase', '2', 'clinical', 'trial', 'smoking', 'cessation']
#
#
# ===Tokens:===
# ['production', 'capacity', 'increase', '36', '000', '85', '000', 'tonnes', 'per', 'year', 'raw', 'material', 'continue', 'recycled', 'paper', 'board']
#
#
# ===Tokens:===
# ['government', 'professional', 'approach', 'assessing', 'offer']
#
#
# ===Tokens:===
# ['onty', 'continues', 'base', 'debate', 'lingers', 'ont', '10', 'data', 'next', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'moves', '10', 'downside', 'limited']
#
#
# ===Tokens:===
# ['result', 'distribution', 'companies', 'start', 'distribute', 'addition', 'current', 'product', 'offering', 'shimano', 'reels', 'rods', 'shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis']
#
#
# ===Tokens:===
# ['gild', 'expanding', 'research', 'facilities', 'keeping', 'pace', 'innovation', 'https', 'co', 'uoe7fj4lop']
#
#
# ===Tokens:===
# ['finnish', 'pulp', 'paper', 'machinery', 'maker', 'vaahto', 'group', 'oyj', 'swung', '1', '1', 'mln', 'euro', '1', '4', 'mln', 'net', 'profit', 'fiscal', '2005', '06', 'ended', 'august', '31', '2006', '249', '000', 'euro', '319', '000', 'net', 'loss', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['drugmaker', 'shire', 'buy', 'baxalta', '32', 'billion', '6', 'month', 'pursuit']
#
#
# ===Tokens:===
# ['fda', 'approves', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '83', '0', 'mn', 'eur', '23', '5', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'klabin', 'tel', 'maco', 'borba', 'mill', 'brazilian', 'state', 'paran']
#
#
# ===Tokens:===
# ['barclays', 'bank', 'america', 'citigroup', 'blockchain', 'sight']
#
#
# ===Tokens:===
# ['savon', 'koulutuskuntayhtyma', 'finland', 'based', 'company', 'awarded', 'contract', 'specialist', 'agricultural', 'forestry', 'machinery']
#
#
# ===Tokens:===
# ['brazilian', 'unit', 'finnish', 'security', 'solutions', 'provider', 'f', 'secure', 'signed', '1', '500', 'new', 'clients', 'last', 'year', 'online', 'news', 'source', 'reseller', 'web', 'quoted', 'division', 'commercial', 'director', 'vladimir', 'brand', 'saying']
#
#
# ===Tokens:===
# ['company', 'make', 'marketing', 'sales', 'investments', 'initiated', '2009', 'even', 'efficient', '2010']
#
#
# ===Tokens:===
# ['amazon', 'grocery', 'deal', 'morrisons', 'beginning']
#
#
# ===Tokens:===
# ['axp', 'looking', 'continuation', 'volume', 'increase', 'http', 'stks', 'co', 'c8sr']
#
#
# ===Tokens:===
# ['total', 'operating', 'revenue', 'grew', '27', '6', 'year', 'year', 'eur61m']
#
#
# ===Tokens:===
# ['coh', 'gaining', 'momentum', 'nice', 'buy', 'signals', 'long', '35', '92', 'http', 'stks', 'co', 't0tah']
#
#
# ===Tokens:===
# ['md', 'henning', 'bahr', 'stockmann', 'gruppen', 'praises', 'trend', 'since', 'chains', 'become', 'stronger', 'decision', 'making', 'processes', 'clear']
#
#
# ===Tokens:===
# ['20', 'october', '2010', 'finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'eur7m', 'first', 'nine', 'months', '2010', 'eur23', '3', 'period', '2009']
#
#
# ===Tokens:===
# ['svyturys', 'utenos', 'alus', 'controlled', 'nordic', 'group', 'baltic', 'beverages', 'holding', 'bbh', 'posted', '4', '7', 'per', 'cent', 'growth', 'beer', 'sales', 'january', 'may', '46', '22', 'million', 'litres']
#
#
# ===Tokens:===
# ['finnish', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'net', 'loss', 'contracted', 'eur', '49', 'million', 'usd', '68', '2', 'first', 'nine', 'months', '2010', 'eur', '229', 'million', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'consolidated', 'net', 'operating', 'profit', 'increased', 'eur', '4', '8', 'mn', 'first', 'quarter', '2005', 'eur', '6', '4', 'mn', 'first', 'quarter', '2006']
#
#
# ===Tokens:===
# ['real', 'corporation', 'press', 'release', '3', 'november', '10', '35', 'real', 'corporation', 'second', 'best', 'company', 'materials', 'sector', 'including', 'e', 'g', 'forest', 'industry', 'companies', 'carbon', 'disclosure', 'leadership', 'index', 'cdli', 'nordic', 'report', '2009']
#
#
# ===Tokens:===
# ['aapl', 'dips', 'bought', 'real', 'quick', 'higher', 'lows', 'fo', 'sho']
#
#
# ===Tokens:===
# ['lse', 'deutsche', 'boerse', 'merger', 'would', 'signal', 'end', 'exchange', 'mega', 'deals']
#
#
# ===Tokens:===
# ['save', 'breaking', 'downtrend', 'line', 'increasing', 'volume', 'move', '20', '57', 'could', 'see', 'upside', 'http', 'stks', 'co', 'l8y4']
#
#
# ===Tokens:===
# ['rcon', 'upside', 'today', 'thing', 'severe', 'low', 'float', 'catalyst', 'guy', 'run']
#
#
# ===Tokens:===
# ['eli', 'lilly', 'co', 'lly', 'broken', 'new', 'high', 'astrazeneca', 'collaboration']
#
#
# ===Tokens:===
# ['iaci', 'http', 'stks', 'co', 'tju', 'looks', 'good', 'weekly', 'chart']
#
#
# ===Tokens:===
# ['vmw', 'got', 'nice', 'push', 'today', 'following', 'small', 'sweepers', 'may', 'c', 'morning']
#
#
# ===Tokens:===
# ['teleste', 'acquisition', 'marks', 'entry', 'services', 'business', 'market', 'long', 'established', 'significant', 'supplier', 'products']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '500', '000', 'usd', '680', '000', 'last', 'quarter', '2010', 'eur', '5', '3', 'million', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '29', '2008', 'finnish', 'lifting', 'equipment', 'maker', 'konecranes', 'oyj', 'omx', 'kcr1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '116', '6', 'million', 'usd', '149', '1', 'first', 'nine', 'months', '2008', 'eur', '73', '6', 'million']
#
#
# ===Tokens:===
# ['lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'kaluga', 'regional', 'administration', 'last', 'november']
#
#
# ===Tokens:===
# ['operating', 'profit', 'asian', 'plants', 'grew', 'markedly']
#
#
# ===Tokens:===
# ['truly', 'takes', 'efficiency', 'new', 'heights', 'mr', 'metso', 'adds']
#
#
# ===Tokens:===
# ['january', 'september', '2007', 'group', 'net', 'sales', 'continuing', 'operations', 'rose', 'eur', '213', '1', 'mn', 'eur', '172', '6', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['transaction', 'strengthens', 'position', 'design', 'branded', 'goods', 'said', 'fiskars', 'president', 'ceo', 'heikki', 'allonen', 'pointing', 'two', 'groups', 'relatively', 'overlapping', 'operations']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '5', '5', 'mn', 'eur', '0', '7', 'mn']
#
#
# ===Tokens:===
# ['memorandum', 'understanding', 'mou', 'parties', 'collaborate', 'preparing', 'implementing', 'joint', 'projects', 'fields', 'combined', 'power', 'heat', 'generation', 'environmental', 'protection', 'energy', 'efficient', 'technologies']
#
#
# ===Tokens:===
# ...
# ['cooperation', 'double', 'switch', 'converter', 'capacity']
#
#
# ===Tokens:===
# ['company', 'also', 'said', 'poland', 'profitability', 'program', 'launched', 'oborniki', 'steel', 'frame', 'sandwich', 'panel', 'plant']
#
#
# ===Tokens:===
# ['repeat', 'order', 'follow', 'successfully', 'installed', '159', 'elevators', 'delhi', 'metro', 'system', 'kone', 'spokeswoman', 'told', 'thomson', 'financial', 'news']
#
#
# ===Tokens:===
# ['easyjet', 'attracts', 'passengers', 'june', 'still', 'lags', 'ryanair']
#
#
# ===Tokens:===
# ['cern', 'consolidating', '50', '200', 'nice', 'long', 'entry', 'w', 'stop', '10', 'targeting', '70', 'area']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'gains', 'land', 'securities', 'dividend', 'hike']
#
#
# ===Tokens:===
# ['bbry', 'ready', 'take']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '5', '8', 'mn', 'loss', 'eur', '1', '7', 'mn', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['metso', 'supply', 'equipment', 'two', 'process', 'lines', 'northland', 'resources', 'new', 'kaunisvaara', 'iron', 'ore', 'project', 'sweden', 'exploits', 'tapuli', 'sahavaara', 'iron', 'ore', 'deposits']
#
#
# ===Tokens:===
# ['carnival', 'corporation', 'china', 'merchants', 'group', 'sign', 'memo', 'understanding']
#
#
# ===Tokens:===
# ['alma', 'media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'order', 'supply', 'uncoated', 'fine', 'paper', 'machine', 'mcc', 'paper', 'yinhe', 'china']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '94', 'mn', 'eur', '2', '45', 'mn']
#
#
# ===Tokens:===
# ['diluted', 'loss', 'per', 'share', 'stood', 'eur', '0', '15', 'versus', 'eur', '0', '26']
#
#
# ===Tokens:===
# ['3', 'january', '2011', 'finnish', 'flag', 'carrier', 'finnair', 'oyj', 'hel', 'fia1s', 'said', 'today', 'sealed', 'nine', 'year', 'sale', 'leaseback', 'agreement', 'newest', 'airbus', 'a330', 'aircraft', 'syndication', 'japanese', 'operating', 'lease', 'market']
#
#
# ===Tokens:===
# ['auto', 'trader', 'share', 'price', 'surges', 'company', 'floats', 'lse']
#
#
# ===Tokens:===
# ['company', 'said', 'estimates', 'make', 'slight', 'profit', 'thanks', 'cost', 'cutting', 'measures']
#
#
# ===Tokens:===
# ['aapl', 'taking', 'shorts', 'punishing', 'reminder', 'spear', 'strongest', 'herd']
#
#
# ===Tokens:===
# ['raute', 'posted', 'net', 'profit', '1', '8', 'mln', 'euro', '2', '6', 'mln', 'third', 'quarter', '2007', 'compared', 'net', 'loss', '299', '000', 'euro', '430', '000', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['yahoo', 'stock', '36', '46', 'bidding', 'war', 'picks', 'company', 'https', 'co', 'jdnzxdcmkl', 'yhoo', 'https', 'co', 'hmoegfhgvn']
#
#
# ===Tokens:===
# ['company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', 'adding', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year']
#
#
# ===Tokens:===
# ['goog', 'breakout', 'likely', 'medium', 'target', '700', 'http', 'stks', 'co', '1lpz', 'http', 'chart', 'ly', 'lgb94rr']
#
#
# ===Tokens:===
# ['singapore', 'icis', '1', 'kemira', 'indian', 'water', 'infrastructure', 'firm', '2', 'ivrcl', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'andhra', 'pradesh', 'state', 'india', 'finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'tuesday']
#
#
# ===Tokens:===
# ['goog', 'testing', '200', 'day', 'consolidation', 'http', 'stks', 'co', 'h0cpj']
#
#
# ===Tokens:===
# ['prlb', 'hanging', 'tough', 'market', 'due', 'analyst', 'upgrades', 'last', 'week', 'almost', '3']
#
#
# ===Tokens:===
# ['energy', 'efficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'state', 'art', 'technology']
#
#
# ===Tokens:===
# ['entering', 'long', 'lockheed', 'martin', 'lmt', 'thursday', 'open', 'http', 'stks', 'co', 'exta']
#
#
# ===Tokens:===
# ['company', 'order', 'book', 'stood', '1', '5', 'bln', 'euro', '2', '2', 'bln', 'september', '30', '2007', '24', '2', 'pct', 'year', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '534', '3', 'mln']
#
#
# ===Tokens:===
# ['aim', 'ensure', 'vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', 'comments', 'vacon', 'plc', 'president', 'ceo', 'vesa', 'laisi']
#
#
# ===Tokens:===
# ['two', 'companies', 'also', 'partner', 'developing', 'raiso', 'cholesterol', 'lowering', 'brand', 'benecol']
#
#
# ===Tokens:===
# ['nyse', 'owner', 'ice', 'considers', 'offer', 'lse']
#
#
# ===Tokens:===
# ['astrazeneca', 'bags', 'another', 'cancer', 'drug', 'deal', 'time', 'inovio']
#
#
# ===Tokens:===
# ['adbe', 'technical', 'alerts', 'expansion', 'breakout', 'gilligan', 'island', 'sell', 'setup', 'volume', 'surge', 'new', '52', 'https', 'co', 'lxx66tknfh']
#
#
# ===Tokens:===
# ['change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', 'said', 'julia', 'prohaska', 'director', 'marketing', 'communications', 'fiskars']
#
#
# ===Tokens:===
# ['ebit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '67', '8', 'mn', 'eur', '38', '1', 'mn']
#
#
# ===Tokens:===
# ['finland', 'national', 'carrier', 'finnair', 'plc', 'carried', 'record', '8', '5', 'million', 'passengers', '2005', 'increase', '4', '5', 'percent', 'previous', 'year', 'airline', 'reported', 'tuesday']
#
#
# ===Tokens:===
# ['fb', 'trending', 'nicely', 'intraday']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur36m', 'eur27m']
#
#
# ===Tokens:===
# ['last', 'week', 'finnish', 'metals', 'technology', 'group', 'announced', 'plans', 'sell', '80', 'percent', 'technology', 'unit', 'company', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'raises', 'prospect', 'investor', 'payout']
#
#
# ===Tokens:===
# ['satama', 'earned', 'data', 'management', 'solutions', 'competency', 'business', 'intelligence', 'specialization', 'recentlyvia', 'acquisition', 'fimentor', 'oy']
#
#
# ===Tokens:===
# ['spain', 'caixabank', 'launches', 'new', 'takeover', 'bid', 'banco', 'bpi']
#
#
# ===Tokens:===
# ['gild', 'chart', 'ibb', 'back', 'support', 'https', 'co', 'gprz2ujfc4']
#
#
# ===Tokens:===
# ['ebit', 'totalled', 'eur', '14', '4', 'mn', 'compared', 'loss', 'eur', '0', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['stora', 'enso', 'r', 'shares', 'rose', '1', '20', 'pct', '11', '84', 'eur', 'upm', 'kymmene', 'also', 'dragged', 'higher', 'rising', '1', '68', 'pct', '17', '56', 'eur', 'real', 'b', 'added', '2', '38', 'pct', '4', '30', 'eur']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'amounted', 'ee', '55', '5', 'mn', '36', '2004']
#
#
# ===Tokens:===
# ['press', 'serco', 'set', 'appoint', 'roy', 'gardner', 'ex', 'centrica', 'chairman', 'ft']
#
#
# ===Tokens:===
# ['aapl', 'downgrade', 'bias', 'stock', 'buy']
#
#
# ===Tokens:===
# ['aapl', 'new', 'long', '110', '61', 'broken', 'targets', '112', '19', '119', '86', '123', '82', 'bears', 'must', 'retake', '102', '77', 'qqq', 'nq', 'f', 'ndx', 'https', 'co', '6l3m1wxchw']
#
#
# ===Tokens:===
# ['retailers', 'kingfisher', 'sports', 'direct', 'rise', 'britain', 'share', 'index']
#
#
# ===Tokens:===
# ['bought', 'celg', 'ready', 'bounce']
#
#
# ===Tokens:===
# ['aim', 'convert', 'plants', 'flexible', 'manufacturers', 'new', 'technologically', 'demanding', 'products']
#
#
# ===Tokens:===
# ['arm', 'profits', 'sales', 'shift', 'away', 'mobile', 'gains', 'pace']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'rose', 'eur', '1', '019', 'mn', 'eur', '1', '007', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'ftse', 'higher', 'clubcard', 'bid', 'reports']
#
#
# ===Tokens:===
# ['update', '1', 'astrazeneca', 'sells', 'rare', 'cancer', 'drug', 'sanofi', '300', 'mln']
#
#
# ===Tokens:===
# ['mako', 'hanging', 'well', 'today', 'still', 'basing', 'pattern', 'eyes']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'metso', 'said', 'upgrade', 'one', 'upm', 'kymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', 'machine', 'process', 'controls', 'quality', 'measurements']
#
#
# ===Tokens:===
# ['contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', 'oil', 'shale', 'processing']
#
#
# ===Tokens:===
# ['brooklynbandit', 'simo', 'basing', 'nice', 'close', '24', '18', 'bullish', 'qqq', 'spy', 'study', 'watch', 'close', 'near', 'hod', 'currently', '3', '5']
#
#
# ===Tokens:===
# ['alert', 'new', 'macd', 'signal', 'created', 'ctxs', 'buy', '77', '09', 'time', '18', '23', 'strength', '10', 'powered', 'https', 'co', '4tdgjedllz']
#
#
# ===Tokens:===
# ['resulted', 'improved', 'sales', 'figures', 'sweden']
#
#
# ===Tokens:===
# ['tectia', 'corporation', 'hel', 'tec1v', 'provider', 'real', 'time', 'security', 'solutions', 'today', 'announced', 'appointed', 'lan2lan', 'provider', 'services', 'uk', 'distribute', 'data', 'security', 'manage', 'file', 'transfer', 'software']
#
#
# ===Tokens:===
# ['long', 'aapl']
#
#
# ===Tokens:===
# ['ino', 'back', 'small', 'post']
#
#
# ===Tokens:===
# ['helsinki', 'eliiv', 'today', 'reported', 'eps', 'eur1', '13', '2009', 'increase', 'eps', 'eur1', '12', '2008']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'oyj', 'said', 'november', '13', '2007', '70', 'mln', 'euro', '102', '8', 'mln', 'contract', 'construct', 'new', 'office', 'building', 'local', 'property', 'company', 'tapiola', 'real', 'estate', 'oy']
#
#
# ===Tokens:===
# ['shorts', 'altr', '38', '85', 'loss']
#
#
# ===Tokens:===
# ['2nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increases', 'quarterly', 'cash', 'dividend', '20', 'percent', 'http', 'stks', 'co', 'goan']
#
#
# ===Tokens:===
# ['combining', 'existing', 'solutions', 'single', 'platform', 'comptel', 'said', 'reduced', 'cost', 'deployment']
#
#
# ===Tokens:===
# ['neon', 'oversold']
#
#
# ===Tokens:===
# ['third', 'quarter', '2010', 'net', 'sales', 'increased', '5', '2', 'eur', '205', '5', 'mn', 'operating', 'profit', '34', '9', 'eur', '23', '5', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'long', '630', '91']
#
#
# ===Tokens:===
# ['pioneer', 'library', 'system', 'one', '127', 'libraries', 'municipalities', 'arts', 'culture', 'higher', 'education', 'science', 'organizations', 'awarded', 'grants', 'participate', 'big', 'read', 'largest', 'federal', 'reading', 'program', 'u', 'history']
#
#
# ===Tokens:===
# ['financing', 'arrangements', 'enable', 'company', 'ensure', 'line', 'treasury', 'policy', 'sufficient', 'financial', 'instruments', 'disposal', 'potential', 'capital', 'requirements']
#
#
# ===Tokens:===
# ['operating', 'income', 'rose', 'eur', '696', '4', 'mn', 'eur', '600', '3', 'mn', '2009']
#
#
# ===Tokens:===
# ['rt', 'andrewnyquist', 'chartology', 'yahoo', 'http', 'stks', 'co', '1itr', 'yhoo', 'crazy', 'looking', 'chart', 'nearing', 'breakout', 'resistance', 'line']
#
#
# ===Tokens:===
# ['sainsbury', 'sells', 'unit', 'lloydspharmacy']
#
#
# ===Tokens:===
# ['liking', 'price', 'action', 'swks', 'currently', '21', '80', 'target', '24', '00', 'year', 'end']
#
#
# ===Tokens:===
# ['group', 'expand', 'chain', 'include', '45', 'stores']
#
#
# ===Tokens:===
# ['finnish', 'consulting', 'engineering', 'group', 'poyry', 'plc', 'omx', 'helsinki', 'poy', 'said', 'wednesday', '1', 'october', 'awarded', 'contract', 'tanqia', 'dibba', 'fzc', 'owner', 'engineer', 'wastewater', 'system', 'dibba', 'emirate', 'fujairah', 'uae']
#
#
# ===Tokens:===
# ['trend', 'underpins', 'uk', 'sales', 'growth', 'kingfisher']
#
#
# ===Tokens:===
# ['lee', 'man', 'paper', 'metso', 'long', 'prosperous', 'co', 'operation', 'good', 'example', 'changshu', 'hongmei', 'kraftliner', 'machines', 'delivered', 'earlier']
#
#
# ===Tokens:===
# ['ibm', 'staying', 'strong']
#
#
# ===Tokens:===
# ['open', 'next', 'year', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['turun', 'kaupunkin', 'finland', 'based', 'company', 'awarded', 'contract', 'lemminkainen', 'talotekniikka', 'oy', 'electrical', 'installation', 'work']
#
#
# ===Tokens:===
# ['revenue', 'grew', '12', 'percent', 'x20ac', '3', '6', 'billion', 'us', '4', '5', 'billion']
#
#
# ===Tokens:===
# ['royal', 'dutch', 'shell', 'buy', 'bg', 'group', 'nearly', '70', 'billion']
#
#
# ===Tokens:===
# ['estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters']
#
#
# ===Tokens:===
# ['eps', 'continuing', 'operations', 'came', '0', '30', 'eur', '0', '17']
#
#
# ===Tokens:===
# ['stable', 'outlook', 'reflects', 'nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', 'strong', 'cash', 'flow', 'generation', 'conservative', 'balance', 'sheet', 'said', 'raab']
#
#
# ===Tokens:===
# ['whitbread', 'share', 'price', 'climbs', 'q4', 'sales', 'growth']
#
#
# ===Tokens:===
# ['financial', 'impact', 'estimated', 'annual', 'improvement', 'eur2', '0', 'division', 'results', 'fiscal', 'year', '2008']
#
#
# ===Tokens:===
# ['kndi', 'let', 'see', 'higher', 'highs', 'higher', 'lows', 'rest', 'day', 'slow', 'steady']
#
#
# ===Tokens:===
# ['adp', 'news', 'finnish', 'handling', 'systems', 'provider', 'cargotec', 'oyj', 'hel', 'cgcbv', 'announced', 'friday', 'orders', 'worth', 'eur', '10', 'million', 'usd', '13', '2', 'deliver', 'linkspans', 'jordan', 'morocco', 'ireland']
#
#
# ===Tokens:===
# ['continued', 'actively', 'focus', 'r', 'position', 'offering', 'away', 'point', 'solutions', 'towards', 'dynamic', 'end', 'end', 'solutions', 'ervio', 'stated']
#
#
# ===Tokens:===
# ['sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season']
#
#
# ===Tokens:===
# ['transaction', 'positive', 'impact', 'around', 'eur2m', 'earnings', 'ruukki', 'recognize', 'fourth', 'quarter', 'year']
#
#
# ===Tokens:===
# ['kesko', 'car', 'import', 'retailing', 'business', 'vv', 'auto', 'saw', 'sales', 'grow', '17', '1', 'pct']
#
#
# ===Tokens:===
# ['insight', 'hires', 'aviva', 'david', 'hillier', 'multi', 'asset', 'team']
#
#
# ===Tokens:===
# ['news', 'feedftse', '100', 'movers', 'ashtead', 'jumps', 'strong', 'interims', 'glencore', 'bp']
#
#
# ===Tokens:===
# ['main', 'strength', 'cooperation', 'project', 'lies', 'merging', 'know', 'two', 'large', 'companies']
#
#
# ===Tokens:===
# ['company', 'also', 'featured', 'ethibel', 'pioneer', 'investment', 'register', 'included', 'innovest', 'global', '100', 'list', 'world', 'sustainable', 'corporations']
#
#
# ===Tokens:===
# ['london', 'morning', 'briefing', 'hsbc', 'standard', 'chartered', 'shares', 'rise']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'rose', '11', '4', 'year', '82', '2', 'million', 'euros', '2005', 'sales', '686', '5', 'million', 'euros', '13', '8', 'year', 'company', 'said', 'earlier']
#
#
# ===Tokens:===
# ['tsla', 'bad', 'day', 'short']
#
#
# ===Tokens:===
# ['objective', 'planned', 'measures', 'achieve', 'significant', 'savings', 'next', 'years']
#
#
# ===Tokens:===
# ['update', '3', 'auto', 'trader', 'shares', 'leap', 'uk', 'biggest', 'private', 'equity', 'backed', 'listing']
#
#
# ===Tokens:===
# ['besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', 'paavel', 'said']
#
#
# ===Tokens:===
# ['ftse', 'rallies', 'three', 'month', 'low', 'boosted', 'stanchart', 'sainsbury']
#
#
# ===Tokens:===
# ['aria', 'bounce', 'player', 'long', '6', '17', 'http', 'stks', 'co', 'q0wff']
#
#
# ===Tokens:===
# ['consolidated', 'operating', 'profit', 'excluding', 'one', 'items', 'eur', '30', '6', 'mn', 'eur', '29', '6', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bullya', 'pollux654321', '50', 'kors', '80', 'calls', 'going', 'b', 'blessing', 'daughters', 'tuition']
#
#
# ===Tokens:===
# ['according', 'sepp', 'nen', 'new', 'technology', 'umts900', 'solution', 'network', 'building', 'costs', 'one', 'third', 'lower', 'building', '3', '5', 'g', 'networks', 'operating', '2', '100', 'mhz', 'frequency']
#
#
# ===Tokens:===
# ['crus', 'upgraded', 'buy', 'alpha', 'street', 'research']
#
#
# ===Tokens:===
# ['favourable', 'currency', 'rates', 'also', 'contributed', 'higher', 'net', 'sales', 'ceo', 'kari', 'kauniskangas', 'said']
#
#
# ===Tokens:===
# ['tesco', 'breaks', 'downward', 'slide', 'cutting', 'sales', 'decline', 'half']

# %%
negativeWords = defaultdict(int)

for text in train_set[train_set['Sentiment']=='negative']['Sentence']:
    for word in generate_ngrams(text):
        negativeWords[word]+=1

df_negative = pd.DataFrame(sorted(negativeWords.items(),key=lambda x:x[1],reverse=True))
# Out:
# ===Tokens:===
# ['tesco', 'asda', 'sales', 'fall', 'march', 'discounters', 'continues', 'kantar']
#
#
# ===Tokens:===
# ['stores', '16', 'march', '2010', 'finnish', 'stationery', 'gift', 'retailer', 'tiimari', 'hel', 'tii1v', 'said', 'yesterday', 'cut', 'total', '28', 'jobs', 'units', 'tiimari', 'retail', 'ltd', 'gallerix', 'finland', 'ltd', 'result', 'closure', 'shops']
#
#
# ===Tokens:===
# ['adpnews', 'feb', '5', '2010', 'finnish', 'real', 'estate', 'investor', 'sponda', 'oyj', 'hel', 'sda1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur', '81', '5', 'million', 'usd', '11', '8', '2009', 'profit', 'eur', '29', '3', 'million', '2008']
#
#
# ===Tokens:===
# ['reed', 'elsevier', 'share', 'price', 'slides', 'underwhelming', 'full', 'year', 'results']
#
#
# ===Tokens:===
# ['potential', 'defect', 'third', 'row', 'seat', 'belts', 'tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'yvydncdndi']
#
#
# ===Tokens:===
# ['making', 'matters', 'difficult', 'company', 'said', 'grappling', 'higher', 'oil', 'gas', 'prices', 'pushed', 'cost', 'energy', 'raw', 'materials', 'transportation']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '38', '1', 'mn', 'eur', '55', '3', 'mn', '2007']
#
#
# ===Tokens:===
# ['standard', 'chartered', 'lags', 'capital', 'worries']
#
#
# ===Tokens:===
# ['update', '1', 'bhp', 'billiton', 'credit', 'ratings', 'fragile', 'fy16', 'agencies', 'warn']
#
#
# ===Tokens:===
# ['qcor', 'little', 'pullback', 'fine', 'erases', 'todays', 'gains', 'believe', 'manipulation', 'capable']
#
#
# ===Tokens:===
# ['gmcr', 'way', 'acting', 'may', 'fall', '65', 'today', 'horrible', 'action', 'since', 'hit', '70', 'yesterday']
#
#
# ===Tokens:===
# ['asian', 'traffic', 'declined', '3', '4', 'per', 'cent']
#
#
# ===Tokens:===
# ['petrofac', 'books', '30m', 'cost', 'shetland', 'gas', 'terminal', 'delays']
#
#
# ===Tokens:===
# ['saudi', 'aramco', 'shell', 'plan', 'break', 'motiva', 'divide', 'assets']
#
#
# ===Tokens:===
# ['update', '3', 'bp', 'settles', 'oil', 'spill', 'related', 'claims', 'halliburton', 'transocean']
#
#
# ===Tokens:===
# ['locked', 'fb', 'puts', 'nice', 'gain']
#
#
# ===Tokens:===
# ['external', 'net', 'sales', 'printing', 'business', 'fell', '43', '7', 'partly', 'due', 'termination', 'printing', 'contract', 'ilkka', 'yhtyma', 'printing', 'house', 'print', 'oy', 'sector', 'player', 'hss', 'media', 'ab', 'december', '2009', 'fall', 'printing', 'prices']
#
#
# ===Tokens:===
# ['air', 'traffic', 'finland', 'stoppage', 'since']
#
#
# ===Tokens:===
# ['airline', 'estimated', 'cancellation', 'flights', 'due', 'closure', 'european', 'airspace', 'process', 'recommencing', 'traffic', 'caused', 'company', 'loss', 'eur20m', 'including', 'costs', 'stranded', 'passengers', 'accommodation']
#
#
# ===Tokens:===
# ['cargo', 'traffic', 'fell', '1', 'year', 'year', '8', '561', 'tonnes', 'september', '2009']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', 'declined', 'eur', '803', '6', 'million', 'eur', '1', '2', 'billion']
#
#
# ===Tokens:===
# ['also', 'construction', 'expenses', 'gone', 'russia']
#
#
# ===Tokens:===
# ['raute', 'reported', 'loss', 'per', 'share', 'eur0', '86', 'first', 'half', '2009', 'eps', 'eur0', '74', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['glencore', 'slumps', '25', 'pct', 'debt', 'fears', 'grow']
#
#
# ===Tokens:===
# ['pharmaceuticals', 'group', 'orion', 'corp', 'reported', 'fall', 'third', 'quarter', 'earnings', 'hit', 'larger', 'expenditures', 'r', 'marketing']
#
#
# ===Tokens:===
# ['implementation', 'programs', 'negative', 'impacts', '2006', '2007', 'earnings', 'mr', 'meiklejohn', 'said']
#
#
# ===Tokens:===
# ['dismissed', 'staff', 'members', 'take', 'matter', 'court', 'unless', 'settled', 'outside']
#
#
# ===Tokens:===
# ['diageo', 'receives', 'reports', 'united', 'spirits', 'financial', 'irregularities', 'involving']
#
#
# ===Tokens:===
# ['small', 'investors', 'voiced', 'fears', 'shares', 'end', 'risk', 'investors']
#
#
# ===Tokens:===
# ['xlb', 'weakest', 'sector', 'year', 'possible', 'false', 'breakout', 'http', 'stks', 'co', 'dl1z']
#
#
# ===Tokens:===
# ['furthermore', 'sales', 'new', 'passenger', 'cars', 'light', 'commercial', 'vehicles', 'country', 'declined', '5', '4', 'year', 'year', 'last', 'month']
#
#
# ===Tokens:===
# ['british', 'american', 'tobacco', 'first', 'half', 'sales', 'hurt', 'currency', 'moves']
#
#
# ===Tokens:===
# ['measures', 'result', 'weak', 'demand', 'shipbuilding', 'industry']
#
#
# ===Tokens:===
# ['deutsche', 'bank', 'downgrades', 'starbucks', 'new', 'loyalty', 'program', 'https', 'co', 'iy4lcugabc', 'sbux']
#
#
# ===Tokens:===
# ['17', 'march', '2011', 'goldman', 'sachs', 'estimates', 'negative', 'prospects', 'norwegian', 'mobile', 'operations', 'norway', 'telenor', 'asa', 'osl', 'tel', 'sweden', 'teliasonera', 'ab', 'sto', 'tlsn', 'short', 'term']
#
#
# ===Tokens:===
# ['plug', 'bear', 'raid']
#
#
# ===Tokens:===
# ['scanfil', 'systems', 'supplier', 'contract', 'manufacturer', 'communications', 'sector', 'give', 'notice', '20', 'productional', 'employees', 'temporarily', 'lay', '15', 'employees', 'company', 'plant', 'sievi', 'finland']
#
#
# ===Tokens:===
# ['breaking', 'tesla', 'recalls', 'model', 'x', 'cars', 'details', 'show', 'tsla']
#
#
# ===Tokens:===
# ['2009', '3', 'february', '2010', 'finland', 'based', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'slipped', 'larger', 'expected', 'pretax', 'loss', 'eur46m', 'fourth', 'quarter', '2009', 'year', 'earlier', 'profit', 'eur45m']
#
#
# ===Tokens:===
# ['workforce', 'reduced', 'also', 'amsterdam', 'office', 'netherlands']
#
#
# ===Tokens:===
# ['fastenal', 'misses', '0', '01', 'misses', 'revenue', 'fast', 'nyse', 'https', 'co', '63jhq7pwmn']
#
#
# ===Tokens:===
# ['bbry', 'actually', 'lost', '03c', 'per', 'share', 'u', 'incl', 'vz', 'debt', '3', '1', 'cash']
#
#
# ===Tokens:===
# ['ramirent', 'made', '18', 'million', 'kroons', 'eur', '1', '15', 'mln', 'loss', 'last', 'year', 'year', 'company', '7', '3', 'million', 'kroons', 'black']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'recent', 'quarter', 'also', 'reached', 'eight', 'year', 'low']
#
#
# ===Tokens:===
# ['lloyds', 'cut', '945', 'jobs', 'part', 'three', 'year', 'restructuring', 'strategy']
#
#
# ===Tokens:===
# ['however', 'rapidly', 'increasing', 'costs', 'strengthening', 'euro', 'challenging', 'whole', 'industry', 'impacted', 'results']
#
#
# ===Tokens:===
# ['optimistic', 'amzn', 'fundementals', 'charts', 'look', 'like', 'poopoo', 'quarter']
#
#
# ===Tokens:===
# ['belarus', 'oao', 'lidskoe', 'pivo', 'brewery', 'based', 'grodno', 'region', 'reported', '1', '1', 'decrease', 'output', '1', '045', 'million', 'decaliters', 'january', 'march', '2010', 'representative', 'administration', 'company', 'told']
#
#
# ===Tokens:===
# ['profit', 'period', 'totalled', 'eur', '1', '1', 'mn', 'eur', '1', '6', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['finnish', 'forest', 'industry', 'group', 'stora', 'enso', 'oyj', 'issued', 'thursday', '20', 'march', 'profit', 'warning', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['pcln', 'back', 'back', 'intraday', 'reversals', 'look', 'shorts', 'moving']
#
#
# ===Tokens:===
# ['legal', 'general', 'share', 'price', 'finance', 'chief', 'step']
#
#
# ===Tokens:===
# ['tsla', 'wish', 'puts', 'back', 'see', 'find', 'support', 'around', '243', '39', 'pop', 'get', 'back', 'https', 'co', 'hfklq3wobv']
#
#
# ===Tokens:===
# ['23', 'april', '2010', 'finnish', 'construction', 'engineering', 'company', 'outotec', 'oyj', 'hel', 'ote1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur7', '3', 'first', 'quarter', '2010', 'net', 'profit', 'eur12', '5', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['sweden', 'oversupply', 'pharmacies']
#
#
# ===Tokens:===
# ['hk', 'jan', 'sinking', 'ship']
#
#
# ===Tokens:===
# ['micron', 'technology', 'inc', 'nasdaq', 'mu', '2', '3', 'today', '8', '9', 'since', 'put', 'short', 'https', 'co', 'eqqltfuiou']
#
#
# ===Tokens:===
# ['scanfil', 'execute', 'temporary', 'lay', 'offs', 'mid', 'october', '2009', 'job', 'cuts', 'march', '2010']
#
#
# ===Tokens:===
# ['berkshire', 'discloses', 'unit', 'ties', 'iran', 'opens', 'probe']
#
#
# ===Tokens:===
# ['rnn', 'bleeding', 'monday']
#
#
# ===Tokens:===
# ['british', 'american', 'tobacco', 'drops', 'sues', 'pwc', 'pollution', 'scandal']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'declined', 'eur', '0', '78', 'eur', '1', '76']
#
#
# ===Tokens:===
# ['3rd', 'red', 'day', 'row', 'tsla']
#
#
# ===Tokens:===
# ['result', 'taxes', 'decreased', 'nearly', 'eur', '14', '5', 'mn', 'compared', 'nearly', 'eur', '20mn', 'previous', 'accounting', 'period']
#
#
# ===Tokens:===
# ['l', 'g', 'still', 'paying', 'price', 'dividend', 'cut', 'crisis', 'chief', 'says']
#
#
# ===Tokens:===
# ['55', 'workers', 'l', 'affected', 'close']
#
#
# ===Tokens:===
# ['operating', 'profit', '12', 'month', 'period', 'decreased', 'eur17', '9', 'net', 'sales', 'increased', 'eur58', '3', 'compared', '2007']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '10', '5', 'january', 'sales', 'outside', 'finland', 'dropped', '17']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'company', 'amer', 'sports', 'said', 'decided', 'lay', '370', 'workers', 'salomon', 'division', 'france']
#
#
# ===Tokens:===
# ['building', 'home', 'improvement', 'trade', 'sales', 'decreased', '6', '3', 'totalling', 'eur', '154', '1', 'mn']
#
#
# ===Tokens:===
# ['altogether', 'finnair', 'canceled', '500', 'flights', 'strike']
#
#
# ===Tokens:===
# ['contracts', 'employees', '96', 'blue', 'collar', 'workers', 'ended', 'march', 'august', '2011']
#
#
# ===Tokens:===
# ['liquidity', 'providing', 'interrupted', 'may', '11', '2007', 'aspocomp', 'group', 'oyj', 'shares', 'traded', '0', '50', 'cent', 'aspocomp', 'stock', 'exchange', 'release', '11', '5', '2007']
#
#
# ===Tokens:===
# ['net', 'cash', 'operating', 'activities', 'negative', 'eur', '0', '3', 'mn', 'compared', 'eur', '30', '9', 'mn', '2009']
#
#
# ===Tokens:===
# ['tsla', 'recall', '2', '700', 'model', 'x', 'suvs', 'seat', 'belt', 'fix']
#
#
# ===Tokens:===
# ['sales', 'mid', 'strength', 'beer', 'decreased', '40']
#
#
# ===Tokens:===
# ['situation', 'coated', 'magazine', 'printing', 'paper', 'continue', 'weak']
#
#
# ===Tokens:===
# ['intertek', 'swings', '347', 'mln', 'loss', 'oil', 'slump']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'decreased', 'eur', '6', '2', 'mn', 'eur', '16', '8', 'mn', '2007', 'representing', '2', '3', 'net', 'sales']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', '9', 'eur', '187', '8', 'mn', 'first', 'nine', 'months', '2008', 'compared', 'eur', '207', '1', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bad', 'idea', 'make', '5', 'min', 'predictions', 'based', 'faith', 'rt', 'dandyduct', 'aapl', 'sell', 'signal', 'hit', '584', 'go', 'next', '5', 'min']
#
#
# ===Tokens:===
# ['operating', 'loss', 'increased', 'eur', '17mn', 'loss', 'eur', '10', '8', 'mn', '2005']
#
#
# ===Tokens:===
# ['finland', 'sampo', 'bank', 'part', 'danske', 'bank', 'group', 'lay', 'staff', 'administrative', 'support', 'functions']
#
#
# ===Tokens:===
# ['result', '12', 'people', 'made', 'redundant', 'total', '67', 'persons', 'laid', 'temporarily']
#
#
# ===Tokens:===
# ['apple', 'breaks', 'major', 'support', 'levels', 'watch', 'http', 'stks', 'co', 'jrmw', 'aapl', 'qqq']
#
#
# ===Tokens:===
# ['sainsbury', 'asda', 'tesco', 'morrisons', 'cut', 'petrol', 'prices', 'oil', 'falls']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '8', 'mn', 'compared', 'profit', 'eur', '3', '9', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'january', 'december', '2008', 'negative', 'eur', '18', '1', 'mn', 'compared', 'eur', '39', '0', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['july', 'september', '2009', 'konecranes', 'sales', 'decreased', 'eur', '368', '7', 'mn', 'eur', '520', '4', 'mn', 'july', 'september', '2008']
#
#
# ===Tokens:===
# ['nq', 'got', 'hit', 'hard', 'lower', 'looks', 'like', 'found', 'support', '18', '89', 'http', 'stks', 'co', 's052z']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'wood', 'products', 'technology', 'supplier', 'raute', 'oyj', 'hel', 'rutav', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '4', '7', 'million', 'usd', '6', '1', '2008', 'eur', '6', '6', 'million', '2007']
#
#
# ===Tokens:===
# ['micron', 'shares', 'pounded', 'fears', 'loss', 'business', 'apple', 'stifel', 'defends', 'aapl', 'mu', 'http', 'stks', 'co', 't1z8t', 'marjo']
#
#
# ===Tokens:===
# ['sainsbury', 'sales', 'slip', 'price', 'pressures', 'take', 'toll']
#
#
# ===Tokens:===
# ['renn', 'topping', 'tail', '5', 'min', 'chart', '7', '31', 'short']
#
#
# ===Tokens:===
# ['aapl', 'near', '3', 'drop', 'thats', 'lot', 'best', 'hold', 'er', 'lol']
#
#
# ===Tokens:===
# ['amzn', 'rejected', '604', 'penny', 'weak', 'open', 'goes', 'r', 'g', 'within', 'first', '30', 'mins', 'could', '8', '10', 'points', 'https', 'co', '58teaexxpe']
#
#
# ===Tokens:===
# ['diageo', 'sales', 'disappoint', 'currency', 'comparatives', 'leave', 'bitter', 'taste']
#
#
# ===Tokens:===
# ['royal', 'mail', 'chairman', 'donald', 'brydon', 'set', 'step']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '7', 'mn', 'compared', 'profit', 'eur', '0', '8', 'mn', 'second', 'quarter', '2005']
#
#
# ===Tokens:===
# ['cash', 'flow', 'investments', 'amounted', 'eur45m', 'eur46m']
#
#
# ===Tokens:===
# ['addition', '29', 'employees', 'laid', 'notice', 'whole', 'workforce', 'laid', 'short', 'periods', 'needed']
#
#
# ===Tokens:===
# ['nokia', 'siemens', 'networks', 'struggled', 'make', 'profit', 'past', 'two', 'years']
#
#
# ===Tokens:===
# ['aapl', 'aapl', 'gundlach', 'slams', 'ipad', 'mini', 'sees', 'downside', '425', 'http', 'stks', 'co', 'bdqv']
#
#
# ===Tokens:===
# ['tesco', 'criticised', 'disgraceful', 'advert', 'showing', 'domestic', 'worker', 'slapped']
#
#
# ===Tokens:===
# ['fb', 'rejecting', 'highs', 'shortable', '109']
#
#
# ===Tokens:===
# ['naturalgas', 'settles', '3', 'year', 'low', 'dbo', 'bno', 'http', 'stks', 'co', 'd27qx']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'eur1', '37', 'eur2', '30']
#
#
# ===Tokens:===
# ['fb', 'still', 'dog', 'going', 'much', 'lower', 'week']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'nearly', 'eur', '1', '7', 'mn', 'however']
#
#
# ===Tokens:===
# ['finnair', 'believes', 'strike', 'cause', 'daily', 'net', 'losses', 'excess', 'eur', '2mn', 'due', 'canceled', 'reservations', 'passenger', 'routing']
#
#
# ===Tokens:===
# ['operating', 'profit', '2009', 'lower', 'outlook', 'published', 'earlier']
#
#
# ===Tokens:===
# ['bobe', '2', '84', 'premarket']
#
#
# ===Tokens:===
# ['total', '140', 'jobs', 'reduced', 'raahe', 'steel', 'works']
#
#
# ===Tokens:===
# ['sales', 'tiimari', 'segment', 'fell', '4', '0', 'year', 'year', 'eur3', '3', 'june', '2010']
#
#
# ===Tokens:===
# ['stora', 'enso', 'oyj', 'said', 'second', 'quarter', 'result', 'would', 'fall', 'half', 'compared', 'period', '2007']
#
#
# ===Tokens:===
# ['update', '1', 'lloyds', 'cut', '945', 'jobs', 'part', '3', 'year', 'restructuring', 'plan']
#
#
# ===Tokens:===
# ['net', 'profit', 'three', 'months', 'march', '31', 'fell', 'x20ac', '103', 'million', 'us', '165', 'million', 'x20ac', '131', 'million', 'year', 'earlier', 'finnish', 'company', 'said']
#
#
# ===Tokens:===
# ['astrazeneca', 'patent', 'asthma', 'drug', 'invalidated', 'us', 'court']
#
#
# ===Tokens:===
# ['easyjet', 'dismisses', 'lufthansa', 'low', 'cost', 'plan', 'contest', 'germany']
#
#
# ===Tokens:===
# ['yit', 'baltic', 'sales', 'first', 'three', 'quarters', '2008', 'totaled', '106', '2', 'million', 'euros', 'representing', 'drop', '29', 'percent', 'year', 'year']
#
#
# ===Tokens:===
# ['net', 'sales', 'finnish', 'sanoma', 'learning', 'literature', 'finnish', 'media', 'group', 'sanoma', 'decreased', '3', '6', 'january', 'june', '2009', 'totalling', 'eur', '162', '8', 'mn', 'eur', '168', '8', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['rt', 'alphatrends', 'vmarkets', 'still', 'acting', 'weak', 'http', 'stks', 'co', '1agn', 'spy', 'qqq', 'xlf', 'smh', 'iwm']
#
#
# ===Tokens:===
# ['finland', 'hobby', 'hall', 'sales', 'decreased', '10', 'international', 'sales', 'fell', '19']
#
#
# ===Tokens:===
# ['rbs', 'chairman', 'admits', 'surprise', 'size', 'regulatory', 'penalties']
#
#
# ===Tokens:===
# ['hard', 'find', 'new', 'buyers', 'tsla', '250', 'shorts', 'continue', 'pile']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'totaled', 'eur', '9', '0', 'mn', 'eur', '36', '3', 'mn', '2007']
#
#
# ===Tokens:===
# ['operating', 'result', '12', 'month', 'period', 'decreased', 'profit', 'eur0', '4', 'turnover', 'decreased', 'eur5', '6', 'compared', '2004']
#
#
# ===Tokens:===
# ['kone', 'said', 'court', 'papers', 'union', 'action', 'delayed', 'repairs', 'elevators', 'federal', 'courthouse', 'jan', '21', 'saltonstall', 'state', 'office', 'building', 'jan', '23']
#
#
# ===Tokens:===
# ['operating', 'profit', 'non', 'recurring', 'items', 'eur', '8', '3', 'mn', 'first', 'nine', 'months', '2008', 'compared', 'eur', '8', '4', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', 'eur', '31', '6', 'mn', 'eur', '50', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['intc', 'finally', 'nice', 'downside', 'move', 'looking', '31', 'handle', 'break']
#
#
# ===Tokens:===
# ['refile', 'aviva', 'investors', 'move', '34', 'bln', 'euros', 'assets', 'axa', 'fund', 'arm']
#
#
# ===Tokens:===
# ['airline', 'share', 'price', 'closed', 'slightly', 'x20ac', '12', '51', '15us', '74', 'helsinki']
#
#
# ===Tokens:===
# ['also', 'upset', 'machinery', 'work', 'taken', 'poland']
#
#
# ===Tokens:===
# ['q1', '2009', 'company', 'operating', 'loss', 'totalled', 'eur', '0', '3', 'mn', 'compared', 'profit', 'eur', '3', '6', 'mn', 'q1', '2008']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'reports', 'operating', 'profit', 'eur', '2', '2', 'mn', 'first', 'quarter', '2010', 'eur', '6', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totaled', 'eur', '117mn', 'compared', 'loss', 'eur', '65mn', 'corresponding', 'period']
#
#
# ===Tokens:===
# ['low', 'capacity', 'utilisation', 'rate', 'steel', 'production', 'considerably', 'increases', 'fixed', 'costs', 'per', 'unit', 'steel', 'produced']
#
#
# ===Tokens:===
# ['fb', 'churning', 'high', 'volume', 'ipo', 'price', 'lot', 'sellers', 'trying', 'get', 'might', 'take', 'consolidate', 'moving', 'higher']
#
#
# ===Tokens:===
# ['trouble', 'brewing', 'legal', 'general', 'group', 'plc', 'aviva', 'plc']
#
#
# ===Tokens:===
# ['gps', 'gap', 'september', 'comparable', 'store', 'sales', '4']
#
#
# ===Tokens:===
# ['revenue', 'slightly', 'x20ac', '495', 'million', '634', 'million', 'compared', 'x20ac', '497', 'million', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'financial', 'year', '2006', 'expected', 'amount', 'eur20m', 'operating', 'result', 'ebit', 'expected', 'loss', 'announced']
#
#
# ===Tokens:===
# ['several', 'large', 'stocks', 'tacked', 'lower', 'however']
#
#
# ===Tokens:===
# ['jan', '6', 'ford', 'struggling', 'face', 'slowing', 'truck', 'suv', 'sales', 'surfeit', 'date', 'got', 'ta', 'cars']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'quarter', 'decreased', 'eur510m', 'sales', 'increased', 'eur860m', 'compared', 'third', 'quarter', '2007']
#
#
# ===Tokens:===
# ['26', 'october', '2010', 'finnish', 'environmental', 'management', 'company', 'lassila', 'tikanoja', 'oyj', 'hel', 'lat1v', 'l', 'said', 'today', 'net', 'profit', 'declined', 'eur20', '9', 'first', 'nine', 'months', '2010', 'eur27', '6', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'xdgraexkkz']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '4', '2009', 'finnish', 'broadband', 'data', 'communication', 'systems', 'solutions', 'company', 'teleste', 'oyj', 'hel', 'tlt1v', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '5', '5', 'million', 'usd', '7', '2', '2008', 'eur', '9', '4', 'million', '200']
#
#
# ===Tokens:===
# ['repeats', 'sees', '2008', 'operating', 'profit', 'reporting', 'helsinki', 'newsroom', 'keywords', 'tecnomen', 'results']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur30', '6', 'eur38', '3', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['consolidated', 'pretax', 'profit', 'decreased', '69', '2', 'eur', '41', '0', 'mn', 'eur', '133', '1', 'mn', '2007']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'dips', 'blinkbox', 'books', 'closes', 'ending', 'supermarket', 'digital']
#
#
# ===Tokens:===
# ['glencore', 'cuts', '2015', 'budget', 'plans', 'divest', 'lonmin']
#
#
# ===Tokens:===
# ['endp', 'sued', 'ftc', 'nobody', 'buy', 'hanging', 'heads']
#
#
# ===Tokens:===
# ['tesla', 'voluntary', 'recall', '2', '700', 'model', 'x', 'vehicles', 'due', 'back', 'seat', 'issue', 'tsla', 'https', 'co', 'npakc3u6gs']
#
#
# ===Tokens:===
# ['result', 'company', 'temporarily', 'lay', '25', 'whole', 'personnel', 'approximately', '270', 'persons', 'kirkkonummi', 'nivala', 'factories']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'totaled', 'eur', '4', '9', 'mn', 'compared', 'eur', '5', '2', 'mn', 'first', 'quarter', '2005']
#
#
# ===Tokens:===
# ['grid', 'shows', 'dia', 'capped', 'long', 'term', 'range', '123', '40', '124', '77', 'rally', 'beyond', 'today', 'levels', 'range', 'leads', 'meltdown']
#
#
# ===Tokens:===
# ['first', 'half', '2008', 'bank', 'operating', 'profit', 'fell', 'eur', '11', '8', 'mn', 'eur', '18', '9', 'mn', 'net', 'interest', 'income', 'increased', 'eur', '20', '9', 'mn', 'eur', '18', '8', 'mn', 'first', 'half', '2007']
#
#
# ===Tokens:===
# ['gpro', '25', 'since', 'tue', 'morning']
#
#
# ===Tokens:===
# ['update', '1', 'nomura', 'rbs', 'must', 'pay', '806', 'mln', 'mortgage', 'bond', 'case', 'us', 'judge']
#
#
# ===Tokens:===
# ['dish', 'weakness', 'continues', '49', '43', 'area', 'resistance', 'last', 'week']
#
#
# ===Tokens:===
# ['10', '33', 'huhtamaki', 'market', 'biggest', 'faller', '8', '69', 'pct', 'lower', '11', '35', 'eur', 'omx', 'helsinki', '25', '0', '32', 'pct', 'higher', '3', '332', '41', 'omx', 'helsinki', '0', '47', 'pct', '11', '687', '32']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '9', 'mn', 'first', 'half', '2006', 'compared', 'profit', 'eur', '0', '5', 'mn', 'first', 'half', '2005']
#
#
# ===Tokens:===
# ['eu', 'commission', 'said', 'earlier', 'fined', 'thyssenkrupp', 'united', 'technologies', 'corp', 'otis', 'schindler', 'ag', 'kone', 'oyj', 'total', '992', '3', 'mln', 'eur', 'alleged', 'cartel', 'activity', 'lift', 'market', 'going', 'back', 'twelve', 'years']
#
#
# ===Tokens:===
# ['srv', 'lowered', 'net', 'sales', 'estimate', 'whole', '2008', 'due', 'uncertainties', 'housing', 'sales']
#
#
# ===Tokens:===
# ['11', 'august', '2010', 'finnish', 'measuring', 'equipment', 'maker', 'vaisala', 'oyj', 'hel', 'vaias', 'said', 'today', 'net', 'loss', 'widened', 'eur4', '8', 'first', 'half', '2010', 'eur2', '3', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['glaxosmithkline', 'share', 'price', 'slips', 'fda', 'okays', 'asthma', 'therapy', 'adults']
#
#
# ===Tokens:===
# ['googl', 'short', '740', 'upper', 'bb', 'overbought']
#
#
# ===Tokens:===
# ['know', 'back', 'seat', 'sit', 'tsla', 'tesla', 'recalls', '2', '700', 'model', 'x', 'cars', 'https', 'co', '7j0gwz89zc']
#
#
# ===Tokens:===
# ['juniper', 'tumbles', 'q1', 'warning', 'cisco', 'also', 'lower', 'jnpr', 'csco', 'https', 'co', 'bgvintk43h']
#
#
# ===Tokens:===
# ['walter', 'investment', 'management', 'corp', 'receives', 'sell', 'compass', 'point', 'wac', 'http', 'stks', 'co', 'c1ivx']
#
#
# ===Tokens:===
# ['amrn', 'got', 'sell', 'signal', '7', '1', '14', 'still', 'force', 'target', '1', '50']
#
#
# ===Tokens:===
# ['mcd', 'looks', 'set', 'fall', 'http', 'stks', 'co', 'f2fgj']
#
#
# ===Tokens:===
# ['isolationism', 'another', 'sell', 'rating', 'sell', 'ratings', 'spy', 'qqq', 'iwm', 'several', 'companies', 'https', 'co', 'j35fnnx744', 'aapl', 'apple', 'axp', 'bac']
#
#
# ===Tokens:===
# ['spy', 'bull', 'move', 'ended', 'waiting', 'next', 'setup']
#
#
# ===Tokens:===
# ['finnish', 'plumbing', 'heating', 'systems', 'supplier', 'uponor', 'net', 'sales', 'continuing', 'business', 'operations', 'decreased', 'eur', '249', '1', 'mn', 'july', 'september', '2008', 'compared', 'eur', '262', '1', 'mn', 'third', 'quarter', '2007']
#
#
# ===Tokens:===
# ['majority', 'company', 'personnel', 'finland', 'temporarily', 'laid', 'one', 'six', 'weeks', 'period', 'february', 'june', '2009', 'period']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'contract', 'manufacturer', 'scanfil', 'reports', 'net', 'sales', 'eur', '58', '9', 'mn', 'second', 'quarter', '2007', 'eur', '62', '4', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['spy', 'mitk', 'fast', '56pc', 'dive', 'http', 'stks', 'co', '3ffn']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'flexible', 'packaging', 'cutting', '48', 'jobs', 'unit', 'tampere', 'two', 'nastola', 'finland']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totaled', 'eur', '0', '2', 'mn', 'eur', '0', '8', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['earlier', 'today', 'geberit', 'finnish', 'rival', 'uponor', 'oyj', 'cut', 'full', 'year', 'sales', 'growth', 'forecast', '6', 'pct', '10', 'pct', 'blaming', 'tough', 'conditions', 'germany', 'us', 'well', 'currency', 'factors']
#
#
# ===Tokens:===
# ['rxii', 'tang', 'really', 'toxic', 'keep', 'bringing', 'share', 'price', 'least', 'could', 'let', 'climb', 'little', 'dragging']
#
#
# ===Tokens:===
# ['uncommonly', 'weak', 'snow', 'conditions', 'nearly', 'every', 'market', 'affected', 'first', 'quarter', 'result', 'chief', 'executive', 'roger', 'talermo', 'said']
#
#
# ===Tokens:===
# ['aapl', 'aapl', 'finally', 'breaking', '49', 'buybacks', 'week', 'look', 'aapl', 'test', '120', 'support', 'area']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'decreased', 'eur19', '9', 'net', 'sales', 'increased', 'eur155', '7', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['hobby', 'hall', 'sales', 'decrease', '26', 'pct', 'due', 'implementing', 'new', 'information', 'system', 'involved', 'changing', 'principal', 'posting', 'sales']
#
#
# ===Tokens:===
# ['steelmaker', 'said', 'drop', 'profit', 'explained', 'continuing', 'economic', 'uncertainty', 'mixed', 'current', 'drought', 'bank', 'lending', 'resulting', 'decline', 'demand', 'products', 'customers', 'find', 'increasingly', 'difficult', 'fund', 'operations']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '5', '2', 'mn', 'compared', 'loss', 'eur', '3', '4', 'mn', 'corresponding', 'period', '2008', '2009']
#
#
# ===Tokens:===
# ['result', 'transactions', 'aggregate', 'holdings', 'burrill', 'life', 'sciences', 'capital', 'fund', 'l', 'p', 'decreased', '5', 'per', 'cent', 'total', 'number', 'shares', 'votes', 'company']
#
#
# ===Tokens:===
# ['shell', '70', 'billion', 'bg', 'deal', 'meets', 'shareholder', 'skepticism']
#
#
# ===Tokens:===
# ['samsung', 'currently', 'occupies', 'third', 'place', 'lost', 'ground', 'quarter', 'dropping', '1', '8', '11', '1', 'share', 'overall']
#
#
# ===Tokens:===
# ['sale', 'result', 'capital', 'loss', 'eur5m', 'solidium', 'obtained', 'tikkurila', 'shares', 'march', '2010']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totalled', 'eur', '162', '3', 'mn', 'compared', 'profit', 'eur', '253', '5', 'mn', '2007']
#
#
# ===Tokens:===
# ['timberrrr', 'tsla', 'https', 'co', 'mrbgfdhhva']
#
#
# ===Tokens:===
# ['kone', 'shares', 'dropped', '4', '1', 'percent', 'x20ac', '43', 'us', '55', '77', 'helsinki']
#
#
# ===Tokens:===
# ['sbux', 'downgraded', 'neutral', 'deutsche', 'bank', 'price', 'target', 'reduced', '64', '70']
#
#
# ===Tokens:===
# ['elcoteq', 'group', 'recently', 'announced', 'last', 'three', 'months', 'previous', 'year', 'brought', 'major', 'loss', 'half', 'billion', 'kroons', 'eur', '32', 'mln', 'fifth', 'quarter', 'running']
#
#
# ===Tokens:===
# ['according', 'swedish', 'authorities', 'traces', 'toxic', 'osmium', 'tetroxide', 'found', 'coast', 'per', 'meri', 'northernmost', 'part', 'gulf', 'bothnia']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'tumbles', 'negative', 'broker', 'note']
#
#
# ===Tokens:===
# ['thanks', 'internet', 'consumers', 'compare', 'products', 'previously', 'finnish', 'companies', 'competitive']
#
#
# ===Tokens:===
# ['hsbc', 'says', 'unit', 'book', '585', 'million', 'charge', 'settlement']
#
#
# ===Tokens:===
# ['starbucks', 'shares', 'much', '4', '2', 'sbux', 'https', 'co', 'jlgrprr54k']
#
#
# ===Tokens:===
# ['fb', 'trend', 'hits', 'mid', '110', 'drops']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '12', '7', 'mn', 'compared', 'profit', 'eur', '17', '7', 'mn', 'first', 'half', '2008']
#
#
# ===Tokens:===
# ['company', 'said', 'sales', 'three', 'months', 'end', 'march', 'slid', 'eur86', '4', 'us', '113', '4', 'eur91', '2', 'last', 'year']
#
#
# ===Tokens:===
# ['adp', 'news', 'jan', '22', '2009', 'finnish', 'mobile', 'phones', 'maker', 'nokia', 'oyj', 'omx', 'nok1v', 'said', 'today', 'operating', 'profit', 'decreased', 'eur', '5', 'billion', 'usd', '6', '5', 'bn', '2008', 'eur', '8', 'billion', '2007']
#
#
# ===Tokens:===
# ['department', 'store', 'division', 'sales', 'fell', '8', '6', 'eur', '140', '2', 'mn']
#
#
# ===Tokens:===
# ['tesla', 'recalling', '2', '700', 'model', 'x', 'units', 'related', 'faulty', 'latch', 'third', 'row', 'seats', 'fall', '252', '50', 'level', 'recall', 'shares', '1', 'tsla']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'reports', 'operating', 'profit', 'fell', 'eur', '4', '9', 'mn', 'third', 'quarter', '2007', 'eur', '5', '6', 'mn', 'third', 'quarter', '2006']
#
#
# ===Tokens:===
# ['rt', 'cash', 'cow', 'tlt', 'still', 'rising', 'rsi', 'macd', 'bond', 'buying', 'signaling', 'bad', 'moves', 'market', 'spy', 'uup']
#
#
# ===Tokens:===
# ['investors', 'remain', 'skeptical', 'shell', 'bg', 'deal']
#
#
# ===Tokens:===
# ['temporary', 'lay', 'offs', 'affecting', 'entire', 'workforce', 'also', 'implemented']
#
#
# ===Tokens:===
# ['g4s', 'slides', 'balance', 'sheet', 'worries']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totaled', 'eur', '0', '8', 'mn', 'compared', 'profit', 'eur', '0', '5', 'mn']
#
#
# ===Tokens:===
# ['viking', 'line', 'canceled', 'services']
#
#
# ===Tokens:===
# ['copper', 'market', 'may', 'get', '2003', 'style', 'supply', 'shock', 'glencore', 'closures']
#
#
# ===Tokens:===
# ['however', 'increases', 'signaling', 'traffic', 'wastes', 'network', 'resources', 'allows', 'fewer', 'smartphones', 'connect']
#
#
# ===Tokens:===
# ['aapl', 'beaten', 'hated', 'etc', 'hhhmm', 'opposite', '700', 'happens', 'next']
#
#
# ===Tokens:===
# ['tsla', 'recalls', '2', '700', 'model', 'x', 'cars', 'stock', 'dropping', 'hard']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totaled', 'eur', '25mn', 'compared', 'profit', 'eur', '63mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['due', 'rapid', 'decrease', 'net', 'sales', 'personnel', 'reductions', 'carried', 'wider', 'scale', 'initially', 'expected']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '9', '6', 'mn', 'eur', '42', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['announcement', 'pushed', 'freenet', 'shares', '6', '3', 'eur0', '71', 'frankfurt', 'trade', 'eur10', '65', 'investors', 'gave', 'hope', 'united', 'internet', 'ag', 'drillisch', 'would', 'pursue', 'takeover', 'breakup', 'freenet']
#
#
# ===Tokens:===
# ['result', 'negotiations', 'company', 'decided', 'make', '45', 'people', 'redundant', 'financial', 'production', 'grounds']
#
#
# ===Tokens:===
# ['however', 'company', 'saw', 'net', 'profit', 'third', 'quarter', 'eur', '1', '4', 'million', 'eur', '1', '5', 'million', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['baltic', 'countries', 'development', 'operations', 'reorganisation', 'continued', 'non', 'recurring', 'items', 'related', 'takeover', 'process', 'lowered', 'earnings']
#
#
# ===Tokens:===
# ['lay', 'offs', 'affect', '240', 'people', 'total', '320', 'okmetic', 'employees', 'finland']
#
#
# ===Tokens:===
# ['baltic', 'countries', 'sales', 'fell', '42', '6']
#
#
# ===Tokens:===
# ['uvxy', 'put', 'chum', 'key', 'support', 'next', 'level', 'careful']
#
#
# ===Tokens:===
# ['acom', 'http', 'stks', 'co', '1g6x', 'downside', 'breakout', 'looks', 'coming', 'soon']
#
#
# ===Tokens:===
# ['addition', 'production', 'varpaisj', 'rvi', 'factory', 'stopped', 'beginning', 'april', '2009']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'eur', '4', '0', 'mn', 'eur', '4', '9', 'mn']
#
#
# ===Tokens:===
# ['scanfil', 'also', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['exports', 'goods', 'fell', '59', 'imports', '16', '7']
#
#
# ===Tokens:===
# ['tsla', 'recall', 'model', 'x', 'https', 'co', 'b7izya4bue']
#
#
# ===Tokens:===
# ['baltic', 'states', 'company', 'reports', 'net', 'sales', 'eur', '11', '9', 'mn', 'eur', '14', '2', 'mn', 'operative', 'ebit', 'eur', '2', '2', 'mn', 'eur', '1', '7', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'short', 'term', 'fund', 'redemption', 'liquidations', 'channel', 'cleared', 'soon', 'solid', 'footing', '520', 'new', 'floor', 'come', 'july']
#
#
# ===Tokens:===
# ['net', 'sales', 'kyro', 'main', 'business', 'area', 'glaston', 'technologies', 'manufacturer', 'glass', 'processing', 'machines', 'decreased', 'eur', '161', '5', 'mn', 'eur', '164', '1', 'mn', 'january', 'september', '2005']
#
#
# ===Tokens:===
# ['finnish', 'scanfil', 'contract', 'manufacturer', 'systems', 'supplier', 'communication', 'industrial', 'electronics', 'reports', 'net', 'sales', 'eur', '108', '7', 'mn', 'first', 'half', '2008', 'eur', '111', '1', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totalled', 'eur', '49', '9', 'mn', 'compared', 'loss', 'eur', '15', '4', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['aapl', 'afternoon', 'selloff', 'usual', 'brutal', 'get', 'ready', 'lose', 'ton', 'money']
#
#
# ===Tokens:===
# ['however', 'growth', 'margin', 'slowed', 'due', 'financial', 'crisis']
#
#
# ===Tokens:===
# ['nokia', 'shares', 'hit', '13', '21', 'euros', 'friday', '50', 'percent', 'start', 'year', 'part', 'slow', 'introduction', 'touch', 'screen', 'models']
#
#
# ===Tokens:===
# ['reduction', 'notice', 'applied', '17', 'people']
#
#
# ===Tokens:===
# ['european', 'stocks', 'hover', 'near', '3', 'week', 'low', 'dialog', 'bhp', 'slump']
#
#
# ===Tokens:===
# ['ssh', 'communications', 'security', 'corp', 'stock', 'exchange', 'release', 'october', '14', '2008', '2', '45', 'pm', 'company', 'updates', 'full', 'year', 'outlook', 'estimates', 'results', 'remain', 'loss', 'full', 'year']
#
#
# ===Tokens:===
# ['survey', 'conducted', 'taloustutkimus', 'sampo', 'life', 'shows', 'companies', 'badly', 'prepared', 'losing', 'key', 'staff', 'members']
#
#
# ===Tokens:===
# ['september', 'alone', 'market', 'declined', '10', '2', 'percent', 'year', 'year', '19', '28', 'million', 'liters']
#
#
# ===Tokens:===
# ['espn', 'files', 'lawsuit', 'verizon', 'http', 'stks', 'co', 'i2cj1', 'vz']
#
#
# ===Tokens:===
# ['company', 'slipped', 'operating', 'loss', 'eur', '2', '6', 'million', 'profit', 'eur', '1', '3', 'million']
#
#
# ===Tokens:===
# ['cost', 'costco', 'less', 'stellar', 'day', 'held', '50', 'day', 'moving', 'average']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'fell', 'eur', '0', '63', 'eur', '1', '71']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'eur', '11', '2', 'mn', 'eur', '16', '6', 'mn']
#
#
# ===Tokens:===
# ['ftse', '100', 'drops', '2', '5', 'pct', 'glencore', 'metals', 'price', 'fears']
#
#
# ===Tokens:===
# ['fastjet', 'slams', 'easyjet', 'founder', 'stelios', 'going', 'public', 'taking', 'legal', 'advice', 'letter', 'contractual']
#
#
# ===Tokens:===
# ['spy', 'tomorrow', 'party', 'time', 'bears', 'goog', 'msft', '5', '5']
#
#
# ===Tokens:===
# ['device', 'volume', 'area', 'decreased', '21', '2', '7', 'mn', 'units']
#
#
# ===Tokens:===
# ['finnish', 'textiles', 'clothing', 'group', 'marimekko', 'oyj', 'posted', 'net', 'profit', '7', '99', 'mln', 'euro', '10', '4', 'mln', '2006', 'compared', '8', '4', 'mln', 'euro', '10', '9', 'mln', '2005']
#
#
# ===Tokens:===
# ['company', 'said', 'fall', 'turnover', 'planned']
#
#
# ===Tokens:===
# ['meggitt', 'share', 'price', 'tumbles', 'profit', 'falls', 'challenging', 'year']
#
#
# ===Tokens:===
# ['tietoenator', '1', '13', 'pct', '18', '38', 'extending', 'recent', 'lows', 'last', 'week', 'second', 'quarter', 'report', 'dealers', 'said']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '20', '3', 'mn', 'eur', '74', '2', 'mn', 'second', 'quarter', '2008']
#
#
# ===Tokens:===
# ['net', 'sales', 'fell', '33', 'third', 'quarter', '2008', 'eur', '130', '5', 'mn']
#
#
# ===Tokens:===
# ['small', 'firms', 'suffering', 'moment', 'likely', 'money', 'trouble', 'added']
#
#
# ===Tokens:===
# ['food', 'trade', 'sales', 'amounted', 'eur320', '1', 'decline', '1', '1']
#
#
# ===Tokens:===
# ['company', 'previous', 'estimate', 'lower', 'revenue', 'year', 'ago', 'eur', '93', '9', 'million']
#
#
# ===Tokens:===
# ['adpnews', 'may', '4', '2010', 'finnish', 'cutlery', 'hand', 'tools', 'maker', 'fiskars', 'oyj', 'abp', 'hel', 'fisas', 'said', 'today', 'net', 'profit', 'declined', 'eur', '12', '9', 'million', 'usd', '17m', 'first', 'quarter', '2010', 'eur', '17', 'million', 'correspond']
#
#
# ===Tokens:===
# ['finnish', 'retail', 'software', 'developer', 'aldata', 'solution', 'oyj', 'reported', 'net', 'loss', '11', '7', 'mln', 'euro', '17', '2', 'mln', '2007', 'versus', 'net', 'profit', '2', '5', 'mln', 'euro', '3', '7', 'mln', '2006']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'reducing', 'number', 'start', 'ups', 'market', 'financed', 'residential', 'units', '2007', '2', '300', 'previously', 'announced', '2', '700']
#
#
# ===Tokens:===
# ['cencorp', 'net', 'sales', 'first', 'quarter', 'estimated', 'eur0', '9', '1', '2', 'compared', 'eur4', '5', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['building', 'home', 'improvement', 'trade', 'net', 'sales', 'totalled', 'eur', '1', '173', 'mn', 'eur', '1', '566', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['hsbc', 'hit', 'fresh', 'details', 'tax', 'evasion', 'claims']
#
#
# ===Tokens:===
# ['shell', 'share', 'price', 'standard', 'life', 'announce', 'position', 'bg', 'acquisition']
#
#
# ===Tokens:===
# ['negotiation', 'resulted', 'reduction', '80', 'people', 'regular', 'employment', 'around', 'half', 'covered', 'pension', 'arrangements']
#
#
# ===Tokens:===
# ['royal', 'mail', 'johnson', 'matthey', 'lead', 'ftse', 'lower']
#
#
# ===Tokens:===
# ['adpnews', 'sep', '28', '2009', 'finnish', 'silicon', 'wafers', 'maker', 'okmetic', 'oyj', 'hel', 'okm1v', 'said', 'reduce', 'number', 'clerical', 'workers', '22', 'worldwide', 'result', 'personnel', 'negotiations', 'completed', 'today']
#
#
# ===Tokens:===
# ['helsinki', 'thomson', 'financial', 'shares', 'cargotec', 'fell', 'sharply', 'early', 'afternoon', 'trade', 'cargo', 'handling', 'group', 'posted', 'surprise', 'drop', 'april', 'june', 'profits', 'overshadowed', 'large', 'number', 'new', 'orders', 'received', 'three', 'months']
#
#
# ===Tokens:===
# ['generated', 'operating', 'loss', 'eur', '96', '3', 'mn', 'profit', 'eur', '43', '9', 'mn']
#
#
# ===Tokens:===
# ['cat', 'hangin', 'thread', '1click', 'away', 'cliff', 'drop', 'needs', 'follow', 'snap', 'back', 'vix']
#
#
# ===Tokens:===
# ['iff', 'technical', 'alerts', 'stochastic', 'sell', 'signal', '200', 'dma', 'support', '50', 'dma', 'support', 'http', 'stks', 'co', 'p12qy']
#
#
# ===Tokens:===
# ['supreme', 'court', 'upholds', '236', 'million', 'jury', 'award', 'exxonmobil']
#
#
# ===Tokens:===
# ['media', 'advisory', 'ntsb', 'said', 'subsequent', 'testing', 'train', 'detection', 'system', 'intermittently', 'failed']
#
#
# ===Tokens:===
# ['u', 'energy', 'executives', 'say', 'high', 'steel', 'prices', 'threatening', 'energy', 'exploration']
#
#
# ===Tokens:===
# ['spy', 'weak', 'close']
#
#
# ===Tokens:===
# ['result', 'negotiations', 'employment', '130', 'blue', 'white', 'collar', 'employees', 'oulu', 'plant', 'would', 'terminated']
#
#
# ===Tokens:===
# ['reuters', 'green', 'mountain', 'revenue', 'misses', 'shares', 'plunge', 'http', 'stks', 'co', '13mw', 'gmcr', 'prints', '43', '80', 'market', 'foul', 'mood', 'bad', 'day', 'disappoint']
#
#
# ===Tokens:===
# ['operating', 'loss', 'non', 'recurring', 'items', 'eur', '0', '9', 'mn', 'compared', 'profit', 'eur', '11', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['last', 'year', '8', '3', 'million', 'passengers', 'flew', 'airline', '4', 'percent', '2007']
#
#
# ===Tokens:===
# ['glaston', 'net', 'profit', 'third', 'quarter', '2007', 'dropped', '2', '4', 'mln', 'euro', '3', '5', 'mln', '3', '5', 'mln', 'euro', '5', '1', 'mln', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['nokia', 'u', 'shares', '3', '3', 'percent', 'lower', '12', '73', '1750', 'gmt']
#
#
# ===Tokens:===
# ['paper', 'companies', 'negative', 'territories', 'stora', 'enso', 'r', 'shedding', '1', '62', 'pct', '12', '73', 'eur', 'upm', 'kymmene', '0', '80', 'pct', '18', '64', 'eur', 'real', 'b', '0', '18', 'pct', 'lower', '5', '57', 'eur']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'share', 'price', 'slumps', 'company', 'posts', 'full', 'year', 'results']
#
#
# ===Tokens:===
# ['hargreaves', 'lansdown', 'share', 'price', 'falls', 'costs', 'mount', 'although', 'pensions']
#
#
# ===Tokens:===
# ['googl', 'hit', 'lawsuit', 'russian', 'search', 'engine', 'yndx', 'http', 'stks', 'co', 'b1kd8']
#
#
# ===Tokens:===
# ['information', 'released', '5', 'september', '2008', 'nokia', 'american', 'depositary', 'shares', 'fell', '8']
#
#
# ===Tokens:===
# ['frost', 'sold', 'shares', '19', 'million', '6', '06', '7', '12', 'per', 'share', 'compared', 'friday', 'high', '11', '33', 'low', '10', '14']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '6', '7', 'mn', 'eur', '7', '2', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['cut', 'frequency', 'new', 'york', 'last', 'year', 'explains', 'fall', 'said']
#
#
# ===Tokens:===
# ['managing', 'director', 'comments', 'net', 'sales', 'first', 'quarter', 'notably', 'lower', 'year', 'especially', 'finland', 'russia', 'baltic', 'countries']
#
#
# ===Tokens:===
# ['netapp', 'downgraded', 'macquarie', 'underperform', '22', '00', 'pt', 'https', 'co', 'xcngws0t4q', 'ntap', 'ntap', 'via', 'ratingsnetwork']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'loss', 'eur0', '38']
#
#
# ===Tokens:===
# ['cndo', '21', 'short', 'float', 'shorts', 'likely', 'take', 'profits', 'close']
#
#
# ===Tokens:===
# ['european', 'shares', 'plunge', 'roiled', 'bhp', 'oil', 'hopes', 'turn', 'ecb']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '1', '0', 'mn', 'eur', '1', '6', 'mn']
#
#
# ===Tokens:===
# ['ftse', 'falls', '3', 'month', 'low', 'greek', 'debt', 'concerns', 'easyjet', 'skids']
#
#
# ===Tokens:===
# ['barclays', 'share', 'price', 'subdued', 'bank', 'faces', 'fresh', 'forex', 'probe']
#
#
# ===Tokens:===
# ['companieskingfisher', 'bid', 'mr', 'bricolage', 'runs', 'trouble']
#
#
# ===Tokens:===
# ['adpnews', 'feb', '3', '2010', 'finland', 'based', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'slipped', 'larger', 'expected', 'pretax', 'loss', 'eur', '46', 'million', 'usd', '64', '5', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['operating', 'profit', 'declined', 'mainly', 'due', 'increased', 'cost', 'wood', 'recycled', 'fiber', 'strengthened', 'euro']
#
#
# ===Tokens:===
# ['oil', 'majors', 'like', 'royal', 'dutch', 'shell', 'chevron', 'bp', 'fail', 'find', 'reserves', 'counter']
#
#
# ===Tokens:===
# ['profitability', 'ebit', '13', '6', 'compared', '14', '3', 'q2', '2009']
#
#
# ===Tokens:===
# ['kiosk', 'cinema', 'operations', 'suffered', 'particular']
#
#
# ===Tokens:===
# ['shares', 'royal', 'sun', 'alliance', 'continued', 'slide', 'back', '12', 'month', 'high', '172p', 'last', 'month', 'potential', 'suitor', 'ruled', 'takeover', 'bid']
#
#
# ===Tokens:===
# ['rio', 'tinto', 'swings', 'loss', 'drops', 'dividend', 'policy']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'landsbanken', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '2', '2', 'mn', 'eur', '2', '7', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['antti', 'orkola', 'president', 'kemira', 'growhow', 'industrial', 'solutions', 'unit', 'told', 'thomson', 'financial', 'news', 'company', 'put', 'opening', 'mine', 'prices', 'phosphate', 'quite', 'depressed', 'long', 'time']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '3', '2', 'mn', 'compared', 'profit', 'eur', '7', '2', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'decreased', 'eur', '121', '4', 'mn', 'eur', '165', '5', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['finnish', 'national', 'carrier', 'said', 'net', 'loss', 'april', 'june', 'euro26', 'million', 'net', 'profit', 'euro13', 'million', 'year', 'earlier']
#
#
# ===Tokens:===
# ['scottrade', 'tsla', 'available', 'shorting', 'time', 'w']
#
#
# ===Tokens:===
# ['total', '16', '5', 'mn', 'passenger', 'ship', 'journeys', 'took', 'place', 'northern', 'baltic', 'sea', '2007', 'slightly', '16', '5', 'mn', '2006']
#
#
# ===Tokens:===
# ['finnish', 'solutions', 'provider', 'affecto', 'oyj', 'hel', 'afe1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur', '115', '000', 'usd', '152', '000', 'second', 'quarter', '2010', 'profit', 'eur', '845', '000', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['astrazeneca', 'suffers', 'setback', 'drug', 'fails', 'treat', 'eye', 'cancer']
#
#
# ===Tokens:===
# ['omx', 'nordic', '40', 'omxn40', 'index', 'comprising', '40', 'traded', 'nordic', 'stocks', 'nasdaq', 'omx', 'exchange', 'closed', '0', '87', '1', '064', '14', 'points', 'thursday']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'corporation', 'makes', 'wipes', 'nonwovens', 'flexible', 'packaging', 'expects', 'changes', 'market', 'situation', 'reduce', 'sales', 'suominen', 'nonwovens', 'wet', 'wipes', 'previously', 'estimated', 'volumes']
#
#
# ===Tokens:===
# ['windows', '10', 'awful', 'force', 'upgrade', 'pc', 'without', 'consent', 'windows', 'microsoft', 'msft']
#
#
# ===Tokens:===
# ['twtr', 'best', 'scenario', 'going', 'forward', 'stock', 'slowly', 'falling', 'everyday', 'quite', 'probable']
#
#
# ===Tokens:===
# ['homebuilders', 'ryl', 'breaking', 'support', 'watch', 'one', 'spy']
#
#
# ===Tokens:===
# ['finnish', 'airline', 'finnair', 'starting', 'temporary', 'layoffs', 'cabin', 'crews', 'february', '2010']
#
#
# ===Tokens:===
# ['stock', 'hit', 'profit', 'warning', 'finnish', 'rival', 'rautaruukki', 'oyj', 'omx', 'rtrks']
#
#
# ===Tokens:===
# ['operating', 'cash', 'flow', 'investments', 'totalled', 'eur', '61', '3', 'mn', 'compared', 'eur', '75', '3', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['company', 'confirmed', 'estimate', 'lower', 'revenue', 'whole', '2009', 'year', 'ago', 'eur93', '9', 'given', 'interim', 'report', '5', 'august', '2009']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'grocer', 'faces', 'sfo', 'investigation', 'outcome']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'amounted', 'eur', '40', '6', 'mn', 'eur', '57', '3', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['glencore', 'chief', 'blames', 'rivals', 'overproduction', 'share', 'price', 'fall']
#
#
# ===Tokens:===
# ['profit', 'period', 'totalled', 'eur', '0', '8', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['moment', 'valio', 'worried', 'ban', 'continues', 'long', 'may', 'become', 'quite', 'problem']
#
#
# ===Tokens:===
# ['bhp', 'billiton', 'drags', 'ftse', 'lower', 'slashing', 'dividend']
#
#
# ===Tokens:===
# ['acando', 'ab', 'acanb', 'ss', 'fell', '8', '9', 'percent', '13', '35', 'kronor', 'lowest', 'close', 'since', 'dec', '11']
#
#
# ===Tokens:===
# ['cost', 'short', 'finally', 'making', 'gains', 'take', 'half', 'gains', '147']
#
#
# ===Tokens:===
# ['quick', 'fio', '21', '35', 'market', 'tanking', 'scaling', 'longs']
#
#
# ===Tokens:===
# ['sales', 'seppala', 'diminished', '6', 'per', 'cent']
#
#
# ===Tokens:===
# ['tightened', 'competition', 'situation', 'production', 'automation', 'market', 'affected', 'net', 'sales', '2006', 'cencorp', 'said']
#
#
# ===Tokens:===
# ['dolce', 'gabbana', 'asked', 'european', 'union', 'declare', 'marimekko', 'corporation', 'unikko', 'floral', 'pattern', 'trademark', 'invalid', 'continuing', 'dispute', 'two', 'companies']
#
#
# ===Tokens:===
# ['net', 'sales', 'decreased', 'eur', '49', '8', 'million', 'eur', '59', '9', 'million']
#
#
# ===Tokens:===
# ['yelp', 'wayyy', 'overvalued', 'right', 'imo', 'trading', 'single', 'digits', 'may', 'take', 'short', 'pos', 'earnings', 'near', 'term', 'target', '18']
#
#
# ===Tokens:===
# ['according', 'scanfil', 'demand', 'telecommunications', 'network', 'products', 'fluctuated', 'significantly', 'third', 'quarter', '2006', 'situation', 'expected', 'remain', 'unstable', 'rest', 'year']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['according', 'latvian', 'business', 'register', 'uponor', 'latvia', 'closed', 'red', 'lvl', '99', '000', 'eur', '139', '538', '17', 'usd', '194', '556', '48', 'turnover', 'lvl', '2', '346', 'mn', '2009']
#
#
# ===Tokens:===
# ['standard', 'chartered', 'raising', 'capital', 'yet', 'dividend', 'cut']
#
#
# ===Tokens:===
# ['uk', 'ftse', 'worst', 'day', 'far', '2015', 'bg', 'prudential', 'fall']
#
#
# ===Tokens:===
# ['amazon', 'selling', 'surveillance', 'cameras', 'infected', 'malware', 'amzn', 'amazon', 'https', 'co', 'tohleq8fk6', 'https', 'co', '5pr4cbtvvy']
#
#
# ===Tokens:===
# ['sales', 'volume', 'coca', 'cola', 'market', 'share', 'decreased', '2', '2', '24', '2']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '2', '0', 'international', 'sales', 'decreased', '9', '3', 'terms', 'euros', '15', '1', 'terms', 'local', 'currencies']
#
#
# ===Tokens:===
# ['hpq', 'says', 'breakup', 'cost', 'billions', 'sees', 'savings', 'http', 'stks', 'co', 'p27hz']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'falls', 'back', 'ashtead', 'commodities', 'pressure']
#
#
# ===Tokens:===
# ['tesco', 'sales', 'pickup', 'enough']
#
#
# ===Tokens:===
# ['upm', 'stock', 'fell', '3', 'percent', 'euro', '12', '49', '17', '24', 'early', 'afternoon', 'trading', 'helsinki']
#
#
# ===Tokens:===
# ['finnish', 'power', 'supply', 'solutions', 'systems', 'provider', 'efore', 'oyj', 'said', 'net', 'loss', 'widened', '3', '2', 'mln', 'euro', '4', '2', 'mln', 'first', 'quarter', 'fiscal', '2006', '2007', 'ending', 'october', '31', '2007', '900', '000', 'euro', '1', '2', 'mln', 'period', 'fiscal', '2005', '06']
#
#
# ===Tokens:===
# ['operating', 'margin', 'came', '2', '4', '5', '7']
#
#
# ===Tokens:===
# ['rbi', 'surprises', 'street', 'sensex', 'pares', 'gains', 'hitting', 'mount', '30k']
#
#
# ===Tokens:===
# ['hack', 'extra', 'nefarious', 'tweets', 'activated', 'without', 'clicked', 'enough', 'web', 'surfers', 'move', 'mouse', 'cursors']
#
#
# ===Tokens:===
# ['casinos', 'red', 'bell', 'lvs', '0', '75', 'wynn', '0', '47', 'wynn', '0', '47', 'unusual', 'comibinations', 'running', 'red', 'bell']
#
#
# ===Tokens:===
# ['company', 'reported', 'today', 'operating', 'loss', 'eur0', '1', 'net', 'sales', 'eur4', '5', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['rimm', 'spx', 'nya', 'compq', 'djia', 'going']
#
#
# ===Tokens:===
# ['ferries', 'run', 'trouble', 'outside', 'stockholm', 'archipelago', 'made', '20', '000', 'islands']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '9', '0', 'mn', 'eur', '9', '7', 'mn', 'first', 'half', '2008']
#
#
# ===Tokens:===
# ['finnish', 'exel', 'composites', 'technology', 'company', 'designs', 'manufactures', 'markets', 'composite', 'profiles', 'tubes', 'various', 'industrial', 'applications', 'reports', 'net', 'sales', 'decreased', '0', '6', 'second', 'quarter', '2010', 'eur', '19', '2', 'mn', 'eur', '19', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['soullor', 'regular', 'scrappy', 'q', 'swy', 'usually', 'presents', 'sales', 'weak', 'margins', 'debt', 'still', 'way']
#
#
# ===Tokens:===
# ['upm', 'kymmene', 'corp', 'world', 'largest', 'maker', 'magazine', 'paper', 'tuesday', 'reported', '19', 'percent', 'profit', 'drop', 'lower', 'paper', 'prices', 'higher', 'costs', 'strong', 'euro', 'hurt', 'revenue']
#
#
# ===Tokens:===
# ['hznp', 'havent', 'seen', 'vol', 'like', 'since', 'runup', 'lets', 'see', 'one', 'dip', '2', '0x']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'decreased', '37', 'eur', '193', '1', 'mn', 'eur', '305', '6', 'mn']
#
#
# ===Tokens:===
# ['miners', 'meltdown', 'bhp', 'rio', 'tinto', 'sink', 'commodities', 'rout']
#
#
# ===Tokens:===
# ['traceyryniec', 'energy', 'broad', 'see', 'wwg', 'kaman', 'well', 'short', 'fast']
#
#
# ===Tokens:===
# ['operating', 'profits', 'half', '0', '8', '0', '9', 'glisten', 'invested', 'brand', 'management', 'team']
#
#
# ===Tokens:===
# ['finnlines', 'estimated', 'annual', 'general', 'meeting', '2008', 'financially', 'tough', 'year', 'due', 'large', 'investments']
#
#
# ===Tokens:===
# ['salonen', 'added', 'data', 'shows', 'producers', 'pulp', 'inventories', 'north', 'america', 'declining']
#
#
# ===Tokens:===
# ['vnoto74', 'follow', 'sell', 'signal', 'ndx', 'internals', '06', '23', 'technical', 'sell', 'qqq', '06', '25']
#
#
# ===Tokens:===
# ['arcelormittal', 'chief', 'executive', 'officer', 'lakshmi', 'mittal', 'already', 'cut', 'output', 'furnaces']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '35', '4', 'mn', 'eur', '68', '8', 'mn', '2007', 'including', 'vessel', 'sales', 'gain', 'eur', '12', '3', 'mn']
#
#
# ===Tokens:===
# ['astrazeneca', 'diabetes', 'drug', 'combination', 'faces', 'delay', 'fda', 'rebuff']
#
#
# ===Tokens:===
# ['third', 'quarter', 'fiscal', '2008', 'efore', 'swung', 'net', 'loss', 'eur', '400', '000', 'versus', 'net', 'profit', 'eur', '200', '000', 'corresponding', 'period', 'fiscal', '2007']
#
#
# ===Tokens:===
# ['deutsche', 'bank', 'downgraded', 'starbucks', 'co', 'sbux', 'https', 'co', 'qqlevvwpmv', 'https', 'co', 'f2pdqjutha']
#
#
# ===Tokens:===
# ['adp', 'news', 'apr', '22', '2009', 'finnish', 'business', 'information', 'systems', 'developer', 'solteq', 'oyj', 'hel', 'stq1v', 'said', 'today', 'net', 'loss', 'widened', 'eur', '189', '000', 'usd', '245', '000', 'first', 'quarter', '2009', 'eur', '10', '000', 'peri']
#
#
# ===Tokens:===
# ['boeing', 'company', 'nyse', 'ba', 'bearish', 'trader', 'bets', '550k', 'stock', 'sell', '9', '79', 'july', 'expiry', 'ba', 'http', 'stks', 'co', 'tcse']
#
#
# ===Tokens:===
# ['gevo', 'plunging', 'back', '3', '55']
#
#
# ===Tokens:===
# ['finnish', 'developer', 'manufacturer', 'mobile', 'phone', 'chargers', 'salcomp', 'plc', 'omx', 'helsinki', 'sal1v', 'wednesday', '19', 'november', 'lowered', 'full', 'year', 'net', 'sales', 'estimate']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'stood', 'eur', '0', '25', 'versus', 'eur', '0', '42']
#
#
# ===Tokens:===
# ['net', 'sales', 'decreased', 'eur', '91', '6', 'mn', 'eur', '109mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['budapest', 'august', '10', 'mti', 'finnish', 'electronics', 'maker', 'elcoteq', 'lay', '700', 'workers', 'plants', 'pecs', 'hungary', 'end', 'september', 'falling', 'orders', 'communications', 'director', 'elcoteq', 'local', 'unit', 'zoltan', 'krippl', 'told', 'mti', 'monday']
#
#
# ===Tokens:===
# ['12', '01', 'pm', 'omx', 'helsinki', '25', '0', '66', 'pct', '3', '143', '57', 'omx', 'helsinki', '0', '67', 'pct', 'lower', '10', '530', '74', '253', 'mln', 'eur', 'turnover']
#
#
# ===Tokens:===
# ['finnair', 'total', 'traffic', 'decreased', '8', '7', 'terms', 'revenue', 'passenger', 'kilometres']
#
#
# ===Tokens:===
# ['iwm', 'conditions', 'sent', 'markets', 'tumble', 'hitting', 'week']
#
#
# ===Tokens:===
# ['finnish', 'meat', 'company', 'atria', 'longer', 'promise', 'sufficient', 'amount', 'domestic', 'beef', 'customers']
#
#
# ===Tokens:===
# ['company', 'profit', 'taxes', 'fell', 'eur', '21', '1', 'mn', 'third', 'quarter', '2008', 'compared', 'eur', '35', '8', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['academics', 'claim', 'google', 'android', 'two', 'factor', 'authentication', 'breakable', 'security', 'authentication', 'hacking', 'goog', 'https', 'co', 'njx4mnrglo']
#
#
# ===Tokens:===
# ['aapl', 'rejected', 'hod', 'head', 'lower', 'sitting', 'sidelines']
#
#
# ===Tokens:===
# ['also', 'cut', 'price', 'projections', 'paper', 'packaging', 'analyst', 'goldman', 'sachs', 'said', 'note', 'monday']
#
#
# ===Tokens:===
# ['morrisons', 'finance', 'chief', 'fill', 'gap', 'ceo', 'leaves', 'early']
#
#
# ===Tokens:===
# ['multi', 'top', 'mcd', 'chart', 'finally', 'leads', 'fall', 'price', 'stability', 'questioned', 'stock', 'coming', 'weeks', 'tell']
#
#
# ===Tokens:===
# ['zsl', 'looking', 'weak', 'could', 'good', 'short', 'setup']
#
#
# ===Tokens:===
# ['top', 'us', 'commerce', 'department', 'published', 'worse', 'expected', 'construction', 'spending', 'figures', 'november']
#
#
# ===Tokens:===
# ['finnish', 'glass', 'technology', 'company', 'glaston', 'oyj', 'abp', 'net', 'profit', 'decreased', '2', '6', 'mln', 'euro', '3', '8', 'mln', 'first', 'nine', 'months', '2007', '7', '8', 'mln', 'euro', '11', '4', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['fb', 'guess', 'want', 'look', 'sell', 'orders']
#
#
# ===Tokens:===
# ['vaisala', 'net', 'profit', 'third', 'quarter', '2007', 'dropped', '3', '0', 'mln', 'euro', '4', '3', 'mln', '6', '8', 'mln', 'euro', '9', '8', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['repurchases', 'shall', 'decrease', 'distributable', 'capital', 'reserves']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'contract', 'manufacturer', 'scanfil', 'reports', 'net', 'sales', 'eur', '241', '2', 'mn', '2006', 'eur', '321', '6', 'mn', '2005']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'dropped', 'eur', '0', '21', 'eur', '0', '31']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '1', '6', 'mn', '2005', 'compared', 'eur', '5', '9', 'mn', '2004']
#
#
# ===Tokens:===
# ['kingfisher', 'share', 'price', 'slides', 'cost', 'implement', 'new', 'strategy']
#
#
# ===Tokens:===
# ['cramo', 'slipped', 'pretax', 'loss', 'eur', '6', '7', 'million', 'pretax', 'profit', 'eur', '58', '9', 'million']
#
#
# ===Tokens:===
# ['rivals', 'say', 'qualcomm', 'fewer', 'patents', '3g', 'phones', 'earlier', 'versions', 'lower', 'rates']
#
#
# ===Tokens:===
# ['aviva', 'fined', '27', 'million', 'u', 'k', 'regulator', 'fee', 'failings']
#
#
# ===Tokens:===
# ['aspocomp', 'large', 'factory', 'china', 'factory', 'building', 'project', 'india', 'halted', 'due', 'financing', 'problems']
#
#
# ===Tokens:===
# ['tesco', 'abandons', 'video', 'streaming', 'ambitions', 'blinkbox', 'sale']
#
#
# ===Tokens:===
# ['tsla', 'recall']
#
#
# ===Tokens:===
# ['prices', 'delivery', 'volumes', 'broadband', 'products', 'decreased', 'significantly', '2005']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'decreased', 'eur', '13', '8', 'mn', 'eur', '17', '1', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['ftse', '100', 'falls', 'china', 'devaluation', 'hits', 'burberry', 'mining', 'stocks']
#
#
# ===Tokens:===
# ['finnish', 'communication', 'electronics', 'components', 'supplier', 'scanfil', 'oyj', 'tuesday', 'said', 'sales', 'first', 'half', '2006', '15', 'lower', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['really', 'surprised', 'much', 'fb', 'fallen', 'thought', 'support', 'around', '50d', 'guess']
#
#
# ===Tokens:===
# ['sheryl', 'sandberg', 'sells', '109', '000', 'shares', 'facebook', 'inc', 'fb', 'stock', 'https', 'co', '3vxt7amnpk', 'via', 'ratingsnetwork']
#
#
# ===Tokens:===
# ['market', 'share', 'decreased', 'route', 'helsinki', 'finland', 'tallinn', 'estonia', '0', '1', 'percentage', 'points', '24', '8']
#
#
# ===Tokens:===
# ['finnair', 'passenger', 'load', 'factor', 'measures', 'number', 'sold', 'seats', 'share', 'available', 'seats', 'dropped', '1', '3', 'percentage', 'points', '76', '7', 'september']
#
#
# ===Tokens:===
# ['rapala', 'vmc', 'corporation', 'stock', 'exchange', 'release', 'october', '10', '2008', '11', '45', 'kaupthing', 'bank', 'oyj', 'kapthing', 'informed', 'rapala', 'vmc', 'corporation', 'rapala', 'interrupted', 'liquidity', 'providing', 'rapala', 'share', 'time']
#
#
# ===Tokens:===
# ['slv', '4', '44', '18', 'awful', '42', '50']
#
#
# ===Tokens:===
# ['orion', 'net', 'profit', 'third', 'quarter', '2007', 'decreased', '36', '5', 'mln', 'euro', '52', '1', 'mln', '40', '3', 'mln', 'euro', '57', '5', 'mln', 'year', 'earlier']
#
#
# ===Tokens:===
# ['omx', 'helsinki', 'index', '0', '34', 'pct', '8', '256', '02', 'turnover', '813', '191', 'mln', 'eur']
#
#
# ===Tokens:===
# ['uncertainties', 'cloud', 'long', 'term', 'outlook']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'first', 'half', '2007', 'amounted', 'eur0', '29', 'eur0', '40', 'year', 'ago']
#
#
# ===Tokens:===
# ['still', 'short', 'lng', '11', '70', 'area', 'next', 'stop', 'could', '9', '00', 'someone', 'slammed', 'hard', '230', '000', 'shs', 'follow']
#
#
# ===Tokens:===
# ['capacity', 'ease', 'seikku', 'sawmill', 'pori', 'alholma', 'sawmill', 'pietarsaari', 'result', '60', 'people', 'laid', 'around', 'six', 'weeks', 'starting', 'mid', 'may', 'said']
#
#
# ===Tokens:===
# ['starbucks', 'downgraded', 'day', 'new', 'downgraded', 'rewards', 'program', 'starts', 'sbux']
#
#
# ===Tokens:===
# ['tsla', 'recalls', '2', '700', 'model', 'x', 'vehicles', 'shares', 'volatile', 'https', 'co', 'tckqznmiqx', 'tsla', 'tech', 'stockmarket', 'https', 'co', 'femhjtamqj']
#
#
# ===Tokens:===
# ['iwm', 'relative', 'weakness', 'pretty', 'apparent', 'short', 'boat', 'getting', 'full', 'one', 'prefer', 'boat', 'closer', 'empty']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '15', '1', 'mn', 'eur', '24', '6', 'mn', '2006']
#
#
# ===Tokens:===
# ['ea', 'points', 'two', 'facebook', 'games', 'accuses', 'znga', 'copyright', 'infringement', 'http', 'stks', 'co', 'g3a1']
#
#
# ===Tokens:===
# ['finnish', 'media', 'group', 'talentum', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['hlf', 'shorts', 'made', 'killing', 'last', 'couple', 'days', 'might', 'make', 'cover', 'buy', 'back']
#
#
# ===Tokens:===
# ['smh', 'got', 'sell', 'signal', '6', '4', 'needs', 'take', '39', '28', 'go', 'higher', 'otherwise', 'headed', 'lower', '37', '60', 'gap', '35', '38']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur', '30', '6', 'million', 'eur', '38', '3', 'million', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['far', 'norwegian', 'norske', 'skog', 'reduced', 'staff', 'levels', '1', '000', 'people', 'plans', 'reduce', 'production', '200', '000', 'tons', '2008', 'finnish', 'swedish', 'stora', 'enso', 'cut', 'staff', '1', '700', 'people', 'production', '500', '000', 'tons']
#
#
# ===Tokens:===
# ['gld', 'http', 'stks', 'co', '44ow', 'closer', 'inspection', 'resistance', '10', 'points', 'north', '200d', 'downward', 'trendline', 'chart', '2', '2']
#
#
# ===Tokens:===
# ['fb', 'tsla', 'cracking', 'lower', 'early', 'short', 'correction', 'stocks']
#
#
# ===Tokens:===
# ['stumbled', 'upon', 'amazing', 'chart', 'ofix', 'holy', 'guac', 'super', 'overbought', 'http', 'stks', 'co', 'e0px1']
#
#
# ===Tokens:===
# ['ab', 'inbev', 'attacks', 'sabmiller', 'bid', 'rebuffal']
#
#
# ===Tokens:===
# ['since', 'association', 'data', 'cover', 'sales', 'figures', '100', 'small', 'local', 'breweries', 'sales', 'imported', 'beer', 'products', 'actual', 'market', 'shares', 'members', 'smaller', 'given', 'report']
#
#
# ===Tokens:===
# ['sanoma', 'news', 'advertising', 'sales', 'decreased', '22', 'year']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'elcoteq', 'se', 'posted', 'net', 'loss', '66', '4', 'mln', 'euro', '91', '2', 'mln', 'first', 'half', '2007', 'compared', 'net', 'profit', '7', '1', 'mln', 'euro', '9', '8', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fourth', 'quarter', 'went', 'eur3m', 'eur4', '2', 'corresponding', 'period', '2009', 'included', 'costs', 'growth', 'projects']
#
#
# ===Tokens:===
# ['finnish', 'waste', 'management', 'cleaning', 'group', 'lassila', 'tikanoja', 'oyj', 'l', 'net', 'profit', 'went', '32', '2', 'mln', 'euro', '47', '7', 'mln', '2007', '35', '3', 'mln', 'euro', '52', '3', 'mln', '2006']
#
#
# ===Tokens:===
# ['update', '1', 'dairy', 'crest', 'loses', 'third', 'morrisons', 'milk', 'contract']
#
#
# ===Tokens:===
# ['tullow', 'oil', 'suspends', 'dividend', 'amid', 'oil', 'price', 'fall']
#
#
# ===Tokens:===
# ['finnish', 'laboratory', 'liquid', 'handling', 'diagnostic', 'test', 'systems', 'developer', 'biohit', 'oyj', 'omx', 'helsinki', 'biobv', 'issued', 'tuesday', '3', 'june', 'profit', 'warning', 'financial', 'year', '2008']
#
#
# ===Tokens:===
# ['city', 'spirits', 'sink', 'diageo', 'comes', 'short', 'sales', 'slide']
#
#
# ===Tokens:===
# ['tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'f55dx4aegi']
#
#
# ===Tokens:===
# ['net', 'sales', 'dropped', '6', 'year', 'year', 'eur', '11', '9', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'eur', '7', '8', 'million', 'compared', 'eur', '11', '2', 'million']
#
#
# ===Tokens:===
# ['siga', 'bid', 'reargument', 'denied', 'judge']

# %%
neutralWords = defaultdict(int)
for text in train_set[train_set['Sentiment']=='neutral']['Sentence']:
    for word in generate_ngrams(text):
        neutralWords[word]+=1

df_neutral = pd.DataFrame(sorted(neutralWords.items(),key=lambda x:x[1],reverse=True))
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastics', 'producer', 'suominen', 'corporation', 'omx', 'helsinki', 'suy1v', 'reported', 'wednesday', '22', 'october', 'operating', 'loss', 'eur0', '8', 'net', 'sales', 'eur55', '2', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['uk', 'sarantel', 'outsource', 'part', 'processes', 'elcoteq', 'plant', 'estonia', 'london', 'oct', '13', 'bns', 'british', 'miniature', 'antennas', 'maker', 'sarantel', 'signed', 'agreement', 'outsource', 'assembly', 'test', 'supply', 'chain', 'processes', 'plant', 'elcoteq', 'estonian', 'capital', 'tallinn']
#
#
# ===Tokens:===
# ['12', '59', 'pm', 'omx', 'helsinki', '25', 'index', '0', '32', 'pct', 'lower', '2', '694', '81']
#
#
# ===Tokens:===
# ['finland', 'martela', 'offers', 'comprehensive', 'service', 'cover', 'entire', 'process', 'change', 'initial', 'inventory', 'design', 'removal', 'maintenance']
#
#
# ===Tokens:===
# ['move', 'carried', 'transferring', 'hkscan', 'production', 'related', 'property', 'plant', 'equipment', 'well', 'holdings', 'subsidiaries', 'associate', 'companies', 'country', 'hkscan', 'finland']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '9', '4', 'mn', 'eur', '11', '7', 'mn', '2004']
#
#
# ===Tokens:===
# ['marimekko', 'operates', 'industry', 'changes', 'business', 'climate', 'reflected', 'consumer', 'demand']
#
#
# ===Tokens:===
# ['offer', 'clients', 'integrated', 'management', 'consulting', 'total', 'solutions', 'complex', 'projects', 'efficient', 'best', 'class', 'design', 'supervision']
#
#
# ===Tokens:===
# ['group', 'business', 'sectors', 'building', 'construction', 'infrastructure', 'construction', 'technical', 'building', 'services', 'building', 'products']
#
#
# ===Tokens:===
# ['company', 'expects', 'sales', 'revenue', 'rmb8', '0', 'billion', '2009']
#
#
# ===Tokens:===
# ['according', 'statistics', 'finnish', 'maritime', 'administration', 'shipping', 'increase', 'much', 'january', 'august', '2009', 'however']
#
#
# ===Tokens:===
# ['cranes', 'would', 'installed', 'onboard', 'two', 'freighters', 'ordered', 'singaporean', 'ship', 'owner', 'masterbulk']
#
#
# ===Tokens:===
# ['acquisition', 'avc', 'systemhaus', 'majority', 'stake', 'cableway', 'increase', 'number', 'teleste', 'personnel', '250']
#
#
# ===Tokens:===
# ['proposal', 'board', 'directors', 'issuance', 'option', 'rights', 'otherwise', 'correspond', 'proposal', 'board', 'directors', 'notice', 'general', 'meeting']
#
#
# ===Tokens:===
# ['plant', 'collect', 'raw', 'material', 'baltic', 'sea', 'region']
#
#
# ===Tokens:===
# ['jvc', 'stop', 'producing', 'dvd', 'players', 'brazil', 'jvc', 'brazil', 'subsidiary', 'japan', 'jvc', 'group', 'announced', 'stop', 'production', 'dvd', 'players', 'brazil']
#
#
# ===Tokens:===
# ['efore', 'ceo', 'reijo', 'maihaniemi', 'said', 'company', 'developed', 'already', 'delivered', 'power', 'supply', 'units', 'respective', 'systems', 'based', 'technology', 'chinese', 'sector', 'company', 'zte', 'corp', '000063']
#
#
# ===Tokens:===
# ['secondary', 'antenna', 'also', 'used', 'reception', 'high', 'power', 'signal', 'radar', 'calibrate', 'transmission', 'channels', 'radar']
#
#
# ===Tokens:===
# ['altogether', 'capman', 'employs', 'approximately', '150', 'people', 'helsinki', 'stockholm', 'copenhagen', 'oslo', 'moscow', 'luxembourg']
#
#
# ===Tokens:===
# ['underground', 'parking', 'facilities', 'also', 'built', 'basement', 'floor']
#
#
# ===Tokens:===
# ['fixed', 'acquisition', 'price', 'amounts', 'nok', '70', 'approximately', 'eur', '8', '7', 'million', 'additional', 'price', 'nok', '15', 'eur', '1', '8', 'million', 'maximum']
#
#
# ===Tokens:===
# ['operating', 'profits', 'half', '0', '8', '0', '9', 'glisten', 'invested', 'brand', 'management', 'team']
#
#
# ===Tokens:===
# ['mr', 'clausen', 'however', 'refused', 'comment', 'option', 'nordea', 'would', 'consider', 'buying', 'citadele', 'bank']
#
#
# ===Tokens:===
# ['finnish', 'plumbing', 'heating', 'systems', 'supplier', 'uponor', 'net', 'sales', 'continuing', 'operations', 'decreased', '9', '4', '2008', 'eur', '949', '2', 'mn', 'eur', '1', '047', '4', 'mn', '2007']
#
#
# ===Tokens:===
# ['sales', 'seppala', 'diminished', '6', 'per', 'cent']
#
#
# ===Tokens:===
# ['performance', 'based', 'values', 'sustainability']
#
#
# ===Tokens:===
# ['rosen', 'cautious', 'optimistic', 'inregard', 'second', 'half', 'year']
#
#
# ===Tokens:===
# ['winner', 'present', 'win']
#
#
# ===Tokens:===
# ['group', 'cumulative', 'sales', 'review', 'period', 'eur', '48', '2', 'million', 'eur', '53', '1', 'million', '1', '9', '2007', 'profit', 'taxes', 'eur', '1', '2', '1', '4', 'million']
#
#
# ===Tokens:===
# ['exel', 'wants', 'serve', 'industrial', 'customers', 'individual', 'products']
#
#
# ===Tokens:===
# ['export', 'declined', '6', 'percent', '16', '4', 'million', 'liters']
#
#
# ===Tokens:===
# ['revenue', 'quarter', 'totaled', '27', '4', 'billion', '2', 'percent', '28', '1', 'billion', 'fourth', 'quarter', '2008']
#
#
# ===Tokens:===
# ['total', 'project', 'duration', 'three', 'years', 'valued', 'eur11', '5']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'eur0', '01']
#
#
# ===Tokens:===
# ['mall', 'financed', 'parity', 'basis', 'pearl', 'plaza', 'llc', 'joint', 'venture', 'company', 'established', 'chinese', 'investor', 'shanghai', 'industrial', 'investment', 'holdings', 'co', 'ltd', 'srv', 'group']
#
#
# ===Tokens:===
# ['huhtamaki', 'rigid', 'plastic', 'consumer', 'goods', 'operations', 'mainly', 'europe', 'separated', 'new', 'reporting', 'segment', '1', 'january', '2009']
#
#
# ===Tokens:===
# ['financial', 'details', 'disclosed']
#
#
# ===Tokens:===
# ['den', 'bosch', 'based', 'tomtom', 'europe', 'largest', 'maker', 'automotive', 'navigation', 'devices', 'cayman', 'islands', 'based', 'garmin', 'larger', 'u', 'overall']
#
#
# ===Tokens:===
# ['company', 'said', 'results', 'third', 'quarter', 'include', 'non', 'recurring', 'items']
#
#
# ===Tokens:===
# ['23', 'april', '2010', 'finnish', 'construction', 'engineering', 'company', 'outotec', 'oyj', 'hel', 'ote1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur7', '3', 'first', 'quarter', '2010', 'net', 'profit', 'eur12', '5', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['following', 'demerger', 'vice', 'president', 'group', 'pharmaceutical', 'trade', 'finland', 'jukka', 'niemi', 'appointed', 'managing', 'director', 'oriola', 'addition', 'current', 'responsibilities']
#
#
# ===Tokens:===
# ['full', 'midnighttrader', 'extended', 'hours', 'trading', 'analysis', 'news', 'service', 'available', 'real', 'time', 'comtex']
#
#
# ===Tokens:===
# ['value', 'contract', 'eur', '25mn']
#
#
# ===Tokens:===
# ['aviation', 'systems', 'maintenance', 'based', 'kansas', 'generated', 'net', 'sales', 'usd', '2', '6', 'million', '2008']
#
#
# ===Tokens:===
# ['proposal', 'board', 'directors', 'make', 'annual', 'general', 'meeting', 'attached', 'whole', 'release']
#
#
# ===Tokens:===
# ['nordea', 'bank', 'estonia', 'part', 'largest', 'financial', 'group', 'nordic', 'countries']
#
#
# ===Tokens:===
# ['product', 'front', 'edge', 'folding', 'maximizes', 'weather', 'resilience', 'enables', 'seamless', 'roof', 'finish']
#
#
# ===Tokens:===
# ['capman', 'asset', 'manager', 'eur', '3bn', 'worth', 'assets', 'management', 'nordic', 'region']
#
#
# ===Tokens:===
# ['member', 'hk', 'ruokatalo', 'group', 'finland', 'scan', 'launching', 'joint', 'venture', 'slaughterhouse', 'team', 'ugglarp', 'sk', 'ne', 'southern', 'sweden']
#
#
# ===Tokens:===
# ['l', 'net', 'profit', 'whole', '2010', 'dropped', 'eur', '36', 'million', 'eur', '45', 'million', '2009']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'flexible', 'packaging', 'cutting', '48', 'jobs', 'unit', 'tampere', 'two', 'nastola', 'finland']
#
#
# ===Tokens:===
# ['total', 'number', 'shares', 'company', '585', '236', '987', 'innofactor', 'group', 'innofactor', 'offers', 'customers', 'comprehensive', 'solutions', 'microsoft', 'environment']
#
#
# ===Tokens:===
# ['markets', 'expect', 'heineken', 'sell', 'hartwall', 'whole', 'parts']
#
#
# ===Tokens:===
# ['asian', 'traffic', 'declined', '3', '4', 'per', 'cent']
#
#
# ===Tokens:===
# ['swot', 'analysis', 'one', 'method', 'categorization', 'weaknesses']
#
#
# ===Tokens:===
# ['risk', 'exposure', 'non', 'life', 'insurance', 'moving', '12', 'month', 'expenses', 'function', 'non', 'life', 'insurance', 'excluding', 'expenses', 'investment', 'management', 'expenses', 'services', 'rendered', 'non', 'life', 'insurance', 'investment', 'portfolio', 'allocation']
#
#
# ===Tokens:===
# ['private', 'equity', 'investor', 'capman', 'owner', 'finnish', 'lumene', 'cosmetics', 'company', 'planning', 'list', 'lumene']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '10', '5', 'january', 'sales', 'outside', 'finland', 'dropped', '17']
#
#
# ===Tokens:===
# ['project', 'expected', 'completed', '2009']
#
#
# ===Tokens:===
# ['capman', 'stockholm', 'headquartered', 'private', 'equity', 'firm', 'held', 'first', 'close', 'second', 'private', 'equity', 'real', 'estate', 'fund', 'continues', 'push', 'property', 'sector']
#
#
# ===Tokens:===
# ['24', 'hour', 'news', 'try', 'icis', 'news', 'www', 'icis', 'com', 'click', 'trial', 'icis', 'news']
#
#
# ===Tokens:===
# ['lifted', 'veil', 'various', 'types', 'customer', 'designs', 'phones', 'result', 'social', 'stereotyping', 'taken', 'fine', 'art']
#
#
# ===Tokens:===
# ['finnish', 'holding', 'company', 'panostaja', 'oyj', 'said', 'june', '12', '2007', 'signed', 'letter', 'intent', 'acquire', 'local', 'lahden', 'lampokasittely', 'oy', 'heatmasters', 'oy', 'active', 'heat', 'treatment', 'metals', 'total', '3', '1', 'mln', 'euro', '4', '1', 'mln']
#
#
# ===Tokens:===
# ['company', 'net', 'sales', '2009', 'totalled', 'meur', '307', '8', 'operating', 'margin', '13', '5', 'per', 'cent']
#
#
# ===Tokens:===
# ['barclays', 'poised', 'replace', 'sir', 'mike', 'rake', 'heads', 'exit']
#
#
# ===Tokens:===
# ['previously', 'company', 'expected', '2008', 'financial', 'performance', 'remain', 'level', '2008']
#
#
# ===Tokens:===
# ['currently', '100', 'global', 'fortune', '500', 'companies', 'using', 'ssh', 'security', 'solutions']
#
#
# ===Tokens:===
# ['business', 'units', 'investlesprom', 'group', 'cover', 'full', 'forest', 'industry', 'chain', 'group', 'owns', 'forests', 'sawmills', 'paper', 'pulp', 'mills', 'processing', 'plants']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '0', '9', 'mn', 'profit', 'eur', '2', '7', 'mn']
#
#
# ===Tokens:===
# ['reductions', 'implemented', 'mainly', 'course', 'first', 'half', '2009']
#
#
# ===Tokens:===
# ['growth', 'beer', 'consumption', 'took', 'place', 'far', 'east', 'latin', 'america', 'africa']
#
#
# ===Tokens:===
# ['tekla', 'structures', 'product', 'box', 'needed', 'made', 'recycled', 'material']
#
#
# ===Tokens:===
# ['merisatama', 'far', 'corners', 'world', 'asfaltti', 'osakeyhti', 'lemmink', 'inen', 'established', '1910', 'group', 'master', 'builders', 'helsinki', 'specialist', 'business', 'subcontractor']
#
#
# ===Tokens:===
# ['forecast', '2012', '3', '3']
#
#
# ===Tokens:===
# ['company', 'set', 'services', 'include', 'digital', 'printing', 'printing', 'preparation', 'offset', 'printing', 'treatment', 'services', 'send', 'services']
#
#
# ===Tokens:===
# ['seventy', 'three', 'also', 'extensive', 'training', 'products', 'built', 'latest', 'archestra', 'technologies', 'wonderware', 'system', 'platform']
#
#
# ===Tokens:===
# ['company', 'continuous', 'need', 'alloys', 'nickel', 'ferro', 'chrome', 'molybdenum', 'manganese', 'production', 'said', 'talvivaara']
#
#
# ===Tokens:===
# ['fish', 'content', 'nuggets', '85', 'fish', 'comes', 'canada', 'finland']
#
#
# ===Tokens:===
# ['adpnews', 'may', '4', '2010', 'finnish', 'cutlery', 'hand', 'tools', 'maker', 'fiskars', 'oyj', 'abp', 'hel', 'fisas', 'said', 'today', 'net', 'profit', 'declined', 'eur', '12', '9', 'million', 'usd', '17m', 'first', 'quarter', '2010', 'eur', '17', 'million', 'correspond']
#
#
# ===Tokens:===
# ['copper', 'lead', 'nickel', 'also', 'dropped', 'hbos', 'hbos', 'plummeted', '20', '70', '3', 'pence', 'saying', 'year']
#
#
# ===Tokens:===
# ['exel', 'board', 'directors', 'propose', 'dividend', '0', '2', 'euro', '0', '3', 'per', 'share', '2006', 'annual', 'general', 'meeting', 'april', '19', '2007']
#
#
# ===Tokens:===
# ['result', 'merger', 'largest', 'professional', 'electronics', 'telecommunications', 'technology', 'contract', 'manufacturing', 'center', 'finland', 'formed', 'sievi']
#
#
# ===Tokens:===
# ['aktia', 'forecasts', 'finland', 'inflation', '1', '1', '2010']
#
#
# ===Tokens:===
# ['russia', 'wants', 'utilise', 'huge', 'forest', 'reserves', 'different', 'way', 'done', 'far']
#
#
# ===Tokens:===
# ['decision', 'made', 'whether', 'group', 'agrees', 'import', 'estonian', 'meat', 'meat', 'products', 'finland', 'paper', 'added']
#
#
# ===Tokens:===
# ['financing', 'project', 'come', 'mainly', 'china']
#
#
# ===Tokens:===
# ['financial', 'statements', 'include', 'consolidated', 'financial', 'statements', 'group', 'board', 'directors', 'report', 'auditors', 'report', 'corporate', 'governance', 'statement']
#
#
# ===Tokens:===
# ['according', 'company', 'lay', 'offs', 'temporary']
#
#
# ===Tokens:===
# ['rsa', 'shares', 'closed', '156', '9', 'p', 'time', 'going', 'press']
#
#
# ===Tokens:===
# ['recruitment', 'related', 'relocation', 'stora', 'enso', 'research', 'operations', 'karlstad', 'central', 'sweden']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'bulletin', 'october', '24', '2006', '2', '00', 'p', 'aspo', 'systems', 'division', 'completed', 'statutory', 'negotiations', 'required', 'act', 'co', 'operation', 'within', 'undertakings', 'conducted', 'part', 'action', 'plan', 'launched', 'august']
#
#
# ===Tokens:===
# ['agreement', 'pfizer', 'funding', 'biotie', 'research', 'activities', 'pde10', 'phosphodiesterase', '10', 'inhibitor', 'program', 'since', 'start', 'late', '2006', 'sole', 'authority', 'develop', 'discovered', 'compounds']
#
#
# ===Tokens:===
# ['however', 'brokers', 'ratings', 'stock', 'differ']
#
#
# ===Tokens:===
# ['extraordinary', 'general', 'meeting', 'expected', 'take', 'place', 'later', '18', 'february', '2011']
#
#
# ===Tokens:===
# ['new', 'shares', 'entitle', 'holders', 'dividends', 'fiscal', '2006']
#
#
# ===Tokens:===
# ['swedish', 'telco', 'teliasonera', 'teaming', 'friends', 'swedish', 'organization', 'bullying', 'fight', 'bullying', 'children', 'teenagers', 'via', 'electronic', 'channels']
#
#
# ===Tokens:===
# ['purchase', 'price', 'disclosed']
#
#
# ===Tokens:===
# ['expanded', 'company', 'continue', 'called', 'newpage']
#
#
# ===Tokens:===
# ['mr', 'mcdonald', 'started', 'evening', 'set', 'featuring', 'hits', 'solo', 'career', 'doobie', 'brothers', 'years', 'selection', 'r', 'b', 'cover', 'songs', 'met', 'mixed', 'results']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'decreased', 'eur', '13', '8', 'mn', 'eur', '17', '1', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['department', 'store', 'division', 'sales', 'fell', '8', '6', 'eur', '140', '2', 'mn']
#
#
# ===Tokens:===
# ['scanfil', 'issued', 'profit', 'warning', '10', 'april', '2006']
#
#
# ===Tokens:===
# ['expansion', 'delivered', 'fourth', 'quarter', '2006']
#
#
# ===Tokens:===
# ['finnish', 'forestry', 'company', 'upm', 'kymmene', 'waste', 'management', 'company', 'lassila', 'tikanoja', 'said', 'jan', '30', 'planning', 'produce', 'ethanol', 'energy', 'commercial', 'industrial', 'waste']
#
#
# ===Tokens:===
# ['proline', 'plus', 'available', 'adjustable', 'single', 'multichannel', 'models', 'fixed', 'volume', 'single', 'channel', 'models', 'volume', 'ranges', '0', '1', 'micro', 'litres', '10', 'ml']
#
#
# ===Tokens:===
# ['year', 'personal', 'entertainment', 'plays', 'significant', 'role', 'determining', 'whether', 'fitness', 'facility', 'workout', 'experience', 'pleasurable', 'chore', 'said', 'brian', 'wilson', 'director', 'marketing', 'precor', 'entertainment', 'services', 'division']
#
#
# ===Tokens:===
# ['thanks', 'internet', 'consumers', 'compare', 'products', 'previously', 'finnish', 'companies', 'competitive']
#
#
# ===Tokens:===
# ['sold', 'tsla', 'puts', 'morning', 'closed', 'close', 'helps', 'pay', 'monthly', 'expenses']
#
#
# ===Tokens:===
# ['union', 'company', 'officials', 'return', 'calls', 'yesterday']
#
#
# ===Tokens:===
# ['company', 'give', 'palm', 'oil', 'altogether', 'however']
#
#
# ===Tokens:===
# ['according', 'honka', 'japan', 'managing', 'director', 'marko', 'saarelainen', 'honkarakenne', 'exports', '200', 'ready', 'made', 'log', 'houses', 'japan', 'year']
#
#
# ===Tokens:===
# ['production', 'liquidated', 'june', '2009', '325', 'employees', 'loose', 'jobs']
#
#
# ===Tokens:===
# ['use', 'case', 'dramatically', 'narrows', 'go', 'hot', 'ltd']
#
#
# ===Tokens:===
# ['currently', 'company', 'uses', 'eight', 'similar', 'reach', 'stackers', 'four', 'empty', 'container', 'handlers', 'konecranes']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'decreased', 'eur', '33', '8', 'mn', 'eur', '40', '8', 'mn', 'fourth', 'quarter', '2005']
#
#
# ===Tokens:===
# ['comprehensive', 'range', 'cut', 'length', 'slitting', 'services', 'allow', 'ruukki', 'particular', 'serve', 'light', 'engineering', 'customers', 'relocate', 'production', 'st', 'petersburg', 'area']
#
#
# ===Tokens:===
# ['natural', 'source', 'isoprene', 'tree', 'species', 'hevea', 'brasiliensis', 'also', 'known', 'rubber', 'tree']
#
#
# ===Tokens:===
# ['aspocomp', 'group', 'headquartered', 'helsinki', 'finland', 'develops', 'interconnection', 'solutions', 'electronics', 'industry']
#
#
# ===Tokens:===
# ['frost', 'sold', 'shares', '19', 'million', '6', '06', '7', '12', 'per', 'share', 'compared', 'friday', 'high', '11', '33', 'low', '10', '14']
#
#
# ===Tokens:===
# ['transaction', 'tikkurila', 'powder', 'coatings', 'related', 'operations']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'march', '15', 'jaakko', 'vilo', 'turku', 'finland', 'developed', 'panel', 'press']
#
#
# ===Tokens:===
# ['total', 'value', 'contract', 'eur', '8', 'million']
#
#
# ===Tokens:===
# ['elisa', 'commissioned', 'finland', 'poyry', 'telecom', 'oy', 'conduct', 'study', 'reception', 'estonia', 'largest', 'cities', 'besides', 'tallinn']
#
#
# ===Tokens:===
# ['solidium', 'holds', '5', '0', 'per', 'cent', 'shares', 'solidium', 'oy', 'acquired', '5', '0', 'per', 'cent', 'shares', 'tieto', 'corporation', 'approximately', 'eur', '58', 'million']
#
#
# ===Tokens:===
# ['september', 'alone', 'market', 'declined', '10', '2', 'percent', 'year', 'year', '19', '28', 'million', 'liters']
#
#
# ===Tokens:===
# ['potential', 'clients', 'include', 'public', 'administration', 'organizations', 'investing', 'utility', 'networks', 'services']
#
#
# ===Tokens:===
# ['last', 'july', 'group', 'said', 'intended', 'relocate', 'warehouse', 'office', 'space', 'loudeac', 'saint', 'marcel', 'morvillars', 'east', 'france', 'already', 'operates', 'hook', 'manufacturing', 'distribution', 'unit']
#
#
# ===Tokens:===
# ['would', 'premature', 'talk', 'dates', 'volume', 'investment', 'procedure', 'said']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'fell', 'eur', '0', '63', 'eur', '1', '71']
#
#
# ===Tokens:===
# ['duration', 'contract', '37', 'months']
#
#
# ===Tokens:===
# ['negotiations', 'concern', '246', 'salaried', 'senior', 'salaried', 'employees', 'scheduled', 'completed', 'six', 'weeks']
#
#
# ===Tokens:===
# ['following', 'divestment', 'fiskars', 'outdoor', 'unit', 'comprise', 'brands', 'gerber', 'silva', 'buster', 'focus', 'multi', 'tools', 'knives', 'compasses', 'mobile', 'lighting', 'pedometers', 'aluminium', 'boats']
#
#
# ===Tokens:===
# ['2009', 'kone', 'annual', 'net', 'sales', 'eur', '4', '7', 'billion', 'approximately', '34', '000', 'employees']
#
#
# ===Tokens:===
# ['objective', 'trading', 'shares', 'commence', 'may', '2', '2007']
#
#
# ===Tokens:===
# ['need', 'ready', 'window', 'opens', 'rosberg', 'said']
#
#
# ===Tokens:===
# ['group', 'revenue', '2009', 'amounted', 'eur', '70', 'million', 'company', 'currently', 'employs', 'approximately', '780', 'people']
#
#
# ===Tokens:===
# ['said', 'comptel', 'delivers', 'reliable', 'provisioning', 'activation', 'solutions', 'improve', 'fulfilment', 'processes', 'operators']
#
#
# ===Tokens:===
# ['strike', 'finnair', 'estimates', 'incur', 'net', 'loss', 'eur2m', 'eur2', '5', 'per', 'day']
#
#
# ===Tokens:===
# ['measures', 'result', 'weak', 'demand', 'shipbuilding', 'industry']
#
#
# ===Tokens:===
# ['share', 'transactions', 'part', 'company', 'strategy', 'relinquishing', 'assets', 'part', 'core', 'business']
#
#
# ===Tokens:===
# ['decision', 'french', 'court', 'relates', 'claims', 'raised', 'twenty', 'one', 'former', 'aspocomp', 'employees', 'company', 'said']
#
#
# ===Tokens:===
# ['report', 'oriola', 'kd', 'chief', 'executive', 'officer', 'eero', 'hautaniemi']
#
#
# ===Tokens:===
# ['swedish', 'subsidiary', 'holds', '1', '0', 'net', 'smelter', 'return', 'nsr', 'royalties', 'two', 'advanced', 'copper', 'projects', 'northern', 'sweden', 'viscaria', 'adak', 'projects', 'developed', 'avalon', 'minerals', 'ltd', 'asx', 'avi']
#
#
# ===Tokens:===
# ['atria', 'chose', 'delight', 'attract', 'consumers', '25', '45', 'age', 'group', 'atria', 'fresh', 'range', 'microwaveable', 'meals']
#
#
# ===Tokens:===
# ['according', 'swedish', 'authorities', 'traces', 'toxic', 'osmium', 'tetroxide', 'found', 'coast', 'per', 'meri', 'northernmost', 'part', 'gulf', 'bothnia']
#
#
# ===Tokens:===
# ['group', 'net', 'sales', '2007', 'eur683', '6']
#
#
# ===Tokens:===
# ['l', 'nnen', 'tehtaat', 'showed', 'loss', 'recently', 'started', 'streamlining', 'measures']
#
#
# ===Tokens:===
# ['basic', 'banking', 'activities', 'continued', 'normal']
#
#
# ===Tokens:===
# ['inventors', 'bylander', 'johan', 'ponten', 'fredrik', 'lundberg', 'jorgen']
#
#
# ===Tokens:===
# ['finnish', 'l', 'recoil', 'company', 'specialising', 'used', 'oil', 'regeneration', 'building', 'facility', 'hamina', 'finland', '2008']
#
#
# ===Tokens:===
# ['swedish', 'engineering', 'consultant', 'firm', 'etteplan', 'establish', 'unit', 'town', 'borl', 'nge', 'turn', 'month', 'march', 'april', '2008']
#
#
# ===Tokens:===
# ['city', 'cu', 'welcomes', 'dart', 'members', 'dallas', 'city', 'cu', 'welcomes', 'members', 'dart', 'fcu', 'merge', 'city', 'cu']
#
#
# ===Tokens:===
# ['germany', 'innovational', 'centers', 'united', 'focusing', 'companies', 'aim', 'use', 'technologies', 'development', 'new', 'kinds', 'activity', 'supporting', 'beginner', 'companies', 'entire', 'spectrum', 'services']
#
#
# ===Tokens:===
# ['mentioned', 'shareholders', 'suggest', 'monthly', 'salary', 'eur', '1', '400', 'would', 'paid', 'board', 'members', 'outside', 'company']
#
#
# ===Tokens:===
# ['mformation', 'provides', 'enhanced', 'management', 'applications', 'enabling', 'configuration', 'control', 'throughout', 'lifecycle']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2006', 'oko', 'banks', 'expects', 'operating', 'environment', 'banking', 'investment', 'services', 'remain', 'similar', 'january', 'september', '2006']
#
#
# ===Tokens:===
# ['roshan', 'net', 'sales', '2006', '191', 'million', 'ebitda', '66', '5', 'million']
#
#
# ===Tokens:===
# ['westend', 'ict', 'plc', 'new', '409', '665', '891', 'shares', 'increase', 'share', 'capital', 'eur', '2', '000', '000', 'based', 'resolutions', 'extraordinary', 'shareholders', 'meeting', '27', 'december', '2010', 'today', 'registered', 'trade', 'register']
#
#
# ===Tokens:===
# ['reduction', 'notice', 'applied', '17', 'people']
#
#
# ===Tokens:===
# ['aapl', '620', 'resistance', 'area']
#
#
# ===Tokens:===
# ['sweden', 'gallerix', 'accumulated', 'sek', 'denominated', 'sales', '1', 'eur', 'denominated', 'sales', '11']
#
#
# ===Tokens:===
# ['u', 'based', 'corp', 'talks', 'scandinavian', 'telecoms', 'company', 'teliasonera', 'sell', 'stake', 'uzbek', 'cellular', 'operator', 'coscom', 'executive', 'coscom', 'told', 'interfax']
#
#
# ===Tokens:===
# ['17', 'march', '2011', 'goldman', 'sachs', 'estimates', 'negative', 'prospects', 'norwegian', 'mobile', 'operations', 'norway', 'telenor', 'asa', 'osl', 'tel', 'sweden', 'teliasonera', 'ab', 'sto', 'tlsn', 'short', 'term']
#
#
# ===Tokens:===
# ['4', 'complete', 'name', 'shareholder', 'otto', 'henrik', 'bernhard', 'nyberg', '5', 'information', 'amount', 'shares', 'transferred', 'corresponds', '5', '68', 'total', 'number', 'shares', 'aspo', 'plc']
#
#
# ===Tokens:===
# ['altogether', 'finnair', 'canceled', '500', 'flights', 'strike']
#
#
# ===Tokens:===
# ['tikkurila', 'powder', 'coatings', '50', 'employees', 'four', 'paint', 'plants', 'generated', 'revenues', 'eur2', '4', 'usd3', '3', '2010']
#
#
# ===Tokens:===
# ['result', 'total', '82', 'employees', 'would', 'given', 'notice']
#
#
# ===Tokens:===
# ['barclays', 'plc', 'lse', 'barc', 'nyse', 'bcs', 'credit', 'agricole', 'sa', 'epa', 'aca', 'cagr']
#
#
# ===Tokens:===
# ['contract', 'comprises', 'log', 'handling', 'line', 'peeling', 'line', 'veneer', 'drying', 'grading', 'line']
#
#
# ===Tokens:===
# ['flurry', 'analytics', 'spokesperson', 'said', 'measuring', 'windows', 'phone', '7', 'data', 'weeks', 'firm', 'double', 'checked', 'data', 'make', 'sure', '66', 'per', 'cent', 'rise', 'aberration']
#
#
# ===Tokens:===
# ['expenditures', 'must', 'justified', 'pass', 'budget', 'approval', 'hurdles', 'believe', 'rop', 'model', 'help', 'make', 'easier', 'security', 'practitioners', 'make', 'business', 'case', 'acquiring', 'enabling', 'security', 'technologies', 'related', 'control', 'activities']
#
#
# ===Tokens:===
# ['ramirent', 'made', '18', 'million', 'kroons', 'eur', '1', '15', 'mln', 'loss', 'last', 'year', 'year', 'company', '7', '3', 'million', 'kroons', 'black']
#
#
# ===Tokens:===
# ['mercator', 'use', 'software', 'logistic', 'retail', 'wholesale', 'operations', 'slovenia', 'markets', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['full', 'function', 'pc', 'weighs', '1', '25', 'kilograms', 'measures', 'slightly', 'two', 'centimeters', 'thin']
#
#
# ===Tokens:===
# ['okmetic', 'board', 'directors', 'also', 'decided', 'new', 'share', 'ownership', 'program', 'directed', 'company', 'top', 'management']
#
#
# ===Tokens:===
# ['estonia', 'agriculture', 'minister', 'helir', 'valdor', 'seeder', 'finland', 'two', 'day', 'visit', 'course', 'meet', 'finnish', 'counterpart', 'sirkka', 'liisa', 'anttila']
#
#
# ===Tokens:===
# ['company', 'said', 'currently', 'french', 'distribution', 'unit', 'ragot', 'located', 'loudeac', 'normandy', 'distribution', 'unit', 'waterqueen', 'line', 'supplier', 'tortue', 'saint', 'marcel', 'mid', 'france', 'hook', 'manufacturing', 'unit', 'vmc', 'hook', 'distribution', 'unit', 'vmc', 'europe', 'morvillars']
#
#
# ===Tokens:===
# ['finnish', 'component', 'supplier', 'componenta', 'corporation', 'omx', 'helsinki', 'cth1v', 'said', 'monday', '16', 'june', 'changing', 'pricing', 'cycle', 'due', 'increase', 'raw', 'material', 'prices']
#
#
# ===Tokens:===
# ['profit', 'accounting', 'period', 'eur', '0', '3', 'mn']
#
#
# ===Tokens:===
# ['benefon', 'turn', 'salo', 'unit', 'b2b', 'business', 'unit', 'establish', 'b2c', 'business', 'unit', 'uk']
#
#
# ===Tokens:===
# ['indexes', 'include', 'top', 'companies', 'committed', 'sustainable', 'development']
#
#
# ===Tokens:===
# ['agreement', 'includes', 'entire', 'process', 'managing', 'mercator', 'supply', 'chain', 'regions', 'company', 'currently', 'present']
#
#
# ===Tokens:===
# ['corrensponds', '4', '628', 'percent', 'okmetic', 'share', 'capital', 'voting', 'rights']
#
#
# ===Tokens:===
# ['part', 'agreement', '10', 'employees', 'john', 'deere', 'forestry', 'documentation', 'functions', 'transfer', 'dokumentori', 'oy']
#
#
# ===Tokens:===
# ['zip', 'experts', 'warned', 'tuesday']
#
#
# ===Tokens:===
# ['sanoma', 'magazines', 'international', 'invite', 'shareholders', 'holding', 'approximately', '15', 'shares', 'sell', 'shares']
#
#
# ===Tokens:===
# ['stora', 'enso', 'oyj', 'said', 'second', 'quarter', 'result', 'would', 'fall', 'half', 'compared', 'period', '2007']
#
#
# ===Tokens:===
# ['upm', 'kymmene', 'www', 'upm', 'kymmene', 'com', 'produces', 'magazine', 'papers', 'newsprint', 'well', 'fine', 'specialty', 'papers', 'converting', 'materials', 'wood', 'products']
#
#
# ===Tokens:===
# ['rivals', 'say', 'qualcomm', 'fewer', 'patents', '3g', 'phones', 'earlier', 'versions', 'lower', 'rates']
#
#
# ===Tokens:===
# ['digia', 'also', 'set', 'two', 'subsidiaries', 'digia', 'norway', 'digia', 'usa', 'inc']
#
#
# ===Tokens:===
# ['according', 'shipping', 'company', 'viking', 'line', 'eu', 'decision', 'significant', 'financial', 'impact']
#
#
# ===Tokens:===
# ['total', 'value', 'project', 'eur53m', 'including', 'plots', 'transferred', 'atria']
#
#
# ===Tokens:===
# ['718', '430', 'new', 'series', 'shares', 'become', 'subject', 'trading', 'helsinki', 'stock', 'exchange', 'main', 'list', 'together', 'old', 'series', 'shares', 'july', '3', '2006']
#
#
# ===Tokens:===
# ['development', 'technological', 'park', 'specialize', 'telecommunications', 'information', 'technologies', 'part', 'state', 'program', 'formation', 'technoparks', 'hi', 'tech', 'sectors', 'russia']
#
#
# ===Tokens:===
# ['rad', 'charts', 'flashing', 'oversold']
#
#
# ===Tokens:===
# ['poyry', 'plccompany', 'announcement', '10', 'december', '2010', '4', '10', 'p', 'pursuant', 'poyry', 'plc', 'stock', 'option', 'program', '2004', '63', '792', 'new', 'shares', 'company', 'subscribed', 'since', '27', 'october', '2010', 'stock', 'options', '2004b']
#
#
# ===Tokens:===
# ['markets', 'almost', 'completely', 'controlled', 'three', 'banks', 'nordea', 'op', 'bank', 'group', 'sampo']
#
#
# ===Tokens:===
# ['offers', 'advanced', 'machinery', 'maintenance', 'process', 'development', 'services', 'pulp', 'paper', 'industry', 'northern', 'china']
#
#
# ===Tokens:===
# ['financialwire', 'tm', 'press', 'release', 'service', 'receives', 'compensation', 'news', 'opinions', 'distributions']
#
#
# ===Tokens:===
# ['total', 'headcount', 'reduction', '50', 'persons', 'company', 'said']
#
#
# ===Tokens:===
# ['order', 'valued', 'usd12', '2']
#
#
# ===Tokens:===
# ['elite', 'residence', 'tower', 'new', 'development', 'tameer', 'located', 'heart', 'dubai', 'marina']
#
#
# ===Tokens:===
# ['cut', 'bring', 'outdoors', 'birch', 'branch', 'coasters']
#
#
# ===Tokens:===
# ['country', 'switzerland', 'sector', 'pharmaceuticals', 'target', 'synosia', 'therapeutics', 'holding', 'ag', 'buyer', 'biotie', 'therapies', 'corp', 'deal', 'size', 'usd', '129', '4', 'type', 'corporate', 'acquisition', 'financing', 'stock', 'status', 'closed']
#
#
# ===Tokens:===
# ['timo', 'penttila', 'appointed', 'new', 'manager', 'responsible', 'asset', 'management', 'nordea', 'institutional', 'customers', 'finland']
#
#
# ===Tokens:===
# ['order', 'comprises', 'production', 'lines', 'plywood', 'mill', 'company', 'said', 'statement', 'received', 'lesprom', 'network']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'nearly', 'eur', '1', '7', 'mn', 'however']
#
#
# ===Tokens:===
# ['met', 'located', 'central', 'business', 'district', 'cbd', 'bangkok']
#
#
# ===Tokens:===
# ['teollisuuden', 'voima', 'oyj', 'finnish', 'utility', 'known', 'tvo', 'said', 'shortlisted', 'mitsubishi', 'heavy', 'eu', 'apwr', 'model', 'along', 'reactors', 'areva', 'toshiba', 'corp', 'ge', 'hitachi', 'nuclear', 'energy', 'korea', 'hydro', 'nuclear', 'power', 'co']
#
#
# ===Tokens:===
# ['pharmaceuticals', 'belgium', 'brand', 'new', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'pharmaceutical', 'market', 'belgium']
#
#
# ===Tokens:===
# ['2003', 'emphasis', 'kyro', 'strategy', 'glaston', 'growth']
#
#
# ===Tokens:===
# ['according', 'original', 'merger', 'plan', 'scanfil', 'would', 'get', '79', 'stake', 'combined', 'business']
#
#
# ===Tokens:===
# ['profitability', 'ebit', '13', '6', 'compared', '14', '3', 'q2', '2009']
#
#
# ===Tokens:===
# ['arena', 'partners', 'oy', 'development', 'company', 'electronic', 'business']
#
#
# ===Tokens:===
# ['curators', 'divided', 'material', 'eight', 'themes']
#
#
# ===Tokens:===
# ['new', 'production', 'lines', 'novator', 'mill', 'veliky', 'ustjug', 'vologda', 'oblast', 'sveza', 'change', 'current', '1', '5', '1', '5', 'birch', 'plywood', 'production', 'targeting', 'domestic', 'market', 'produce', '1', '5', '3', '0', 'overlaid', 'birch', 'plywood', 'global', 'market']
#
#
# ===Tokens:===
# ['1411', 'cet', 'arcelormittal', 'lost', '7', '26', 'eur', '17', '38', 'euronext', 'paris', 'coming', 'lead', 'blue', 'chip', 'fallers']
#
#
# ===Tokens:===
# ['rights', 'reserved']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '6', '7', 'mn', 'eur', '7', '2', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['operating', 'loss', 'pulp', 'paper', 'machinery', 'unit', 'eur', '3mn', 'september', '2007', 'august', '2008', 'compared', 'profit', 'eur', '3', '7', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['ruukki', 'group', 'calculates', 'lost', 'eur', '4mn', 'failed', 'project']
#
#
# ===Tokens:===
# ['proha', 'plc', 'euronext', '7327', 'announced', 'today', '19', 'may', 'fully', 'owned', 'subsidiary', 'safran', 'software', 'solutions', 'agreed', 'sell', '49', 'share', 'safran', 'north', 'america', 'llc', 'sna', 'holding', 'investment', 'group', 'based', 'norway']
#
#
# ===Tokens:===
# ['made', 'long', 'term', 'investments', 'developing', 'system', 'implementation', 'model']
#
#
# ===Tokens:===
# ['unit', 'planned', 'operational', 'second', 'half', '2007', 'full', 'stream', '2008']
#
#
# ===Tokens:===
# ['trip', 'maintains', 'neutral', 'rating', 'jp', 'morgan', 'pt', 'cut', '61', '66']
#
#
# ===Tokens:===
# ['sales', 'mid', 'strength', 'beer', 'decreased', '40']
#
#
# ===Tokens:===
# ['marimekko', 'aims', 'expand', 'distribution', 'network', 'primarily', 'increasing', 'number', 'concept', 'stores', 'shop', 'shops']
#
#
# ===Tokens:===
# ['return', 'capital', 'employed', 'roce', 'negative', '2', '3', 'compared', '11', '3', '2007']
#
#
# ===Tokens:===
# ['hkscan', 'headquartered', 'turku', 'finland', 'leading', 'northern', 'european', 'food', 'group', '10', '000', 'employees', 'nine', 'countries']
#
#
# ===Tokens:===
# ['maximum', '666', '104', 'new', 'shares', 'subscribed', 'exercising', 'b', 'options', '2004', 'stock', 'option', 'plan']
#
#
# ===Tokens:===
# ['two', 'contracts', 'turntable', 'anode', 'vibrocompactors', 'delivered', 'gansu', 'hualu', 'aluminum', 'co', 'ltd', 'another', 'unnamed', 'costumer']
#
#
# ===Tokens:===
# ['addus', 'services', 'include', 'personal', 'care', 'assistance', 'activities', 'daily', 'living', 'skilled', 'nursing', 'rehabilitative', 'therapies', 'adult', 'day', 'care']
#
#
# ===Tokens:===
# ['mr', 'koistinen', 'joins', 'nokia', 'siemens', 'networks', 'held', 'various', 'senior', 'sales', 'management', 'business', 'development', 'positions', 'since', '1997']
#
#
# ===Tokens:===
# ['pentik', 'inen', 'emphasises', 'internet', 'contents', 'media', 'houses', 'provide', 'free', 'forever']
#
#
# ===Tokens:===
# ['update', '1', 'meggitt', 'reiterates', 'annual', 'outlook', 'tough', '2014']
#
#
# ===Tokens:===
# ['new', 'chairman', 'board', 'directors', 'mr', 'chaim', 'katzman', 'give', 'presentation', 'answer', 'questions']
#
#
# ===Tokens:===
# ['transaction', 'herttaassa', 'holding', 'alma', 'media', 'fallen', 'flagging', 'limit', '5']
#
#
# ===Tokens:===
# ['april', '2010', 'olvi', 'range', 'ciders', 'expand', 'strawberry', 'rhubarb', 'apple', 'pear', 'cider', 'green', 'bottles', 'new', 'shape']
#
#
# ===Tokens:===
# ['kemira', 'headquartered', 'helsinki', 'finland', 'international', 'chemicals', 'group', 'comprising', 'business', 'areas', 'kemira', 'pulp', 'paper', 'kemira', 'water', 'kemira', 'specialty', 'kemira', 'coatings']
#
#
# ===Tokens:===
# ['according', 'gallup', 'food', 'farm', 'facts', 'beef', 'consumption', 'totaled', '99mn', 'kilos', 'finland', '2007']
#
#
# ===Tokens:===
# ['nokia', 'inaugurated', 'manufacturing', 'plant', 'near', 'chennai', '11', 'mar', '2006']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'denies', 'reports', 'starwood', 'merger', 'talks']
#
#
# ===Tokens:===
# ['sales', 'fell', 'abroad', 'increased', 'finland']
#
#
# ===Tokens:===
# ['sanoma', 'corporation', 'wants', 'new', 'better', 'frequency', 'helsinki', 'metropolitan', 'area']
#
#
# ===Tokens:===
# ['economic', 'development', 'trade', 'ministry', 'industry', 'energy', 'ministry', 'along', 'kostroma', 'regional', 'administration', 'russian', 'lumberman', 'timber', 'exporters', 'union', 'carrying', 'work', 'acquire', 'investment', 'construction', 'pulp', 'paper', 'mill', 'neya', 'since', '2003']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur', '30', '6', 'million', 'eur', '38', '3', 'million', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['said', 'losing', 'five', 'families', 'month', 'economy', 'many', 'make', 'alternative', 'arrangements', 'save', 'money']
#
#
# ===Tokens:===
# ['honkarakenne', 'starts', 'production', 'need', 'partner', 'sawmill', 'operations']
#
#
# ===Tokens:===
# ['acquisition', 'teliasonera', 'would', 'france', 'telecom', 'biggest', 'since', '2000', 'purchase', 'orange', 'plc', '27', '8', 'billion', '55', '1', 'billion', 'would', 'create', 'world', 'fourth', 'largest', 'telecom', 'company', 'behind', 'inc', 'verizon', 'communications', 'inc', 'ntt', 'corp', 'japan']
#
#
# ===Tokens:===
# ['finnish', 'developer', 'manufacturer', 'mobile', 'phone', 'chargers', 'salcomp', 'plc', 'omx', 'helsinki', 'sal1v', 'wednesday', '19', 'november', 'lowered', 'full', 'year', 'net', 'sales', 'estimate']
#
#
# ===Tokens:===
# ['meantime', 'ceo', 'duties', 'assumed', 'outotec', 'deputy', 'ceo', 'seppo', 'rantakari']
#
#
# ===Tokens:===
# ['way', 'industry', 'starting', 'point', 'consumers', 'needs']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'loss', 'eur0', '06']
#
#
# ===Tokens:===
# ['loss', 'financial', 'items', 'totalled', 'eur', '9', '7', 'mn', 'compared', 'profit', 'eur', '1', '3', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['building', 'house', 'example', 'respecta', 'oy', 'jyvaskyla', 'premises', 'well', 'companies', 'announced', 'later', 'says', 'samuel', 'koivisto', 'director', 'technopolis', 'operations', 'jyvaskyla']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'dec', '19', 'united', 'states', 'patent', '7', '853', '620', 'issued', 'dec', '14', 'assigned', 'nokia', 'corp', 'espoo', 'finland']
#
#
# ===Tokens:===
# ['north', 'rhine', 'westphalia', 'issue', 'benchmark', '5', 'year', 'fixed', 'rate', 'deal', 'euros']
#
#
# ===Tokens:===
# ['report', 'full', 'year', 'results', 'august', '22']
#
#
# ===Tokens:===
# ['pge', 'belchatow', 'runs', '4', '44', 'gw', 'belchatow', 'coal', 'fired', 'power', 'plant', 'fortum', 'intentions', 'start', 'ccs', 'demonstration', 'project', 'jointly', 'teollisuuden', 'voima', 'oyj', 'tvo', 'another', 'finnish', 'utility', 'jointly', 'owned', '565mw', 'meri', 'pori', 'coal', 'fired', 'facility']
#
#
# ===Tokens:===
# ['share', 'issue', 'derogating', 'pre', 'emptive', 'right', 'shareholders', 'comprising', 'six', 'million', 'new', 'shares', 'market', 'price', 'offered', 'subscription', 'shareholders', 'holders', 'capital', 'notes', 'professional', 'clients']
#
#
# ===Tokens:===
# ['german', 'commerzbank', 'ag', 'hamburg', 'branch', 'us', 'jp', 'morgan', 'nyse', 'jpm', 'participated', 'arrangers', 'dutch', 'ing', 'ams', 'inga', 'co', 'arranger']
#
#
# ===Tokens:===
# ['process', 'products', 'orders', 'installation', 'separation', 'filtration', 'equipment', 'three', 'natural', 'gas', 'pipeline', 'projects', 'china', 'south', 'america', 'saudi', 'arabia']
#
#
# ===Tokens:===
# ['report', 'examines', 'medical', 'equipment', 'business', 'structure', 'operations', 'history', 'products', 'provides', 'analysis', 'key', 'medical', 'equipment', 'revenue', 'lines']
#
#
# ===Tokens:===
# ['net', 'profit', 'three', 'months', 'march', '31', 'fell', 'x20ac', '103', 'million', 'us', '165', 'million', 'x20ac', '131', 'million', 'year', 'earlier', 'finnish', 'company', 'said']
#
#
# ===Tokens:===
# ['honkarakenne', 'oyj', 'world', 'leading', 'manufacturer', 'genuine', 'wooden', 'homes', 'sponsoring', 'finnish', 'crosscountry', 'skier', 'virpi', 'kuitunen', 'next', 'three', 'years']
#
#
# ===Tokens:===
# ['reported', 'operating', 'margin', 'negative', '5', '9']
#
#
# ===Tokens:===
# ['ahlstrom', 'corporation', 'seppo', 'parvi', 'cfo', 'distribution', 'main', 'media', 'www', 'ahlstrom', 'com', 'ahlstrom', 'brief', 'ahlstrom', 'global', 'leader', 'development', 'manufacture', 'marketing', 'high', 'performance', 'nonwovens', 'specialty', 'papers']
#
#
# ===Tokens:===
# ['finland', 'alma', 'media', 'focus', 'quality', 'developing', 'chain', 'operations']
#
#
# ===Tokens:===
# ['company', 'share', 'quoted', 'nasdaq', 'omx', 'helsinki', 'rautaruukki', 'oyj', 'rtrks']
#
#
# ===Tokens:===
# ['warmly', 'welcome']
#
#
# ===Tokens:===
# ['sale', 'price', 'disclosed']
#
#
# ===Tokens:===
# ['site', 'cover', 'six', 'hectares']
#
#
# ===Tokens:===
# ['details', 'provided']
#
#
# ===Tokens:===
# ['technology', 'park', 'built', 'near', 'st', 'petersburg', 'based', 'pulkovo', 'airport']
#
#
# ===Tokens:===
# ['route', 'helsinki', 'finland', 'tallinn', 'estonia', 'cargo', 'volumes', 'increased', '36', 'cargo', 'volumes', 'finland', 'sweden', 'fell', '9']
#
#
# ===Tokens:===
# ['mylan', 'appoints', 'ranjan', 'ray', 'chaudhuri', 'global', 'commercial', 'lead', 'mylan']
#
#
# ===Tokens:===
# ['parties', 'also', 'agreed', 'l', 'nnen', 'tehtaat', 'right', 'sell', 'remaining', 'shares', 'suomen', 'rehu', 'hankkija', 'maatalous', '15', 'months', 'purchase', 'majority', 'holding', 'earliest']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'wood', 'products', 'technology', 'supplier', 'raute', 'oyj', 'hel', 'rutav', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '4', '7', 'million', 'usd', '6', '1', '2008', 'eur', '6', '6', 'million', '2007']
#
#
# ===Tokens:===
# ['metso', 'global', 'supplier', 'sustainable', 'technology', 'services', 'mining', 'construction', 'power', 'generation', 'automation', 'recycling', 'pulp', 'paper', 'industries']
#
#
# ===Tokens:===
# ['financial', 'terms', 'disclosed']
#
#
# ===Tokens:===
# ['first', 'two', 'project', 'phases', 'expected', 'completed', 'end', '2012']
#
#
# ===Tokens:===
# ['stora', 'enso', 'global', 'paper', 'packaging', 'wood', 'products', 'company', 'neste', 'oil', 'finnish', 'company', 'engaged', 'refining', 'marketing', 'oil', 'inaugurated', 'demonstration', 'plant', 'varkaus', 'finland', 'biomass', 'liquids', 'production', 'utilizing', 'forestry', 'residues']
#
#
# ===Tokens:===
# ['implementation', 'important', 'operator', 'since', 'launch', 'fixed', 'mobile', 'convergence', 'service', 'brazil', 'see', 'brazil', '8', 'may', '2006']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'eur', '4', '0', 'mn', 'eur', '4', '9', 'mn']
#
#
# ===Tokens:===
# ['construction', 'scheduled', 'start', 'april', 'june', '2007', 'completed', 'early', '2008']
#
#
# ===Tokens:===
# ['group', 'revenue', 'amounts', 'eur', '80', 'million', 'half', 'accounted', 'exports']
#
#
# ===Tokens:===
# ['layoff', 'talks', 'first', 'announced', 'august']
#
#
# ===Tokens:===
# ['beers', 'olvi', 'retained', 'market', 'position']
#
#
# ===Tokens:===
# ['eps', 'dropped', 'eur0', '2', 'eur0', '3']
#
#
# ===Tokens:===
# ['finland', 'based', 'company', 'says', 'move', 'existing', '260', '000', 'square', 'foot', 'facility', 'september']
#
#
# ===Tokens:===
# ['seem', 'enough', 'hours', 'day', 'pekkarinen']
#
#
# ===Tokens:===
# ['according', 'arokarhu', 'purchases', 'scanned', 'cash', 'register', 'computer', 'disappeared', 'total', 'sum', 'key', 'pressed']
#
#
# ===Tokens:===
# ['nordstjernan', 'make', 'offer', 'approximately', 'one', 'month', 'september', '2007']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '3', '2', 'mn', 'compared', 'profit', 'eur', '7', '2', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['opportunity', 'available', 'employees', 'however']
#
#
# ===Tokens:===
# ['according', 'heikkil', 'refreshment', 'energy', 'soon', 'found', 'soft', 'drinks', 'also', 'finland']
#
#
# ===Tokens:===
# ['dividend', 'come', 'top', '0', '45', 'eur', 'shares', '0', '43', 'k', 'shares', 'already', 'paid', 'last', 'year', 'accounts']
#
#
# ===Tokens:===
# ['finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'temporarily', 'lay', '200', 'people', 'maximum', '90', 'day', 'finland', 'aiming', 'achieve', 'cost', 'savings', 'eur', '1', '7', 'million', 'usd', '2m', 'second', 'half', '2010']
#
#
# ===Tokens:===
# ['testament', 'quality', 'lte', 'solution', 'commitment', 'japanese', 'market', 'added']
#
#
# ===Tokens:===
# ['according', 'notification', 'holdings', 'ameriprice', 'inc', 'group', 'companies', 'total', '808', '973', 'shares', 'represent', '3', '582', 'tekla', 'shares', 'voting', 'rights']
#
#
# ===Tokens:===
# ['marketing', 'use', 'tikkurila', 'existing', 'infra', 'structure', 'local', 'knowledge', 'russia']
#
#
# ===Tokens:===
# ['authorisation', 'force', 'end', 'next', 'annual', 'general', 'meeting', 'repeals', 'authorisation', 'acquire', 'shares', 'given', 'general', 'meeting', 'held', 'april', '4', '2007']
#
#
# ===Tokens:===
# ['tulikivi', 'manufactures', 'heat', 'retaining', 'soapstone', 'ceramic', 'fireplaces', 'well', 'natural', 'stone', 'products', 'utility', 'ceramics']
#
#
# ===Tokens:===
# ['choose', 'giant', 'countdown', 'red', 'head', 'rainbow', 'trout', 'giant', 'shad', 'rap', 'perch', 'color']
#
#
# ===Tokens:===
# ['whats', 'lulu', 'numbers', 'looked', 'good', 'great', 'good', 'think', 'conference', 'call', 'instill', 'confidence']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'corporation', 'makes', 'wipes', 'nonwovens', 'flexible', 'packaging', 'plant', 'near', 'warsaw', 'poland', 'makes', 'flexible', 'packaging']
#
#
# ===Tokens:===
# ['finnish', 'retail', 'software', 'developer', 'aldata', 'solution', 'oyj', 'reported', 'net', 'loss', '11', '7', 'mln', 'euro', '17', '2', 'mln', '2007', 'versus', 'net', 'profit', '2', '5', 'mln', 'euro', '3', '7', 'mln', '2006']
#
#
# ===Tokens:===
# ['f', 'secure', 'internet', 'security', '2010', 'security', 'service', 'surfing', 'web', 'online', 'banking', 'shopping', 'e', 'mail', 'online', 'activities']
#
#
# ===Tokens:===
# ['order', 'included', 'metso', 'fourth', 'quarter', '2007', 'order', 'backlog']
#
#
# ===Tokens:===
# ['latin', 'america', 'currently', 'accounts', 'approximately', '40', 'sales', 'tecnotree', 'company', 'president', 'ceo', 'eero', 'mertano', 'recently', 'told', 'bnamericas']
#
#
# ===Tokens:===
# ['effect', 'may', 'remain', 'short', 'lived', 'however']
#
#
# ===Tokens:===
# ['ebrd', 'using', 'funds', 'provide', '21', '6', 'mln', 'loan', 'b', 'portion', '10', 'mln', 'euros', 'syndicated', 'two', 'finnish', 'commercial', 'banks', 'nordea', 'bank', 'finland', 'plc', '7', '7', 'mln', 'euros', 'pohjola', 'bank', 'plc', '2', '3', 'mln', 'euros']
#
#
# ===Tokens:===
# ['parties', 'therefore', 'agreed', 'leave', 'avena', 'deal']
#
#
# ===Tokens:===
# ['april', '2005', 'neste', 'separated', 'parent', 'company', 'finnish', 'energy', 'company', 'fortum', 'became', 'listed', 'helsinki', 'stock', 'exchange']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', '2005', 'amounted', 'loss', 'eur1', '26']
#
#
# ===Tokens:===
# ['result', 'transactions', 'aggregate', 'holdings', 'burrill', 'life', 'sciences', 'capital', 'fund', 'l', 'p', 'decreased', '5', 'per', 'cent', 'total', 'number', 'shares', 'votes', 'company']
#
#
# ===Tokens:===
# ['1', 'april', '2007', 'cencorp', 'employees', 'territory']
#
#
# ===Tokens:===
# ['however', 'offering', 'probably', 'made', 'current', 'valuation', 'partly', 'derives', 'deal', 'company', 'merged', 'stock', 'market', 'shell']
#
#
# ===Tokens:===
# ['electricity', 'consumption', 'grows', 'higher', 'frequencies']
#
#
# ===Tokens:===
# ['contract', 'value', 'amounts', 'eur11m', 'company', 'added']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '5', '2', 'mn', 'compared', 'loss', 'eur', '3', '4', 'mn', 'corresponding', 'period', '2008', '2009']
#
#
# ===Tokens:===
# ['neste', 'shipping', 'likely', 'remain', 'finnish', 'oil', 'sector', 'transports', 'significant', 'emergency', 'supply']
#
#
# ===Tokens:===
# ['vehvilainen', 'currently', 'chief', 'operating', 'officer', 'nokia', 'siemens', 'networks', 'join', 'finnair', '5', 'january', '2010', 'take', 'ceo', 'effective', '1', 'february', '2010']
#
#
# ===Tokens:===
# ['emsa', 'deputy', 'chairman', 'board', 'juri', 'lember', 'told', 'bns', 'wednesday', 'first', 'time', 'heard', 'strike', 'swedish', 'side', 'informed', 'estonian', 'union', 'yet']
#
#
# ===Tokens:===
# ['bridge', 'part', 'highway', '14', 'development', 'project']
#
#
# ===Tokens:===
# ['potential', 'acquirer', 'cencorp', 'corporation', 'related', 'entity', 'sav', 'owing', 'sav', 'cencorp', 'subsidiary', 'finnish', 'savcor', 'group', 'oy']
#
#
# ===Tokens:===
# ['elcoteq', 'global', 'service', 'offering', 'covers', 'entire', 'lifecycle', 'products', 'product', 'development', 'market', 'services']
#
#
# ===Tokens:===
# ['financial', 'details', 'n', 'disclosed']
#
#
# ===Tokens:===
# ['counter', 'competitor', 'strengths', 'target', 'weaknesses']
#
#
# ===Tokens:===
# ['amendment', 'incur', 'additional', 'costs']
#
#
# ===Tokens:===
# ['project', '2', 'x', '600', 'mw', 'coal', 'fired', 'power', 'plant', 'located', '420', 'km', 'south', 'hanoi', 'company', 'said']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['event', 'also', 'viewed', 'live', 'webcast', 'www', 'cargotec', 'com']
#
#
# ===Tokens:===
# ['building', 'house', 'product', 'development', 'test', 'laboratories']
#
#
# ===Tokens:===
# ['boomeranger', 'boats', 'oy', 'specialises', 'boat', 'building', 'designs', 'manufactures', 'sells', 'customised', 'rigid', 'inflatable', 'boats', 'rib', 'primarily', 'baltic', 'sea', 'market']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '4', '0', 'mn', 'compared', 'profit', 'eur', '8', '6', 'mn', 'second', 'quarter', '2008']
#
#
# ===Tokens:===
# ['stora', 'enso', 'target', 'cut', 'eur', '4', '85', 'eur', '5', '55', 'holmen', 'target', 'sek', '135', 'sek', '150']
#
#
# ===Tokens:===
# ['finnish', 'investor', 'scanfil', 'oyj', 'hel', 'scf1v', 'said', 'last', 'friday', 'bought', '57', 'million', 'shares', '32', '96', 'norwegian', 'contract', 'electronics', 'manufacturer', 'kitron', 'asa', 'osl', 'kit', 'nok', '143', '9', 'million', 'usd', '24', '4', 'eur', '18', '1']
#
#
# ===Tokens:===
# ['annual', 'report', 'contains', 'financial', 'statements', 'consolidated', 'financial', 'statements', 'report', 'board', 'directors', 'auditor', 'report']
#
#
# ===Tokens:===
# ['sales', 'volume', 'coca', 'cola', 'market', 'share', 'decreased', '2', '2', '24', '2']
#
#
# ===Tokens:===
# ['based', 'negotiations', 'personnel', '20', 'indicated', 'willingness', 'move', 'new', 'location']
#
#
# ===Tokens:===
# ['company', 'transportation', 'business', 'conducted', 'florida', 'rock', 'tank', 'lines', 'southeastern', 'transportation', 'company', 'concentrating', 'hauling', 'motor', 'carrier', 'liquid', 'dry', 'bulk', 'commodities']
#
#
# ===Tokens:===
# ['according', 'hk', 'ruokatalo', 'almost', 'meat', 'used', 'company', 'comes', 'finland']
#
#
# ===Tokens:===
# ['order', 'consists', 'capacity', 'expansion', 'maintenance', 'services', 'new', 'charging', 'functionality', 'company', 'said']
#
#
# ===Tokens:===
# ['paper', 'company', 'real', 'calculated', '100', '000', 'biscuit', 'cartons', 'made', 'using', '25gsm', 'lighter', 'board', 'co2', 'saved', 'course', '12', 'months', 'would', 'equal', 'generated', 'driving', '1', '000', 'km', 'car']
#
#
# ===Tokens:===
# ['key', 'level', 'watch', 'fb', 'today', '25', '53', 'watching', 'see', 'hold', 'support', 'http', 'stks', 'co', 'boh4']
#
#
# ===Tokens:===
# ['part', 'agreement', 'aspocomp', 'also', 'give', 'meadville', '10', 'pct', 'slice', 'subsidiary', 'operating', 'oulu', 'finland']
#
#
# ===Tokens:===
# ['original', 'contract', 'signed', 'last', 'summer']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'components', 'supplier', 'componenta', 'december', '26', '2006', 'applied', 'approval', 'turkish', 'capital', 'markets', 'board', 'launch', 'mandatory', 'offer', 'remaining', 'shares', 'iron', 'aluminium', 'castings', 'producer', 'doktas', 'dokumculuk']
#
#
# ===Tokens:===
# ['cargo', 'traffic', 'fell', '1', 'year', 'year', '8', '561', 'tonnes', 'september', '2009']
#
#
# ===Tokens:===
# ['net', 'sales', 'kyro', 'main', 'business', 'area', 'glaston', 'technologies', 'manufacturer', 'glass', 'processing', 'machines', 'decreased', 'eur', '161', '5', 'mn', 'eur', '164', '1', 'mn', 'january', 'september', '2005']
#
#
# ===Tokens:===
# ['ab', 'inbev', 'sell', 'sab', 'assets', 'seeks', 'eu', 'deal', 'approval']
#
#
# ===Tokens:===
# ['market', 'share', '6', 'percent', 'according', 'ac', 'nielsen', '2008', 'data']
#
#
# ===Tokens:===
# ['salcomp', 'charger', 'manufacturing', 'plant', 'india', 'located', 'nokia', 'telecom', 'park', 'state', 'tamil', 'nadu', 'eastern', 'part', 'india']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', 'eur', '31', '6', 'mn', 'eur', '50', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['veidekke', 'headquartered', 'oslo', 'norway', 'scandinavian', 'construction', 'property', 'development', 'group', '6', '350', 'employees', 'norway', 'sweden', 'denmark', 'annual', 'turnover', 'nok16', '4', 'bn']
#
#
# ===Tokens:===
# ['shares', 'subscribed', 'eligible', 'trade', 'following', 'day', 'registration']
#
#
# ===Tokens:===
# ['erkki', 'jarvinen', 'president', 'rautakirja', 'head', 'sanoma', 'trade', 'division', 'leave', 'current', 'tasks', 'spring', '2009', 'similar', 'position', 'outside', 'sanoma', 'group']
#
#
# ===Tokens:===
# ['agreement', 'larox', 'transfer', '10', 'employees', 'within', 'engineering', 'documentation', 'related', 'delivery', 'projects', 'product', 'maintenance', 'finland', 'etteplan', 'january', '1', '2007']
#
#
# ===Tokens:===
# ['2007', 'etteplan', 'reported', 'turnover', 'eur125', '2']
#
#
# ===Tokens:===
# ['eu', 'commission', 'said', 'earlier', 'fined', 'thyssenkrupp', 'united', 'technologies', 'corp', 'otis', 'schindler', 'ag', 'kone', 'oyj', 'total', '992', '3', 'mln', 'eur', 'alleged', 'cartel', 'activity', 'lift', 'market', 'going', 'back', 'twelve', 'years']
#
#
# ===Tokens:===
# ['ruukki', 'delivery', 'includes', 'steel', 'structures', 'including', 'installation', 'krakeroy', 'bascule', 'bridge', 'steel', 'piles', 'bridge', 'foundations']
#
#
# ===Tokens:===
# ['based', 'design', 'previous', 'handsets', 'nokia', 'e72', 'nokia', 'e63', 'symbian', 'based', 'model', 'promised', 'offer', 'direct', 'access', '90', 'per', 'cent', 'world', 'corporate', 'email', 'mail', 'exchange', 'ibm', 'lotus', 'notes', 'traveler']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'oct', '6', 'united', 'states', 'patent', '7', '804', '288', 'issued', 'sept', '28', 'assigned', 'vacon', 'oyj', 'vaasa', 'finland']
#
#
# ===Tokens:===
# ['reason', 'st', 'petersburg', 'status', 'capital', 'one', 'participants', 'meeting', 'quoted', 'chikunov', 'saying']
#
#
# ===Tokens:===
# ['negotiations', 'started', 'neste', 'oil', 'anticipated', '450', 'people', 'would', 'affected']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '30', '2', 'mn', 'eur', '43', '8', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['total', 'investment', 'necessary', 'eur40m', 'company', 'estimated']
#
#
# ===Tokens:===
# ['helsinki', 'based', 'componenta', 'bought', 'turkish', 'listed', 'company', 'doktas', 'october', '2006', '89', 'million', 'euros', 'making', 'largest', 'finnish', 'investment', 'turkey', 'date']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '3', '8', 'mn', 'eur', '4', '5', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['deliveries', 'start', 'second', 'half', '2007', 'start', 'mill', 'scheduled', '2008']
#
#
# ===Tokens:===
# ['even', 'little', 'bit', 'higher', 'yara', 'multiples', 'analyst', 'helsinki', 'said']
#
#
# ===Tokens:===
# ['size', 'cider', 'bottle', 'remain', 'unchanged']
#
#
# ===Tokens:===
# ['ferries', 'run', 'trouble', 'outside', 'stockholm', 'archipelago', 'made', '20', '000', 'islands']
#
#
# ===Tokens:===
# ['motorola', 'inc', 'united', 'states', 'came', 'second', 'shipments', '217', '4', 'million', 'units', '21', '3', 'percent', 'market', 'share', 'followed', 'south', 'korea', 'samsung', 'electronics', 'co', 'shipments', '118', '0', 'million', 'units', '11', '6', 'percent', 'share']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'nov', '19', 'erkki', 'aho', 'elimaki', 'finland', 'developed', 'method', 'apparatus', 'conjunction', 'shoe', 'press']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'may', '23', 'matti', 'harkonen', 'pentti', 'sipponen', 'espoo', 'finland', 'osmo', 'suovaniemi', 'helsinki', 'finland', 'tapani', 'tiusanen', 'vantaa', 'finland', 'developed', 'paper', 'web', 'press', 'device']
#
#
# ===Tokens:===
# ['survey', 'conducted', 'taloustutkimus', 'sampo', 'life', 'shows', 'companies', 'badly', 'prepared', 'losing', 'key', 'staff', 'members']
#
#
# ===Tokens:===
# ['deal', 'includes', 'entire', 'personnel', 'planmill', 'oy', 'transfer', 'new', 'company', 'called', 'old', 'employees']
#
#
# ===Tokens:===
# ['metso', 'oyj', 'said', 'sold', 'spreader', 'roll', 'manufacturing', 'business', 'related', 'assets', 'town', 'nokia', 'southern', 'finland', 'group', 'finnish', 'investors', 'operate', 'business', 'name', 'finbow', 'oy']
#
#
# ===Tokens:===
# ['hu', 'offer', 'discount', '25', '50', 'selected', 'books']
#
#
# ===Tokens:===
# ['fiscal', 'year', 'ending', 'september', '30', '2009', 'revenue', 'customers', '10', '012', 'million', 'around', '11', '0', 'transportation', 'group', 'revenue']
#
#
# ===Tokens:===
# ['yit', 'lodged', 'counter', 'claims', 'neste', 'oil', 'totaling', 'eur25m', 'primarily', 'based', 'work', 'carried', 'contract', 'additional', 'costs', 'incurred', 'due', 'prolongation', 'project']
#
#
# ===Tokens:===
# ['fortum', 'also', 'blocking', 'stake', 'northwestern', 'tgk', '1']
#
#
# ===Tokens:===
# ['one', 'opportunities', 'would', 'bring', 'baltic', 'meat', 'processing', 'rakvere', 'like', 'processing', 'concentrated', 'vantaa', 'meat', 'packing', 'unit', 'finland', 'paper', 'wrote']
#
#
# ===Tokens:===
# ['tanks', 'delivered', 'company', 'currently', 'building', 'chemical', 'tank', 'farm', 'antwerp', 'northern', 'belgium']
#
#
# ===Tokens:===
# ['lemmink', 'inen', 'started', 'manufacture', 'roofing', 'felt', '1920', 'production', 'asphalt', '1930s']
#
#
# ===Tokens:===
# ['metso', 'foundries', 'jyvaskyla', 'oy', 'discontinue', 'production', 'line', '30', 'september', '2008']
#
#
# ===Tokens:===
# ['tightened', 'competition', 'situation', 'production', 'automation', 'market', 'affected', 'net', 'sales', '2006', 'cencorp', 'said']
#
#
# ===Tokens:===
# ['jon', 'risfelt', '49', 'years', 'old', 'holds', 'master', 'science', 'chemical', 'engineering', 'swedish', 'royal', 'institute', 'technology']
#
#
# ===Tokens:===
# ['2009', 'comptel', 'slipped', 'net', 'loss', 'eur2', '1', 'profit', 'eur6', '6', 'previous', 'year']
#
#
# ===Tokens:===
# ['abn', 'amro', 'capital', 'agreed', 'sell', 'helsinki', 'based', 'designer', 'homeware', 'producer', 'iittala', 'oyj', 'crosstown', 'consumer', 'products', 'group', 'fiskars', 'corp', 'eur230', 'million', 'eur235', 'million', '310', 'million', '316', 'million']
#
#
# ===Tokens:===
# ['europe', 'however', 'remains', 'important', 'strong', 'market', 'us']
#
#
# ===Tokens:===
# ['westpac', 'banking', 'corp', 'issue', 'benchmark', '3', 'year', 'frn', 'deal', 'euros']
#
#
# ===Tokens:===
# ['past', '10', 'years', 'factory', 'produced', 'many', 'nokia', 'popular', 'models', 'including', 'nokia', '2760', 'nokia', '6300', 'well', 'nokia', 'latest', 'music', 'device', 'nokia', '5800', 'express', 'music']
#
#
# ===Tokens:===
# ['cargotec', 'share', 'capital', 'increase', 'totals', '64', '046', '460', 'euros']
#
#
# ===Tokens:===
# ['incap', 'corporation', 'stock', 'exchange', 'announcement', '29', 'april', '2010', '1', 'p', 'invitation', 'news', 'conference', 'incap', 'interim', 'report', 'q1', '2010', 'incap', 'publish', 'interim', 'report', 'january', 'march', '2010', 'wednesday', '5', 'may', '2010']
#
#
# ===Tokens:===
# ['pa', 'jpmorgan', 'chase', 'co', 'nyse', 'jpm', 'pohjoa', 'bank', 'joint', 'lead', 'managers', 'senior', 'unsecured', 'deal']
#
#
# ===Tokens:===
# ['ruukki', 'included', 'djsi', 'world', 'second', 'year', 'running', 'european', 'djsi', 'stoxx', 'third', 'year', 'running']
#
#
# ===Tokens:===
# ['shares', 'shall', 'repurchased', 'public', 'trading', 'reason', 'shares', 'repurchased', 'otherwise', 'proportion', 'holdings', 'shareholders']
#
#
# ===Tokens:===
# ['okhta', 'center', 'area', 'expected', '700', '000', 'square', 'metres', 'office', 'premises', '2016']
#
#
# ===Tokens:===
# ['company', 'decided', 'stop', 'operations', 'ruukki', 'construction', 'division', 'latvia', 'lithuania', 'concentrate', 'production', 'logistics', 'parnu', 'estonia', '2009']
#
#
# ===Tokens:===
# ['uranium', 'found', 'locally', 'naturally', 'occurring', 'makes', 'sense', 'extract', 'way', 'metals']
#
#
# ===Tokens:===
# ['company', 'operates', 'u', 'division', 'lisle', 'ill']
#
#
# ===Tokens:===
# ['guidance', 'set', '90', 'basis', 'points', 'mid', 'swaps', 'report', 'said']
#
#
# ===Tokens:===
# ['finnish', 'media', 'company', 'talentum', 'oyj', 'net', 'profit', 'decreased', '2', '5', 'mln', 'euro', '4', '0', 'mln', 'first', 'quarter', '2008', '3', '0', 'mln', 'euro', '4', '7', 'mln', 'period', '2007']
#
#
# ===Tokens:===
# ['total', 'need', 'staff', 'cuts', 'corresponds', '300', 'man', 'years']
#
#
# ===Tokens:===
# ['country', 'finland', 'sector', 'construction', 'real', 'estate', 'target', 'pohjolan', 'design', 'talo', 'oy', 'buyer', 'capman', 'oyj', 'vendor', 'ruukki', 'group', 'oyj', 'deal', 'size', 'usd', '102', '6', 'type', 'divestment', 'status', 'agreed']
#
#
# ===Tokens:===
# ['program', 'started', 'summer', '2007', 'originally', 'estimated', 'last', 'approximately', 'two', 'years']
#
#
# ===Tokens:===
# ['company', 'reiterates', 'outlook', '2009']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operating', 'activities', 'investments', 'eur', '7', '6', 'million', 'eur', '2', '5', 'million']
#
#
# ===Tokens:===
# ['lsc', '30', 'employees', 'move', 'ixonos', 'existing', 'status', 'benefits']
#
#
# ===Tokens:===
# ['sampo', 'group', 'become', 'major', 'shareholder', 'nordea', 'owns', 'trygvesta', 'main', 'competitor', 'p', 'c', 'insurance']
#
#
# ===Tokens:===
# ['increase', 'number', 'shares', 'based', 'option', 'rights', 'granted', 'management', 'company', 'stock', 'option', 'plan', '2006']
#
#
# ===Tokens:===
# ['third', 'quarter', 'result', 'also', 'includes', '400', '000', 'euro', '575', '000', 'provision', 'sizing', 'lure', 'manufacturing', 'ireland']
#
#
# ===Tokens:===
# ['company', 'board', 'directors', 'would', 'propose', 'dividend', 'eur1', '00', 'per', 'share', '2005']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operating', 'activities', 'investments', 'eur', '0', '8', '1', '2', 'million']
#
#
# ===Tokens:===
# ['believe', 'however', 'hkscan', 'atria', 'start', 'use', 'imported', 'meat', 'finnish', 'consumers', 'prefer', 'domestic', 'products']
#
#
# ===Tokens:===
# ['net', 'sales', 'dropped', '6', 'year', 'year', 'eur', '11', '9', 'million']
#
#
# ===Tokens:===
# ['finnish', 'food', 'workers', 'union', 'sel', 'plans', 'hasten', 'collective', 'bargaining', 'two', 'day', 'strike', 'would', 'begin', '7', 'april', '2010', 'finland']
#
#
# ===Tokens:===
# ['neste', 'oil', 'refineries', 'combined', 'crude', 'oil', 'refining', 'capacity', 'approximately', '260', '000', 'barrels', 'day']
#
#
# ===Tokens:===
# ['incap', 'estimates', 'generate', 'revenue', '10', 'mln', 'euro', '13', '2', 'mln', 'indian', 'operations', '2007']
#
#
# ===Tokens:===
# ['target', 'company', 'tieto', 'corporation', 'business', 'identity', 'code', '0101138', '5', 'date', 'change', 'holding', '22', 'january', '2010', 'portion', 'shares', 'votes', 'current', 'group', 'holding', 'op', 'pohjola', 'group', 'central', 'cooperative', 'opk', '2982', '587', 'shares', 'represents', '4', '14', 'shares', 'voting', 'rights']
#
#
# ===Tokens:===
# ['alma', 'media', 'corporation', 'press', 'release', '15', 'march', '2010', 'tyrvaan', 'sanomat', 'paikallissanomat', 'bought', 'suomen', 'paikallissanomat', 'two', 'local', 'papers', 'tyrvaan', 'sanomat', 'paikallissanomat', 'appearing', 'sastamala', 'neighbouring', 'municipalities', 'bought', 'suomen', 'paikallissanomat', 'oy']
#
#
# ===Tokens:===
# ['rohwedder', 'group', 'automotive', 'supplies', 'telecommunications', 'electronics', 'industry', 'provider', 'customers', 'europe', 'north', 'america', 'asia']
#
#
# ===Tokens:===
# ['group', 'loyal', 'customer', 'magazine', 'yhteishyv', 'came', 'second', '1', '629', '000', 'readers', 'sanoma', 'corporation', 'daily', 'newspaper', 'helsingin', 'sanomat', 'third', '1', '097', '000', 'readers']
#
#
# ===Tokens:===
# ['olli', 'pekka', 'kallasvuo', 'elected', 'vice', 'chairman', 'board']
#
#
# ===Tokens:===
# ['steelmaker', 'said', 'drop', 'profit', 'explained', 'continuing', 'economic', 'uncertainty', 'mixed', 'current', 'drought', 'bank', 'lending', 'resulting', 'decline', 'demand', 'products', 'customers', 'find', 'increasingly', 'difficult', 'fund', 'operations']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'dropped', 'eur', '0', '21', 'eur', '0', '31']
#
#
# ===Tokens:===
# ['company', 'also', 'appointed', 'leif', 'rosen', 'head', 'special', 'plate', 'unit', 'includes', 'quarto', 'plate', 'units', 'degerfors', 'sweden', 'new', 'castle', 'usa', 'unit', 'willich', 'germany', 'well', 'pressplate', 'prefab', 'avesta', 'plate', 'service', 'centre', 'nordic', 'degerfors']

# %%
x_positive = df_positive[0][:10]
y_positive = df_positive[1][:10]

x_negative = df_negative[0][:10]
y_negative = df_negative[1][:10]

x_neutral = df_neutral[0][:10]
y_neutral = df_neutral[1][:10]


fig, ax = plt.subplots(3, 1, figsize=(10, 7), dpi=100)

ax[0].bar(x_positive, y_positive, color='g')
ax[0].set_title('Top 10 words with positive sentiment')
ax[0].set_xlabel('Words in the positive df')
ax[0].set_ylabel('Count')

ax[1].bar(x_negative, y_negative, color='r')
ax[1].set_title('Top 10 words with negative sentiment')
ax[1].set_xlabel('Words in the negative df')
ax[1].set_ylabel('Count')

ax[2].bar(x_neutral, y_neutral, color='gray')
ax[2].set_title('Top 10 words with neutral sentiment')
ax[2].set_xlabel('Words in the neutral df')
ax[2].set_ylabel('Count')
plt.tight_layout()

# %%
# Defined new dictionaries

positiveWords_bi=defaultdict(int)
negativeWords_bi=defaultdict(int)
neutralWords_bi=defaultdict(int)

# %%
# Creating positive bigrams

for text in train_set[train_set['Sentiment']=='positive']['Sentence']:
    for word in generate_ngrams(text, 2):
        positiveWords_bi[word]+=1
df_positive_bi = pd.DataFrame(sorted(positiveWords_bi.items(),key=lambda x:x[1],reverse=True))
df_positive_bi
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['contrast', 'company', 'net', 'loss', 'third', 'quarter', '2009', 'contracted', 'eur', '76', 'million', 'eur', '256', 'million', 'corresponding', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finland', 'neste', 'oil', 'awarded', 'chemical', 'industry', 'federation', 'finland', 'innovation', 'award', 'nexbtl', 'technology', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['combining', 'deep', 'domain', 'expertise', 'application', 'service', 'management', 'asm', 'outsourcing', 'service', 'offerings', 'proved', 'winning', 'combination']
#
#
# ===Tokens:===
# ['trx', 'http', 'stks', 'co', '1kkk', 'long', 'setup', 'macd', 'cross']
#
#
# ===Tokens:===
# ['meanwhile', 'electrowatt', 'ekono', 'philippines', 'inc', 'also', 'awarded', 'three', 'year', 'operation', 'maintenance', 'contract', 'fr', 'cement', 'corporation']
#
#
# ===Tokens:===
# ['madison', 'wis', 'feb', '6', 'prnewswire', 'fiskars', 'announces', 'united', 'states', 'patent', 'trademark', 'office', 'granted', 'trademark', 'registration', 'color', 'orange', 'iconic', 'scissor', 'handles']
#
#
# ===Tokens:===
# ['wfm', 'bought', 'little', 'yesterday', 'hoping', 'earnings', 'pop']
#
#
# ===Tokens:===
# ['ragutis', 'controlled', 'finnish', 'brewery', 'reported', '5', '4', 'per', 'cent', 'rise', 'beer', 'sales', '10', '44', 'million', 'litres', 'held', '11', '09', 'per', 'cent', 'market', 'share']
#
#
# ===Tokens:===
# ['addition', 'cramo', 'peab', 'signed', 'exclusive', 'five', 'year', 'rental', 'agreements', 'finland', 'extended', 'existing', 'rental', 'agreements', 'swedish', 'market', 'another', 'five', 'years']
#
#
# ===Tokens:===
# ['combined', 'foreign', 'investments', 'creates', 'interesting', 'opportunities', 'solteq']
#
#
# ===Tokens:===
# ['osur', '33', 'since', '6', '25', 'buy', 'signal', 'resistance', '5', '33', 'expect', '1', 'pullback', '2nd', 'half', 'day', '2', 'break', 'abov', '5', '33', 'continue', 'rally', '4', '5', 'days']
#
#
# ===Tokens:===
# ['federal', 'secretary', 'transport', 'communication', 'mexico', 'awarded', 'poyry', 'mexican', 'partner', 'sintra', 'consulting', 'contract', 'connection', 'buenavista', 'cuautitlan', 'suburban', 'railway']
#
#
# ===Tokens:===
# ['kndi', 'china', 'electriccar', 'maker', 'china', 'car', 'sales', '7', '8', 'also', 'may', 'feed', 'tsla', 'momentum', 'run', 'lately']
#
#
# ===Tokens:===
# ['agreement', 'signed', 'biohit', 'healthcare', 'ltd', 'uk', 'based', 'subsidiary', 'biohit', 'oyj', 'finnish', 'public', 'company', 'develops', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems']
#
#
# ===Tokens:===
# ['third', 'quarter', 'net', 'sales', 'increased', '12', 'year', 'year', 'eur159', '5', '6', 'comparable', 'currency', 'rates', 'growth']
#
#
# ===Tokens:===
# ['finnish', 'vacon', 'signed', 'significant', 'deals', 'norwegian', 'scandinavian', 'electric', 'systems', 'ses', 'supply', 'ac', 'drives']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'bounces', 'back', 'mondi', 'barratt', 'lead']
#
#
# ===Tokens:===
# ['update', 'barclays', 'expects', 'gain', 'settling', 'lehman', 'bros', 'trustee']
#
#
# ===Tokens:===
# ['interest', 'heats', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'co', 'j5jvji9bia']
#
#
# ===Tokens:===
# ['according', 'pkc', 'acquisition', 'would', 'bring', 'significant', 'addition', 'pkc', 'customer', 'base']
#
#
# ===Tokens:===
# ['buffett', 'berkshire', 'builds', 'deere', 'stake', 'dumps', 'exxon']
#
#
# ===Tokens:===
# ['etteplan', 'targets', 'employ', 'least', '20', 'people', 'borl', 'nge']
#
#
# ===Tokens:===
# ['slw', 'weekly', '34', 'calls', '28', '95', '23', 'x', '25', '321', 'volume', 'worth', 'chance', 'jmho', 'http', 'stks', 'co', '1qfg']
#
#
# ===Tokens:===
# ['finnish', 'food', 'industry', 'companies', 'hk', 'ruokatalo', 'atria', 'form', 'joint', 'venture', 'company', 'called', 'l', 'nsi', 'kalkkuna', 'produce', 'turkey', 'meat']
#
#
# ===Tokens:===
# ['sales', 'climbed', '19', '2', 'pct', '1', '002', 'bln', 'eur', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure']
#
#
# ===Tokens:===
# ['continuing', 'operations', 'turned', 'operating', 'loss', 'eur', '0', '1', 'mn', 'slight', 'improvement', 'loss', 'eur', '0', '2', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'leap', 'ftse', '100', 'marks', 'spencer', 'drops']
#
#
# ===Tokens:===
# ['basware', 'corporation', 'stock', 'exchange', 'release', 'august', '31', '2010', '16', '25', 'basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'basware', 'deliver', 'invoice', 'automation', 'solution', 'connectivity', 'services', 'international', 'industrial', 'group']
#
#
# ===Tokens:===
# ['also', 'turned', 'earnings', 'per', 'share', 'eps', 'eur', '0', '08', 'versus', 'loss', 'per', 'share', 'eur', '0', '04']
#
#
# ===Tokens:===
# ['company', 'consolidated', 'operating', 'profit', 'amounted', 'eur', '15', '86', 'mn', 'eur', '4', '14', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['aapl', 'right', 'back', 'buy', 'dips', 'brought', 'cnbc', 'lol']
#
#
# ===Tokens:===
# ['capman', 'partner', 'able', 'develop', 'business', 'continue', 'focus', 'providing', 'quality', 'restaurant', 'services', 'customers', 'says', 'christopher', 'wynne', 'ceo', 'papa', 'john', 'russia']
#
#
# ===Tokens:===
# ['technical', 'indicators', 'stock', 'bullish', 'p', 'gives', 'nok', 'positive', '4', 'stars', '5', 'buy', 'ranking']
#
#
# ===Tokens:===
# ['upm', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', 'efficiency', 'operations', 'improved', 'chief', 'executive', 'jussi', 'pesonen', 'said']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'maker', 'amer', 'sports', 'oyj', 'hel', 'ameas', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '16', '9', 'million', 'usd', '22', '3', 'second', 'quarter', '2010', 'eur', '23', '2', 'million', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['outokumpu', 'chief', 'executive', 'juha', 'rantanen', 'expressed', 'confidence', 'china', 'market']
#
#
# ===Tokens:===
# ['nflx', 'vision', 'short', 'term', 'consolidation', 'movement', 'higher', 'http', 'stks', 'co', 'j05uu']
#
#
# ===Tokens:===
# ['elcoteq', 'elcoteq', 'se', 'leading', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'communications', 'technology', 'field']
#
#
# ===Tokens:===
# ['renovation', 'biggest', 'moulding', 'line', 'orhangazi', 'foundry', 'modern', 'line', 'europe']
#
#
# ===Tokens:===
# ['company', 'established', '3g', 'base', 'station', '17', '000', 'feet', 'foot', 'mount', 'everest', 'enable', 'mountain', 'climbers', '29', '035', 'foot', 'summit', 'surf', 'internet', 'even', 'send', 'videos', 'exploits']
#
#
# ===Tokens:===
# ['spy', 'hang', 'bull', 'hat', 'yet', 'next', 'week', 'pop', 'higher', 'qe3', 'hope', 'back', 'fed', '2', 'day', 'meeting']
#
#
# ===Tokens:===
# ['return', 'investment', '16', '6', 'compared', '15', '8', '2004']
#
#
# ===Tokens:===
# ['finnish', 'investment', 'group', 'panostaja', 'oyj', 'said', 'net', 'profit', 'went', '8', '6', 'mln', 'euro', '11', '4', 'mln', 'fiscal', '2005', '06', 'ended', 'october', '31', '2006', '2', '8', 'mln', 'euro', '3', '7', 'mln', 'period', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['analysts', 'impressed', 'progress', 'tesla', 'flagship', 'factory', 'co', 'spent', '1', '6b', 'upgrades', '15', 'https', 'co', 'sabxcsn8cd', 'tsrandall', 'tsla']
#
#
# ===Tokens:===
# ['london', 'afx', 'shares', 'rautaruukki', 'corp', 'upgraded', 'hold', 'sell', 'abn', 'amro', 'price', 'target', 'raised', '25', '75', 'eur', '14', '5', 'said', 'dealers']
#
#
# ===Tokens:===
# ['narrows', 'eur2', '8', '9', 'mo', '09', '29', 'october', '2009', 'finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'net', 'loss', 'narrowed', 'eur2', '8', 'first', 'nine', 'months', '2009', 'eur35', '6', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['adp', 'news', 'nov', '18', '2008', 'finnish', 'ac', 'drives', 'manufacturer', 'vacon', 'oyj', 'omx', 'vac1v', 'said', 'today', 'set', 'new', 'representative', 'offices', 'romania', 'ukraine', 'serve', 'growing', 'markets', 'eastern', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['finnish', 'aktia', 'group', 'operating', 'profit', 'rose', 'eur', '17', '5', 'mn', 'first', 'quarter', '2010', 'eur', '8', '2', 'mn', 'first', 'quarter', '2009']
#
#
# ===Tokens:===
# ['first', 'nine', 'months', '2010', 'talvivaara', 'net', 'loss', 'narrowed', 'eur', '8', '3', 'million', 'eur', '21', '9', 'million', 'period', '2009']
#
#
# ===Tokens:===
# ['wpp', 'boosts', 'sales', 'despite', 'cautious', 'clients']
#
#
# ===Tokens:===
# ['fb', 'small', 'long', '109', '25', 'via', 'calls']
#
#
# ===Tokens:===
# ['altia', 'operating', 'profit', 'jumped', 'eur', '47', 'million', 'eur', '6', '6', 'million']
#
#
# ===Tokens:===
# ['lnt', 'increases', 'annual', 'dividend', 'target', '1', '80', 'share', '1', '70', 'share']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'kci', 'konecranes', 'said', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'ltd']
#
#
# ===Tokens:===
# ['vaahto', 'pulp', 'paper', 'finnish', 'vaahto', 'group', 'awarded', 'order', 'renovate', 'finnish', 'swedish', 'forest', 'industry', 'company', 'stora', 'enso', 'paperboard', 'machine', 'ingerois', 'board', 'mill', 'finland']
#
#
# ===Tokens:===
# ['buy', 'recommendation', 'reiterated']
#
#
# ===Tokens:===
# ['bristol', 'port', 'company', 'sealed', 'one', 'million', 'pound', 'contract', 'cooper', 'specialised', 'handling', 'supply', 'four', '45', 'tonne', 'customised', 'reach', 'stackers', 'konecranes']
#
#
# ===Tokens:===
# ['h', 'move', 'enhance', 'growth']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'period', 'eur0', '9', 'eur0', '01', 'last', 'year']
#
#
# ===Tokens:===
# ['subscriptions', 'increase', 'cargotec', 'share', 'capital', '36', '780', 'euros']
#
#
# ===Tokens:===
# ['new', 'representation', 'extends', 'comptel', 'global', 'presence', 'total', '18', 'countries', 'serving', '250', 'customers', '80', 'countries', 'worldwide']
#
#
# ===Tokens:===
# ['china', 'finnish', 'kone', 'provides', 'elevators', 'escalators', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'high', 'speed', 'railway', 'section', 'beijing', 'shanghai', '1', '5', 'years', 'time']
#
#
# ===Tokens:===
# ['shares', 'standard', 'chartered', 'stan', 'rose', '1', '2', 'ftse', '100', 'royal', 'bank', 'scotland', 'rbs', 'shares', 'rose', '2', 'barclays', 'shares', 'barc', 'bcs', '1', '7']
#
#
# ===Tokens:===
# ['cargo', 'volume', 'increased', 'approximately', '5']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'retail', 'wholesale', 'group', 'kesko', 'reported', 'net', 'sales', '659', '4', 'mln', 'eur', 'february', 'increase', '10', '8', 'pct', 'year', 'year']
#
#
# ===Tokens:===
# ['lule', 'municipality', 'awarded', 'yit', '2', 'year', 'contract', 'property', 'management', 'one', 'third', 'municipality', 'properties', 'total', 'area', '140', '000', 'sq', 'metres']
#
#
# ===Tokens:===
# ['pre', 'tax', 'profit', 'totaled', 'eur', '397', '4', 'mn', 'eur', '164', '7', 'mn']
#
#
# ===Tokens:===
# ['yhoo', 'break', '5', 'min']
#
#
# ===Tokens:===
# ['today', 'bought', 'mu', 'yhoo', 'vale', 'nbl', 'twtr', 'axp', 'znga', 'https', 'co', 'vt6t5zp2is']
#
#
# ===Tokens:===
# ['kalnapilio', 'tauro', 'grupe', 'kalnapilis', 'tauras', 'group', 'owned', 'denmark', 'royal', 'unibrew', 'raised', 'market', 'share', '25', '2', 'percent', '23', '91', 'percent', 'beer', 'sales', 'nine', 'months', 'jumped', '11', '4', 'percent', '52', '99', 'million', 'liters']
#
#
# ===Tokens:===
# ['mos', 'looking', 'good', '58', '65', 'calls', 'active', 'month', 'weekly']
#
#
# ===Tokens:===
# ['nokian', 'tyre', 'proves', 'high', 'safety', 'excellently', 'important', 'driving', 'qualities', 'stability', 'mark', '1', '4', 'handling', '1', '5', 'braking', 'wet', 'road', '1', '9']
#
#
# ===Tokens:===
# ['several', 'growth', 'initiatives', 'chosen', 'geographic', 'areas', 'already', 'ongoing', 'continued', 'noting', 'lindex', 'opened', 'first', 'store', 'czech', 'republic', 'autumn', 'brno']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'totalled', 'eur', '2', '71', 'mn', 'compared', 'negative', 'eur', '0', '83', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['sppi', 'building', 'rs', 'sweet', 'want', 'break', 'new', '52week', 'earnings', 'growth', 'justifies', 'way', 'higher']
#
#
# ===Tokens:===
# ['according', 'finnish', 'metso', 'minerals', 'value', 'company', 'orders', 'gone', 'eur', '1', '9', 'bn', '12', 'months']
#
#
# ===Tokens:===
# ['return', 'equity', 'stood', '18', '3', 'compared', '15', '4', 'third', 'quarter', '2005']
#
#
# ===Tokens:===
# ['fio', 'stay']
#
#
# ===Tokens:===
# ['intuitiv', 'clne', 'gasoline', 'prices', 'spike', 'california', 'http', 'stks', 'co', 't1boi']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '6', '2009', 'finnish', 'fishing', 'tackle', 'company', 'rapala', 'vmc', 'corp', 'hel', 'rap1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '19', '2', 'million', 'usd', '24', '6', '2008', 'eur', '17', '5', 'million', '2007']
#
#
# ===Tokens:===
# ['warmly', 'welcome', 'michael', 'frei', 'outotec']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'group', 'share', 'price', 'climbs', '1', '5bn', 'special', 'dividend']
#
#
# ===Tokens:===
# ['stora', 'enso', 'third', 'quarter', 'pre', 'tax', 'profit', 'doubled', 'eur', '197mn']
#
#
# ===Tokens:===
# ['kesko', 'agro', 'lietuva', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'kesko', 'group', 'boosted', 'sales', '42', '9', 'percent', '13', '4', 'million', 'euros', 'vat', 'inclusive']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur13', '6', 'net', 'sales', 'increased', 'eur394', '7', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['compass', 'group', 'says', 'positive', 'year', 'ahead']
#
#
# ===Tokens:===
# ['shire', 'ceo', 'steps', 'drive', 'get', 'baxalta', 'board', 'talking']
#
#
# ===Tokens:===
# ['astrazeneca', 'acquires', 'zs', 'pharma', '2', '7', 'billion', 'deal']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '11', '4', 'mn', 'eur', '7', '5', 'mn']
#
#
# ===Tokens:===
# ['net', 'interest', 'income', 'eur', '152', '2', 'mn', 'eur', '101', '0', 'mn', '2008']
#
#
# ===Tokens:===
# ['president', 'ceo', 'mika', 'vehvil', 'inen', 'says', 'positive', 'signs', 'first', 'foremost', 'emerging', 'outside', 'finland']
#
#
# ===Tokens:===
# ['fb', 'slight', 'green', 'may', 'runner', 'later']
#
#
# ===Tokens:===
# ['contract', 'signed', 'august', 'papua', 'new', 'guinea', 'based', 'lihir', 'gold', 'ltd', 'asx', 'lgl']
#
#
# ===Tokens:===
# ['stora', 'enso', 'norske', 'skog', 'real', 'upm', 'kymmene', 'credit', 'suisse', 'first', 'boston', 'cfsb', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'nordic', 'forestry', 'groups']
#
#
# ===Tokens:===
# ['pleased', 'welcome', 'tapeks', 'noma', 'cramo', 'group']
#
#
# ===Tokens:===
# ['berkshire', 'applies', 'boost', 'wells', 'fargo', 'stake', '10', 'percent']
#
#
# ===Tokens:===
# ['outotec', 'oyj', 'press', 'release', 'december', '4', '2009', '10', '30', 'outotec', 'establishes', 'new', 'subsidiary', 'kolkata', 'outotec', 'established', 'subsidiary', 'india', 'order', 'better', 'serve', 'indian', 'customers', 'increase', 'business', 'growing', 'indian', 'market']
#
#
# ===Tokens:===
# ['amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'company']
#
#
# ===Tokens:===
# ['honored', 'acknowledged', 'commitment', 'industry', 'especially', 'asia', 'pacific']
#
#
# ===Tokens:===
# ['navteq', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'north', 'american', 'vehicles', 'may', 'leader', 'turn', 'turn', 'navigation', 'data', 'offered', 'services', 'onstar', 'north', 'america', 'said', 'analyst', 'phil', 'magney', 'telematics', 'research', 'group', 'minnetonka', 'minn']
#
#
# ===Tokens:===
# ['gsk', 'joins', 'china', 'trade', 'push', 'uk', 'trumpets', 'healthcare', 'deals']
#
#
# ===Tokens:===
# ['value', 'firm', 'forestry', 'holdings', 'increased', 'sek', '3', '6', 'bn']
#
#
# ===Tokens:===
# ['hammerson', 'jv', 'partner', 'secure', 'ownership', 'ireland', 'dundrum', 'quick', 'facts']
#
#
# ===Tokens:===
# ['2009', 'fiskars', 'cash', 'flow', 'operating', 'activities', 'amounted', 'eur121m', 'eur97m', 'previous', 'year']
#
#
# ===Tokens:===
# ['long', 'vvus', 'shares', 'call', 'option', 'w', 'expiration', 'umm', 'today', 'hitting', 'hod']
#
#
# ===Tokens:===
# ['chime', 'communications', 'set', 'acquired', 'wpp', 'providence']
#
#
# ===Tokens:===
# ['asdfllc', 'nice', 'pop', 'today', 'told', 'ya', 'would', 'green', 'haha', 'funny', 'bring', 'actually', 'working', 'story', 'nok', 'moment']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'company', 'elcoteq', 'signing', 'cooperation', 'agreement', 'japanese', 'mobile', 'phone', 'manufacturer', 'bypasses', 'elcoteq', 'tallinn', 'says', 'jan', 'kotka', 'ceo', 'elcoteq', 'tallinn']
#
#
# ===Tokens:===
# ['based', 'upon', 'unique', 'fiber', 'expertise', 'innovative', 'approach', 'company', 'strong', 'market', 'position', 'several', 'business', 'areas', 'operates']
#
#
# ===Tokens:===
# ['company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market']
#
#
# ===Tokens:===
# ['developers', 'project', 'predict', 'completed', 'april', '2009', 'skanssi', 'attract', '4', '5', 'million', 'visitors', 'annually']
#
#
# ===Tokens:===
# ['ftse', '100', 'flat', 'standard', 'chartered', 'leads', 'risers']
#
#
# ===Tokens:===
# ['manavigator', 'september', '7', '2010', 'kemira', 'unveils', 'indian', 'jv', 'ivrcl', 'finnish', 'chemicals', 'group', 'kemira', 'hel', 'kra1v', 'tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'india', 'local', 'construction', 'firm', 'ivrcl', 'infrastructure', 'projects', 'ltd', 'bom', '530773']
#
#
# ===Tokens:===
# ['according', 'finnish', 'aktia', 'bank', 'managing', 'director', 'jussi', 'laitinen', 'bank', 'aim', 'triple', 'number', 'customers', 'finland', 'next', 'five', 'years']
#
#
# ===Tokens:===
# ['finland', 'nokian', 'tyres', 'kazakhstan', 'ordabasy', 'corporation', 'signed', 'agreement', 'build', 'plant', 'astana', 'produce', 'car', 'tires', 'ordabasy', 'chairman', 'dinmukhamet', 'idrisov', 'said', 'press', 'conference']
#
#
# ===Tokens:===
# ['danske', 'bank', 'danske', 'dc', 'jumped', '3', '7', 'percent', '133', '4', 'kroner', 'rebounding', 'yesterday', '3', '5', 'percent', 'slide']
#
#
# ===Tokens:===
# ['vessel', 'order', 'help', 'aspo', 'secure', 'long', 'term', 'competitiveness', 'fleet', 'terms', 'technology', 'pricing']
#
#
# ===Tokens:===
# ['enb', 'ca', 'head', 'shoulders', 'bullish', 'reversal', 'setup', 'breakout', 'oil', 'gas', 'pipleline', 'stock', 'uso']
#
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastic', 'products', 'maker', 'suominen', 'corporation', 'said', 'net', 'loss', 'narrowed', '1', '6', 'mln', 'euro', '2', '0', 'mln', 'first', 'nine', 'months', '2006', '2', '16', 'mln', 'euro', '2', '7', 'mln', 'period', '2005']
#
#
# ===Tokens:===
# ['upside', 'moves', 'volatile', 'mining', 'sector', 'sending', 'anglo', 'american', 'plc', 'aal', '6', '8', '4', '30', 'pm', 'london', 'time']
#
#
# ===Tokens:===
# ['rad', 'would', 'consider', 'opportunity', 'add', 'position', 'company', 'right', 'track', 'still', 'improving', 'sales']
#
#
# ===Tokens:===
# ['ocn', 'stuff', 'looking', 'add', 'shares', 'get', 'new', 'high', 'breakout']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'net', 'profit', 'rose', '26', '1', 'mln', 'euro', '35', '9', 'mln', 'first', 'quarter', '2007', '5', '3', 'mln', 'euro', '7', '3', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['rapala', 'estimates', 'net', 'sales', '2008', 'increase', '8', '0', 'pct', '12', 'pct', 'assuming', '2007', 'exchange', 'rates']
#
#
# ===Tokens:===
# ['free', 'ha', 'heeeeeere', 'comes', 'pump', 'glad', 'picked', '9k', 'end', 'day', 'get', 'ready', 'bull', 'ride']
#
#
# ===Tokens:===
# ['eps', 'grew', '0', '04', 'eur', '0', '02', 'eur']
#
#
# ===Tokens:===
# ['held', 'recent', 'double', 'bottom', 'buy', 'point', '56', '57', 'almost', 'penny', 'today', 'wmt', 'http', 'chart', 'ly', '6nosp5q']
#
#
# ===Tokens:===
# ['astrazeneca', 'shares', 'climb', '3', 'drug', 'maker', 'ups', 'profits', 'forecasts']
#
#
# ===Tokens:===
# ['group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets']
#
#
# ===Tokens:===
# ['companiescar', 'insurer', 'hastings', 'group', 'driving', '180m', 'ipo']
#
#
# ===Tokens:===
# ['vrtx', 'early', 'technical', 'buy', 'signal', 'confirmation', '86', 'needs', 'fundam', 'incentive', 'https', 'co', 'quysrqfo2x']
#
#
# ===Tokens:===
# ['systeemitiimi', 'sales', 'project', 'resources', 'also', 'strengthened', 'director', 'paul', 'skogberg', 'said']
#
#
# ===Tokens:===
# ['accordance', 'strategy', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'south', 'africa', 'october']
#
#
# ===Tokens:===
# ['metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'china', 'lee', 'man', 'paper', 'co']
#
#
# ===Tokens:===
# ['poyry', 'recognized', 'one', 'world', 'leading', 'advisors', 'global', 'forestry', 'industry']
#
#
# ===Tokens:===
# ['skf', '6', 'april', '2010', 'alandsbanken', 'given', 'buy', 'recommendation', 'swedish', 'industrial', 'company', 'skf', 'ab', 'sto', 'skf', 'b', 'share', 'price', 'target', 'sek150']
#
#
# ===Tokens:===
# ['investments', 'operational', 'changes', 'enable', 'additional', 'optimisation', 'working', 'hours', 'thereby', 'cost', 'savings', '7', '9']
#
#
# ===Tokens:===
# ['finnish', 'software', 'developer', 'basware', 'oyj', 'said', 'november', '30', '2006', 'u', 'subsidiary', 'basware', 'inc', 'order', 'provide', 'software', 'contract', 'lifecycle', 'management', 'unnamed', 'u', 'medical', 'technology', 'company']
#
#
# ===Tokens:===
# ['repair', 'maintenance', 'business', 'accounted', 'net', 'sales', 'eur', '645', '3', 'mn', 'eur', '563', '6', 'mn']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'increased', '2', 'eur', '1', '050', '7', 'mn', 'eur', '1', '027', '0', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['stock', 'trading', 'maps', '50', 'day', 'map', 'sek72', '983', 'higher', '200', 'day', 'map', 'sek70', '283', 'bullish', 'indicator']
#
#
# ===Tokens:===
# ['luv', 'continues', 'consolidate', 'previous', 'break', 'area']
#
#
# ===Tokens:===
# ['recommendable', 'nokian', 'z', 'g2', 'according', 'adac', 'judgement', 'latest', 'summer', 'tyre', 'test', 'german', 'automobile', 'association', 'adac']
#
#
# ===Tokens:===
# ['economic', 'occupancy', 'rate', 'sponda', 'property', 'portfolio', 'rose', '91', '2', '88', '8', '2006']
#
#
# ===Tokens:===
# ['leipurin', 'growing', 'rapidly', 'internationalizing', 'group']
#
#
# ===Tokens:===
# ['2008', 'deal', 'likely', 'bring', 'savings', 'eur', '20mn', '25mn']
#
#
# ===Tokens:===
# ['cargotec', 'germany', 'gmbh', 'awarded', 'contract', 'stadtverwaltung', 'mainz', 'chassis', 'bodies', 'open', 'procedure']
#
#
# ===Tokens:===
# ['exports', 'accounted', '65', '4', 'net', 'sales', 'representing', 'time', 'record', 'company']
#
#
# ===Tokens:===
# ['previously', 'eb', 'delivered', 'custom', 'solution', 'lg', 'electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators']
#
#
# ===Tokens:===
# ['marimekko', 'group', 'full', 'year', 'net', 'sales', 'estimated', 'increase', '10']
#
#
# ===Tokens:===
# ['terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', 'chief', 'executive', 'veli', 'matti', 'mattila', 'said']
#
#
# ===Tokens:===
# ['profit', 'taking', 'aapl', 'morning', 'pressure', 'stock', 'still', 'bullish', 'aapl']
#
#
# ===Tokens:===
# ['passenger', 'related', 'revenue', 'rose', '5', '1', 'eur', '460', '8', 'mn', 'eur', '438', '5', 'mn', '2009']
#
#
# ===Tokens:===
# ['end', 'review', 'period', 'nordic', 'aluminium', 'order', 'book', 'stood', 'eur', '8', '77', 'mn', 'compared', 'eur', '7', '04', '2005']
#
#
# ===Tokens:===
# ['tesco', 'closes', 'new', 'chairman', 'dixons', 'carphone', 'john', 'allan', 'frame']
#
#
# ===Tokens:===
# ['takeover', 'cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'latvian', 'market']
#
#
# ===Tokens:===
# ['cencorp', 'estimates', 'net', 'sales', 'last', 'quarter', 'earlier', 'stated', 'eur4', '3', 'eur5', '0', 'operating', 'profit', 'ebit', 'estimated', 'positive']
#
#
# ===Tokens:===
# ['teliasonera', 'said', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', 'nepal', 'population']
#
#
# ===Tokens:===
# ['amazon', 'declares', 'best', 'ever', 'black', 'friday', 'cyber', 'monday', 'kindle', 'family', 'http', 'stks', 'co', 'cetw', 'via', 'engadget', 'amzn']
#
#
# ===Tokens:===
# ['rdc', 'rowan', 'expands', 'share', 'repurchase', 'program', '150', 'million']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', '2010', 'seen', 'grown', 'eur598', '3', 'eur582', '3', '2009']
#
#
# ===Tokens:===
# ['clothing', 'chain', 'sepp', 'l', 'net', 'sales', 'increased', '7', '0', 'eur', '30', '8', 'mn']
#
#
# ===Tokens:===
# ['ilmn', 'piper', 'jeffries', 'raises', 'pt', 'remain', 'long']
#
#
# ===Tokens:===
# ['dxcm', 'making', 'higher', 'highs', 'higher', 'lows', 'consolidates', 'past', 'several', 'weeks', '26', '70', 'time', 'high', '2006']
#
#
# ===Tokens:===
# ['mr', 'lee', 'said', 'hoped', 'neste', 'move', 'pave', 'way', 'collaboration', 'projects', 'two', 'countries']
#
#
# ===Tokens:===
# ['addition', 'fireplace', 'exports', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'sales', 'three', 'month', 'period', 'increased', 'respectively', 'eur0', '3', 'eur13', '1', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['also', 'bringing', 'right', 'kind', 'people', 'upgrade', 'human', 'resources']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '27', '8', 'mn', 'eur', '17', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['endp', 'saw', 'large', 'order', 'one', 'last', 'week', 'someone', 'also', 'accumulating', 'may', 'jun', '35', 'calls', 'today']
#
#
# ===Tokens:===
# ['commencing', 'construction', 'works', 'pearl', 'plaza', 'significant', 'step', 'russian', 'projects']
#
#
# ===Tokens:===
# ['raisio', 'divisions', 'recorded', 'operating', 'profit']
#
#
# ===Tokens:===
# ['meanwhile', 'nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout']
#
#
# ===Tokens:===
# ['glaxo', 'viiv', 'healthcare', 'signs', 'china', 'manufacturing', 'deal', 'desano']
#
#
# ===Tokens:===
# ['bot', 'amzn', '600', 'weekly', 'calls', '5', '93']
#
#
# ===Tokens:===
# ['finnish', 'lifting', 'equipment', 'maker', 'kone', 'oyj', 'said', 'october', '4', '2007', 'order', 'worth', '15', 'mln', 'euro', '21', '2', 'mln', 'deliver', 'total', '53', 'custom', 'designed', 'elevators', 'norwegian', 'shipbuilder', 'aker', 'yards', 'asa']
#
#
# ===Tokens:===
# ['standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'itella']
#
#
# ===Tokens:===
# ['refining', 'margin', 'year', '13', '39', 'bbl', 'compared', '10', '46', 'bbl', 'prior', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '103', '4', 'mn', 'eur', '23', '2', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['kraft', 'heinz', 'merger', 'came', 'together', 'speedy', '10', 'weeks']
#
#
# ===Tokens:===
# ['net', 'sales', 'vegetable', 'oil', 'business', 'rose', 'eur', '10', '6', 'mn', 'eur', '10', '1', 'mn']
#
#
# ===Tokens:===
# ['company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'eur', '67', '1', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'surged', 'eur21m', 'eur106', '000']
#
#
# ===Tokens:===
# ['bilfinger', 'industrial', 'services', 'win', '100m', 'bp', 'contract', 'extension']
#
#
# ===Tokens:===
# ['would', 'invest', 'physical', 'infrastructure', 'would', 'also', 'provide', 'know', 'managing', 'developing', 'science', 'technology', 'parks', 'said', 'sunrise', 'valley', 'director', 'andrius', 'bagdonas']
#
#
# ===Tokens:===
# ['rationalization', 'operations', 'seeks', 'achieve', 'eur', '1', 'million', 'yearly', 'savings', 'second', 'quarter', 'current', 'financial', 'year']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'outperforms', 'europe', 'royal', 'mail', 'tesco', 'rise']
#
#
# ===Tokens:===
# ['profit', 'period', 'eur', '5', '9', 'mn', 'eur', '1', '3', 'mn']
#
#
# ===Tokens:===
# ['cision', 'says', 'sale', 'return', 'u', 'k', 'operation', 'profitability']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'higher', '0', '48', '0', '37', 'year', 'ahead', 'market', 'consensus', '0', '40', 'eur']
#
#
# ===Tokens:===
# ['ebit', 'margin', '1', '4', '5', '1']
#
#
# ===Tokens:===
# ['ruukki', 'forecast', '15', '20', 'annual', 'sales', 'growth', 'positive', 'pretax', 'result', '2010']
#
#
# ===Tokens:===
# ['acquiring', 'rcp', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company']
#
#
# ===Tokens:===
# ['4', 'beaten', 'internet', 'companies', 'may', 'ripe', 'takeover', 'target', 'twitter', 'twtr', 'linkedin', 'lnkd', 'yahoo', 'yhoo', 'groupon', 'grpn']
#
#
# ===Tokens:===
# ['sonc', 'amazing', 'run', 'since', 'middle', 'march', 'obvious', 'quality', 'tastiness', 'burgers', 'factored', 'price', 'advance']
#
#
# ===Tokens:===
# ['activision', 'blizzard', 'media', 'networks', 'announces', 'record', 'esports', 'viewership', 'https', 'co', '729biqlbtk', 'atvi', 'partnered', 'hdsi', '9', 'tournament']
#
#
# ===Tokens:===
# ['dara', 'breaking']
#
#
# ===Tokens:===
# ['supermarket', 'stocks', 'rally', 'tesco', 'plans', 'axe', 'non', 'core', 'uk', 'assets', 'tsco', 'https', 'co', 'bmvhcrwrea']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '4', '7', 'mn', 'eur', '4', '6', 'mn']
#
#
# ===Tokens:===
# ['strategic', 'cooperation', 'rentakran', 'brings', 'us', 'new', 'customers', 'already', 'working', 'relationships', 'authorities', 'new', 'territories', 'said', 'jarmo', 'laasanen', 'senior', 'manager', 'cramo']
#
#
# ===Tokens:===
# ['kitd', 'looking', 'oversold', 'bounce']
#
#
# ===Tokens:===
# ['wft', 'closng', 'higher']
#
#
# ===Tokens:===
# ['kauko', 'telko', 'ltd', 'press', 'release', '19', '06', '2007', '14', '00', '1', '1', 'telko', 'group', 'kauko', 'telko', 'expanding', 'strategic', 'partnership', 'bp', 'industrial', 'lubricants', 'services', 'bp', 'ils', 'acquiring', 'total', 'ownership', 'bp', 'swedish', 'retail', 'company', 'molub', 'alloy', 'ab']
#
#
# ===Tokens:===
# ['eln', 'longs', 'congrats', 'another', 'hod']
#
#
# ===Tokens:===
# ['solutions', 'used', 'upgrading', 'networks', 'russian', 'mso', '37', 'different', 'cities', 'russia']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '9', '2009', 'finnish', 'computer', 'services', 'company', 'proha', 'oyj', 'hel', 'art1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '113', '000', 'usd', '146', '000', '2008', 'eur', '1', '2', 'million', '2007']
#
#
# ===Tokens:===
# ['major', 'breweries', 'increased', 'domestic', 'beer', 'sales', '4', '5', 'per', 'cent', 'last', 'year', '256', '88', 'million', 'litres', '245', '92', 'million', 'litres', '2004']
#
#
# ===Tokens:===
# ['shopping', 'center', 'opened', 'st', 'petersburg', 'russia', 'november', '2010', 'turn', 'cash', 'flow', 'finnish', 'department', 'store', 'chain', 'stockmann', 'russian', 'operations', 'positive', 'first', 'time', '2011']
#
#
# ===Tokens:===
# ['company', 'also', 'estimates', 'already', 'carried', 'investments', 'lead', 'increase', 'net', 'sales', '2010', '2009', 'reached', 'eur', '141', '7', 'million']
#
#
# ===Tokens:===
# ['poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'latin', 'america']
#
#
# ===Tokens:===
# ['stx', 'long', 'play', 'another', 'consistent', 'profit', 'zone', 'check', 'https', 'co', 'dqfuzozylh', 'https', 'co', 'ggne4ayzqn']
#
#
# ===Tokens:===
# ['combine', 'renew', 'contents', 'functionality', 'current', 'systems', 'funding', 'online', 'service', 'well', 'maintenance']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '6', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['daily', 'mail', 'owner', 'considering', 'yahoo', 'bid', 'yhoo', '2', '05', 'https', 'co', 'extzr1riyp']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'seen', 'eur', '0', '56', 'eur', '0', '38']
#
#
# ===Tokens:===
# ['went', 'long', 'ilmn']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'awarded', 'contract', 'rebuild', 'sabah', 'forest', 'industries', 'sfi', 'pulp', 'mill', 'sabah', 'malaysia']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '1', '2008', 'finnish', 'consulting', 'engineering', 'company', 'poyry', 'oyj', 'omx', 'poy1v', 'said', 'today', 'awarded', 'eur', '5', '2', 'million', 'usd', '7', '4', 'extension', 'existing', 'consultancy', 'engineering', 'contract', 'venezuel']
#
#
# ===Tokens:===
# ['finnish', 'kci', 'konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'delivered', '2007']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'release', 'february', '11', '2011', 'at8', '45', 'esl', 'shipping', 'ltd', 'part', 'aspo', 'group', 'signed', 'new', 'long', 'term', 'contract', 'rautaruukki', 'corporation', 'marine', 'transport', 'raw', 'materials', 'baltic', 'sea']
#
#
# ===Tokens:===
# ['long', 'pcln']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'management', 'software', 'solutions', 'provider', 'ixonos', 'oyj', 'hel', 'xns1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '3', '5', 'million', 'usd', '4', '5', '2008', 'eur', '3', '1', 'million', '2007']
#
#
# ===Tokens:===
# ['stock', 'rose', 'second', 'day', 'wednesday', 'bringing', 'two', 'day', 'rise', 'gbx12', '0', '2', '0']
#
#
# ===Tokens:===
# ['new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties']
#
#
# ===Tokens:===
# ['handelsbanken', 'ranked', 'local', 'cooperative', 'banks', 'aktia', 'customer', 'loyalty', 'time', 'however']
#
#
# ===Tokens:===
# ['fedday', 'looking', 'sharp', 'move', 'equities', 'aapl', 'hd', 'low', 'fb', 'seeing', 'uvxy', 'tvix', 'getting', 'hammered', 'even', 'though', 'market']
#
#
# ===Tokens:===
# ['operating', 'profit', 'grain', 'trading', 'increased', 'eur', '2', '0', 'mn', 'eur', '1', '4', 'mn', '2005']
#
#
# ===Tokens:===
# ['section', 'regional', 'news', 'demand', 'finnair', 'asian', 'traffic', 'measured', 'passenger', 'kilometers', '34', '9', 'august', 'compare', 'last', 'year']
#
#
# ===Tokens:===
# ['nflx', '3', 'lows']
#
#
# ===Tokens:===
# ['geosolutions', 'technology', 'leverage', 'benefon', 'gps', 'solutions', 'providing', 'location', 'based', 'search', 'technology', 'communities', 'platform', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model']
#
#
# ===Tokens:===
# ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa']
#
#
# ===Tokens:===
# ['15', 'december', '2010', 'finnish', 'german', 'telecoms', 'equipment', 'maker', 'nokia', 'siemens', 'networks', 'said', 'today', 'contract', 'upgrade', 'radio', 'network', 'home', 'based', 'telecommunications', 'company', 'elisa', 'oyj', 'hel', 'eli1v']
#
#
# ===Tokens:===
# ['zurich', 'insurance', 'considering', 'offer', 'uk', 'rival', 'rsa', 'insurance']
#
#
# ===Tokens:===
# ['full', '2010', 'company', 'expects', 'net', 'sales', 'operating', 'result', 'improve', 'previous', 'year', 'saying', 'positive', 'operating', 'result', 'amount', 'depend', 'order', 'intake', 'end', 'summer']
#
#
# ===Tokens:===
# ['looking', 'strong', 'bounce', 'spy', 'lunchtime', 'rally', 'coming', 'dia', 'iwm', 'qqq', 'aa', 'fb']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur', '36', 'million', 'eur', '27', 'million']
#
#
# ===Tokens:===
# ['company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230', '000', 'tonnes', 'copper']
#
#
# ===Tokens:===
# ['long', 'position', 'gol', 'updating', 'http', 'stks', 'co', 'fdmm']
#
#
# ===Tokens:===
# ['transaction', 'also', 'rationalize', 'pulp', 'paper', 'industry', 'related', 'solutions']
#
#
# ===Tokens:===
# ['neste', 'oil', 'corp', 'signed', 'long', 'term', 'procurement', 'contracts', 'honkajoki', 'oy', 'findest', 'protein', 'oy', 'owned', 'finnish', 'food', 'manufacturers', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'neste', '200', '000', 'b', 'cd', 'porvoo', 'finland', 'refinery']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur3', '1', 'net', 'sales', 'increased', 'eur61', '5', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['finnish', 'aldata', 'solution', 'signed', 'contract', 'supply', 'g', 'l', 'system', 'two', 'french', 'retail', 'chains']
#
#
# ===Tokens:===
# ['reached', 'agreement', 'union', 'flights', 'continue', 'normal', 'finnair', 'spokesman', 'usko', 'maatta', 'said']
#
#
# ===Tokens:===
# ['real', 'sales', 'expected', 'increased', '4', 'year', 'year', 'eur609m', 'second', 'quarter', '2010']
#
#
# ===Tokens:===
# ['australia', 'clears', 'ab', 'inbev', '100', 'billion', 'sabmiller', 'buyout', 'plan']
#
#
# ===Tokens:===
# ['far', 'mr', 'galvan', 'able', 'avoid', 'laying', 'workers']
#
#
# ===Tokens:===
# ['abb', 'deutsche', 'bank', 'upgraded', 'recommendation', 'swiss', 'swedish', 'engineering', 'group', 'abb', 'ltd', 'buy', 'hold']
#
#
# ===Tokens:===
# ['slowly', 'adding', 'fio', 'got', 'ta', 'careful', 'one', 'biggest', 'winners', '2012']
#
#
# ===Tokens:===
# ['see', '200', 'day', 'sma', 'big', 'hurdle', 'good', 'base', 'building', 'nflx', 'https', 'co', 'imkygo2cyc']
#
#
# ===Tokens:===
# ['news', 'feedschroders', 'books', 'solid', 'earnings', 'growth', 'several', 'board', 'changes']
#
#
# ===Tokens:===
# ['astrazeneca', 'weighing', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug']
#
#
# ===Tokens:===
# ['thanks', 'wide', 'contact', 'network', 'good', 'knowledge', 'market', 'business', 'environment', 'give', 'great', 'contribution', 'development', 'indian', 'operations', 'tells', 'incap', 'president', 'ceo', 'juhani', 'hanninen']
#
#
# ===Tokens:===
# ['design', 'team', 'long', 'admired', 'marimekko', 'vivid', 'patterns', 'colors']
#
#
# ===Tokens:===
# ['much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'finland', 'canada']
#
#
# ===Tokens:===
# ['arm', 'royalties', 'accelerate', 'smartphone', 'market', 'regains', 'strength']
#
#
# ===Tokens:===
# ['following', 'transaction', 'lundbeck', 'worldwide', 'rights', 'nalmefene', 'excluding', 'north', 'america', 'mexico', 'turkey', 'south', 'korea']
#
#
# ===Tokens:===
# ['fb', '110', '20', 'starting', 'show', 'relative', 'strength', 'signs', 'potential', 'b', 'daily']
#
#
# ===Tokens:===
# ['piper', 'upgrades', 'symantec', 'improving', 'renewal', 'rates', 'enterprise', 'growth', 'symc']
#
#
# ===Tokens:===
# ['district', 'court', 'helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005']
#
#
# ===Tokens:===
# ['china', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', 'also', 'strengthen', 'capability', 'offer', 'industry', 'leading', 'products', 'customers', 'china']
#
#
# ===Tokens:===
# ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'co', 'xk6lz3ui3k']
#
#
# ===Tokens:===
# ['adobe', 'receives', 'new', 'rating', 'top', 'analyst', 'adbe', 'https', 'co', 'ljnxpevhzn']
#
#
# ===Tokens:===
# ['assignment', 'strengthens', 'poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry']
#
#
# ===Tokens:===
# ['finnish', 'outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'ozk', 'kardzhali', 'zinc', 'smelter', 'bulgaria']
#
#
# ===Tokens:===
# ['london', 'open', 'taylor', 'wimpey', 'ashtead', 'drive', 'markets', 'higher', 'barclays', 'falls']
#
#
# ===Tokens:===
# ['es', 'f', 'nice', 'little', 'cup', 'handle', 'shaping', '15', 'minute', 'end', 'day', 'spy', 'spx', 'favours', 'good', 'day', 'index', 'see', 'gap', 'open']
#
#
# ===Tokens:===
# ['finland', 'insurance', 'company', 'pohjola', 'finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', 'traffic', 'safety']
#
#
# ===Tokens:===
# ['soapstone', 'deposits', 'medvezhyegorsk', 'area', 'expected', 'increase', 'tulikivi', 'current', 'reserves', 'considerably']
#
#
# ===Tokens:===
# ['q1', '10', '19', 'april', '2010', 'finnish', 'forest', 'machinery', 'equipment', 'maker', 'ponsse', 'oyj', 'hel', 'pon1v', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'eur6', '3', 'first', 'quarter', '2010', 'eur9', '6', 'loss', 'year', 'earlier']
#
#
# ===Tokens:===
# ['isrg', 'pt', 'raised', '700', '640', 'leerink', 'keeps', 'outperform', 'rated']
#
#
# ===Tokens:===
# ['q1', '2010', '18', 'may', '2010', 'finnish', 'electrical', 'components', 'maker', 'salcomp', 'oy', 'hel', 'sal1v', 'said', 'today', 'turned', 'net', 'profit', 'eur1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'eur2m', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['purchase', 'agreement', '7', '200', 'tons', 'gasoline', 'delivery', 'hamina', 'terminal', 'finland', 'signed', 'neste', 'oil', 'oyj', 'average', 'platts', 'index', 'september', 'plus', 'eight', 'us', 'dollars', 'per', 'month']
#
#
# ===Tokens:===
# ['added', 'bbby', 'jimcramer', 'wrong', 'one', 'still', 'profitable', 'merchant', 'profitable', 'stores']
#
#
# ===Tokens:===
# ['reporting', 'period', 'biotie', 'north', 'american', 'licensing', 'partner', 'somaxon', 'pharmaceuticals', 'announced', 'positive', 'results', 'nalmefene', 'pilot', 'phase', '2', 'clinical', 'trial', 'smoking', 'cessation']
#
#
# ===Tokens:===
# ['production', 'capacity', 'increase', '36', '000', '85', '000', 'tonnes', 'per', 'year', 'raw', 'material', 'continue', 'recycled', 'paper', 'board']
#
#
# ===Tokens:===
# ['government', 'professional', 'approach', 'assessing', 'offer']
#
#
# ===Tokens:===
# ['onty', 'continues', 'base', 'debate', 'lingers', 'ont', '10', 'data', 'next', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'moves', '10', 'downside', 'limited']
#
#
# ===Tokens:===
# ['result', 'distribution', 'companies', 'start', 'distribute', 'addition', 'current', 'product', 'offering', 'shimano', 'reels', 'rods', 'shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis']
#
#
# ===Tokens:===
# ['gild', 'expanding', 'research', 'facilities', 'keeping', 'pace', 'innovation', 'https', 'co', 'uoe7fj4lop']
#
#
# ===Tokens:===
# ['finnish', 'pulp', 'paper', 'machinery', 'maker', 'vaahto', 'group', 'oyj', 'swung', '1', '1', 'mln', 'euro', '1', '4', 'mln', 'net', 'profit', 'fiscal', '2005', '06', 'ended', 'august', '31', '2006', '249', '000', 'euro', '319', '000', 'net', 'loss', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['drugmaker', 'shire', 'buy', 'baxalta', '32', 'billion', '6', 'month', 'pursuit']
#
#
# ===Tokens:===
# ['fda', 'approves', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '83', '0', 'mn', 'eur', '23', '5', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'klabin', 'tel', 'maco', 'borba', 'mill', 'brazilian', 'state', 'paran']
#
#
# ===Tokens:===
# ['barclays', 'bank', 'america', 'citigroup', 'blockchain', 'sight']
#
#
# ===Tokens:===
# ['savon', 'koulutuskuntayhtyma', 'finland', 'based', 'company', 'awarded', 'contract', 'specialist', 'agricultural', 'forestry', 'machinery']
#
#
# ===Tokens:===
# ['brazilian', 'unit', 'finnish', 'security', 'solutions', 'provider', 'f', 'secure', 'signed', '1', '500', 'new', 'clients', 'last', 'year', 'online', 'news', 'source', 'reseller', 'web', 'quoted', 'division', 'commercial', 'director', 'vladimir', 'brand', 'saying']
#
#
# ===Tokens:===
# ['company', 'make', 'marketing', 'sales', 'investments', 'initiated', '2009', 'even', 'efficient', '2010']
#
#
# ===Tokens:===
# ['amazon', 'grocery', 'deal', 'morrisons', 'beginning']
#
#
# ===Tokens:===
# ['axp', 'looking', 'continuation', 'volume', 'increase', 'http', 'stks', 'co', 'c8sr']
#
#
# ===Tokens:===
# ['total', 'operating', 'revenue', 'grew', '27', '6', 'year', 'year', 'eur61m']
#
#
# ===Tokens:===
# ['coh', 'gaining', 'momentum', 'nice', 'buy', 'signals', 'long', '35', '92', 'http', 'stks', 'co', 't0tah']
#
#
# ===Tokens:===
# ['md', 'henning', 'bahr', 'stockmann', 'gruppen', 'praises', 'trend', 'since', 'chains', 'become', 'stronger', 'decision', 'making', 'processes', 'clear']
#
#
# ===Tokens:===
# ['20', 'october', '2010', 'finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'eur7m', 'first', 'nine', 'months', '2010', 'eur23', '3', 'period', '2009']
#
#
# ===Tokens:===
# ['svyturys', 'utenos', 'alus', 'controlled', 'nordic', 'group', 'baltic', 'beverages', 'holding', 'bbh', 'posted', '4', '7', 'per', 'cent', 'growth', 'beer', 'sales', 'january', 'may', '46', '22', 'million', 'litres']
#
#
# ===Tokens:===
# ['finnish', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'net', 'loss', 'contracted', 'eur', '49', 'million', 'usd', '68', '2', 'first', 'nine', 'months', '2010', 'eur', '229', 'million', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'consolidated', 'net', 'operating', 'profit', 'increased', 'eur', '4', '8', 'mn', 'first', 'quarter', '2005', 'eur', '6', '4', 'mn', 'first', 'quarter', '2006']
#
#
# ===Tokens:===
# ['real', 'corporation', 'press', 'release', '3', 'november', '10', '35', 'real', 'corporation', 'second', 'best', 'company', 'materials', 'sector', 'including', 'e', 'g', 'forest', 'industry', 'companies', 'carbon', 'disclosure', 'leadership', 'index', 'cdli', 'nordic', 'report', '2009']
#
#
# ===Tokens:===
# ['aapl', 'dips', 'bought', 'real', 'quick', 'higher', 'lows', 'fo', 'sho']
#
#
# ===Tokens:===
# ['lse', 'deutsche', 'boerse', 'merger', 'would', 'signal', 'end', 'exchange', 'mega', 'deals']
#
#
# ===Tokens:===
# ['save', 'breaking', 'downtrend', 'line', 'increasing', 'volume', 'move', '20', '57', 'could', 'see', 'upside', 'http', 'stks', 'co', 'l8y4']
#
#
# ===Tokens:===
# ['rcon', 'upside', 'today', 'thing', 'severe', 'low', 'float', 'catalyst', 'guy', 'run']
#
#
# ===Tokens:===
# ['eli', 'lilly', 'co', 'lly', 'broken', 'new', 'high', 'astrazeneca', 'collaboration']
#
#
# ===Tokens:===
# ['iaci', 'http', 'stks', 'co', 'tju', 'looks', 'good', 'weekly', 'chart']
#
#
# ===Tokens:===
# ['vmw', 'got', 'nice', 'push', 'today', 'following', 'small', 'sweepers', 'may', 'c', 'morning']
#
#
# ===Tokens:===
# ['teleste', 'acquisition', 'marks', 'entry', 'services', 'business', 'market', 'long', 'established', 'significant', 'supplier', 'products']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '500', '000', 'usd', '680', '000', 'last', 'quarter', '2010', 'eur', '5', '3', 'million', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '29', '2008', 'finnish', 'lifting', 'equipment', 'maker', 'konecranes', 'oyj', 'omx', 'kcr1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '116', '6', 'million', 'usd', '149', '1', 'first', 'nine', 'months', '2008', 'eur', '73', '6', 'million']
#
#
# ===Tokens:===
# ['lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'kaluga', 'regional', 'administration', 'last', 'november']
#
#
# ===Tokens:===
# ['operating', 'profit', 'asian', 'plants', 'grew', 'markedly']
#
#
# ===Tokens:===
# ['truly', 'takes', 'efficiency', 'new', 'heights', 'mr', 'metso', 'adds']
#
#
# ===Tokens:===
# ['january', 'september', '2007', 'group', 'net', 'sales', 'continuing', 'operations', 'rose', 'eur', '213', '1', 'mn', 'eur', '172', '6', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['transaction', 'strengthens', 'position', 'design', 'branded', 'goods', 'said', 'fiskars', 'president', 'ceo', 'heikki', 'allonen', 'pointing', 'two', 'groups', 'relatively', 'overlapping', 'operations']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '5', '5', 'mn', 'eur', '0', '7', 'mn']
#
#
# ===Tokens:===
# ['memorandum', 'understanding', 'mou', 'parties', 'collaborate', 'preparing', 'implementing', 'joint', 'projects', 'fields', 'combined', 'power', 'heat', 'generation', 'environmental', 'protection', 'energy', 'efficient', 'technologies']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['easyjet', 'attracts', 'passengers', 'june', 'still', 'lags', 'ryanair']
#
#
# ===Tokens:===
# ['cern', 'consolidating', '50', '200', 'nice', 'long', 'entry', 'w', 'stop', '10', 'targeting', '70', 'area']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'gains', 'land', 'securities', 'dividend', 'hike']
#
#
# ===Tokens:===
# ['bbry', 'ready', 'take']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '5', '8', 'mn', 'loss', 'eur', '1', '7', 'mn', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['metso', 'supply', 'equipment', 'two', 'process', 'lines', 'northland', 'resources', 'new', 'kaunisvaara', 'iron', 'ore', 'project', 'sweden', 'exploits', 'tapuli', 'sahavaara', 'iron', 'ore', 'deposits']
#
#
# ===Tokens:===
# ['carnival', 'corporation', 'china', 'merchants', 'group', 'sign', 'memo', 'understanding']
#
#
# ===Tokens:===
# ['alma', 'media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'order', 'supply', 'uncoated', 'fine', 'paper', 'machine', 'mcc', 'paper', 'yinhe', 'china']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '94', 'mn', 'eur', '2', '45', 'mn']
#
#
# ===Tokens:===
# ['diluted', 'loss', 'per', 'share', 'stood', 'eur', '0', '15', 'versus', 'eur', '0', '26']
#
#
# ===Tokens:===
# ['3', 'january', '2011', 'finnish', 'flag', 'carrier', 'finnair', 'oyj', 'hel', 'fia1s', 'said', 'today', 'sealed', 'nine', 'year', 'sale', 'leaseback', 'agreement', 'newest', 'airbus', 'a330', 'aircraft', 'syndication', 'japanese', 'operating', 'lease', 'market']
#
#
# ===Tokens:===
# ['auto', 'trader', 'share', 'price', 'surges', 'company', 'floats', 'lse']
#
#
# ===Tokens:===
# ['company', 'said', 'estimates', 'make', 'slight', 'profit', 'thanks', 'cost', 'cutting', 'measures']
#
#
# ===Tokens:===
# ['aapl', 'taking', 'shorts', 'punishing', 'reminder', 'spear', 'strongest', 'herd']
#
#
# ===Tokens:===
# ['raute', 'posted', 'net', 'profit', '1', '8', 'mln', 'euro', '2', '6', 'mln', 'third', 'quarter', '2007', 'compared', 'net', 'loss', '299', '000', 'euro', '430', '000', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['yahoo', 'stock', '36', '46', 'bidding', 'war', 'picks', 'company', 'https', 'co', 'jdnzxdcmkl', 'yhoo', 'https', 'co', 'hmoegfhgvn']
#
#
# ===Tokens:===
# ['company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', 'adding', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year']
#
#
# ===Tokens:===
# ['goog', 'breakout', 'likely', 'medium', 'target', '700', 'http', 'stks', 'co', '1lpz', 'http', 'chart', 'ly', 'lgb94rr']
#
#
# ===Tokens:===
# ['singapore', 'icis', '1', 'kemira', 'indian', 'water', 'infrastructure', 'firm', '2', 'ivrcl', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'andhra', 'pradesh', 'state', 'india', 'finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'tuesday']
#
#
# ===Tokens:===
# ['goog', 'testing', '200', 'day', 'consolidation', 'http', 'stks', 'co', 'h0cpj']
#
#
# ===Tokens:===
# ['prlb', 'hanging', 'tough', 'market', 'due', 'analyst', 'upgrades', 'last', 'week', 'almost', '3']
#
#
# ===Tokens:===
# ['energy', 'efficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'state', 'art', 'technology']
#
#
# ===Tokens:===
# ['entering', 'long', 'lockheed', 'martin', 'lmt', 'thursday', 'open', 'http', 'stks', 'co', 'exta']
#
#
# ===Tokens:===
# ['company', 'order', 'book', 'stood', '1', '5', 'bln', 'euro', '2', '2', 'bln', 'september', '30', '2007', '24', '2', 'pct', 'year', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '534', '3', 'mln']
#
#
# ===Tokens:===
# ['aim', 'ensure', 'vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', 'comments', 'vacon', 'plc', 'president', 'ceo', 'vesa', 'laisi']
#
#
# ===Tokens:===
# ['two', 'companies', 'also', 'partner', 'developing', 'raiso', 'cholesterol', 'lowering', 'brand', 'benecol']
#
#
# ===Tokens:===
# ['nyse', 'owner', 'ice', 'considers', 'offer', 'lse']
#
#
# ===Tokens:===
# ['astrazeneca', 'bags', 'another', 'cancer', 'drug', 'deal', 'time', 'inovio']
#
#
# ===Tokens:===
# ['adbe', 'technical', 'alerts', 'expansion', 'breakout', 'gilligan', 'island', 'sell', 'setup', 'volume', 'surge', 'new', '52', 'https', 'co', 'lxx66tknfh']
#
#
# ===Tokens:===
# ['change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', 'said', 'julia', 'prohaska', 'director', 'marketing', 'communications', 'fiskars']
#
#
# ===Tokens:===
# ['ebit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '67', '8', 'mn', 'eur', '38', '1', 'mn']
#
#
# ===Tokens:===
# ['finland', 'national', 'carrier', 'finnair', 'plc', 'carried', 'record', '8', '5', 'million', 'passengers', '2005', 'increase', '4', '5', 'percent', 'previous', 'year', 'airline', 'reported', 'tuesday']
#
#
# ===Tokens:===
# ['fb', 'trending', 'nicely', 'intraday']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur36m', 'eur27m']
#
#
# ===Tokens:===
# ['last', 'week', 'finnish', 'metals', 'technology', 'group', 'announced', 'plans', 'sell', '80', 'percent', 'technology', 'unit', 'company', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'raises', 'prospect', 'investor', 'payout']
#
#
# ===Tokens:===
# ['satama', 'earned', 'data', 'management', 'solutions', 'competency', 'business', 'intelligence', 'specialization', 'recentlyvia', 'acquisition', 'fimentor', 'oy']
#
#
# ===Tokens:===
# ['spain', 'caixabank', 'launches', 'new', 'takeover', 'bid', 'banco', 'bpi']
#
#
# ===Tokens:===
# ['gild', 'chart', 'ibb', 'back', 'support', 'https', 'co', 'gprz2ujfc4']
#
#
# ===Tokens:===
# ['ebit', 'totalled', 'eur', '14', '4', 'mn', 'compared', 'loss', 'eur', '0', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['stora', 'enso', 'r', 'shares', 'rose', '1', '20', 'pct', '11', '84', 'eur', 'upm', 'kymmene', 'also', 'dragged', 'higher', 'rising', '1', '68', 'pct', '17', '56', 'eur', 'real', 'b', 'added', '2', '38', 'pct', '4', '30', 'eur']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'amounted', 'ee', '55', '5', 'mn', '36', '2004']
#
#
# ===Tokens:===
# ['press', 'serco', 'set', 'appoint', 'roy', 'gardner', 'ex', 'centrica', 'chairman', 'ft']
#
#
# ===Tokens:===
# ['aapl', 'downgrade', 'bias', 'stock', 'buy']
#
#
# ===Tokens:===
# ['aapl', 'new', 'long', '110', '61', 'broken', 'targets', '112', '19', '119', '86', '123', '82', 'bears', 'must', 'retake', '102', '77', 'qqq', 'nq', 'f', 'ndx', 'https', 'co', '6l3m1wxchw']
#
#
# ===Tokens:===
# ['retailers', 'kingfisher', 'sports', 'direct', 'rise', 'britain', 'share', 'index']
#
#
# ===Tokens:===
# ['bought', 'celg', 'ready', 'bounce']
#
#
# ===Tokens:===
# ['aim', 'convert', 'plants', 'flexible', 'manufacturers', 'new', 'technologically', 'demanding', 'products']
#
#
# ===Tokens:===
# ['arm', 'profits', 'sales', 'shift', 'away', 'mobile', 'gains', 'pace']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'rose', 'eur', '1', '019', 'mn', 'eur', '1', '007', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'ftse', 'higher', 'clubcard', 'bid', 'reports']
#
#
# ===Tokens:===
# ['update', '1', 'astrazeneca', 'sells', 'rare', 'cancer', 'drug', 'sanofi', '300', 'mln']
#
#
# ===Tokens:===
# ['mako', 'hanging', 'well', 'today', 'still', 'basing', 'pattern', 'eyes']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'metso', 'said', 'upgrade', 'one', 'upm', 'kymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', 'machine', 'process', 'controls', 'quality', 'measurements']
#
#
# ===Tokens:===
# ['contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', 'oil', 'shale', 'processing']
#
#
# ===Tokens:===
# ['brooklynbandit', 'simo', 'basing', 'nice', 'close', '24', '18', 'bullish', 'qqq', 'spy', 'study', 'watch', 'close', 'near', 'hod', 'currently', '3', '5']
#
#
# ===Tokens:===
# ['alert', 'new', 'macd', 'signal', 'created', 'ctxs', 'buy', '77', '09', 'time', '18', '23', 'strength', '10', 'powered', 'https', 'co', '4tdgjedllz']
#
#
# ===Tokens:===
# ['resulted', 'improved', 'sales', 'figures', 'sweden']
#
#
# ===Tokens:===
# ['tectia', 'corporation', 'hel', 'tec1v', 'provider', 'real', 'time', 'security', 'solutions', 'today', 'announced', 'appointed', 'lan2lan', 'provider', 'services', 'uk', 'distribute', 'data', 'security', 'manage', 'file', 'transfer', 'software']
#
#
# ===Tokens:===
# ['long', 'aapl']
#
#
# ===Tokens:===
# ['ino', 'back', 'small', 'post']
#
#
# ===Tokens:===
# ['helsinki', 'eliiv', 'today', 'reported', 'eps', 'eur1', '13', '2009', 'increase', 'eps', 'eur1', '12', '2008']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'oyj', 'said', 'november', '13', '2007', '70', 'mln', 'euro', '102', '8', 'mln', 'contract', 'construct', 'new', 'office', 'building', 'local', 'property', 'company', 'tapiola', 'real', 'estate', 'oy']
#
#
# ===Tokens:===
# ['shorts', 'altr', '38', '85', 'loss']
#
#
# ===Tokens:===
# ['2nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increases', 'quarterly', 'cash', 'dividend', '20', 'percent', 'http', 'stks', 'co', 'goan']
#
#
# ===Tokens:===
# ['combining', 'existing', 'solutions', 'single', 'platform', 'comptel', 'said', 'reduced', 'cost', 'deployment']
#
#
# ===Tokens:===
# ['neon', 'oversold']
#
#
# ===Tokens:===
# ['third', 'quarter', '2010', 'net', 'sales', 'increased', '5', '2', 'eur', '205', '5', 'mn', 'operating', 'profit', '34', '9', 'eur', '23', '5', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'long', '630', '91']
#
#
# ===Tokens:===
# ['pioneer', 'library', 'system', 'one', '127', 'libraries', 'municipalities', 'arts', 'culture', 'higher', 'education', 'science', 'organizations', 'awarded', 'grants', 'participate', 'big', 'read', 'largest', 'federal', 'reading', 'program', 'u', 'history']
#
#
# ===Tokens:===
# ['financing', 'arrangements', 'enable', 'company', 'ensure', 'line', 'treasury', 'policy', 'sufficient', 'financial', 'instruments', 'disposal', 'potential', 'capital', 'requirements']
#
#
# ===Tokens:===
# ['operating', 'income', 'rose', 'eur', '696', '4', 'mn', 'eur', '600', '3', 'mn', '2009']
#
#
# ===Tokens:===
# ['rt', 'andrewnyquist', 'chartology', 'yahoo', 'http', 'stks', 'co', '1itr', 'yhoo', 'crazy', 'looking', 'chart', 'nearing', 'breakout', 'resistance', 'line']
#
#
# ===Tokens:===
# ['sainsbury', 'sells', 'unit', 'lloydspharmacy']
#
#
# ===Tokens:===
# ['liking', 'price', 'action', 'swks', 'currently', '21', '80', 'target', '24', '00', 'year', 'end']
#
#
# ===Tokens:===
# ['group', 'expand', 'chain', 'include', '45', 'stores']
#
#
# ===Tokens:===
# ['finnish', 'consulting', 'engineering', 'group', 'poyry', 'plc', 'omx', 'helsinki', 'poy', 'said', 'wednesday', '1', 'october', 'awarded', 'contract', 'tanqia', 'dibba', 'fzc', 'owner', 'engineer', 'wastewater', 'system', 'dibba', 'emirate', 'fujairah', 'uae']
#
#
# ===Tokens:===
# ['trend', 'underpins', 'uk', 'sales', 'growth', 'kingfisher']
#
#
# ===Tokens:===
# ['lee', 'man', 'paper', 'metso', 'long', 'prosperous', 'co', 'operation', 'good', 'example', 'changshu', 'hongmei', 'kraftliner', 'machines', 'delivered', 'earlier']
#
#
# ===Tokens:===
# ['ibm', 'staying', 'strong']
#
#
# ===Tokens:===
# ['open', 'next', 'year', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['turun', 'kaupunkin', 'finland', 'based', 'company', 'awarded', 'contract', 'lemminkainen', 'talotekniikka', 'oy', 'electrical', 'installation', 'work']
#
#
# ===Tokens:===
# ['revenue', 'grew', '12', 'percent', 'x20ac', '3', '6', 'billion', 'us', '4', '5', 'billion']
#
#
# ===Tokens:===
# ['royal', 'dutch', 'shell', 'buy', 'bg', 'group', 'nearly', '70', 'billion']
#
#
# ===Tokens:===
# ['estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters']
#
#
# ===Tokens:===
# ['eps', 'continuing', 'operations', 'came', '0', '30', 'eur', '0', '17']
#
#
# ===Tokens:===
# ['stable', 'outlook', 'reflects', 'nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', 'strong', 'cash', 'flow', 'generation', 'conservative', 'balance', 'sheet', 'said', 'raab']
#
#
# ===Tokens:===
# ['whitbread', 'share', 'price', 'climbs', 'q4', 'sales', 'growth']
#
#
# ===Tokens:===
# ['financial', 'impact', 'estimated', 'annual', 'improvement', 'eur2', '0', 'division', 'results', 'fiscal', 'year', '2008']
#
#
# ===Tokens:===
# ['kndi', 'let', 'see', 'higher', 'highs', 'higher', 'lows', 'rest', 'day', 'slow', 'steady']
#
#
# ===Tokens:===
# ['adp', 'news', 'finnish', 'handling', 'systems', 'provider', 'cargotec', 'oyj', 'hel', 'cgcbv', 'announced', 'friday', 'orders', 'worth', 'eur', '10', 'million', 'usd', '13', '2', 'deliver', 'linkspans', 'jordan', 'morocco', 'ireland']
#
#
# ===Tokens:===
# ['continued', 'actively', 'focus', 'r', 'position', 'offering', 'away', 'point', 'solutions', 'towards', 'dynamic', 'end', 'end', 'solutions', 'ervio', 'stated']
#
#
# ===Tokens:===
# ['sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season']
#
#
# ===Tokens:===
# ['transaction', 'positive', 'impact', 'around', 'eur2m', 'earnings', 'ruukki', 'recognize', 'fourth', 'quarter', 'year']
#
#
# ===Tokens:===
# ['kesko', 'car', 'import', 'retailing', 'business', 'vv', 'auto', 'saw', 'sales', 'grow', '17', '1', 'pct']
#
#
# ===Tokens:===
# ['insight', 'hires', 'aviva', 'david', 'hillier', 'multi', 'asset', 'team']
#
#
# ===Tokens:===
# ['news', 'feedftse', '100', 'movers', 'ashtead', 'jumps', 'strong', 'interims', 'glencore', 'bp']
#
#
# ===Tokens:===
# ['main', 'strength', 'cooperation', 'project', 'lies', 'merging', 'know', 'two', 'large', 'companies']
#
#
# ===Tokens:===
# ['company', 'also', 'featured', 'ethibel', 'pioneer', 'investment', 'register', 'included', 'innovest', 'global', '100', 'list', 'world', 'sustainable', 'corporations']
#
#
# ===Tokens:===
# ['london', 'morning', 'briefing', 'hsbc', 'standard', 'chartered', 'shares', 'rise']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'rose', '11', '4', 'year', '82', '2', 'million', 'euros', '2005', 'sales', '686', '5', 'million', 'euros', '13', '8', 'year', 'company', 'said', 'earlier']
#
#
# ===Tokens:===
# ['tsla', 'bad', 'day', 'short']
#
#
# ===Tokens:===
# ['objective', 'planned', 'measures', 'achieve', 'significant', 'savings', 'next', 'years']
#
#
# ===Tokens:===
# ['update', '3', 'auto', 'trader', 'shares', 'leap', 'uk', 'biggest', 'private', 'equity', 'backed', 'listing']
#
#
# ===Tokens:===
# ['besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', 'paavel', 'said']
#
#
# ===Tokens:===
# ['ftse', 'rallies', 'three', 'month', 'low', 'boosted', 'stanchart', 'sainsbury']
#
#
# ===Tokens:===
# ['aria', 'bounce', 'player', 'long', '6', '17', 'http', 'stks', 'co', 'q0wff']
#
#
# ===Tokens:===
# ['consolidated', 'operating', 'profit', 'excluding', 'one', 'items', 'eur', '30', '6', 'mn', 'eur', '29', '6', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bullya', 'pollux654321', '50', 'kors', '80', 'calls', 'going', 'b', 'blessing', 'daughters', 'tuition']
#
#
# ===Tokens:===
# ['according', 'sepp', 'nen', 'new', 'technology', 'umts900', 'solution', 'network', 'building', 'costs', 'one', 'third', 'lower', 'building', '3', '5', 'g', 'networks', 'operating', '2', '100', 'mhz', 'frequency']
#
#
# ===Tokens:===
# ['crus', 'upgraded', 'buy', 'alpha', 'street', 'research']
#
#
# ===Tokens:===
# ['favourable', 'currency', 'rates', 'also', 'contributed', 'higher', 'net', 'sales', 'ceo', 'kari', 'kauniskangas', 'said']
#
#
# ===Tokens:===
# ['tesco', 'breaks', 'downward', 'slide', 'cutting', 'sales', 'decline', 'half']
#                       0   1
# 0             net sales  80
# 1      operating profit  77
# 2             http stks  73
# 3               stks co  73
# 4              https co  62
# ...                 ...  ..
# 14097    downward slide   1
# 14098     slide cutting   1
# 14099     cutting sales   1
# 14100     sales decline   1
# 14101      decline half   1
#
# [14102 rows x 2 columns]

# %%
# Creating negative bigrams

for text in train_set[train_set['Sentiment']=='positive']['Sentence']:
    for word in generate_ngrams(text, 2):
        negativeWords_bi[word]+=1
df_negative_bi = pd.DataFrame(sorted(negativeWords_bi.items(),key=lambda x:x[1],reverse=True))
df_negative_bi
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['contrast', 'company', 'net', 'loss', 'third', 'quarter', '2009', 'contracted', 'eur', '76', 'million', 'eur', '256', 'million', 'corresponding', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finland', 'neste', 'oil', 'awarded', 'chemical', 'industry', 'federation', 'finland', 'innovation', 'award', 'nexbtl', 'technology', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['combining', 'deep', 'domain', 'expertise', 'application', 'service', 'management', 'asm', 'outsourcing', 'service', 'offerings', 'proved', 'winning', 'combination']
#
#
# ===Tokens:===
# ['trx', 'http', 'stks', 'co', '1kkk', 'long', 'setup', 'macd', 'cross']
#
#
# ===Tokens:===
# ['meanwhile', 'electrowatt', 'ekono', 'philippines', 'inc', 'also', 'awarded', 'three', 'year', 'operation', 'maintenance', 'contract', 'fr', 'cement', 'corporation']
#
#
# ===Tokens:===
# ['madison', 'wis', 'feb', '6', 'prnewswire', 'fiskars', 'announces', 'united', 'states', 'patent', 'trademark', 'office', 'granted', 'trademark', 'registration', 'color', 'orange', 'iconic', 'scissor', 'handles']
#
#
# ===Tokens:===
# ['wfm', 'bought', 'little', 'yesterday', 'hoping', 'earnings', 'pop']
#
#
# ===Tokens:===
# ['ragutis', 'controlled', 'finnish', 'brewery', 'reported', '5', '4', 'per', 'cent', 'rise', 'beer', 'sales', '10', '44', 'million', 'litres', 'held', '11', '09', 'per', 'cent', 'market', 'share']
#
#
# ===Tokens:===
# ['addition', 'cramo', 'peab', 'signed', 'exclusive', 'five', 'year', 'rental', 'agreements', 'finland', 'extended', 'existing', 'rental', 'agreements', 'swedish', 'market', 'another', 'five', 'years']
#
#
# ===Tokens:===
# ['combined', 'foreign', 'investments', 'creates', 'interesting', 'opportunities', 'solteq']
#
#
# ===Tokens:===
# ['osur', '33', 'since', '6', '25', 'buy', 'signal', 'resistance', '5', '33', 'expect', '1', 'pullback', '2nd', 'half', 'day', '2', 'break', 'abov', '5', '33', 'continue', 'rally', '4', '5', 'days']
#
#
# ===Tokens:===
# ['federal', 'secretary', 'transport', 'communication', 'mexico', 'awarded', 'poyry', 'mexican', 'partner', 'sintra', 'consulting', 'contract', 'connection', 'buenavista', 'cuautitlan', 'suburban', 'railway']
#
#
# ===Tokens:===
# ['kndi', 'china', 'electriccar', 'maker', 'china', 'car', 'sales', '7', '8', 'also', 'may', 'feed', 'tsla', 'momentum', 'run', 'lately']
#
#
# ===Tokens:===
# ['agreement', 'signed', 'biohit', 'healthcare', 'ltd', 'uk', 'based', 'subsidiary', 'biohit', 'oyj', 'finnish', 'public', 'company', 'develops', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems']
#
#
# ===Tokens:===
# ['third', 'quarter', 'net', 'sales', 'increased', '12', 'year', 'year', 'eur159', '5', '6', 'comparable', 'currency', 'rates', 'growth']
#
#
# ===Tokens:===
# ['finnish', 'vacon', 'signed', 'significant', 'deals', 'norwegian', 'scandinavian', 'electric', 'systems', 'ses', 'supply', 'ac', 'drives']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'bounces', 'back', 'mondi', 'barratt', 'lead']
#
#
# ===Tokens:===
# ['update', 'barclays', 'expects', 'gain', 'settling', 'lehman', 'bros', 'trustee']
#
#
# ===Tokens:===
# ['interest', 'heats', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'co', 'j5jvji9bia']
#
#
# ===Tokens:===
# ['according', 'pkc', 'acquisition', 'would', 'bring', 'significant', 'addition', 'pkc', 'customer', 'base']
#
#
# ===Tokens:===
# ['buffett', 'berkshire', 'builds', 'deere', 'stake', 'dumps', 'exxon']
#
#
# ===Tokens:===
# ['etteplan', 'targets', 'employ', 'least', '20', 'people', 'borl', 'nge']
#
#
# ===Tokens:===
# ['slw', 'weekly', '34', 'calls', '28', '95', '23', 'x', '25', '321', 'volume', 'worth', 'chance', 'jmho', 'http', 'stks', 'co', '1qfg']
#
#
# ===Tokens:===
# ['finnish', 'food', 'industry', 'companies', 'hk', 'ruokatalo', 'atria', 'form', 'joint', 'venture', 'company', 'called', 'l', 'nsi', 'kalkkuna', 'produce', 'turkey', 'meat']
#
#
# ===Tokens:===
# ['sales', 'climbed', '19', '2', 'pct', '1', '002', 'bln', 'eur', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure']
#
#
# ===Tokens:===
# ['continuing', 'operations', 'turned', 'operating', 'loss', 'eur', '0', '1', 'mn', 'slight', 'improvement', 'loss', 'eur', '0', '2', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'leap', 'ftse', '100', 'marks', 'spencer', 'drops']
#
#
# ===Tokens:===
# ['basware', 'corporation', 'stock', 'exchange', 'release', 'august', '31', '2010', '16', '25', 'basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'basware', 'deliver', 'invoice', 'automation', 'solution', 'connectivity', 'services', 'international', 'industrial', 'group']
#
#
# ===Tokens:===
# ['also', 'turned', 'earnings', 'per', 'share', 'eps', 'eur', '0', '08', 'versus', 'loss', 'per', 'share', 'eur', '0', '04']
#
#
# ===Tokens:===
# ['company', 'consolidated', 'operating', 'profit', 'amounted', 'eur', '15', '86', 'mn', 'eur', '4', '14', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['aapl', 'right', 'back', 'buy', 'dips', 'brought', 'cnbc', 'lol']
#
#
# ===Tokens:===
# ['capman', 'partner', 'able', 'develop', 'business', 'continue', 'focus', 'providing', 'quality', 'restaurant', 'services', 'customers', 'says', 'christopher', 'wynne', 'ceo', 'papa', 'john', 'russia']
#
#
# ===Tokens:===
# ['technical', 'indicators', 'stock', 'bullish', 'p', 'gives', 'nok', 'positive', '4', 'stars', '5', 'buy', 'ranking']
#
#
# ===Tokens:===
# ['upm', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', 'efficiency', 'operations', 'improved', 'chief', 'executive', 'jussi', 'pesonen', 'said']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'maker', 'amer', 'sports', 'oyj', 'hel', 'ameas', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '16', '9', 'million', 'usd', '22', '3', 'second', 'quarter', '2010', 'eur', '23', '2', 'million', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['outokumpu', 'chief', 'executive', 'juha', 'rantanen', 'expressed', 'confidence', 'china', 'market']
#
#
# ===Tokens:===
# ['nflx', 'vision', 'short', 'term', 'consolidation', 'movement', 'higher', 'http', 'stks', 'co', 'j05uu']
#
#
# ===Tokens:===
# ['elcoteq', 'elcoteq', 'se', 'leading', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'communications', 'technology', 'field']
#
#
# ===Tokens:===
# ['renovation', 'biggest', 'moulding', 'line', 'orhangazi', 'foundry', 'modern', 'line', 'europe']
#
#
# ===Tokens:===
# ['company', 'established', '3g', 'base', 'station', '17', '000', 'feet', 'foot', 'mount', 'everest', 'enable', 'mountain', 'climbers', '29', '035', 'foot', 'summit', 'surf', 'internet', 'even', 'send', 'videos', 'exploits']
#
#
# ===Tokens:===
# ['spy', 'hang', 'bull', 'hat', 'yet', 'next', 'week', 'pop', 'higher', 'qe3', 'hope', 'back', 'fed', '2', 'day', 'meeting']
#
#
# ===Tokens:===
# ['return', 'investment', '16', '6', 'compared', '15', '8', '2004']
#
#
# ===Tokens:===
# ['finnish', 'investment', 'group', 'panostaja', 'oyj', 'said', 'net', 'profit', 'went', '8', '6', 'mln', 'euro', '11', '4', 'mln', 'fiscal', '2005', '06', 'ended', 'october', '31', '2006', '2', '8', 'mln', 'euro', '3', '7', 'mln', 'period', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['analysts', 'impressed', 'progress', 'tesla', 'flagship', 'factory', 'co', 'spent', '1', '6b', 'upgrades', '15', 'https', 'co', 'sabxcsn8cd', 'tsrandall', 'tsla']
#
#
# ===Tokens:===
# ['london', 'afx', 'shares', 'rautaruukki', 'corp', 'upgraded', 'hold', 'sell', 'abn', 'amro', 'price', 'target', 'raised', '25', '75', 'eur', '14', '5', 'said', 'dealers']
#
#
# ===Tokens:===
# ['narrows', 'eur2', '8', '9', 'mo', '09', '29', 'october', '2009', 'finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'net', 'loss', 'narrowed', 'eur2', '8', 'first', 'nine', 'months', '2009', 'eur35', '6', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['adp', 'news', 'nov', '18', '2008', 'finnish', 'ac', 'drives', 'manufacturer', 'vacon', 'oyj', 'omx', 'vac1v', 'said', 'today', 'set', 'new', 'representative', 'offices', 'romania', 'ukraine', 'serve', 'growing', 'markets', 'eastern', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['finnish', 'aktia', 'group', 'operating', 'profit', 'rose', 'eur', '17', '5', 'mn', 'first', 'quarter', '2010', 'eur', '8', '2', 'mn', 'first', 'quarter', '2009']
#
#
# ===Tokens:===
# ['first', 'nine', 'months', '2010', 'talvivaara', 'net', 'loss', 'narrowed', 'eur', '8', '3', 'million', 'eur', '21', '9', 'million', 'period', '2009']
#
#
# ===Tokens:===
# ['wpp', 'boosts', 'sales', 'despite', 'cautious', 'clients']
#
#
# ===Tokens:===
# ['fb', 'small', 'long', '109', '25', 'via', 'calls']
#
#
# ===Tokens:===
# ['altia', 'operating', 'profit', 'jumped', 'eur', '47', 'million', 'eur', '6', '6', 'million']
#
#
# ===Tokens:===
# ['lnt', 'increases', 'annual', 'dividend', 'target', '1', '80', 'share', '1', '70', 'share']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'kci', 'konecranes', 'said', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'ltd']
#
#
# ===Tokens:===
# ['vaahto', 'pulp', 'paper', 'finnish', 'vaahto', 'group', 'awarded', 'order', 'renovate', 'finnish', 'swedish', 'forest', 'industry', 'company', 'stora', 'enso', 'paperboard', 'machine', 'ingerois', 'board', 'mill', 'finland']
#
#
# ===Tokens:===
# ['buy', 'recommendation', 'reiterated']
#
#
# ===Tokens:===
# ['bristol', 'port', 'company', 'sealed', 'one', 'million', 'pound', 'contract', 'cooper', 'specialised', 'handling', 'supply', 'four', '45', 'tonne', 'customised', 'reach', 'stackers', 'konecranes']
#
#
# ===Tokens:===
# ['h', 'move', 'enhance', 'growth']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'period', 'eur0', '9', 'eur0', '01', 'last', 'year']
#
#
# ===Tokens:===
# ['subscriptions', 'increase', 'cargotec', 'share', 'capital', '36', '780', 'euros']
#
#
# ===Tokens:===
# ['new', 'representation', 'extends', 'comptel', 'global', 'presence', 'total', '18', 'countries', 'serving', '250', 'customers', '80', 'countries', 'worldwide']
#
#
# ===Tokens:===
# ['china', 'finnish', 'kone', 'provides', 'elevators', 'escalators', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'high', 'speed', 'railway', 'section', 'beijing', 'shanghai', '1', '5', 'years', 'time']
#
#
# ===Tokens:===
# ['shares', 'standard', 'chartered', 'stan', 'rose', '1', '2', 'ftse', '100', 'royal', 'bank', 'scotland', 'rbs', 'shares', 'rose', '2', 'barclays', 'shares', 'barc', 'bcs', '1', '7']
#
#
# ===Tokens:===
# ['cargo', 'volume', 'increased', 'approximately', '5']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'retail', 'wholesale', 'group', 'kesko', 'reported', 'net', 'sales', '659', '4', 'mln', 'eur', 'february', 'increase', '10', '8', 'pct', 'year', 'year']
#
#
# ===Tokens:===
# ['lule', 'municipality', 'awarded', 'yit', '2', 'year', 'contract', 'property', 'management', 'one', 'third', 'municipality', 'properties', 'total', 'area', '140', '000', 'sq', 'metres']
#
#
# ===Tokens:===
# ['pre', 'tax', 'profit', 'totaled', 'eur', '397', '4', 'mn', 'eur', '164', '7', 'mn']
#
#
# ===Tokens:===
# ['yhoo', 'break', '5', 'min']
#
#
# ===Tokens:===
# ['today', 'bought', 'mu', 'yhoo', 'vale', 'nbl', 'twtr', 'axp', 'znga', 'https', 'co', 'vt6t5zp2is']
#
#
# ===Tokens:===
# ['kalnapilio', 'tauro', 'grupe', 'kalnapilis', 'tauras', 'group', 'owned', 'denmark', 'royal', 'unibrew', 'raised', 'market', 'share', '25', '2', 'percent', '23', '91', 'percent', 'beer', 'sales', 'nine', 'months', 'jumped', '11', '4', 'percent', '52', '99', 'million', 'liters']
#
#
# ===Tokens:===
# ['mos', 'looking', 'good', '58', '65', 'calls', 'active', 'month', 'weekly']
#
#
# ===Tokens:===
# ['nokian', 'tyre', 'proves', 'high', 'safety', 'excellently', 'important', 'driving', 'qualities', 'stability', 'mark', '1', '4', 'handling', '1', '5', 'braking', 'wet', 'road', '1', '9']
#
#
# ===Tokens:===
# ['several', 'growth', 'initiatives', 'chosen', 'geographic', 'areas', 'already', 'ongoing', 'continued', 'noting', 'lindex', 'opened', 'first', 'store', 'czech', 'republic', 'autumn', 'brno']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'totalled', 'eur', '2', '71', 'mn', 'compared', 'negative', 'eur', '0', '83', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['sppi', 'building', 'rs', 'sweet', 'want', 'break', 'new', '52week', 'earnings', 'growth', 'justifies', 'way', 'higher']
#
#
# ===Tokens:===
# ['according', 'finnish', 'metso', 'minerals', 'value', 'company', 'orders', 'gone', 'eur', '1', '9', 'bn', '12', 'months']
#
#
# ===Tokens:===
# ['return', 'equity', 'stood', '18', '3', 'compared', '15', '4', 'third', 'quarter', '2005']
#
#
# ===Tokens:===
# ['fio', 'stay']
#
#
# ===Tokens:===
# ['intuitiv', 'clne', 'gasoline', 'prices', 'spike', 'california', 'http', 'stks', 'co', 't1boi']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '6', '2009', 'finnish', 'fishing', 'tackle', 'company', 'rapala', 'vmc', 'corp', 'hel', 'rap1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '19', '2', 'million', 'usd', '24', '6', '2008', 'eur', '17', '5', 'million', '2007']
#
#
# ===Tokens:===
# ['warmly', 'welcome', 'michael', 'frei', 'outotec']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'group', 'share', 'price', 'climbs', '1', '5bn', 'special', 'dividend']
#
#
# ===Tokens:===
# ['stora', 'enso', 'third', 'quarter', 'pre', 'tax', 'profit', 'doubled', 'eur', '197mn']
#
#
# ===Tokens:===
# ['kesko', 'agro', 'lietuva', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'kesko', 'group', 'boosted', 'sales', '42', '9', 'percent', '13', '4', 'million', 'euros', 'vat', 'inclusive']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur13', '6', 'net', 'sales', 'increased', 'eur394', '7', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['compass', 'group', 'says', 'positive', 'year', 'ahead']
#
#
# ===Tokens:===
# ['shire', 'ceo', 'steps', 'drive', 'get', 'baxalta', 'board', 'talking']
#
#
# ===Tokens:===
# ['astrazeneca', 'acquires', 'zs', 'pharma', '2', '7', 'billion', 'deal']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '11', '4', 'mn', 'eur', '7', '5', 'mn']
#
#
# ===Tokens:===
# ['net', 'interest', 'income', 'eur', '152', '2', 'mn', 'eur', '101', '0', 'mn', '2008']
#
#
# ===Tokens:===
# ['president', 'ceo', 'mika', 'vehvil', 'inen', 'says', 'positive', 'signs', 'first', 'foremost', 'emerging', 'outside', 'finland']
#
#
# ===Tokens:===
# ['fb', 'slight', 'green', 'may', 'runner', 'later']
#
#
# ===Tokens:===
# ['contract', 'signed', 'august', 'papua', 'new', 'guinea', 'based', 'lihir', 'gold', 'ltd', 'asx', 'lgl']
#
#
# ===Tokens:===
# ['stora', 'enso', 'norske', 'skog', 'real', 'upm', 'kymmene', 'credit', 'suisse', 'first', 'boston', 'cfsb', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'nordic', 'forestry', 'groups']
#
#
# ===Tokens:===
# ['pleased', 'welcome', 'tapeks', 'noma', 'cramo', 'group']
#
#
# ===Tokens:===
# ['berkshire', 'applies', 'boost', 'wells', 'fargo', 'stake', '10', 'percent']
#
#
# ===Tokens:===
# ['outotec', 'oyj', 'press', 'release', 'december', '4', '2009', '10', '30', 'outotec', 'establishes', 'new', 'subsidiary', 'kolkata', 'outotec', 'established', 'subsidiary', 'india', 'order', 'better', 'serve', 'indian', 'customers', 'increase', 'business', 'growing', 'indian', 'market']
#
#
# ===Tokens:===
# ['amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'company']
#
#
# ===Tokens:===
# ['honored', 'acknowledged', 'commitment', 'industry', 'especially', 'asia', 'pacific']
#
#
# ===Tokens:===
# ['navteq', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'north', 'american', 'vehicles', 'may', 'leader', 'turn', 'turn', 'navigation', 'data', 'offered', 'services', 'onstar', 'north', 'america', 'said', 'analyst', 'phil', 'magney', 'telematics', 'research', 'group', 'minnetonka', 'minn']
#
#
# ===Tokens:===
# ['gsk', 'joins', 'china', 'trade', 'push', 'uk', 'trumpets', 'healthcare', 'deals']
#
#
# ===Tokens:===
# ['value', 'firm', 'forestry', 'holdings', 'increased', 'sek', '3', '6', 'bn']
#
#
# ===Tokens:===
# ['hammerson', 'jv', 'partner', 'secure', 'ownership', 'ireland', 'dundrum', 'quick', 'facts']
#
#
# ===Tokens:===
# ['2009', 'fiskars', 'cash', 'flow', 'operating', 'activities', 'amounted', 'eur121m', 'eur97m', 'previous', 'year']
#
#
# ===Tokens:===
# ['long', 'vvus', 'shares', 'call', 'option', 'w', 'expiration', 'umm', 'today', 'hitting', 'hod']
#
#
# ===Tokens:===
# ['chime', 'communications', 'set', 'acquired', 'wpp', 'providence']
#
#
# ===Tokens:===
# ['asdfllc', 'nice', 'pop', 'today', 'told', 'ya', 'would', 'green', 'haha', 'funny', 'bring', 'actually', 'working', 'story', 'nok', 'moment']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'company', 'elcoteq', 'signing', 'cooperation', 'agreement', 'japanese', 'mobile', 'phone', 'manufacturer', 'bypasses', 'elcoteq', 'tallinn', 'says', 'jan', 'kotka', 'ceo', 'elcoteq', 'tallinn']
#
#
# ===Tokens:===
# ['based', 'upon', 'unique', 'fiber', 'expertise', 'innovative', 'approach', 'company', 'strong', 'market', 'position', 'several', 'business', 'areas', 'operates']
#
#
# ===Tokens:===
# ['company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market']
#
#
# ===Tokens:===
# ['developers', 'project', 'predict', 'completed', 'april', '2009', 'skanssi', 'attract', '4', '5', 'million', 'visitors', 'annually']
#
#
# ===Tokens:===
# ['ftse', '100', 'flat', 'standard', 'chartered', 'leads', 'risers']
#
#
# ===Tokens:===
# ['manavigator', 'september', '7', '2010', 'kemira', 'unveils', 'indian', 'jv', 'ivrcl', 'finnish', 'chemicals', 'group', 'kemira', 'hel', 'kra1v', 'tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'india', 'local', 'construction', 'firm', 'ivrcl', 'infrastructure', 'projects', 'ltd', 'bom', '530773']
#
#
# ===Tokens:===
# ['according', 'finnish', 'aktia', 'bank', 'managing', 'director', 'jussi', 'laitinen', 'bank', 'aim', 'triple', 'number', 'customers', 'finland', 'next', 'five', 'years']
#
#
# ===Tokens:===
# ['finland', 'nokian', 'tyres', 'kazakhstan', 'ordabasy', 'corporation', 'signed', 'agreement', 'build', 'plant', 'astana', 'produce', 'car', 'tires', 'ordabasy', 'chairman', 'dinmukhamet', 'idrisov', 'said', 'press', 'conference']
#
#
# ===Tokens:===
# ['danske', 'bank', 'danske', 'dc', 'jumped', '3', '7', 'percent', '133', '4', 'kroner', 'rebounding', 'yesterday', '3', '5', 'percent', 'slide']
#
#
# ===Tokens:===
# ['vessel', 'order', 'help', 'aspo', 'secure', 'long', 'term', 'competitiveness', 'fleet', 'terms', 'technology', 'pricing']
#
#
# ===Tokens:===
# ['enb', 'ca', 'head', 'shoulders', 'bullish', 'reversal', 'setup', 'breakout', 'oil', 'gas', 'pipleline', 'stock', 'uso']
#
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastic', 'products', 'maker', 'suominen', 'corporation', 'said', 'net', 'loss', 'narrowed', '1', '6', 'mln', 'euro', '2', '0', 'mln', 'first', 'nine', 'months', '2006', '2', '16', 'mln', 'euro', '2', '7', 'mln', 'period', '2005']
#
#
# ===Tokens:===
# ['upside', 'moves', 'volatile', 'mining', 'sector', 'sending', 'anglo', 'american', 'plc', 'aal', '6', '8', '4', '30', 'pm', 'london', 'time']
#
#
# ===Tokens:===
# ['rad', 'would', 'consider', 'opportunity', 'add', 'position', 'company', 'right', 'track', 'still', 'improving', 'sales']
#
#
# ===Tokens:===
# ['ocn', 'stuff', 'looking', 'add', 'shares', 'get', 'new', 'high', 'breakout']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'net', 'profit', 'rose', '26', '1', 'mln', 'euro', '35', '9', 'mln', 'first', 'quarter', '2007', '5', '3', 'mln', 'euro', '7', '3', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['rapala', 'estimates', 'net', 'sales', '2008', 'increase', '8', '0', 'pct', '12', 'pct', 'assuming', '2007', 'exchange', 'rates']
#
#
# ===Tokens:===
# ['free', 'ha', 'heeeeeere', 'comes', 'pump', 'glad', 'picked', '9k', 'end', 'day', 'get', 'ready', 'bull', 'ride']
#
#
# ===Tokens:===
# ['eps', 'grew', '0', '04', 'eur', '0', '02', 'eur']
#
#
# ===Tokens:===
# ['held', 'recent', 'double', 'bottom', 'buy', 'point', '56', '57', 'almost', 'penny', 'today', 'wmt', 'http', 'chart', 'ly', '6nosp5q']
#
#
# ===Tokens:===
# ['astrazeneca', 'shares', 'climb', '3', 'drug', 'maker', 'ups', 'profits', 'forecasts']
#
#
# ===Tokens:===
# ['group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets']
#
#
# ===Tokens:===
# ['companiescar', 'insurer', 'hastings', 'group', 'driving', '180m', 'ipo']
#
#
# ===Tokens:===
# ['vrtx', 'early', 'technical', 'buy', 'signal', 'confirmation', '86', 'needs', 'fundam', 'incentive', 'https', 'co', 'quysrqfo2x']
#
#
# ===Tokens:===
# ['systeemitiimi', 'sales', 'project', 'resources', 'also', 'strengthened', 'director', 'paul', 'skogberg', 'said']
#
#
# ===Tokens:===
# ['accordance', 'strategy', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'south', 'africa', 'october']
#
#
# ===Tokens:===
# ['metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'china', 'lee', 'man', 'paper', 'co']
#
#
# ===Tokens:===
# ['poyry', 'recognized', 'one', 'world', 'leading', 'advisors', 'global', 'forestry', 'industry']
#
#
# ===Tokens:===
# ['skf', '6', 'april', '2010', 'alandsbanken', 'given', 'buy', 'recommendation', 'swedish', 'industrial', 'company', 'skf', 'ab', 'sto', 'skf', 'b', 'share', 'price', 'target', 'sek150']
#
#
# ===Tokens:===
# ['investments', 'operational', 'changes', 'enable', 'additional', 'optimisation', 'working', 'hours', 'thereby', 'cost', 'savings', '7', '9']
#
#
# ===Tokens:===
# ['finnish', 'software', 'developer', 'basware', 'oyj', 'said', 'november', '30', '2006', 'u', 'subsidiary', 'basware', 'inc', 'order', 'provide', 'software', 'contract', 'lifecycle', 'management', 'unnamed', 'u', 'medical', 'technology', 'company']
#
#
# ===Tokens:===
# ['repair', 'maintenance', 'business', 'accounted', 'net', 'sales', 'eur', '645', '3', 'mn', 'eur', '563', '6', 'mn']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'increased', '2', 'eur', '1', '050', '7', 'mn', 'eur', '1', '027', '0', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['stock', 'trading', 'maps', '50', 'day', 'map', 'sek72', '983', 'higher', '200', 'day', 'map', 'sek70', '283', 'bullish', 'indicator']
#
#
# ===Tokens:===
# ['luv', 'continues', 'consolidate', 'previous', 'break', 'area']
#
#
# ===Tokens:===
# ['recommendable', 'nokian', 'z', 'g2', 'according', 'adac', 'judgement', 'latest', 'summer', 'tyre', 'test', 'german', 'automobile', 'association', 'adac']
#
#
# ===Tokens:===
# ['economic', 'occupancy', 'rate', 'sponda', 'property', 'portfolio', 'rose', '91', '2', '88', '8', '2006']
#
#
# ===Tokens:===
# ['leipurin', 'growing', 'rapidly', 'internationalizing', 'group']
#
#
# ===Tokens:===
# ['2008', 'deal', 'likely', 'bring', 'savings', 'eur', '20mn', '25mn']
#
#
# ===Tokens:===
# ['cargotec', 'germany', 'gmbh', 'awarded', 'contract', 'stadtverwaltung', 'mainz', 'chassis', 'bodies', 'open', 'procedure']
#
#
# ===Tokens:===
# ['exports', 'accounted', '65', '4', 'net', 'sales', 'representing', 'time', 'record', 'company']
#
#
# ===Tokens:===
# ['previously', 'eb', 'delivered', 'custom', 'solution', 'lg', 'electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators']
#
#
# ===Tokens:===
# ['marimekko', 'group', 'full', 'year', 'net', 'sales', 'estimated', 'increase', '10']
#
#
# ===Tokens:===
# ['terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', 'chief', 'executive', 'veli', 'matti', 'mattila', 'said']
#
#
# ===Tokens:===
# ['profit', 'taking', 'aapl', 'morning', 'pressure', 'stock', 'still', 'bullish', 'aapl']
#
#
# ===Tokens:===
# ['passenger', 'related', 'revenue', 'rose', '5', '1', 'eur', '460', '8', 'mn', 'eur', '438', '5', 'mn', '2009']
#
#
# ===Tokens:===
# ['end', 'review', 'period', 'nordic', 'aluminium', 'order', 'book', 'stood', 'eur', '8', '77', 'mn', 'compared', 'eur', '7', '04', '2005']
#
#
# ===Tokens:===
# ['tesco', 'closes', 'new', 'chairman', 'dixons', 'carphone', 'john', 'allan', 'frame']
#
#
# ===Tokens:===
# ['takeover', 'cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'latvian', 'market']
#
#
# ===Tokens:===
# ['cencorp', 'estimates', 'net', 'sales', 'last', 'quarter', 'earlier', 'stated', 'eur4', '3', 'eur5', '0', 'operating', 'profit', 'ebit', 'estimated', 'positive']
#
#
# ===Tokens:===
# ['teliasonera', 'said', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', 'nepal', 'population']
#
#
# ===Tokens:===
# ['amazon', 'declares', 'best', 'ever', 'black', 'friday', 'cyber', 'monday', 'kindle', 'family', 'http', 'stks', 'co', 'cetw', 'via', 'engadget', 'amzn']
#
#
# ===Tokens:===
# ['rdc', 'rowan', 'expands', 'share', 'repurchase', 'program', '150', 'million']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', '2010', 'seen', 'grown', 'eur598', '3', 'eur582', '3', '2009']
#
#
# ===Tokens:===
# ['clothing', 'chain', 'sepp', 'l', 'net', 'sales', 'increased', '7', '0', 'eur', '30', '8', 'mn']
#
#
# ===Tokens:===
# ['ilmn', 'piper', 'jeffries', 'raises', 'pt', 'remain', 'long']
#
#
# ===Tokens:===
# ['dxcm', 'making', 'higher', 'highs', 'higher', 'lows', 'consolidates', 'past', 'several', 'weeks', '26', '70', 'time', 'high', '2006']
#
#
# ===Tokens:===
# ['mr', 'lee', 'said', 'hoped', 'neste', 'move', 'pave', 'way', 'collaboration', 'projects', 'two', 'countries']
#
#
# ===Tokens:===
# ['addition', 'fireplace', 'exports', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'sales', 'three', 'month', 'period', 'increased', 'respectively', 'eur0', '3', 'eur13', '1', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['also', 'bringing', 'right', 'kind', 'people', 'upgrade', 'human', 'resources']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '27', '8', 'mn', 'eur', '17', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['endp', 'saw', 'large', 'order', 'one', 'last', 'week', 'someone', 'also', 'accumulating', 'may', 'jun', '35', 'calls', 'today']
#
#
# ===Tokens:===
# ['commencing', 'construction', 'works', 'pearl', 'plaza', 'significant', 'step', 'russian', 'projects']
#
#
# ===Tokens:===
# ['raisio', 'divisions', 'recorded', 'operating', 'profit']
#
#
# ===Tokens:===
# ['meanwhile', 'nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout']
#
#
# ===Tokens:===
# ['glaxo', 'viiv', 'healthcare', 'signs', 'china', 'manufacturing', 'deal', 'desano']
#
#
# ===Tokens:===
# ['bot', 'amzn', '600', 'weekly', 'calls', '5', '93']
#
#
# ===Tokens:===
# ['finnish', 'lifting', 'equipment', 'maker', 'kone', 'oyj', 'said', 'october', '4', '2007', 'order', 'worth', '15', 'mln', 'euro', '21', '2', 'mln', 'deliver', 'total', '53', 'custom', 'designed', 'elevators', 'norwegian', 'shipbuilder', 'aker', 'yards', 'asa']
#
#
# ===Tokens:===
# ['standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'itella']
#
#
# ===Tokens:===
# ['refining', 'margin', 'year', '13', '39', 'bbl', 'compared', '10', '46', 'bbl', 'prior', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '103', '4', 'mn', 'eur', '23', '2', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['kraft', 'heinz', 'merger', 'came', 'together', 'speedy', '10', 'weeks']
#
#
# ===Tokens:===
# ['net', 'sales', 'vegetable', 'oil', 'business', 'rose', 'eur', '10', '6', 'mn', 'eur', '10', '1', 'mn']
#
#
# ===Tokens:===
# ['company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'eur', '67', '1', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'surged', 'eur21m', 'eur106', '000']
#
#
# ===Tokens:===
# ['bilfinger', 'industrial', 'services', 'win', '100m', 'bp', 'contract', 'extension']
#
#
# ===Tokens:===
# ['would', 'invest', 'physical', 'infrastructure', 'would', 'also', 'provide', 'know', 'managing', 'developing', 'science', 'technology', 'parks', 'said', 'sunrise', 'valley', 'director', 'andrius', 'bagdonas']
#
#
# ===Tokens:===
# ['rationalization', 'operations', 'seeks', 'achieve', 'eur', '1', 'million', 'yearly', 'savings', 'second', 'quarter', 'current', 'financial', 'year']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'outperforms', 'europe', 'royal', 'mail', 'tesco', 'rise']
#
#
# ===Tokens:===
# ['profit', 'period', 'eur', '5', '9', 'mn', 'eur', '1', '3', 'mn']
#
#
# ===Tokens:===
# ['cision', 'says', 'sale', 'return', 'u', 'k', 'operation', 'profitability']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'higher', '0', '48', '0', '37', 'year', 'ahead', 'market', 'consensus', '0', '40', 'eur']
#
#
# ===Tokens:===
# ['ebit', 'margin', '1', '4', '5', '1']
#
#
# ===Tokens:===
# ['ruukki', 'forecast', '15', '20', 'annual', 'sales', 'growth', 'positive', 'pretax', 'result', '2010']
#
#
# ===Tokens:===
# ['acquiring', 'rcp', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company']
#
#
# ===Tokens:===
# ['4', 'beaten', 'internet', 'companies', 'may', 'ripe', 'takeover', 'target', 'twitter', 'twtr', 'linkedin', 'lnkd', 'yahoo', 'yhoo', 'groupon', 'grpn']
#
#
# ===Tokens:===
# ['sonc', 'amazing', 'run', 'since', 'middle', 'march', 'obvious', 'quality', 'tastiness', 'burgers', 'factored', 'price', 'advance']
#
#
# ===Tokens:===
# ['activision', 'blizzard', 'media', 'networks', 'announces', 'record', 'esports', 'viewership', 'https', 'co', '729biqlbtk', 'atvi', 'partnered', 'hdsi', '9', 'tournament']
#
#
# ===Tokens:===
# ['dara', 'breaking']
#
#
# ===Tokens:===
# ['supermarket', 'stocks', 'rally', 'tesco', 'plans', 'axe', 'non', 'core', 'uk', 'assets', 'tsco', 'https', 'co', 'bmvhcrwrea']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '4', '7', 'mn', 'eur', '4', '6', 'mn']
#
#
# ===Tokens:===
# ['strategic', 'cooperation', 'rentakran', 'brings', 'us', 'new', 'customers', 'already', 'working', 'relationships', 'authorities', 'new', 'territories', 'said', 'jarmo', 'laasanen', 'senior', 'manager', 'cramo']
#
#
# ===Tokens:===
# ['kitd', 'looking', 'oversold', 'bounce']
#
#
# ===Tokens:===
# ['wft', 'closng', 'higher']
#
#
# ===Tokens:===
# ['kauko', 'telko', 'ltd', 'press', 'release', '19', '06', '2007', '14', '00', '1', '1', 'telko', 'group', 'kauko', 'telko', 'expanding', 'strategic', 'partnership', 'bp', 'industrial', 'lubricants', 'services', 'bp', 'ils', 'acquiring', 'total', 'ownership', 'bp', 'swedish', 'retail', 'company', 'molub', 'alloy', 'ab']
#
#
# ===Tokens:===
# ['eln', 'longs', 'congrats', 'another', 'hod']
#
#
# ===Tokens:===
# ['solutions', 'used', 'upgrading', 'networks', 'russian', 'mso', '37', 'different', 'cities', 'russia']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '9', '2009', 'finnish', 'computer', 'services', 'company', 'proha', 'oyj', 'hel', 'art1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '113', '000', 'usd', '146', '000', '2008', 'eur', '1', '2', 'million', '2007']
#
#
# ===Tokens:===
# ['major', 'breweries', 'increased', 'domestic', 'beer', 'sales', '4', '5', 'per', 'cent', 'last', 'year', '256', '88', 'million', 'litres', '245', '92', 'million', 'litres', '2004']
#
#
# ===Tokens:===
# ['shopping', 'center', 'opened', 'st', 'petersburg', 'russia', 'november', '2010', 'turn', 'cash', 'flow', 'finnish', 'department', 'store', 'chain', 'stockmann', 'russian', 'operations', 'positive', 'first', 'time', '2011']
#
#
# ===Tokens:===
# ['company', 'also', 'estimates', 'already', 'carried', 'investments', 'lead', 'increase', 'net', 'sales', '2010', '2009', 'reached', 'eur', '141', '7', 'million']
#
#
# ===Tokens:===
# ['poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'latin', 'america']
#
#
# ===Tokens:===
# ['stx', 'long', 'play', 'another', 'consistent', 'profit', 'zone', 'check', 'https', 'co', 'dqfuzozylh', 'https', 'co', 'ggne4ayzqn']
#
#
# ===Tokens:===
# ['combine', 'renew', 'contents', 'functionality', 'current', 'systems', 'funding', 'online', 'service', 'well', 'maintenance']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '6', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['daily', 'mail', 'owner', 'considering', 'yahoo', 'bid', 'yhoo', '2', '05', 'https', 'co', 'extzr1riyp']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'seen', 'eur', '0', '56', 'eur', '0', '38']
#
#
# ===Tokens:===
# ['went', 'long', 'ilmn']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'awarded', 'contract', 'rebuild', 'sabah', 'forest', 'industries', 'sfi', 'pulp', 'mill', 'sabah', 'malaysia']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '1', '2008', 'finnish', 'consulting', 'engineering', 'company', 'poyry', 'oyj', 'omx', 'poy1v', 'said', 'today', 'awarded', 'eur', '5', '2', 'million', 'usd', '7', '4', 'extension', 'existing', 'consultancy', 'engineering', 'contract', 'venezuel']
#
#
# ===Tokens:===
# ['finnish', 'kci', 'konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'delivered', '2007']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'release', 'february', '11', '2011', 'at8', '45', 'esl', 'shipping', 'ltd', 'part', 'aspo', 'group', 'signed', 'new', 'long', 'term', 'contract', 'rautaruukki', 'corporation', 'marine', 'transport', 'raw', 'materials', 'baltic', 'sea']
#
#
# ===Tokens:===
# ['long', 'pcln']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'management', 'software', 'solutions', 'provider', 'ixonos', 'oyj', 'hel', 'xns1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '3', '5', 'million', 'usd', '4', '5', '2008', 'eur', '3', '1', 'million', '2007']
#
#
# ===Tokens:===
# ['stock', 'rose', 'second', 'day', 'wednesday', 'bringing', 'two', 'day', 'rise', 'gbx12', '0', '2', '0']
#
#
# ===Tokens:===
# ['new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties']
#
#
# ===Tokens:===
# ['handelsbanken', 'ranked', 'local', 'cooperative', 'banks', 'aktia', 'customer', 'loyalty', 'time', 'however']
#
#
# ===Tokens:===
# ['fedday', 'looking', 'sharp', 'move', 'equities', 'aapl', 'hd', 'low', 'fb', 'seeing', 'uvxy', 'tvix', 'getting', 'hammered', 'even', 'though', 'market']
#
#
# ===Tokens:===
# ['operating', 'profit', 'grain', 'trading', 'increased', 'eur', '2', '0', 'mn', 'eur', '1', '4', 'mn', '2005']
#
#
# ===Tokens:===
# ['section', 'regional', 'news', 'demand', 'finnair', 'asian', 'traffic', 'measured', 'passenger', 'kilometers', '34', '9', 'august', 'compare', 'last', 'year']
#
#
# ===Tokens:===
# ['nflx', '3', 'lows']
#
#
# ===Tokens:===
# ['geosolutions', 'technology', 'leverage', 'benefon', 'gps', 'solutions', 'providing', 'location', 'based', 'search', 'technology', 'communities', 'platform', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model']
#
#
# ===Tokens:===
# ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa']
#
#
# ===Tokens:===
# ['15', 'december', '2010', 'finnish', 'german', 'telecoms', 'equipment', 'maker', 'nokia', 'siemens', 'networks', 'said', 'today', 'contract', 'upgrade', 'radio', 'network', 'home', 'based', 'telecommunications', 'company', 'elisa', 'oyj', 'hel', 'eli1v']
#
#
# ===Tokens:===
# ['zurich', 'insurance', 'considering', 'offer', 'uk', 'rival', 'rsa', 'insurance']
#
#
# ===Tokens:===
# ['full', '2010', 'company', 'expects', 'net', 'sales', 'operating', 'result', 'improve', 'previous', 'year', 'saying', 'positive', 'operating', 'result', 'amount', 'depend', 'order', 'intake', 'end', 'summer']
#
#
# ===Tokens:===
# ['looking', 'strong', 'bounce', 'spy', 'lunchtime', 'rally', 'coming', 'dia', 'iwm', 'qqq', 'aa', 'fb']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur', '36', 'million', 'eur', '27', 'million']
#
#
# ===Tokens:===
# ['company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230', '000', 'tonnes', 'copper']
#
#
# ===Tokens:===
# ['long', 'position', 'gol', 'updating', 'http', 'stks', 'co', 'fdmm']
#
#
# ===Tokens:===
# ['transaction', 'also', 'rationalize', 'pulp', 'paper', 'industry', 'related', 'solutions']
#
#
# ===Tokens:===
# ['neste', 'oil', 'corp', 'signed', 'long', 'term', 'procurement', 'contracts', 'honkajoki', 'oy', 'findest', 'protein', 'oy', 'owned', 'finnish', 'food', 'manufacturers', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'neste', '200', '000', 'b', 'cd', 'porvoo', 'finland', 'refinery']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur3', '1', 'net', 'sales', 'increased', 'eur61', '5', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['finnish', 'aldata', 'solution', 'signed', 'contract', 'supply', 'g', 'l', 'system', 'two', 'french', 'retail', 'chains']
#
#
# ===Tokens:===
# ['reached', 'agreement', 'union', 'flights', 'continue', 'normal', 'finnair', 'spokesman', 'usko', 'maatta', 'said']
#
#
# ===Tokens:===
# ['real', 'sales', 'expected', 'increased', '4', 'year', 'year', 'eur609m', 'second', 'quarter', '2010']
#
#
# ===Tokens:===
# ['australia', 'clears', 'ab', 'inbev', '100', 'billion', 'sabmiller', 'buyout', 'plan']
#
#
# ===Tokens:===
# ['far', 'mr', 'galvan', 'able', 'avoid', 'laying', 'workers']
#
#
# ===Tokens:===
# ['abb', 'deutsche', 'bank', 'upgraded', 'recommendation', 'swiss', 'swedish', 'engineering', 'group', 'abb', 'ltd', 'buy', 'hold']
#
#
# ===Tokens:===
# ['slowly', 'adding', 'fio', 'got', 'ta', 'careful', 'one', 'biggest', 'winners', '2012']
#
#
# ===Tokens:===
# ['see', '200', 'day', 'sma', 'big', 'hurdle', 'good', 'base', 'building', 'nflx', 'https', 'co', 'imkygo2cyc']
#
#
# ===Tokens:===
# ['news', 'feedschroders', 'books', 'solid', 'earnings', 'growth', 'several', 'board', 'changes']
#
#
# ===Tokens:===
# ['astrazeneca', 'weighing', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug']
#
#
# ===Tokens:===
# ['thanks', 'wide', 'contact', 'network', 'good', 'knowledge', 'market', 'business', 'environment', 'give', 'great', 'contribution', 'development', 'indian', 'operations', 'tells', 'incap', 'president', 'ceo', 'juhani', 'hanninen']
#
#
# ===Tokens:===
# ['design', 'team', 'long', 'admired', 'marimekko', 'vivid', 'patterns', 'colors']
#
#
# ===Tokens:===
# ['much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'finland', 'canada']
#
#
# ===Tokens:===
# ['arm', 'royalties', 'accelerate', 'smartphone', 'market', 'regains', 'strength']
#
#
# ===Tokens:===
# ['following', 'transaction', 'lundbeck', 'worldwide', 'rights', 'nalmefene', 'excluding', 'north', 'america', 'mexico', 'turkey', 'south', 'korea']
#
#
# ===Tokens:===
# ['fb', '110', '20', 'starting', 'show', 'relative', 'strength', 'signs', 'potential', 'b', 'daily']
#
#
# ===Tokens:===
# ['piper', 'upgrades', 'symantec', 'improving', 'renewal', 'rates', 'enterprise', 'growth', 'symc']
#
#
# ===Tokens:===
# ['district', 'court', 'helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005']
#
#
# ===Tokens:===
# ['china', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', 'also', 'strengthen', 'capability', 'offer', 'industry', 'leading', 'products', 'customers', 'china']
#
#
# ===Tokens:===
# ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'co', 'xk6lz3ui3k']
#
#
# ===Tokens:===
# ['adobe', 'receives', 'new', 'rating', 'top', 'analyst', 'adbe', 'https', 'co', 'ljnxpevhzn']
#
#
# ===Tokens:===
# ['assignment', 'strengthens', 'poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry']
#
#
# ===Tokens:===
# ['finnish', 'outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'ozk', 'kardzhali', 'zinc', 'smelter', 'bulgaria']
#
#
# ===Tokens:===
# ['london', 'open', 'taylor', 'wimpey', 'ashtead', 'drive', 'markets', 'higher', 'barclays', 'falls']
#
#
# ===Tokens:===
# ['es', 'f', 'nice', 'little', 'cup', 'handle', 'shaping', '15', 'minute', 'end', 'day', 'spy', 'spx', 'favours', 'good', 'day', 'index', 'see', 'gap', 'open']
#
#
# ===Tokens:===
# ['finland', 'insurance', 'company', 'pohjola', 'finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', 'traffic', 'safety']
#
#
# ===Tokens:===
# ['soapstone', 'deposits', 'medvezhyegorsk', 'area', 'expected', 'increase', 'tulikivi', 'current', 'reserves', 'considerably']
#
#
# ===Tokens:===
# ['q1', '10', '19', 'april', '2010', 'finnish', 'forest', 'machinery', 'equipment', 'maker', 'ponsse', 'oyj', 'hel', 'pon1v', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'eur6', '3', 'first', 'quarter', '2010', 'eur9', '6', 'loss', 'year', 'earlier']
#
#
# ===Tokens:===
# ['isrg', 'pt', 'raised', '700', '640', 'leerink', 'keeps', 'outperform', 'rated']
#
#
# ===Tokens:===
# ['q1', '2010', '18', 'may', '2010', 'finnish', 'electrical', 'components', 'maker', 'salcomp', 'oy', 'hel', 'sal1v', 'said', 'today', 'turned', 'net', 'profit', 'eur1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'eur2m', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['purchase', 'agreement', '7', '200', 'tons', 'gasoline', 'delivery', 'hamina', 'terminal', 'finland', 'signed', 'neste', 'oil', 'oyj', 'average', 'platts', 'index', 'september', 'plus', 'eight', 'us', 'dollars', 'per', 'month']
#
#
# ===Tokens:===
# ['added', 'bbby', 'jimcramer', 'wrong', 'one', 'still', 'profitable', 'merchant', 'profitable', 'stores']
#
#
# ===Tokens:===
# ['reporting', 'period', 'biotie', 'north', 'american', 'licensing', 'partner', 'somaxon', 'pharmaceuticals', 'announced', 'positive', 'results', 'nalmefene', 'pilot', 'phase', '2', 'clinical', 'trial', 'smoking', 'cessation']
#
#
# ===Tokens:===
# ['production', 'capacity', 'increase', '36', '000', '85', '000', 'tonnes', 'per', 'year', 'raw', 'material', 'continue', 'recycled', 'paper', 'board']
#
#
# ===Tokens:===
# ['government', 'professional', 'approach', 'assessing', 'offer']
#
#
# ===Tokens:===
# ['onty', 'continues', 'base', 'debate', 'lingers', 'ont', '10', 'data', 'next', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'moves', '10', 'downside', 'limited']
#
#
# ===Tokens:===
# ['result', 'distribution', 'companies', 'start', 'distribute', 'addition', 'current', 'product', 'offering', 'shimano', 'reels', 'rods', 'shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis']
#
#
# ===Tokens:===
# ['gild', 'expanding', 'research', 'facilities', 'keeping', 'pace', 'innovation', 'https', 'co', 'uoe7fj4lop']
#
#
# ===Tokens:===
# ['finnish', 'pulp', 'paper', 'machinery', 'maker', 'vaahto', 'group', 'oyj', 'swung', '1', '1', 'mln', 'euro', '1', '4', 'mln', 'net', 'profit', 'fiscal', '2005', '06', 'ended', 'august', '31', '2006', '249', '000', 'euro', '319', '000', 'net', 'loss', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['drugmaker', 'shire', 'buy', 'baxalta', '32', 'billion', '6', 'month', 'pursuit']
#
#
# ===Tokens:===
# ['fda', 'approves', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '83', '0', 'mn', 'eur', '23', '5', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'klabin', 'tel', 'maco', 'borba', 'mill', 'brazilian', 'state', 'paran']
#
#
# ===Tokens:===
# ['barclays', 'bank', 'america', 'citigroup', 'blockchain', 'sight']
#
#
# ===Tokens:===
# ['savon', 'koulutuskuntayhtyma', 'finland', 'based', 'company', 'awarded', 'contract', 'specialist', 'agricultural', 'forestry', 'machinery']
#
#
# ===Tokens:===
# ['brazilian', 'unit', 'finnish', 'security', 'solutions', 'provider', 'f', 'secure', 'signed', '1', '500', 'new', 'clients', 'last', 'year', 'online', 'news', 'source', 'reseller', 'web', 'quoted', 'division', 'commercial', 'director', 'vladimir', 'brand', 'saying']
#
#
# ===Tokens:===
# ['company', 'make', 'marketing', 'sales', 'investments', 'initiated', '2009', 'even', 'efficient', '2010']
#
#
# ===Tokens:===
# ['amazon', 'grocery', 'deal', 'morrisons', 'beginning']
#
#
# ===Tokens:===
# ['axp', 'looking', 'continuation', 'volume', 'increase', 'http', 'stks', 'co', 'c8sr']
#
#
# ===Tokens:===
# ['total', 'operating', 'revenue', 'grew', '27', '6', 'year', 'year', 'eur61m']
#
#
# ===Tokens:===
# ['coh', 'gaining', 'momentum', 'nice', 'buy', 'signals', 'long', '35', '92', 'http', 'stks', 'co', 't0tah']
#
#
# ===Tokens:===
# ['md', 'henning', 'bahr', 'stockmann', 'gruppen', 'praises', 'trend', 'since', 'chains', 'become', 'stronger', 'decision', 'making', 'processes', 'clear']
#
#
# ===Tokens:===
# ['20', 'october', '2010', 'finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'eur7m', 'first', 'nine', 'months', '2010', 'eur23', '3', 'period', '2009']
#
#
# ===Tokens:===
# ['svyturys', 'utenos', 'alus', 'controlled', 'nordic', 'group', 'baltic', 'beverages', 'holding', 'bbh', 'posted', '4', '7', 'per', 'cent', 'growth', 'beer', 'sales', 'january', 'may', '46', '22', 'million', 'litres']
#
#
# ===Tokens:===
# ['finnish', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'net', 'loss', 'contracted', 'eur', '49', 'million', 'usd', '68', '2', 'first', 'nine', 'months', '2010', 'eur', '229', 'million', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'consolidated', 'net', 'operating', 'profit', 'increased', 'eur', '4', '8', 'mn', 'first', 'quarter', '2005', 'eur', '6', '4', 'mn', 'first', 'quarter', '2006']
#
#
# ===Tokens:===
# ['real', 'corporation', 'press', 'release', '3', 'november', '10', '35', 'real', 'corporation', 'second', 'best', 'company', 'materials', 'sector', 'including', 'e', 'g', 'forest', 'industry', 'companies', 'carbon', 'disclosure', 'leadership', 'index', 'cdli', 'nordic', 'report', '2009']
#
#
# ===Tokens:===
# ['aapl', 'dips', 'bought', 'real', 'quick', 'higher', 'lows', 'fo', 'sho']
#
#
# ===Tokens:===
# ['lse', 'deutsche', 'boerse', 'merger', 'would', 'signal', 'end', 'exchange', 'mega', 'deals']
#
#
# ===Tokens:===
# ['save', 'breaking', 'downtrend', 'line', 'increasing', 'volume', 'move', '20', '57', 'could', 'see', 'upside', 'http', 'stks', 'co', 'l8y4']
#
#
# ===Tokens:===
# ['rcon', 'upside', 'today', 'thing', 'severe', 'low', 'float', 'catalyst', 'guy', 'run']
#
#
# ===Tokens:===
# ['eli', 'lilly', 'co', 'lly', 'broken', 'new', 'high', 'astrazeneca', 'collaboration']
#
#
# ===Tokens:===
# ['iaci', 'http', 'stks', 'co', 'tju', 'looks', 'good', 'weekly', 'chart']
#
#
# ===Tokens:===
# ['vmw', 'got', 'nice', 'push', 'today', 'following', 'small', 'sweepers', 'may', 'c', 'morning']
#
#
# ===Tokens:===
# ['teleste', 'acquisition', 'marks', 'entry', 'services', 'business', 'market', 'long', 'established', 'significant', 'supplier', 'products']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '500', '000', 'usd', '680', '000', 'last', 'quarter', '2010', 'eur', '5', '3', 'million', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '29', '2008', 'finnish', 'lifting', 'equipment', 'maker', 'konecranes', 'oyj', 'omx', 'kcr1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '116', '6', 'million', 'usd', '149', '1', 'first', 'nine', 'months', '2008', 'eur', '73', '6', 'million']
#
#
# ===Tokens:===
# ['lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'kaluga', 'regional', 'administration', 'last', 'november']
#
#
# ===Tokens:===
# ['operating', 'profit', 'asian', 'plants', 'grew', 'markedly']
#
#
# ===Tokens:===
# ['truly', 'takes', 'efficiency', 'new', 'heights', 'mr', 'metso', 'adds']
#
#
# ===Tokens:===
# ['january', 'september', '2007', 'group', 'net', 'sales', 'continuing', 'operations', 'rose', 'eur', '213', '1', 'mn', 'eur', '172', '6', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['transaction', 'strengthens', 'position', 'design', 'branded', 'goods', 'said', 'fiskars', 'president', 'ceo', 'heikki', 'allonen', 'pointing', 'two', 'groups', 'relatively', 'overlapping', 'operations']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '5', '5', 'mn', 'eur', '0', '7', 'mn']
#
#
# ===Tokens:===
# ['memorandum', 'understanding', 'mou', 'parties', 'collaborate', 'preparing', 'implementing', 'joint', 'projects', 'fields', 'combined', 'power', 'heat', 'generation', 'environmental', 'protection', 'energy', 'efficient', 'technologies']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['easyjet', 'attracts', 'passengers', 'june', 'still', 'lags', 'ryanair']
#
#
# ===Tokens:===
# ['cern', 'consolidating', '50', '200', 'nice', 'long', 'entry', 'w', 'stop', '10', 'targeting', '70', 'area']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'gains', 'land', 'securities', 'dividend', 'hike']
#
#
# ===Tokens:===
# ['bbry', 'ready', 'take']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '5', '8', 'mn', 'loss', 'eur', '1', '7', 'mn', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['metso', 'supply', 'equipment', 'two', 'process', 'lines', 'northland', 'resources', 'new', 'kaunisvaara', 'iron', 'ore', 'project', 'sweden', 'exploits', 'tapuli', 'sahavaara', 'iron', 'ore', 'deposits']
#
#
# ===Tokens:===
# ['carnival', 'corporation', 'china', 'merchants', 'group', 'sign', 'memo', 'understanding']
#
#
# ===Tokens:===
# ['alma', 'media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'order', 'supply', 'uncoated', 'fine', 'paper', 'machine', 'mcc', 'paper', 'yinhe', 'china']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '94', 'mn', 'eur', '2', '45', 'mn']
#
#
# ===Tokens:===
# ['diluted', 'loss', 'per', 'share', 'stood', 'eur', '0', '15', 'versus', 'eur', '0', '26']
#
#
# ===Tokens:===
# ['3', 'january', '2011', 'finnish', 'flag', 'carrier', 'finnair', 'oyj', 'hel', 'fia1s', 'said', 'today', 'sealed', 'nine', 'year', 'sale', 'leaseback', 'agreement', 'newest', 'airbus', 'a330', 'aircraft', 'syndication', 'japanese', 'operating', 'lease', 'market']
#
#
# ===Tokens:===
# ['auto', 'trader', 'share', 'price', 'surges', 'company', 'floats', 'lse']
#
#
# ===Tokens:===
# ['company', 'said', 'estimates', 'make', 'slight', 'profit', 'thanks', 'cost', 'cutting', 'measures']
#
#
# ===Tokens:===
# ['aapl', 'taking', 'shorts', 'punishing', 'reminder', 'spear', 'strongest', 'herd']
#
#
# ===Tokens:===
# ['raute', 'posted', 'net', 'profit', '1', '8', 'mln', 'euro', '2', '6', 'mln', 'third', 'quarter', '2007', 'compared', 'net', 'loss', '299', '000', 'euro', '430', '000', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['yahoo', 'stock', '36', '46', 'bidding', 'war', 'picks', 'company', 'https', 'co', 'jdnzxdcmkl', 'yhoo', 'https', 'co', 'hmoegfhgvn']
#
#
# ===Tokens:===
# ['company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', 'adding', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year']
#
#
# ===Tokens:===
# ['goog', 'breakout', 'likely', 'medium', 'target', '700', 'http', 'stks', 'co', '1lpz', 'http', 'chart', 'ly', 'lgb94rr']
#
#
# ===Tokens:===
# ['singapore', 'icis', '1', 'kemira', 'indian', 'water', 'infrastructure', 'firm', '2', 'ivrcl', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'andhra', 'pradesh', 'state', 'india', 'finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'tuesday']
#
#
# ===Tokens:===
# ['goog', 'testing', '200', 'day', 'consolidation', 'http', 'stks', 'co', 'h0cpj']
#
#
# ===Tokens:===
# ['prlb', 'hanging', 'tough', 'market', 'due', 'analyst', 'upgrades', 'last', 'week', 'almost', '3']
#
#
# ===Tokens:===
# ['energy', 'efficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'state', 'art', 'technology']
#
#
# ===Tokens:===
# ['entering', 'long', 'lockheed', 'martin', 'lmt', 'thursday', 'open', 'http', 'stks', 'co', 'exta']
#
#
# ===Tokens:===
# ['company', 'order', 'book', 'stood', '1', '5', 'bln', 'euro', '2', '2', 'bln', 'september', '30', '2007', '24', '2', 'pct', 'year', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '534', '3', 'mln']
#
#
# ===Tokens:===
# ['aim', 'ensure', 'vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', 'comments', 'vacon', 'plc', 'president', 'ceo', 'vesa', 'laisi']
#
#
# ===Tokens:===
# ['two', 'companies', 'also', 'partner', 'developing', 'raiso', 'cholesterol', 'lowering', 'brand', 'benecol']
#
#
# ===Tokens:===
# ['nyse', 'owner', 'ice', 'considers', 'offer', 'lse']
#
#
# ===Tokens:===
# ['astrazeneca', 'bags', 'another', 'cancer', 'drug', 'deal', 'time', 'inovio']
#
#
# ===Tokens:===
# ['adbe', 'technical', 'alerts', 'expansion', 'breakout', 'gilligan', 'island', 'sell', 'setup', 'volume', 'surge', 'new', '52', 'https', 'co', 'lxx66tknfh']
#
#
# ===Tokens:===
# ['change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', 'said', 'julia', 'prohaska', 'director', 'marketing', 'communications', 'fiskars']
#
#
# ===Tokens:===
# ['ebit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '67', '8', 'mn', 'eur', '38', '1', 'mn']
#
#
# ===Tokens:===
# ['finland', 'national', 'carrier', 'finnair', 'plc', 'carried', 'record', '8', '5', 'million', 'passengers', '2005', 'increase', '4', '5', 'percent', 'previous', 'year', 'airline', 'reported', 'tuesday']
#
#
# ===Tokens:===
# ['fb', 'trending', 'nicely', 'intraday']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur36m', 'eur27m']
#
#
# ===Tokens:===
# ['last', 'week', 'finnish', 'metals', 'technology', 'group', 'announced', 'plans', 'sell', '80', 'percent', 'technology', 'unit', 'company', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'raises', 'prospect', 'investor', 'payout']
#
#
# ===Tokens:===
# ['satama', 'earned', 'data', 'management', 'solutions', 'competency', 'business', 'intelligence', 'specialization', 'recentlyvia', 'acquisition', 'fimentor', 'oy']
#
#
# ===Tokens:===
# ['spain', 'caixabank', 'launches', 'new', 'takeover', 'bid', 'banco', 'bpi']
#
#
# ===Tokens:===
# ['gild', 'chart', 'ibb', 'back', 'support', 'https', 'co', 'gprz2ujfc4']
#
#
# ===Tokens:===
# ['ebit', 'totalled', 'eur', '14', '4', 'mn', 'compared', 'loss', 'eur', '0', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['stora', 'enso', 'r', 'shares', 'rose', '1', '20', 'pct', '11', '84', 'eur', 'upm', 'kymmene', 'also', 'dragged', 'higher', 'rising', '1', '68', 'pct', '17', '56', 'eur', 'real', 'b', 'added', '2', '38', 'pct', '4', '30', 'eur']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'amounted', 'ee', '55', '5', 'mn', '36', '2004']
#
#
# ===Tokens:===
# ['press', 'serco', 'set', 'appoint', 'roy', 'gardner', 'ex', 'centrica', 'chairman', 'ft']
#
#
# ===Tokens:===
# ['aapl', 'downgrade', 'bias', 'stock', 'buy']
#
#
# ===Tokens:===
# ['aapl', 'new', 'long', '110', '61', 'broken', 'targets', '112', '19', '119', '86', '123', '82', 'bears', 'must', 'retake', '102', '77', 'qqq', 'nq', 'f', 'ndx', 'https', 'co', '6l3m1wxchw']
#
#
# ===Tokens:===
# ['retailers', 'kingfisher', 'sports', 'direct', 'rise', 'britain', 'share', 'index']
#
#
# ===Tokens:===
# ['bought', 'celg', 'ready', 'bounce']
#
#
# ===Tokens:===
# ['aim', 'convert', 'plants', 'flexible', 'manufacturers', 'new', 'technologically', 'demanding', 'products']
#
#
# ===Tokens:===
# ['arm', 'profits', 'sales', 'shift', 'away', 'mobile', 'gains', 'pace']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'rose', 'eur', '1', '019', 'mn', 'eur', '1', '007', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'ftse', 'higher', 'clubcard', 'bid', 'reports']
#
#
# ===Tokens:===
# ['update', '1', 'astrazeneca', 'sells', 'rare', 'cancer', 'drug', 'sanofi', '300', 'mln']
#
#
# ===Tokens:===
# ['mako', 'hanging', 'well', 'today', 'still', 'basing', 'pattern', 'eyes']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'metso', 'said', 'upgrade', 'one', 'upm', 'kymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', 'machine', 'process', 'controls', 'quality', 'measurements']
#
#
# ===Tokens:===
# ['contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', 'oil', 'shale', 'processing']
#
#
# ===Tokens:===
# ['brooklynbandit', 'simo', 'basing', 'nice', 'close', '24', '18', 'bullish', 'qqq', 'spy', 'study', 'watch', 'close', 'near', 'hod', 'currently', '3', '5']
#
#
# ===Tokens:===
# ['alert', 'new', 'macd', 'signal', 'created', 'ctxs', 'buy', '77', '09', 'time', '18', '23', 'strength', '10', 'powered', 'https', 'co', '4tdgjedllz']
#
#
# ===Tokens:===
# ['resulted', 'improved', 'sales', 'figures', 'sweden']
#
#
# ===Tokens:===
# ['tectia', 'corporation', 'hel', 'tec1v', 'provider', 'real', 'time', 'security', 'solutions', 'today', 'announced', 'appointed', 'lan2lan', 'provider', 'services', 'uk', 'distribute', 'data', 'security', 'manage', 'file', 'transfer', 'software']
#
#
# ===Tokens:===
# ['long', 'aapl']
#
#
# ===Tokens:===
# ['ino', 'back', 'small', 'post']
#
#
# ===Tokens:===
# ['helsinki', 'eliiv', 'today', 'reported', 'eps', 'eur1', '13', '2009', 'increase', 'eps', 'eur1', '12', '2008']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'oyj', 'said', 'november', '13', '2007', '70', 'mln', 'euro', '102', '8', 'mln', 'contract', 'construct', 'new', 'office', 'building', 'local', 'property', 'company', 'tapiola', 'real', 'estate', 'oy']
#
#
# ===Tokens:===
# ['shorts', 'altr', '38', '85', 'loss']
#
#
# ===Tokens:===
# ['2nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increases', 'quarterly', 'cash', 'dividend', '20', 'percent', 'http', 'stks', 'co', 'goan']
#
#
# ===Tokens:===
# ['combining', 'existing', 'solutions', 'single', 'platform', 'comptel', 'said', 'reduced', 'cost', 'deployment']
#
#
# ===Tokens:===
# ['neon', 'oversold']
#
#
# ===Tokens:===
# ['third', 'quarter', '2010', 'net', 'sales', 'increased', '5', '2', 'eur', '205', '5', 'mn', 'operating', 'profit', '34', '9', 'eur', '23', '5', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'long', '630', '91']
#
#
# ===Tokens:===
# ['pioneer', 'library', 'system', 'one', '127', 'libraries', 'municipalities', 'arts', 'culture', 'higher', 'education', 'science', 'organizations', 'awarded', 'grants', 'participate', 'big', 'read', 'largest', 'federal', 'reading', 'program', 'u', 'history']
#
#
# ===Tokens:===
# ['financing', 'arrangements', 'enable', 'company', 'ensure', 'line', 'treasury', 'policy', 'sufficient', 'financial', 'instruments', 'disposal', 'potential', 'capital', 'requirements']
#
#
# ===Tokens:===
# ['operating', 'income', 'rose', 'eur', '696', '4', 'mn', 'eur', '600', '3', 'mn', '2009']
#
#
# ===Tokens:===
# ['rt', 'andrewnyquist', 'chartology', 'yahoo', 'http', 'stks', 'co', '1itr', 'yhoo', 'crazy', 'looking', 'chart', 'nearing', 'breakout', 'resistance', 'line']
#
#
# ===Tokens:===
# ['sainsbury', 'sells', 'unit', 'lloydspharmacy']
#
#
# ===Tokens:===
# ['liking', 'price', 'action', 'swks', 'currently', '21', '80', 'target', '24', '00', 'year', 'end']
#
#
# ===Tokens:===
# ['group', 'expand', 'chain', 'include', '45', 'stores']
#
#
# ===Tokens:===
# ['finnish', 'consulting', 'engineering', 'group', 'poyry', 'plc', 'omx', 'helsinki', 'poy', 'said', 'wednesday', '1', 'october', 'awarded', 'contract', 'tanqia', 'dibba', 'fzc', 'owner', 'engineer', 'wastewater', 'system', 'dibba', 'emirate', 'fujairah', 'uae']
#
#
# ===Tokens:===
# ['trend', 'underpins', 'uk', 'sales', 'growth', 'kingfisher']
#
#
# ===Tokens:===
# ['lee', 'man', 'paper', 'metso', 'long', 'prosperous', 'co', 'operation', 'good', 'example', 'changshu', 'hongmei', 'kraftliner', 'machines', 'delivered', 'earlier']
#
#
# ===Tokens:===
# ['ibm', 'staying', 'strong']
#
#
# ===Tokens:===
# ['open', 'next', 'year', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['turun', 'kaupunkin', 'finland', 'based', 'company', 'awarded', 'contract', 'lemminkainen', 'talotekniikka', 'oy', 'electrical', 'installation', 'work']
#
#
# ===Tokens:===
# ['revenue', 'grew', '12', 'percent', 'x20ac', '3', '6', 'billion', 'us', '4', '5', 'billion']
#
#
# ===Tokens:===
# ['royal', 'dutch', 'shell', 'buy', 'bg', 'group', 'nearly', '70', 'billion']
#
#
# ===Tokens:===
# ['estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters']
#
#
# ===Tokens:===
# ['eps', 'continuing', 'operations', 'came', '0', '30', 'eur', '0', '17']
#
#
# ===Tokens:===
# ['stable', 'outlook', 'reflects', 'nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', 'strong', 'cash', 'flow', 'generation', 'conservative', 'balance', 'sheet', 'said', 'raab']
#
#
# ===Tokens:===
# ['whitbread', 'share', 'price', 'climbs', 'q4', 'sales', 'growth']
#
#
# ===Tokens:===
# ['financial', 'impact', 'estimated', 'annual', 'improvement', 'eur2', '0', 'division', 'results', 'fiscal', 'year', '2008']
#
#
# ===Tokens:===
# ['kndi', 'let', 'see', 'higher', 'highs', 'higher', 'lows', 'rest', 'day', 'slow', 'steady']
#
#
# ===Tokens:===
# ['adp', 'news', 'finnish', 'handling', 'systems', 'provider', 'cargotec', 'oyj', 'hel', 'cgcbv', 'announced', 'friday', 'orders', 'worth', 'eur', '10', 'million', 'usd', '13', '2', 'deliver', 'linkspans', 'jordan', 'morocco', 'ireland']
#
#
# ===Tokens:===
# ['continued', 'actively', 'focus', 'r', 'position', 'offering', 'away', 'point', 'solutions', 'towards', 'dynamic', 'end', 'end', 'solutions', 'ervio', 'stated']
#
#
# ===Tokens:===
# ['sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season']
#
#
# ===Tokens:===
# ['transaction', 'positive', 'impact', 'around', 'eur2m', 'earnings', 'ruukki', 'recognize', 'fourth', 'quarter', 'year']
#
#
# ===Tokens:===
# ['kesko', 'car', 'import', 'retailing', 'business', 'vv', 'auto', 'saw', 'sales', 'grow', '17', '1', 'pct']
#
#
# ===Tokens:===
# ['insight', 'hires', 'aviva', 'david', 'hillier', 'multi', 'asset', 'team']
#
#
# ===Tokens:===
# ['news', 'feedftse', '100', 'movers', 'ashtead', 'jumps', 'strong', 'interims', 'glencore', 'bp']
#
#
# ===Tokens:===
# ['main', 'strength', 'cooperation', 'project', 'lies', 'merging', 'know', 'two', 'large', 'companies']
#
#
# ===Tokens:===
# ['company', 'also', 'featured', 'ethibel', 'pioneer', 'investment', 'register', 'included', 'innovest', 'global', '100', 'list', 'world', 'sustainable', 'corporations']
#
#
# ===Tokens:===
# ['london', 'morning', 'briefing', 'hsbc', 'standard', 'chartered', 'shares', 'rise']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'rose', '11', '4', 'year', '82', '2', 'million', 'euros', '2005', 'sales', '686', '5', 'million', 'euros', '13', '8', 'year', 'company', 'said', 'earlier']
#
#
# ===Tokens:===
# ['tsla', 'bad', 'day', 'short']
#
#
# ===Tokens:===
# ['objective', 'planned', 'measures', 'achieve', 'significant', 'savings', 'next', 'years']
#
#
# ===Tokens:===
# ['update', '3', 'auto', 'trader', 'shares', 'leap', 'uk', 'biggest', 'private', 'equity', 'backed', 'listing']
#
#
# ===Tokens:===
# ['besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', 'paavel', 'said']
#
#
# ===Tokens:===
# ['ftse', 'rallies', 'three', 'month', 'low', 'boosted', 'stanchart', 'sainsbury']
#
#
# ===Tokens:===
# ['aria', 'bounce', 'player', 'long', '6', '17', 'http', 'stks', 'co', 'q0wff']
#
#
# ===Tokens:===
# ['consolidated', 'operating', 'profit', 'excluding', 'one', 'items', 'eur', '30', '6', 'mn', 'eur', '29', '6', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bullya', 'pollux654321', '50', 'kors', '80', 'calls', 'going', 'b', 'blessing', 'daughters', 'tuition']
#
#
# ===Tokens:===
# ['according', 'sepp', 'nen', 'new', 'technology', 'umts900', 'solution', 'network', 'building', 'costs', 'one', 'third', 'lower', 'building', '3', '5', 'g', 'networks', 'operating', '2', '100', 'mhz', 'frequency']
#
#
# ===Tokens:===
# ['crus', 'upgraded', 'buy', 'alpha', 'street', 'research']
#
#
# ===Tokens:===
# ['favourable', 'currency', 'rates', 'also', 'contributed', 'higher', 'net', 'sales', 'ceo', 'kari', 'kauniskangas', 'said']
#
#
# ===Tokens:===
# ['tesco', 'breaks', 'downward', 'slide', 'cutting', 'sales', 'decline', 'half']
#                       0   1
# 0             net sales  80
# 1      operating profit  77
# 2             http stks  73
# 3               stks co  73
# 4              https co  62
# ...                 ...  ..
# 14097    downward slide   1
# 14098     slide cutting   1
# 14099     cutting sales   1
# 14100     sales decline   1
# 14101      decline half   1
#
# [14102 rows x 2 columns]

# %%
# Creating neutral bigrams

for text in train_set[train_set['Sentiment']=='positive']['Sentence']:
    for word in generate_ngrams(text, 2):
        neutralWords_bi[word]+=1
df_neutral_bi = pd.DataFrame(sorted(neutralWords_bi.items(),key=lambda x:x[1],reverse=True))
df_neutral_bi
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['contrast', 'company', 'net', 'loss', 'third', 'quarter', '2009', 'contracted', 'eur', '76', 'million', 'eur', '256', 'million', 'corresponding', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finland', 'neste', 'oil', 'awarded', 'chemical', 'industry', 'federation', 'finland', 'innovation', 'award', 'nexbtl', 'technology', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['combining', 'deep', 'domain', 'expertise', 'application', 'service', 'management', 'asm', 'outsourcing', 'service', 'offerings', 'proved', 'winning', 'combination']
#
#
# ===Tokens:===
# ['trx', 'http', 'stks', 'co', '1kkk', 'long', 'setup', 'macd', 'cross']
#
#
# ===Tokens:===
# ['meanwhile', 'electrowatt', 'ekono', 'philippines', 'inc', 'also', 'awarded', 'three', 'year', 'operation', 'maintenance', 'contract', 'fr', 'cement', 'corporation']
#
#
# ===Tokens:===
# ['madison', 'wis', 'feb', '6', 'prnewswire', 'fiskars', 'announces', 'united', 'states', 'patent', 'trademark', 'office', 'granted', 'trademark', 'registration', 'color', 'orange', 'iconic', 'scissor', 'handles']
#
#
# ===Tokens:===
# ['wfm', 'bought', 'little', 'yesterday', 'hoping', 'earnings', 'pop']
#
#
# ===Tokens:===
# ['ragutis', 'controlled', 'finnish', 'brewery', 'reported', '5', '4', 'per', 'cent', 'rise', 'beer', 'sales', '10', '44', 'million', 'litres', 'held', '11', '09', 'per', 'cent', 'market', 'share']
#
#
# ===Tokens:===
# ['addition', 'cramo', 'peab', 'signed', 'exclusive', 'five', 'year', 'rental', 'agreements', 'finland', 'extended', 'existing', 'rental', 'agreements', 'swedish', 'market', 'another', 'five', 'years']
#
#
# ===Tokens:===
# ['combined', 'foreign', 'investments', 'creates', 'interesting', 'opportunities', 'solteq']
#
#
# ===Tokens:===
# ['osur', '33', 'since', '6', '25', 'buy', 'signal', 'resistance', '5', '33', 'expect', '1', 'pullback', '2nd', 'half', 'day', '2', 'break', 'abov', '5', '33', 'continue', 'rally', '4', '5', 'days']
#
#
# ===Tokens:===
# ['federal', 'secretary', 'transport', 'communication', 'mexico', 'awarded', 'poyry', 'mexican', 'partner', 'sintra', 'consulting', 'contract', 'connection', 'buenavista', 'cuautitlan', 'suburban', 'railway']
#
#
# ===Tokens:===
# ['kndi', 'china', 'electriccar', 'maker', 'china', 'car', 'sales', '7', '8', 'also', 'may', 'feed', 'tsla', 'momentum', 'run', 'lately']
#
#
# ===Tokens:===
# ['agreement', 'signed', 'biohit', 'healthcare', 'ltd', 'uk', 'based', 'subsidiary', 'biohit', 'oyj', 'finnish', 'public', 'company', 'develops', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems']
#
#
# ===Tokens:===
# ['third', 'quarter', 'net', 'sales', 'increased', '12', 'year', 'year', 'eur159', '5', '6', 'comparable', 'currency', 'rates', 'growth']
#
#
# ===Tokens:===
# ['finnish', 'vacon', 'signed', 'significant', 'deals', 'norwegian', 'scandinavian', 'electric', 'systems', 'ses', 'supply', 'ac', 'drives']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'bounces', 'back', 'mondi', 'barratt', 'lead']
#
#
# ===Tokens:===
# ['update', 'barclays', 'expects', 'gain', 'settling', 'lehman', 'bros', 'trustee']
#
#
# ===Tokens:===
# ['interest', 'heats', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'co', 'j5jvji9bia']
#
#
# ===Tokens:===
# ['according', 'pkc', 'acquisition', 'would', 'bring', 'significant', 'addition', 'pkc', 'customer', 'base']
#
#
# ===Tokens:===
# ['buffett', 'berkshire', 'builds', 'deere', 'stake', 'dumps', 'exxon']
#
#
# ===Tokens:===
# ['etteplan', 'targets', 'employ', 'least', '20', 'people', 'borl', 'nge']
#
#
# ===Tokens:===
# ['slw', 'weekly', '34', 'calls', '28', '95', '23', 'x', '25', '321', 'volume', 'worth', 'chance', 'jmho', 'http', 'stks', 'co', '1qfg']
#
#
# ===Tokens:===
# ['finnish', 'food', 'industry', 'companies', 'hk', 'ruokatalo', 'atria', 'form', 'joint', 'venture', 'company', 'called', 'l', 'nsi', 'kalkkuna', 'produce', 'turkey', 'meat']
#
#
# ===Tokens:===
# ['sales', 'climbed', '19', '2', 'pct', '1', '002', 'bln', 'eur', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure']
#
#
# ===Tokens:===
# ['continuing', 'operations', 'turned', 'operating', 'loss', 'eur', '0', '1', 'mn', 'slight', 'improvement', 'loss', 'eur', '0', '2', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'leap', 'ftse', '100', 'marks', 'spencer', 'drops']
#
#
# ===Tokens:===
# ['basware', 'corporation', 'stock', 'exchange', 'release', 'august', '31', '2010', '16', '25', 'basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'basware', 'deliver', 'invoice', 'automation', 'solution', 'connectivity', 'services', 'international', 'industrial', 'group']
#
#
# ===Tokens:===
# ['also', 'turned', 'earnings', 'per', 'share', 'eps', 'eur', '0', '08', 'versus', 'loss', 'per', 'share', 'eur', '0', '04']
#
#
# ===Tokens:===
# ['company', 'consolidated', 'operating', 'profit', 'amounted', 'eur', '15', '86', 'mn', 'eur', '4', '14', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['aapl', 'right', 'back', 'buy', 'dips', 'brought', 'cnbc', 'lol']
#
#
# ===Tokens:===
# ['capman', 'partner', 'able', 'develop', 'business', 'continue', 'focus', 'providing', 'quality', 'restaurant', 'services', 'customers', 'says', 'christopher', 'wynne', 'ceo', 'papa', 'john', 'russia']
#
#
# ===Tokens:===
# ['technical', 'indicators', 'stock', 'bullish', 'p', 'gives', 'nok', 'positive', '4', 'stars', '5', 'buy', 'ranking']
#
#
# ===Tokens:===
# ['upm', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', 'efficiency', 'operations', 'improved', 'chief', 'executive', 'jussi', 'pesonen', 'said']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'maker', 'amer', 'sports', 'oyj', 'hel', 'ameas', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '16', '9', 'million', 'usd', '22', '3', 'second', 'quarter', '2010', 'eur', '23', '2', 'million', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['outokumpu', 'chief', 'executive', 'juha', 'rantanen', 'expressed', 'confidence', 'china', 'market']
#
#
# ===Tokens:===
# ['nflx', 'vision', 'short', 'term', 'consolidation', 'movement', 'higher', 'http', 'stks', 'co', 'j05uu']
#
#
# ===Tokens:===
# ['elcoteq', 'elcoteq', 'se', 'leading', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'communications', 'technology', 'field']
#
#
# ===Tokens:===
# ['renovation', 'biggest', 'moulding', 'line', 'orhangazi', 'foundry', 'modern', 'line', 'europe']
#
#
# ===Tokens:===
# ['company', 'established', '3g', 'base', 'station', '17', '000', 'feet', 'foot', 'mount', 'everest', 'enable', 'mountain', 'climbers', '29', '035', 'foot', 'summit', 'surf', 'internet', 'even', 'send', 'videos', 'exploits']
#
#
# ===Tokens:===
# ['spy', 'hang', 'bull', 'hat', 'yet', 'next', 'week', 'pop', 'higher', 'qe3', 'hope', 'back', 'fed', '2', 'day', 'meeting']
#
#
# ===Tokens:===
# ['return', 'investment', '16', '6', 'compared', '15', '8', '2004']
#
#
# ===Tokens:===
# ['finnish', 'investment', 'group', 'panostaja', 'oyj', 'said', 'net', 'profit', 'went', '8', '6', 'mln', 'euro', '11', '4', 'mln', 'fiscal', '2005', '06', 'ended', 'october', '31', '2006', '2', '8', 'mln', 'euro', '3', '7', 'mln', 'period', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['analysts', 'impressed', 'progress', 'tesla', 'flagship', 'factory', 'co', 'spent', '1', '6b', 'upgrades', '15', 'https', 'co', 'sabxcsn8cd', 'tsrandall', 'tsla']
#
#
# ===Tokens:===
# ['london', 'afx', 'shares', 'rautaruukki', 'corp', 'upgraded', 'hold', 'sell', 'abn', 'amro', 'price', 'target', 'raised', '25', '75', 'eur', '14', '5', 'said', 'dealers']
#
#
# ===Tokens:===
# ['narrows', 'eur2', '8', '9', 'mo', '09', '29', 'october', '2009', 'finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'net', 'loss', 'narrowed', 'eur2', '8', 'first', 'nine', 'months', '2009', 'eur35', '6', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['adp', 'news', 'nov', '18', '2008', 'finnish', 'ac', 'drives', 'manufacturer', 'vacon', 'oyj', 'omx', 'vac1v', 'said', 'today', 'set', 'new', 'representative', 'offices', 'romania', 'ukraine', 'serve', 'growing', 'markets', 'eastern', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['finnish', 'aktia', 'group', 'operating', 'profit', 'rose', 'eur', '17', '5', 'mn', 'first', 'quarter', '2010', 'eur', '8', '2', 'mn', 'first', 'quarter', '2009']
#
#
# ===Tokens:===
# ['first', 'nine', 'months', '2010', 'talvivaara', 'net', 'loss', 'narrowed', 'eur', '8', '3', 'million', 'eur', '21', '9', 'million', 'period', '2009']
#
#
# ===Tokens:===
# ['wpp', 'boosts', 'sales', 'despite', 'cautious', 'clients']
#
#
# ===Tokens:===
# ['fb', 'small', 'long', '109', '25', 'via', 'calls']
#
#
# ===Tokens:===
# ['altia', 'operating', 'profit', 'jumped', 'eur', '47', 'million', 'eur', '6', '6', 'million']
#
#
# ===Tokens:===
# ['lnt', 'increases', 'annual', 'dividend', 'target', '1', '80', 'share', '1', '70', 'share']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'kci', 'konecranes', 'said', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'ltd']
#
#
# ===Tokens:===
# ['vaahto', 'pulp', 'paper', 'finnish', 'vaahto', 'group', 'awarded', 'order', 'renovate', 'finnish', 'swedish', 'forest', 'industry', 'company', 'stora', 'enso', 'paperboard', 'machine', 'ingerois', 'board', 'mill', 'finland']
#
#
# ===Tokens:===
# ['buy', 'recommendation', 'reiterated']
#
#
# ===Tokens:===
# ['bristol', 'port', 'company', 'sealed', 'one', 'million', 'pound', 'contract', 'cooper', 'specialised', 'handling', 'supply', 'four', '45', 'tonne', 'customised', 'reach', 'stackers', 'konecranes']
#
#
# ===Tokens:===
# ['h', 'move', 'enhance', 'growth']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'period', 'eur0', '9', 'eur0', '01', 'last', 'year']
#
#
# ===Tokens:===
# ['subscriptions', 'increase', 'cargotec', 'share', 'capital', '36', '780', 'euros']
#
#
# ===Tokens:===
# ['new', 'representation', 'extends', 'comptel', 'global', 'presence', 'total', '18', 'countries', 'serving', '250', 'customers', '80', 'countries', 'worldwide']
#
#
# ===Tokens:===
# ['china', 'finnish', 'kone', 'provides', 'elevators', 'escalators', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'high', 'speed', 'railway', 'section', 'beijing', 'shanghai', '1', '5', 'years', 'time']
#
#
# ===Tokens:===
# ['shares', 'standard', 'chartered', 'stan', 'rose', '1', '2', 'ftse', '100', 'royal', 'bank', 'scotland', 'rbs', 'shares', 'rose', '2', 'barclays', 'shares', 'barc', 'bcs', '1', '7']
#
#
# ===Tokens:===
# ['cargo', 'volume', 'increased', 'approximately', '5']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'retail', 'wholesale', 'group', 'kesko', 'reported', 'net', 'sales', '659', '4', 'mln', 'eur', 'february', 'increase', '10', '8', 'pct', 'year', 'year']
#
#
# ===Tokens:===
# ['lule', 'municipality', 'awarded', 'yit', '2', 'year', 'contract', 'property', 'management', 'one', 'third', 'municipality', 'properties', 'total', 'area', '140', '000', 'sq', 'metres']
#
#
# ===Tokens:===
# ['pre', 'tax', 'profit', 'totaled', 'eur', '397', '4', 'mn', 'eur', '164', '7', 'mn']
#
#
# ===Tokens:===
# ['yhoo', 'break', '5', 'min']
#
#
# ===Tokens:===
# ['today', 'bought', 'mu', 'yhoo', 'vale', 'nbl', 'twtr', 'axp', 'znga', 'https', 'co', 'vt6t5zp2is']
#
#
# ===Tokens:===
# ['kalnapilio', 'tauro', 'grupe', 'kalnapilis', 'tauras', 'group', 'owned', 'denmark', 'royal', 'unibrew', 'raised', 'market', 'share', '25', '2', 'percent', '23', '91', 'percent', 'beer', 'sales', 'nine', 'months', 'jumped', '11', '4', 'percent', '52', '99', 'million', 'liters']
#
#
# ===Tokens:===
# ['mos', 'looking', 'good', '58', '65', 'calls', 'active', 'month', 'weekly']
#
#
# ===Tokens:===
# ['nokian', 'tyre', 'proves', 'high', 'safety', 'excellently', 'important', 'driving', 'qualities', 'stability', 'mark', '1', '4', 'handling', '1', '5', 'braking', 'wet', 'road', '1', '9']
#
#
# ===Tokens:===
# ['several', 'growth', 'initiatives', 'chosen', 'geographic', 'areas', 'already', 'ongoing', 'continued', 'noting', 'lindex', 'opened', 'first', 'store', 'czech', 'republic', 'autumn', 'brno']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'totalled', 'eur', '2', '71', 'mn', 'compared', 'negative', 'eur', '0', '83', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['sppi', 'building', 'rs', 'sweet', 'want', 'break', 'new', '52week', 'earnings', 'growth', 'justifies', 'way', 'higher']
#
#
# ===Tokens:===
# ['according', 'finnish', 'metso', 'minerals', 'value', 'company', 'orders', 'gone', 'eur', '1', '9', 'bn', '12', 'months']
#
#
# ===Tokens:===
# ['return', 'equity', 'stood', '18', '3', 'compared', '15', '4', 'third', 'quarter', '2005']
#
#
# ===Tokens:===
# ['fio', 'stay']
#
#
# ===Tokens:===
# ['intuitiv', 'clne', 'gasoline', 'prices', 'spike', 'california', 'http', 'stks', 'co', 't1boi']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '6', '2009', 'finnish', 'fishing', 'tackle', 'company', 'rapala', 'vmc', 'corp', 'hel', 'rap1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '19', '2', 'million', 'usd', '24', '6', '2008', 'eur', '17', '5', 'million', '2007']
#
#
# ===Tokens:===
# ['warmly', 'welcome', 'michael', 'frei', 'outotec']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'group', 'share', 'price', 'climbs', '1', '5bn', 'special', 'dividend']
#
#
# ===Tokens:===
# ['stora', 'enso', 'third', 'quarter', 'pre', 'tax', 'profit', 'doubled', 'eur', '197mn']
#
#
# ===Tokens:===
# ['kesko', 'agro', 'lietuva', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'kesko', 'group', 'boosted', 'sales', '42', '9', 'percent', '13', '4', 'million', 'euros', 'vat', 'inclusive']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur13', '6', 'net', 'sales', 'increased', 'eur394', '7', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['compass', 'group', 'says', 'positive', 'year', 'ahead']
#
#
# ===Tokens:===
# ['shire', 'ceo', 'steps', 'drive', 'get', 'baxalta', 'board', 'talking']
#
#
# ===Tokens:===
# ['astrazeneca', 'acquires', 'zs', 'pharma', '2', '7', 'billion', 'deal']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '11', '4', 'mn', 'eur', '7', '5', 'mn']
#
#
# ===Tokens:===
# ['net', 'interest', 'income', 'eur', '152', '2', 'mn', 'eur', '101', '0', 'mn', '2008']
#
#
# ===Tokens:===
# ['president', 'ceo', 'mika', 'vehvil', 'inen', 'says', 'positive', 'signs', 'first', 'foremost', 'emerging', 'outside', 'finland']
#
#
# ===Tokens:===
# ['fb', 'slight', 'green', 'may', 'runner', 'later']
#
#
# ===Tokens:===
# ['contract', 'signed', 'august', 'papua', 'new', 'guinea', 'based', 'lihir', 'gold', 'ltd', 'asx', 'lgl']
#
#
# ===Tokens:===
# ['stora', 'enso', 'norske', 'skog', 'real', 'upm', 'kymmene', 'credit', 'suisse', 'first', 'boston', 'cfsb', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'nordic', 'forestry', 'groups']
#
#
# ===Tokens:===
# ['pleased', 'welcome', 'tapeks', 'noma', 'cramo', 'group']
#
#
# ===Tokens:===
# ['berkshire', 'applies', 'boost', 'wells', 'fargo', 'stake', '10', 'percent']
#
#
# ===Tokens:===
# ['outotec', 'oyj', 'press', 'release', 'december', '4', '2009', '10', '30', 'outotec', 'establishes', 'new', 'subsidiary', 'kolkata', 'outotec', 'established', 'subsidiary', 'india', 'order', 'better', 'serve', 'indian', 'customers', 'increase', 'business', 'growing', 'indian', 'market']
#
#
# ===Tokens:===
# ['amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'company']
#
#
# ===Tokens:===
# ['honored', 'acknowledged', 'commitment', 'industry', 'especially', 'asia', 'pacific']
#
#
# ===Tokens:===
# ['navteq', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'north', 'american', 'vehicles', 'may', 'leader', 'turn', 'turn', 'navigation', 'data', 'offered', 'services', 'onstar', 'north', 'america', 'said', 'analyst', 'phil', 'magney', 'telematics', 'research', 'group', 'minnetonka', 'minn']
#
#
# ===Tokens:===
# ['gsk', 'joins', 'china', 'trade', 'push', 'uk', 'trumpets', 'healthcare', 'deals']
#
#
# ===Tokens:===
# ['value', 'firm', 'forestry', 'holdings', 'increased', 'sek', '3', '6', 'bn']
#
#
# ===Tokens:===
# ['hammerson', 'jv', 'partner', 'secure', 'ownership', 'ireland', 'dundrum', 'quick', 'facts']
#
#
# ===Tokens:===
# ['2009', 'fiskars', 'cash', 'flow', 'operating', 'activities', 'amounted', 'eur121m', 'eur97m', 'previous', 'year']
#
#
# ===Tokens:===
# ['long', 'vvus', 'shares', 'call', 'option', 'w', 'expiration', 'umm', 'today', 'hitting', 'hod']
#
#
# ===Tokens:===
# ['chime', 'communications', 'set', 'acquired', 'wpp', 'providence']
#
#
# ===Tokens:===
# ['asdfllc', 'nice', 'pop', 'today', 'told', 'ya', 'would', 'green', 'haha', 'funny', 'bring', 'actually', 'working', 'story', 'nok', 'moment']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'company', 'elcoteq', 'signing', 'cooperation', 'agreement', 'japanese', 'mobile', 'phone', 'manufacturer', 'bypasses', 'elcoteq', 'tallinn', 'says', 'jan', 'kotka', 'ceo', 'elcoteq', 'tallinn']
#
#
# ===Tokens:===
# ['based', 'upon', 'unique', 'fiber', 'expertise', 'innovative', 'approach', 'company', 'strong', 'market', 'position', 'several', 'business', 'areas', 'operates']
#
#
# ===Tokens:===
# ['company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market']
#
#
# ===Tokens:===
# ['developers', 'project', 'predict', 'completed', 'april', '2009', 'skanssi', 'attract', '4', '5', 'million', 'visitors', 'annually']
#
#
# ===Tokens:===
# ['ftse', '100', 'flat', 'standard', 'chartered', 'leads', 'risers']
#
#
# ===Tokens:===
# ['manavigator', 'september', '7', '2010', 'kemira', 'unveils', 'indian', 'jv', 'ivrcl', 'finnish', 'chemicals', 'group', 'kemira', 'hel', 'kra1v', 'tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'india', 'local', 'construction', 'firm', 'ivrcl', 'infrastructure', 'projects', 'ltd', 'bom', '530773']
#
#
# ===Tokens:===
# ['according', 'finnish', 'aktia', 'bank', 'managing', 'director', 'jussi', 'laitinen', 'bank', 'aim', 'triple', 'number', 'customers', 'finland', 'next', 'five', 'years']
#
#
# ===Tokens:===
# ['finland', 'nokian', 'tyres', 'kazakhstan', 'ordabasy', 'corporation', 'signed', 'agreement', 'build', 'plant', 'astana', 'produce', 'car', 'tires', 'ordabasy', 'chairman', 'dinmukhamet', 'idrisov', 'said', 'press', 'conference']
#
#
# ===Tokens:===
# ['danske', 'bank', 'danske', 'dc', 'jumped', '3', '7', 'percent', '133', '4', 'kroner', 'rebounding', 'yesterday', '3', '5', 'percent', 'slide']
#
#
# ===Tokens:===
# ['vessel', 'order', 'help', 'aspo', 'secure', 'long', 'term', 'competitiveness', 'fleet', 'terms', 'technology', 'pricing']
#
#
# ===Tokens:===
# ['enb', 'ca', 'head', 'shoulders', 'bullish', 'reversal', 'setup', 'breakout', 'oil', 'gas', 'pipleline', 'stock', 'uso']
#
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastic', 'products', 'maker', 'suominen', 'corporation', 'said', 'net', 'loss', 'narrowed', '1', '6', 'mln', 'euro', '2', '0', 'mln', 'first', 'nine', 'months', '2006', '2', '16', 'mln', 'euro', '2', '7', 'mln', 'period', '2005']
#
#
# ===Tokens:===
# ['upside', 'moves', 'volatile', 'mining', 'sector', 'sending', 'anglo', 'american', 'plc', 'aal', '6', '8', '4', '30', 'pm', 'london', 'time']
#
#
# ===Tokens:===
# ['rad', 'would', 'consider', 'opportunity', 'add', 'position', 'company', 'right', 'track', 'still', 'improving', 'sales']
#
#
# ===Tokens:===
# ['ocn', 'stuff', 'looking', 'add', 'shares', 'get', 'new', 'high', 'breakout']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'net', 'profit', 'rose', '26', '1', 'mln', 'euro', '35', '9', 'mln', 'first', 'quarter', '2007', '5', '3', 'mln', 'euro', '7', '3', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['rapala', 'estimates', 'net', 'sales', '2008', 'increase', '8', '0', 'pct', '12', 'pct', 'assuming', '2007', 'exchange', 'rates']
#
#
# ===Tokens:===
# ['free', 'ha', 'heeeeeere', 'comes', 'pump', 'glad', 'picked', '9k', 'end', 'day', 'get', 'ready', 'bull', 'ride']
#
#
# ===Tokens:===
# ['eps', 'grew', '0', '04', 'eur', '0', '02', 'eur']
#
#
# ===Tokens:===
# ['held', 'recent', 'double', 'bottom', 'buy', 'point', '56', '57', 'almost', 'penny', 'today', 'wmt', 'http', 'chart', 'ly', '6nosp5q']
#
#
# ===Tokens:===
# ['astrazeneca', 'shares', 'climb', '3', 'drug', 'maker', 'ups', 'profits', 'forecasts']
#
#
# ===Tokens:===
# ['group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets']
#
#
# ===Tokens:===
# ['companiescar', 'insurer', 'hastings', 'group', 'driving', '180m', 'ipo']
#
#
# ===Tokens:===
# ['vrtx', 'early', 'technical', 'buy', 'signal', 'confirmation', '86', 'needs', 'fundam', 'incentive', 'https', 'co', 'quysrqfo2x']
#
#
# ===Tokens:===
# ['systeemitiimi', 'sales', 'project', 'resources', 'also', 'strengthened', 'director', 'paul', 'skogberg', 'said']
#
#
# ===Tokens:===
# ['accordance', 'strategy', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'south', 'africa', 'october']
#
#
# ===Tokens:===
# ['metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'china', 'lee', 'man', 'paper', 'co']
#
#
# ===Tokens:===
# ['poyry', 'recognized', 'one', 'world', 'leading', 'advisors', 'global', 'forestry', 'industry']
#
#
# ===Tokens:===
# ['skf', '6', 'april', '2010', 'alandsbanken', 'given', 'buy', 'recommendation', 'swedish', 'industrial', 'company', 'skf', 'ab', 'sto', 'skf', 'b', 'share', 'price', 'target', 'sek150']
#
#
# ===Tokens:===
# ['investments', 'operational', 'changes', 'enable', 'additional', 'optimisation', 'working', 'hours', 'thereby', 'cost', 'savings', '7', '9']
#
#
# ===Tokens:===
# ['finnish', 'software', 'developer', 'basware', 'oyj', 'said', 'november', '30', '2006', 'u', 'subsidiary', 'basware', 'inc', 'order', 'provide', 'software', 'contract', 'lifecycle', 'management', 'unnamed', 'u', 'medical', 'technology', 'company']
#
#
# ===Tokens:===
# ['repair', 'maintenance', 'business', 'accounted', 'net', 'sales', 'eur', '645', '3', 'mn', 'eur', '563', '6', 'mn']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'increased', '2', 'eur', '1', '050', '7', 'mn', 'eur', '1', '027', '0', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['stock', 'trading', 'maps', '50', 'day', 'map', 'sek72', '983', 'higher', '200', 'day', 'map', 'sek70', '283', 'bullish', 'indicator']
#
#
# ===Tokens:===
# ['luv', 'continues', 'consolidate', 'previous', 'break', 'area']
#
#
# ===Tokens:===
# ['recommendable', 'nokian', 'z', 'g2', 'according', 'adac', 'judgement', 'latest', 'summer', 'tyre', 'test', 'german', 'automobile', 'association', 'adac']
#
#
# ===Tokens:===
# ['economic', 'occupancy', 'rate', 'sponda', 'property', 'portfolio', 'rose', '91', '2', '88', '8', '2006']
#
#
# ===Tokens:===
# ['leipurin', 'growing', 'rapidly', 'internationalizing', 'group']
#
#
# ===Tokens:===
# ['2008', 'deal', 'likely', 'bring', 'savings', 'eur', '20mn', '25mn']
#
#
# ===Tokens:===
# ['cargotec', 'germany', 'gmbh', 'awarded', 'contract', 'stadtverwaltung', 'mainz', 'chassis', 'bodies', 'open', 'procedure']
#
#
# ===Tokens:===
# ['exports', 'accounted', '65', '4', 'net', 'sales', 'representing', 'time', 'record', 'company']
#
#
# ===Tokens:===
# ['previously', 'eb', 'delivered', 'custom', 'solution', 'lg', 'electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators']
#
#
# ===Tokens:===
# ['marimekko', 'group', 'full', 'year', 'net', 'sales', 'estimated', 'increase', '10']
#
#
# ===Tokens:===
# ['terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', 'chief', 'executive', 'veli', 'matti', 'mattila', 'said']
#
#
# ===Tokens:===
# ['profit', 'taking', 'aapl', 'morning', 'pressure', 'stock', 'still', 'bullish', 'aapl']
#
#
# ===Tokens:===
# ['passenger', 'related', 'revenue', 'rose', '5', '1', 'eur', '460', '8', 'mn', 'eur', '438', '5', 'mn', '2009']
#
#
# ===Tokens:===
# ['end', 'review', 'period', 'nordic', 'aluminium', 'order', 'book', 'stood', 'eur', '8', '77', 'mn', 'compared', 'eur', '7', '04', '2005']
#
#
# ===Tokens:===
# ['tesco', 'closes', 'new', 'chairman', 'dixons', 'carphone', 'john', 'allan', 'frame']
#
#
# ===Tokens:===
# ['takeover', 'cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'latvian', 'market']
#
#
# ===Tokens:===
# ['cencorp', 'estimates', 'net', 'sales', 'last', 'quarter', 'earlier', 'stated', 'eur4', '3', 'eur5', '0', 'operating', 'profit', 'ebit', 'estimated', 'positive']
#
#
# ===Tokens:===
# ['teliasonera', 'said', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', 'nepal', 'population']
#
#
# ===Tokens:===
# ['amazon', 'declares', 'best', 'ever', 'black', 'friday', 'cyber', 'monday', 'kindle', 'family', 'http', 'stks', 'co', 'cetw', 'via', 'engadget', 'amzn']
#
#
# ===Tokens:===
# ['rdc', 'rowan', 'expands', 'share', 'repurchase', 'program', '150', 'million']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', '2010', 'seen', 'grown', 'eur598', '3', 'eur582', '3', '2009']
#
#
# ===Tokens:===
# ['clothing', 'chain', 'sepp', 'l', 'net', 'sales', 'increased', '7', '0', 'eur', '30', '8', 'mn']
#
#
# ===Tokens:===
# ['ilmn', 'piper', 'jeffries', 'raises', 'pt', 'remain', 'long']
#
#
# ===Tokens:===
# ['dxcm', 'making', 'higher', 'highs', 'higher', 'lows', 'consolidates', 'past', 'several', 'weeks', '26', '70', 'time', 'high', '2006']
#
#
# ===Tokens:===
# ['mr', 'lee', 'said', 'hoped', 'neste', 'move', 'pave', 'way', 'collaboration', 'projects', 'two', 'countries']
#
#
# ===Tokens:===
# ['addition', 'fireplace', 'exports', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'sales', 'three', 'month', 'period', 'increased', 'respectively', 'eur0', '3', 'eur13', '1', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['also', 'bringing', 'right', 'kind', 'people', 'upgrade', 'human', 'resources']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '27', '8', 'mn', 'eur', '17', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['endp', 'saw', 'large', 'order', 'one', 'last', 'week', 'someone', 'also', 'accumulating', 'may', 'jun', '35', 'calls', 'today']
#
#
# ===Tokens:===
# ['commencing', 'construction', 'works', 'pearl', 'plaza', 'significant', 'step', 'russian', 'projects']
#
#
# ===Tokens:===
# ['raisio', 'divisions', 'recorded', 'operating', 'profit']
#
#
# ===Tokens:===
# ['meanwhile', 'nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout']
#
#
# ===Tokens:===
# ['glaxo', 'viiv', 'healthcare', 'signs', 'china', 'manufacturing', 'deal', 'desano']
#
#
# ===Tokens:===
# ['bot', 'amzn', '600', 'weekly', 'calls', '5', '93']
#
#
# ===Tokens:===
# ['finnish', 'lifting', 'equipment', 'maker', 'kone', 'oyj', 'said', 'october', '4', '2007', 'order', 'worth', '15', 'mln', 'euro', '21', '2', 'mln', 'deliver', 'total', '53', 'custom', 'designed', 'elevators', 'norwegian', 'shipbuilder', 'aker', 'yards', 'asa']
#
#
# ===Tokens:===
# ['standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'itella']
#
#
# ===Tokens:===
# ['refining', 'margin', 'year', '13', '39', 'bbl', 'compared', '10', '46', 'bbl', 'prior', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '103', '4', 'mn', 'eur', '23', '2', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['kraft', 'heinz', 'merger', 'came', 'together', 'speedy', '10', 'weeks']
#
#
# ===Tokens:===
# ['net', 'sales', 'vegetable', 'oil', 'business', 'rose', 'eur', '10', '6', 'mn', 'eur', '10', '1', 'mn']
#
#
# ===Tokens:===
# ['company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'eur', '67', '1', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'surged', 'eur21m', 'eur106', '000']
#
#
# ===Tokens:===
# ['bilfinger', 'industrial', 'services', 'win', '100m', 'bp', 'contract', 'extension']
#
#
# ===Tokens:===
# ['would', 'invest', 'physical', 'infrastructure', 'would', 'also', 'provide', 'know', 'managing', 'developing', 'science', 'technology', 'parks', 'said', 'sunrise', 'valley', 'director', 'andrius', 'bagdonas']
#
#
# ===Tokens:===
# ['rationalization', 'operations', 'seeks', 'achieve', 'eur', '1', 'million', 'yearly', 'savings', 'second', 'quarter', 'current', 'financial', 'year']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'outperforms', 'europe', 'royal', 'mail', 'tesco', 'rise']
#
#
# ===Tokens:===
# ['profit', 'period', 'eur', '5', '9', 'mn', 'eur', '1', '3', 'mn']
#
#
# ===Tokens:===
# ['cision', 'says', 'sale', 'return', 'u', 'k', 'operation', 'profitability']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'higher', '0', '48', '0', '37', 'year', 'ahead', 'market', 'consensus', '0', '40', 'eur']
#
#
# ===Tokens:===
# ['ebit', 'margin', '1', '4', '5', '1']
#
#
# ===Tokens:===
# ['ruukki', 'forecast', '15', '20', 'annual', 'sales', 'growth', 'positive', 'pretax', 'result', '2010']
#
#
# ===Tokens:===
# ['acquiring', 'rcp', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company']
#
#
# ===Tokens:===
# ['4', 'beaten', 'internet', 'companies', 'may', 'ripe', 'takeover', 'target', 'twitter', 'twtr', 'linkedin', 'lnkd', 'yahoo', 'yhoo', 'groupon', 'grpn']
#
#
# ===Tokens:===
# ['sonc', 'amazing', 'run', 'since', 'middle', 'march', 'obvious', 'quality', 'tastiness', 'burgers', 'factored', 'price', 'advance']
#
#
# ===Tokens:===
# ['activision', 'blizzard', 'media', 'networks', 'announces', 'record', 'esports', 'viewership', 'https', 'co', '729biqlbtk', 'atvi', 'partnered', 'hdsi', '9', 'tournament']
#
#
# ===Tokens:===
# ['dara', 'breaking']
#
#
# ===Tokens:===
# ['supermarket', 'stocks', 'rally', 'tesco', 'plans', 'axe', 'non', 'core', 'uk', 'assets', 'tsco', 'https', 'co', 'bmvhcrwrea']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '4', '7', 'mn', 'eur', '4', '6', 'mn']
#
#
# ===Tokens:===
# ['strategic', 'cooperation', 'rentakran', 'brings', 'us', 'new', 'customers', 'already', 'working', 'relationships', 'authorities', 'new', 'territories', 'said', 'jarmo', 'laasanen', 'senior', 'manager', 'cramo']
#
#
# ===Tokens:===
# ['kitd', 'looking', 'oversold', 'bounce']
#
#
# ===Tokens:===
# ['wft', 'closng', 'higher']
#
#
# ===Tokens:===
# ['kauko', 'telko', 'ltd', 'press', 'release', '19', '06', '2007', '14', '00', '1', '1', 'telko', 'group', 'kauko', 'telko', 'expanding', 'strategic', 'partnership', 'bp', 'industrial', 'lubricants', 'services', 'bp', 'ils', 'acquiring', 'total', 'ownership', 'bp', 'swedish', 'retail', 'company', 'molub', 'alloy', 'ab']
#
#
# ===Tokens:===
# ['eln', 'longs', 'congrats', 'another', 'hod']
#
#
# ===Tokens:===
# ['solutions', 'used', 'upgrading', 'networks', 'russian', 'mso', '37', 'different', 'cities', 'russia']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '9', '2009', 'finnish', 'computer', 'services', 'company', 'proha', 'oyj', 'hel', 'art1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '113', '000', 'usd', '146', '000', '2008', 'eur', '1', '2', 'million', '2007']
#
#
# ===Tokens:===
# ['major', 'breweries', 'increased', 'domestic', 'beer', 'sales', '4', '5', 'per', 'cent', 'last', 'year', '256', '88', 'million', 'litres', '245', '92', 'million', 'litres', '2004']
#
#
# ===Tokens:===
# ['shopping', 'center', 'opened', 'st', 'petersburg', 'russia', 'november', '2010', 'turn', 'cash', 'flow', 'finnish', 'department', 'store', 'chain', 'stockmann', 'russian', 'operations', 'positive', 'first', 'time', '2011']
#
#
# ===Tokens:===
# ['company', 'also', 'estimates', 'already', 'carried', 'investments', 'lead', 'increase', 'net', 'sales', '2010', '2009', 'reached', 'eur', '141', '7', 'million']
#
#
# ===Tokens:===
# ['poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'latin', 'america']
#
#
# ===Tokens:===
# ['stx', 'long', 'play', 'another', 'consistent', 'profit', 'zone', 'check', 'https', 'co', 'dqfuzozylh', 'https', 'co', 'ggne4ayzqn']
#
#
# ===Tokens:===
# ['combine', 'renew', 'contents', 'functionality', 'current', 'systems', 'funding', 'online', 'service', 'well', 'maintenance']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '6', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['daily', 'mail', 'owner', 'considering', 'yahoo', 'bid', 'yhoo', '2', '05', 'https', 'co', 'extzr1riyp']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'seen', 'eur', '0', '56', 'eur', '0', '38']
#
#
# ===Tokens:===
# ['went', 'long', 'ilmn']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'awarded', 'contract', 'rebuild', 'sabah', 'forest', 'industries', 'sfi', 'pulp', 'mill', 'sabah', 'malaysia']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '1', '2008', 'finnish', 'consulting', 'engineering', 'company', 'poyry', 'oyj', 'omx', 'poy1v', 'said', 'today', 'awarded', 'eur', '5', '2', 'million', 'usd', '7', '4', 'extension', 'existing', 'consultancy', 'engineering', 'contract', 'venezuel']
#
#
# ===Tokens:===
# ['finnish', 'kci', 'konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'delivered', '2007']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'release', 'february', '11', '2011', 'at8', '45', 'esl', 'shipping', 'ltd', 'part', 'aspo', 'group', 'signed', 'new', 'long', 'term', 'contract', 'rautaruukki', 'corporation', 'marine', 'transport', 'raw', 'materials', 'baltic', 'sea']
#
#
# ===Tokens:===
# ['long', 'pcln']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'management', 'software', 'solutions', 'provider', 'ixonos', 'oyj', 'hel', 'xns1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '3', '5', 'million', 'usd', '4', '5', '2008', 'eur', '3', '1', 'million', '2007']
#
#
# ===Tokens:===
# ['stock', 'rose', 'second', 'day', 'wednesday', 'bringing', 'two', 'day', 'rise', 'gbx12', '0', '2', '0']
#
#
# ===Tokens:===
# ['new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties']
#
#
# ===Tokens:===
# ['handelsbanken', 'ranked', 'local', 'cooperative', 'banks', 'aktia', 'customer', 'loyalty', 'time', 'however']
#
#
# ===Tokens:===
# ['fedday', 'looking', 'sharp', 'move', 'equities', 'aapl', 'hd', 'low', 'fb', 'seeing', 'uvxy', 'tvix', 'getting', 'hammered', 'even', 'though', 'market']
#
#
# ===Tokens:===
# ['operating', 'profit', 'grain', 'trading', 'increased', 'eur', '2', '0', 'mn', 'eur', '1', '4', 'mn', '2005']
#
#
# ===Tokens:===
# ['section', 'regional', 'news', 'demand', 'finnair', 'asian', 'traffic', 'measured', 'passenger', 'kilometers', '34', '9', 'august', 'compare', 'last', 'year']
#
#
# ===Tokens:===
# ['nflx', '3', 'lows']
#
#
# ===Tokens:===
# ['geosolutions', 'technology', 'leverage', 'benefon', 'gps', 'solutions', 'providing', 'location', 'based', 'search', 'technology', 'communities', 'platform', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model']
#
#
# ===Tokens:===
# ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa']
#
#
# ===Tokens:===
# ['15', 'december', '2010', 'finnish', 'german', 'telecoms', 'equipment', 'maker', 'nokia', 'siemens', 'networks', 'said', 'today', 'contract', 'upgrade', 'radio', 'network', 'home', 'based', 'telecommunications', 'company', 'elisa', 'oyj', 'hel', 'eli1v']
#
#
# ===Tokens:===
# ['zurich', 'insurance', 'considering', 'offer', 'uk', 'rival', 'rsa', 'insurance']
#
#
# ===Tokens:===
# ['full', '2010', 'company', 'expects', 'net', 'sales', 'operating', 'result', 'improve', 'previous', 'year', 'saying', 'positive', 'operating', 'result', 'amount', 'depend', 'order', 'intake', 'end', 'summer']
#
#
# ===Tokens:===
# ['looking', 'strong', 'bounce', 'spy', 'lunchtime', 'rally', 'coming', 'dia', 'iwm', 'qqq', 'aa', 'fb']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur', '36', 'million', 'eur', '27', 'million']
#
#
# ===Tokens:===
# ['company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230', '000', 'tonnes', 'copper']
#
#
# ===Tokens:===
# ['long', 'position', 'gol', 'updating', 'http', 'stks', 'co', 'fdmm']
#
#
# ===Tokens:===
# ['transaction', 'also', 'rationalize', 'pulp', 'paper', 'industry', 'related', 'solutions']
#
#
# ===Tokens:===
# ['neste', 'oil', 'corp', 'signed', 'long', 'term', 'procurement', 'contracts', 'honkajoki', 'oy', 'findest', 'protein', 'oy', 'owned', 'finnish', 'food', 'manufacturers', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'neste', '200', '000', 'b', 'cd', 'porvoo', 'finland', 'refinery']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur3', '1', 'net', 'sales', 'increased', 'eur61', '5', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['finnish', 'aldata', 'solution', 'signed', 'contract', 'supply', 'g', 'l', 'system', 'two', 'french', 'retail', 'chains']
#
#
# ===Tokens:===
# ['reached', 'agreement', 'union', 'flights', 'continue', 'normal', 'finnair', 'spokesman', 'usko', 'maatta', 'said']
#
#
# ===Tokens:===
# ['real', 'sales', 'expected', 'increased', '4', 'year', 'year', 'eur609m', 'second', 'quarter', '2010']
#
#
# ===Tokens:===
# ['australia', 'clears', 'ab', 'inbev', '100', 'billion', 'sabmiller', 'buyout', 'plan']
#
#
# ===Tokens:===
# ['far', 'mr', 'galvan', 'able', 'avoid', 'laying', 'workers']
#
#
# ===Tokens:===
# ['abb', 'deutsche', 'bank', 'upgraded', 'recommendation', 'swiss', 'swedish', 'engineering', 'group', 'abb', 'ltd', 'buy', 'hold']
#
#
# ===Tokens:===
# ['slowly', 'adding', 'fio', 'got', 'ta', 'careful', 'one', 'biggest', 'winners', '2012']
#
#
# ===Tokens:===
# ['see', '200', 'day', 'sma', 'big', 'hurdle', 'good', 'base', 'building', 'nflx', 'https', 'co', 'imkygo2cyc']
#
#
# ===Tokens:===
# ['news', 'feedschroders', 'books', 'solid', 'earnings', 'growth', 'several', 'board', 'changes']
#
#
# ===Tokens:===
# ['astrazeneca', 'weighing', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug']
#
#
# ===Tokens:===
# ['thanks', 'wide', 'contact', 'network', 'good', 'knowledge', 'market', 'business', 'environment', 'give', 'great', 'contribution', 'development', 'indian', 'operations', 'tells', 'incap', 'president', 'ceo', 'juhani', 'hanninen']
#
#
# ===Tokens:===
# ['design', 'team', 'long', 'admired', 'marimekko', 'vivid', 'patterns', 'colors']
#
#
# ===Tokens:===
# ['much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'finland', 'canada']
#
#
# ===Tokens:===
# ['arm', 'royalties', 'accelerate', 'smartphone', 'market', 'regains', 'strength']
#
#
# ===Tokens:===
# ['following', 'transaction', 'lundbeck', 'worldwide', 'rights', 'nalmefene', 'excluding', 'north', 'america', 'mexico', 'turkey', 'south', 'korea']
#
#
# ===Tokens:===
# ['fb', '110', '20', 'starting', 'show', 'relative', 'strength', 'signs', 'potential', 'b', 'daily']
#
#
# ===Tokens:===
# ['piper', 'upgrades', 'symantec', 'improving', 'renewal', 'rates', 'enterprise', 'growth', 'symc']
#
#
# ===Tokens:===
# ['district', 'court', 'helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005']
#
#
# ===Tokens:===
# ['china', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', 'also', 'strengthen', 'capability', 'offer', 'industry', 'leading', 'products', 'customers', 'china']
#
#
# ===Tokens:===
# ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'co', 'xk6lz3ui3k']
#
#
# ===Tokens:===
# ['adobe', 'receives', 'new', 'rating', 'top', 'analyst', 'adbe', 'https', 'co', 'ljnxpevhzn']
#
#
# ===Tokens:===
# ['assignment', 'strengthens', 'poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry']
#
#
# ===Tokens:===
# ['finnish', 'outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'ozk', 'kardzhali', 'zinc', 'smelter', 'bulgaria']
#
#
# ===Tokens:===
# ['london', 'open', 'taylor', 'wimpey', 'ashtead', 'drive', 'markets', 'higher', 'barclays', 'falls']
#
#
# ===Tokens:===
# ['es', 'f', 'nice', 'little', 'cup', 'handle', 'shaping', '15', 'minute', 'end', 'day', 'spy', 'spx', 'favours', 'good', 'day', 'index', 'see', 'gap', 'open']
#
#
# ===Tokens:===
# ['finland', 'insurance', 'company', 'pohjola', 'finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', 'traffic', 'safety']
#
#
# ===Tokens:===
# ['soapstone', 'deposits', 'medvezhyegorsk', 'area', 'expected', 'increase', 'tulikivi', 'current', 'reserves', 'considerably']
#
#
# ===Tokens:===
# ['q1', '10', '19', 'april', '2010', 'finnish', 'forest', 'machinery', 'equipment', 'maker', 'ponsse', 'oyj', 'hel', 'pon1v', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'eur6', '3', 'first', 'quarter', '2010', 'eur9', '6', 'loss', 'year', 'earlier']
#
#
# ===Tokens:===
# ['isrg', 'pt', 'raised', '700', '640', 'leerink', 'keeps', 'outperform', 'rated']
#
#
# ===Tokens:===
# ['q1', '2010', '18', 'may', '2010', 'finnish', 'electrical', 'components', 'maker', 'salcomp', 'oy', 'hel', 'sal1v', 'said', 'today', 'turned', 'net', 'profit', 'eur1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'eur2m', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['purchase', 'agreement', '7', '200', 'tons', 'gasoline', 'delivery', 'hamina', 'terminal', 'finland', 'signed', 'neste', 'oil', 'oyj', 'average', 'platts', 'index', 'september', 'plus', 'eight', 'us', 'dollars', 'per', 'month']
#
#
# ===Tokens:===
# ['added', 'bbby', 'jimcramer', 'wrong', 'one', 'still', 'profitable', 'merchant', 'profitable', 'stores']
#
#
# ===Tokens:===
# ['reporting', 'period', 'biotie', 'north', 'american', 'licensing', 'partner', 'somaxon', 'pharmaceuticals', 'announced', 'positive', 'results', 'nalmefene', 'pilot', 'phase', '2', 'clinical', 'trial', 'smoking', 'cessation']
#
#
# ===Tokens:===
# ['production', 'capacity', 'increase', '36', '000', '85', '000', 'tonnes', 'per', 'year', 'raw', 'material', 'continue', 'recycled', 'paper', 'board']
#
#
# ===Tokens:===
# ['government', 'professional', 'approach', 'assessing', 'offer']
#
#
# ===Tokens:===
# ['onty', 'continues', 'base', 'debate', 'lingers', 'ont', '10', 'data', 'next', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'moves', '10', 'downside', 'limited']
#
#
# ===Tokens:===
# ['result', 'distribution', 'companies', 'start', 'distribute', 'addition', 'current', 'product', 'offering', 'shimano', 'reels', 'rods', 'shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis']
#
#
# ===Tokens:===
# ['gild', 'expanding', 'research', 'facilities', 'keeping', 'pace', 'innovation', 'https', 'co', 'uoe7fj4lop']
#
#
# ===Tokens:===
# ['finnish', 'pulp', 'paper', 'machinery', 'maker', 'vaahto', 'group', 'oyj', 'swung', '1', '1', 'mln', 'euro', '1', '4', 'mln', 'net', 'profit', 'fiscal', '2005', '06', 'ended', 'august', '31', '2006', '249', '000', 'euro', '319', '000', 'net', 'loss', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['drugmaker', 'shire', 'buy', 'baxalta', '32', 'billion', '6', 'month', 'pursuit']
#
#
# ===Tokens:===
# ['fda', 'approves', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '83', '0', 'mn', 'eur', '23', '5', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'klabin', 'tel', 'maco', 'borba', 'mill', 'brazilian', 'state', 'paran']
#
#
# ===Tokens:===
# ['barclays', 'bank', 'america', 'citigroup', 'blockchain', 'sight']
#
#
# ===Tokens:===
# ['savon', 'koulutuskuntayhtyma', 'finland', 'based', 'company', 'awarded', 'contract', 'specialist', 'agricultural', 'forestry', 'machinery']
#
#
# ===Tokens:===
# ['brazilian', 'unit', 'finnish', 'security', 'solutions', 'provider', 'f', 'secure', 'signed', '1', '500', 'new', 'clients', 'last', 'year', 'online', 'news', 'source', 'reseller', 'web', 'quoted', 'division', 'commercial', 'director', 'vladimir', 'brand', 'saying']
#
#
# ===Tokens:===
# ['company', 'make', 'marketing', 'sales', 'investments', 'initiated', '2009', 'even', 'efficient', '2010']
#
#
# ===Tokens:===
# ['amazon', 'grocery', 'deal', 'morrisons', 'beginning']
#
#
# ===Tokens:===
# ['axp', 'looking', 'continuation', 'volume', 'increase', 'http', 'stks', 'co', 'c8sr']
#
#
# ===Tokens:===
# ['total', 'operating', 'revenue', 'grew', '27', '6', 'year', 'year', 'eur61m']
#
#
# ===Tokens:===
# ['coh', 'gaining', 'momentum', 'nice', 'buy', 'signals', 'long', '35', '92', 'http', 'stks', 'co', 't0tah']
#
#
# ===Tokens:===
# ['md', 'henning', 'bahr', 'stockmann', 'gruppen', 'praises', 'trend', 'since', 'chains', 'become', 'stronger', 'decision', 'making', 'processes', 'clear']
#
#
# ===Tokens:===
# ['20', 'october', '2010', 'finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'eur7m', 'first', 'nine', 'months', '2010', 'eur23', '3', 'period', '2009']
#
#
# ===Tokens:===
# ['svyturys', 'utenos', 'alus', 'controlled', 'nordic', 'group', 'baltic', 'beverages', 'holding', 'bbh', 'posted', '4', '7', 'per', 'cent', 'growth', 'beer', 'sales', 'january', 'may', '46', '22', 'million', 'litres']
#
#
# ===Tokens:===
# ['finnish', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'net', 'loss', 'contracted', 'eur', '49', 'million', 'usd', '68', '2', 'first', 'nine', 'months', '2010', 'eur', '229', 'million', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'consolidated', 'net', 'operating', 'profit', 'increased', 'eur', '4', '8', 'mn', 'first', 'quarter', '2005', 'eur', '6', '4', 'mn', 'first', 'quarter', '2006']
#
#
# ===Tokens:===
# ['real', 'corporation', 'press', 'release', '3', 'november', '10', '35', 'real', 'corporation', 'second', 'best', 'company', 'materials', 'sector', 'including', 'e', 'g', 'forest', 'industry', 'companies', 'carbon', 'disclosure', 'leadership', 'index', 'cdli', 'nordic', 'report', '2009']
#
#
# ===Tokens:===
# ['aapl', 'dips', 'bought', 'real', 'quick', 'higher', 'lows', 'fo', 'sho']
#
#
# ===Tokens:===
# ['lse', 'deutsche', 'boerse', 'merger', 'would', 'signal', 'end', 'exchange', 'mega', 'deals']
#
#
# ===Tokens:===
# ['save', 'breaking', 'downtrend', 'line', 'increasing', 'volume', 'move', '20', '57', 'could', 'see', 'upside', 'http', 'stks', 'co', 'l8y4']
#
#
# ===Tokens:===
# ['rcon', 'upside', 'today', 'thing', 'severe', 'low', 'float', 'catalyst', 'guy', 'run']
#
#
# ===Tokens:===
# ['eli', 'lilly', 'co', 'lly', 'broken', 'new', 'high', 'astrazeneca', 'collaboration']
#
#
# ===Tokens:===
# ['iaci', 'http', 'stks', 'co', 'tju', 'looks', 'good', 'weekly', 'chart']
#
#
# ===Tokens:===
# ['vmw', 'got', 'nice', 'push', 'today', 'following', 'small', 'sweepers', 'may', 'c', 'morning']
#
#
# ===Tokens:===
# ['teleste', 'acquisition', 'marks', 'entry', 'services', 'business', 'market', 'long', 'established', 'significant', 'supplier', 'products']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '500', '000', 'usd', '680', '000', 'last', 'quarter', '2010', 'eur', '5', '3', 'million', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '29', '2008', 'finnish', 'lifting', 'equipment', 'maker', 'konecranes', 'oyj', 'omx', 'kcr1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '116', '6', 'million', 'usd', '149', '1', 'first', 'nine', 'months', '2008', 'eur', '73', '6', 'million']
#
#
# ===Tokens:===
# ['lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'kaluga', 'regional', 'administration', 'last', 'november']
#
#
# ===Tokens:===
# ['operating', 'profit', 'asian', 'plants', 'grew', 'markedly']
#
#
# ===Tokens:===
# ['truly', 'takes', 'efficiency', 'new', 'heights', 'mr', 'metso', 'adds']
#
#
# ===Tokens:===
# ['january', 'september', '2007', 'group', 'net', 'sales', 'continuing', 'operations', 'rose', 'eur', '213', '1', 'mn', 'eur', '172', '6', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['transaction', 'strengthens', 'position', 'design', 'branded', 'goods', 'said', 'fiskars', 'president', 'ceo', 'heikki', 'allonen', 'pointing', 'two', 'groups', 'relatively', 'overlapping', 'operations']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '5', '5', 'mn', 'eur', '0', '7', 'mn']
#
#
# ===Tokens:===
# ['memorandum', 'understanding', 'mou', 'parties', 'collaborate', 'preparing', 'implementing', 'joint', 'projects', 'fields', 'combined', 'power', 'heat', 'generation', 'environmental', 'protection', 'energy', 'efficient', 'technologies']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['easyjet', 'attracts', 'passengers', 'june', 'still', 'lags', 'ryanair']
#
#
# ===Tokens:===
# ['cern', 'consolidating', '50', '200', 'nice', 'long', 'entry', 'w', 'stop', '10', 'targeting', '70', 'area']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'gains', 'land', 'securities', 'dividend', 'hike']
#
#
# ===Tokens:===
# ['bbry', 'ready', 'take']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '5', '8', 'mn', 'loss', 'eur', '1', '7', 'mn', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['metso', 'supply', 'equipment', 'two', 'process', 'lines', 'northland', 'resources', 'new', 'kaunisvaara', 'iron', 'ore', 'project', 'sweden', 'exploits', 'tapuli', 'sahavaara', 'iron', 'ore', 'deposits']
#
#
# ===Tokens:===
# ['carnival', 'corporation', 'china', 'merchants', 'group', 'sign', 'memo', 'understanding']
#
#
# ===Tokens:===
# ['alma', 'media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'order', 'supply', 'uncoated', 'fine', 'paper', 'machine', 'mcc', 'paper', 'yinhe', 'china']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '94', 'mn', 'eur', '2', '45', 'mn']
#
#
# ===Tokens:===
# ['diluted', 'loss', 'per', 'share', 'stood', 'eur', '0', '15', 'versus', 'eur', '0', '26']
#
#
# ===Tokens:===
# ['3', 'january', '2011', 'finnish', 'flag', 'carrier', 'finnair', 'oyj', 'hel', 'fia1s', 'said', 'today', 'sealed', 'nine', 'year', 'sale', 'leaseback', 'agreement', 'newest', 'airbus', 'a330', 'aircraft', 'syndication', 'japanese', 'operating', 'lease', 'market']
#
#
# ===Tokens:===
# ['auto', 'trader', 'share', 'price', 'surges', 'company', 'floats', 'lse']
#
#
# ===Tokens:===
# ['company', 'said', 'estimates', 'make', 'slight', 'profit', 'thanks', 'cost', 'cutting', 'measures']
#
#
# ===Tokens:===
# ['aapl', 'taking', 'shorts', 'punishing', 'reminder', 'spear', 'strongest', 'herd']
#
#
# ===Tokens:===
# ['raute', 'posted', 'net', 'profit', '1', '8', 'mln', 'euro', '2', '6', 'mln', 'third', 'quarter', '2007', 'compared', 'net', 'loss', '299', '000', 'euro', '430', '000', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['yahoo', 'stock', '36', '46', 'bidding', 'war', 'picks', 'company', 'https', 'co', 'jdnzxdcmkl', 'yhoo', 'https', 'co', 'hmoegfhgvn']
#
#
# ===Tokens:===
# ['company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', 'adding', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year']
#
#
# ===Tokens:===
# ['goog', 'breakout', 'likely', 'medium', 'target', '700', 'http', 'stks', 'co', '1lpz', 'http', 'chart', 'ly', 'lgb94rr']
#
#
# ===Tokens:===
# ['singapore', 'icis', '1', 'kemira', 'indian', 'water', 'infrastructure', 'firm', '2', 'ivrcl', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'andhra', 'pradesh', 'state', 'india', 'finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'tuesday']
#
#
# ===Tokens:===
# ['goog', 'testing', '200', 'day', 'consolidation', 'http', 'stks', 'co', 'h0cpj']
#
#
# ===Tokens:===
# ['prlb', 'hanging', 'tough', 'market', 'due', 'analyst', 'upgrades', 'last', 'week', 'almost', '3']
#
#
# ===Tokens:===
# ['energy', 'efficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'state', 'art', 'technology']
#
#
# ===Tokens:===
# ['entering', 'long', 'lockheed', 'martin', 'lmt', 'thursday', 'open', 'http', 'stks', 'co', 'exta']
#
#
# ===Tokens:===
# ['company', 'order', 'book', 'stood', '1', '5', 'bln', 'euro', '2', '2', 'bln', 'september', '30', '2007', '24', '2', 'pct', 'year', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '534', '3', 'mln']
#
#
# ===Tokens:===
# ['aim', 'ensure', 'vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', 'comments', 'vacon', 'plc', 'president', 'ceo', 'vesa', 'laisi']
#
#
# ===Tokens:===
# ['two', 'companies', 'also', 'partner', 'developing', 'raiso', 'cholesterol', 'lowering', 'brand', 'benecol']
#
#
# ===Tokens:===
# ['nyse', 'owner', 'ice', 'considers', 'offer', 'lse']
#
#
# ===Tokens:===
# ['astrazeneca', 'bags', 'another', 'cancer', 'drug', 'deal', 'time', 'inovio']
#
#
# ===Tokens:===
# ['adbe', 'technical', 'alerts', 'expansion', 'breakout', 'gilligan', 'island', 'sell', 'setup', 'volume', 'surge', 'new', '52', 'https', 'co', 'lxx66tknfh']
#
#
# ===Tokens:===
# ['change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', 'said', 'julia', 'prohaska', 'director', 'marketing', 'communications', 'fiskars']
#
#
# ===Tokens:===
# ['ebit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '67', '8', 'mn', 'eur', '38', '1', 'mn']
#
#
# ===Tokens:===
# ['finland', 'national', 'carrier', 'finnair', 'plc', 'carried', 'record', '8', '5', 'million', 'passengers', '2005', 'increase', '4', '5', 'percent', 'previous', 'year', 'airline', 'reported', 'tuesday']
#
#
# ===Tokens:===
# ['fb', 'trending', 'nicely', 'intraday']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur36m', 'eur27m']
#
#
# ===Tokens:===
# ['last', 'week', 'finnish', 'metals', 'technology', 'group', 'announced', 'plans', 'sell', '80', 'percent', 'technology', 'unit', 'company', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'raises', 'prospect', 'investor', 'payout']
#
#
# ===Tokens:===
# ['satama', 'earned', 'data', 'management', 'solutions', 'competency', 'business', 'intelligence', 'specialization', 'recentlyvia', 'acquisition', 'fimentor', 'oy']
#
#
# ===Tokens:===
# ['spain', 'caixabank', 'launches', 'new', 'takeover', 'bid', 'banco', 'bpi']
#
#
# ===Tokens:===
# ['gild', 'chart', 'ibb', 'back', 'support', 'https', 'co', 'gprz2ujfc4']
#
#
# ===Tokens:===
# ['ebit', 'totalled', 'eur', '14', '4', 'mn', 'compared', 'loss', 'eur', '0', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['stora', 'enso', 'r', 'shares', 'rose', '1', '20', 'pct', '11', '84', 'eur', 'upm', 'kymmene', 'also', 'dragged', 'higher', 'rising', '1', '68', 'pct', '17', '56', 'eur', 'real', 'b', 'added', '2', '38', 'pct', '4', '30', 'eur']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'amounted', 'ee', '55', '5', 'mn', '36', '2004']
#
#
# ===Tokens:===
# ['press', 'serco', 'set', 'appoint', 'roy', 'gardner', 'ex', 'centrica', 'chairman', 'ft']
#
#
# ===Tokens:===
# ['aapl', 'downgrade', 'bias', 'stock', 'buy']
#
#
# ===Tokens:===
# ['aapl', 'new', 'long', '110', '61', 'broken', 'targets', '112', '19', '119', '86', '123', '82', 'bears', 'must', 'retake', '102', '77', 'qqq', 'nq', 'f', 'ndx', 'https', 'co', '6l3m1wxchw']
#
#
# ===Tokens:===
# ['retailers', 'kingfisher', 'sports', 'direct', 'rise', 'britain', 'share', 'index']
#
#
# ===Tokens:===
# ['bought', 'celg', 'ready', 'bounce']
#
#
# ===Tokens:===
# ['aim', 'convert', 'plants', 'flexible', 'manufacturers', 'new', 'technologically', 'demanding', 'products']
#
#
# ===Tokens:===
# ['arm', 'profits', 'sales', 'shift', 'away', 'mobile', 'gains', 'pace']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'rose', 'eur', '1', '019', 'mn', 'eur', '1', '007', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'ftse', 'higher', 'clubcard', 'bid', 'reports']
#
#
# ===Tokens:===
# ['update', '1', 'astrazeneca', 'sells', 'rare', 'cancer', 'drug', 'sanofi', '300', 'mln']
#
#
# ===Tokens:===
# ['mako', 'hanging', 'well', 'today', 'still', 'basing', 'pattern', 'eyes']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'metso', 'said', 'upgrade', 'one', 'upm', 'kymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', 'machine', 'process', 'controls', 'quality', 'measurements']
#
#
# ===Tokens:===
# ['contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', 'oil', 'shale', 'processing']
#
#
# ===Tokens:===
# ['brooklynbandit', 'simo', 'basing', 'nice', 'close', '24', '18', 'bullish', 'qqq', 'spy', 'study', 'watch', 'close', 'near', 'hod', 'currently', '3', '5']
#
#
# ===Tokens:===
# ['alert', 'new', 'macd', 'signal', 'created', 'ctxs', 'buy', '77', '09', 'time', '18', '23', 'strength', '10', 'powered', 'https', 'co', '4tdgjedllz']
#
#
# ===Tokens:===
# ['resulted', 'improved', 'sales', 'figures', 'sweden']
#
#
# ===Tokens:===
# ['tectia', 'corporation', 'hel', 'tec1v', 'provider', 'real', 'time', 'security', 'solutions', 'today', 'announced', 'appointed', 'lan2lan', 'provider', 'services', 'uk', 'distribute', 'data', 'security', 'manage', 'file', 'transfer', 'software']
#
#
# ===Tokens:===
# ['long', 'aapl']
#
#
# ===Tokens:===
# ['ino', 'back', 'small', 'post']
#
#
# ===Tokens:===
# ['helsinki', 'eliiv', 'today', 'reported', 'eps', 'eur1', '13', '2009', 'increase', 'eps', 'eur1', '12', '2008']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'oyj', 'said', 'november', '13', '2007', '70', 'mln', 'euro', '102', '8', 'mln', 'contract', 'construct', 'new', 'office', 'building', 'local', 'property', 'company', 'tapiola', 'real', 'estate', 'oy']
#
#
# ===Tokens:===
# ['shorts', 'altr', '38', '85', 'loss']
#
#
# ===Tokens:===
# ['2nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increases', 'quarterly', 'cash', 'dividend', '20', 'percent', 'http', 'stks', 'co', 'goan']
#
#
# ===Tokens:===
# ['combining', 'existing', 'solutions', 'single', 'platform', 'comptel', 'said', 'reduced', 'cost', 'deployment']
#
#
# ===Tokens:===
# ['neon', 'oversold']
#
#
# ===Tokens:===
# ['third', 'quarter', '2010', 'net', 'sales', 'increased', '5', '2', 'eur', '205', '5', 'mn', 'operating', 'profit', '34', '9', 'eur', '23', '5', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'long', '630', '91']
#
#
# ===Tokens:===
# ['pioneer', 'library', 'system', 'one', '127', 'libraries', 'municipalities', 'arts', 'culture', 'higher', 'education', 'science', 'organizations', 'awarded', 'grants', 'participate', 'big', 'read', 'largest', 'federal', 'reading', 'program', 'u', 'history']
#
#
# ===Tokens:===
# ['financing', 'arrangements', 'enable', 'company', 'ensure', 'line', 'treasury', 'policy', 'sufficient', 'financial', 'instruments', 'disposal', 'potential', 'capital', 'requirements']
#
#
# ===Tokens:===
# ['operating', 'income', 'rose', 'eur', '696', '4', 'mn', 'eur', '600', '3', 'mn', '2009']
#
#
# ===Tokens:===
# ['rt', 'andrewnyquist', 'chartology', 'yahoo', 'http', 'stks', 'co', '1itr', 'yhoo', 'crazy', 'looking', 'chart', 'nearing', 'breakout', 'resistance', 'line']
#
#
# ===Tokens:===
# ['sainsbury', 'sells', 'unit', 'lloydspharmacy']
#
#
# ===Tokens:===
# ['liking', 'price', 'action', 'swks', 'currently', '21', '80', 'target', '24', '00', 'year', 'end']
#
#
# ===Tokens:===
# ['group', 'expand', 'chain', 'include', '45', 'stores']
#
#
# ===Tokens:===
# ['finnish', 'consulting', 'engineering', 'group', 'poyry', 'plc', 'omx', 'helsinki', 'poy', 'said', 'wednesday', '1', 'october', 'awarded', 'contract', 'tanqia', 'dibba', 'fzc', 'owner', 'engineer', 'wastewater', 'system', 'dibba', 'emirate', 'fujairah', 'uae']
#
#
# ===Tokens:===
# ['trend', 'underpins', 'uk', 'sales', 'growth', 'kingfisher']
#
#
# ===Tokens:===
# ['lee', 'man', 'paper', 'metso', 'long', 'prosperous', 'co', 'operation', 'good', 'example', 'changshu', 'hongmei', 'kraftliner', 'machines', 'delivered', 'earlier']
#
#
# ===Tokens:===
# ['ibm', 'staying', 'strong']
#
#
# ===Tokens:===
# ['open', 'next', 'year', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['turun', 'kaupunkin', 'finland', 'based', 'company', 'awarded', 'contract', 'lemminkainen', 'talotekniikka', 'oy', 'electrical', 'installation', 'work']
#
#
# ===Tokens:===
# ['revenue', 'grew', '12', 'percent', 'x20ac', '3', '6', 'billion', 'us', '4', '5', 'billion']
#
#
# ===Tokens:===
# ['royal', 'dutch', 'shell', 'buy', 'bg', 'group', 'nearly', '70', 'billion']
#
#
# ===Tokens:===
# ['estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters']
#
#
# ===Tokens:===
# ['eps', 'continuing', 'operations', 'came', '0', '30', 'eur', '0', '17']
#
#
# ===Tokens:===
# ['stable', 'outlook', 'reflects', 'nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', 'strong', 'cash', 'flow', 'generation', 'conservative', 'balance', 'sheet', 'said', 'raab']
#
#
# ===Tokens:===
# ['whitbread', 'share', 'price', 'climbs', 'q4', 'sales', 'growth']
#
#
# ===Tokens:===
# ['financial', 'impact', 'estimated', 'annual', 'improvement', 'eur2', '0', 'division', 'results', 'fiscal', 'year', '2008']
#
#
# ===Tokens:===
# ['kndi', 'let', 'see', 'higher', 'highs', 'higher', 'lows', 'rest', 'day', 'slow', 'steady']
#
#
# ===Tokens:===
# ['adp', 'news', 'finnish', 'handling', 'systems', 'provider', 'cargotec', 'oyj', 'hel', 'cgcbv', 'announced', 'friday', 'orders', 'worth', 'eur', '10', 'million', 'usd', '13', '2', 'deliver', 'linkspans', 'jordan', 'morocco', 'ireland']
#
#
# ===Tokens:===
# ['continued', 'actively', 'focus', 'r', 'position', 'offering', 'away', 'point', 'solutions', 'towards', 'dynamic', 'end', 'end', 'solutions', 'ervio', 'stated']
#
#
# ===Tokens:===
# ['sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season']
#
#
# ===Tokens:===
# ['transaction', 'positive', 'impact', 'around', 'eur2m', 'earnings', 'ruukki', 'recognize', 'fourth', 'quarter', 'year']
#
#
# ===Tokens:===
# ['kesko', 'car', 'import', 'retailing', 'business', 'vv', 'auto', 'saw', 'sales', 'grow', '17', '1', 'pct']
#
#
# ===Tokens:===
# ['insight', 'hires', 'aviva', 'david', 'hillier', 'multi', 'asset', 'team']
#
#
# ===Tokens:===
# ['news', 'feedftse', '100', 'movers', 'ashtead', 'jumps', 'strong', 'interims', 'glencore', 'bp']
#
#
# ===Tokens:===
# ['main', 'strength', 'cooperation', 'project', 'lies', 'merging', 'know', 'two', 'large', 'companies']
#
#
# ===Tokens:===
# ['company', 'also', 'featured', 'ethibel', 'pioneer', 'investment', 'register', 'included', 'innovest', 'global', '100', 'list', 'world', 'sustainable', 'corporations']
#
#
# ===Tokens:===
# ['london', 'morning', 'briefing', 'hsbc', 'standard', 'chartered', 'shares', 'rise']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'rose', '11', '4', 'year', '82', '2', 'million', 'euros', '2005', 'sales', '686', '5', 'million', 'euros', '13', '8', 'year', 'company', 'said', 'earlier']
#
#
# ===Tokens:===
# ['tsla', 'bad', 'day', 'short']
#
#
# ===Tokens:===
# ['objective', 'planned', 'measures', 'achieve', 'significant', 'savings', 'next', 'years']
#
#
# ===Tokens:===
# ['update', '3', 'auto', 'trader', 'shares', 'leap', 'uk', 'biggest', 'private', 'equity', 'backed', 'listing']
#
#
# ===Tokens:===
# ['besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', 'paavel', 'said']
#
#
# ===Tokens:===
# ['ftse', 'rallies', 'three', 'month', 'low', 'boosted', 'stanchart', 'sainsbury']
#
#
# ===Tokens:===
# ['aria', 'bounce', 'player', 'long', '6', '17', 'http', 'stks', 'co', 'q0wff']
#
#
# ===Tokens:===
# ['consolidated', 'operating', 'profit', 'excluding', 'one', 'items', 'eur', '30', '6', 'mn', 'eur', '29', '6', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bullya', 'pollux654321', '50', 'kors', '80', 'calls', 'going', 'b', 'blessing', 'daughters', 'tuition']
#
#
# ===Tokens:===
# ['according', 'sepp', 'nen', 'new', 'technology', 'umts900', 'solution', 'network', 'building', 'costs', 'one', 'third', 'lower', 'building', '3', '5', 'g', 'networks', 'operating', '2', '100', 'mhz', 'frequency']
#
#
# ===Tokens:===
# ['crus', 'upgraded', 'buy', 'alpha', 'street', 'research']
#
#
# ===Tokens:===
# ['favourable', 'currency', 'rates', 'also', 'contributed', 'higher', 'net', 'sales', 'ceo', 'kari', 'kauniskangas', 'said']
#
#
# ===Tokens:===
# ['tesco', 'breaks', 'downward', 'slide', 'cutting', 'sales', 'decline', 'half']
#                       0   1
# 0             net sales  80
# 1      operating profit  77
# 2             http stks  73
# 3               stks co  73
# 4              https co  62
# ...                 ...  ..
# 14097    downward slide   1
# 14098     slide cutting   1
# 14099     cutting sales   1
# 14100     sales decline   1
# 14101      decline half   1
#
# [14102 rows x 2 columns]

# %%
x_positive_bi = df_positive_bi[0][:10]
y_positive_bi = df_positive_bi[1][:10]

print(x_positive_bi)
x_negative_bi = df_negative_bi[0][:10]
y_negative_bi = df_negative_bi[1][:10]

x_neutral_bi = df_neutral_bi[0][:10]
y_neutral_bi = df_neutral_bi[1][:10]


fig, ax = plt.subplots(3, 1, figsize=(10, 7), dpi=100)

ax[0].bar(x_positive_bi, y_positive_bi, color='g', width= 0.6)
ax[0].set_title('Top 10 words with positive sentiment(Bigrams)')
ax[0].set_xlabel('Words in the positive df')
ax[0].set_ylabel('Count')

ax[1].bar(x_negative_bi, y_negative_bi, color='r', width= 0.6)
ax[1].set_title('Top 10 words with negative sentiment(Bigrams)')
ax[1].set_xlabel('Words in the negative df')
ax[1].set_ylabel('Count')

ax[2].bar(x_neutral_bi, y_neutral_bi, color='gray', width= 0.6)
ax[2].set_title('Top 10 words with neutral sentiment(Bigrams)')
ax[2].set_xlabel('Words in the neutral df')
ax[2].set_ylabel('Count')
plt.tight_layout()
# Out:
# 0               net sales
# 1        operating profit
# 2               http stks
# 3                 stks co
# 4                https co
# 5                  mn eur
# 6    corresponding period
# 7                   eur 0
# 8              net profit
# 9             profit rose
# Name: 0, dtype: object

# %%
positiveWords_tri = defaultdict(int)
negativeWords_tri = defaultdict(int)
neutralWords_tri = defaultdict(int)

# %%
# Creating positive trigrams

for text in train_set[train_set['Sentiment']=='positive']['Sentence']:
    for word in generate_ngrams(text, 3):
        positiveWords_tri[word] += 1
df_positive_tri = pd.DataFrame(sorted(positiveWords_tri.items(),key=lambda x:x[1],reverse=True))
df_positive_tri
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['contrast', 'company', 'net', 'loss', 'third', 'quarter', '2009', 'contracted', 'eur', '76', 'million', 'eur', '256', 'million', 'corresponding', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finland', 'neste', 'oil', 'awarded', 'chemical', 'industry', 'federation', 'finland', 'innovation', 'award', 'nexbtl', 'technology', 'enables', 'biodiesel', 'produced', 'vegetable', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['combining', 'deep', 'domain', 'expertise', 'application', 'service', 'management', 'asm', 'outsourcing', 'service', 'offerings', 'proved', 'winning', 'combination']
#
#
# ===Tokens:===
# ['trx', 'http', 'stks', 'co', '1kkk', 'long', 'setup', 'macd', 'cross']
#
#
# ===Tokens:===
# ['meanwhile', 'electrowatt', 'ekono', 'philippines', 'inc', 'also', 'awarded', 'three', 'year', 'operation', 'maintenance', 'contract', 'fr', 'cement', 'corporation']
#
#
# ===Tokens:===
# ['madison', 'wis', 'feb', '6', 'prnewswire', 'fiskars', 'announces', 'united', 'states', 'patent', 'trademark', 'office', 'granted', 'trademark', 'registration', 'color', 'orange', 'iconic', 'scissor', 'handles']
#
#
# ===Tokens:===
# ['wfm', 'bought', 'little', 'yesterday', 'hoping', 'earnings', 'pop']
#
#
# ===Tokens:===
# ['ragutis', 'controlled', 'finnish', 'brewery', 'reported', '5', '4', 'per', 'cent', 'rise', 'beer', 'sales', '10', '44', 'million', 'litres', 'held', '11', '09', 'per', 'cent', 'market', 'share']
#
#
# ===Tokens:===
# ['addition', 'cramo', 'peab', 'signed', 'exclusive', 'five', 'year', 'rental', 'agreements', 'finland', 'extended', 'existing', 'rental', 'agreements', 'swedish', 'market', 'another', 'five', 'years']
#
#
# ===Tokens:===
# ['combined', 'foreign', 'investments', 'creates', 'interesting', 'opportunities', 'solteq']
#
#
# ===Tokens:===
# ['osur', '33', 'since', '6', '25', 'buy', 'signal', 'resistance', '5', '33', 'expect', '1', 'pullback', '2nd', 'half', 'day', '2', 'break', 'abov', '5', '33', 'continue', 'rally', '4', '5', 'days']
#
#
# ===Tokens:===
# ['federal', 'secretary', 'transport', 'communication', 'mexico', 'awarded', 'poyry', 'mexican', 'partner', 'sintra', 'consulting', 'contract', 'connection', 'buenavista', 'cuautitlan', 'suburban', 'railway']
#
#
# ===Tokens:===
# ['kndi', 'china', 'electriccar', 'maker', 'china', 'car', 'sales', '7', '8', 'also', 'may', 'feed', 'tsla', 'momentum', 'run', 'lately']
#
#
# ===Tokens:===
# ['agreement', 'signed', 'biohit', 'healthcare', 'ltd', 'uk', 'based', 'subsidiary', 'biohit', 'oyj', 'finnish', 'public', 'company', 'develops', 'manufactures', 'markets', 'liquid', 'handling', 'products', 'diagnostic', 'test', 'systems']
#
#
# ===Tokens:===
# ['third', 'quarter', 'net', 'sales', 'increased', '12', 'year', 'year', 'eur159', '5', '6', 'comparable', 'currency', 'rates', 'growth']
#
#
# ===Tokens:===
# ['finnish', 'vacon', 'signed', 'significant', 'deals', 'norwegian', 'scandinavian', 'electric', 'systems', 'ses', 'supply', 'ac', 'drives']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'bounces', 'back', 'mondi', 'barratt', 'lead']
#
#
# ===Tokens:===
# ['update', 'barclays', 'expects', 'gain', 'settling', 'lehman', 'bros', 'trustee']
#
#
# ===Tokens:===
# ['interest', 'heats', 'yahoo', 'yhoo', 'wall', 'street', 'journal', 'https', 'co', 'j5jvji9bia']
#
#
# ===Tokens:===
# ['according', 'pkc', 'acquisition', 'would', 'bring', 'significant', 'addition', 'pkc', 'customer', 'base']
#
#
# ===Tokens:===
# ['buffett', 'berkshire', 'builds', 'deere', 'stake', 'dumps', 'exxon']
#
#
# ===Tokens:===
# ['etteplan', 'targets', 'employ', 'least', '20', 'people', 'borl', 'nge']
#
#
# ===Tokens:===
# ['slw', 'weekly', '34', 'calls', '28', '95', '23', 'x', '25', '321', 'volume', 'worth', 'chance', 'jmho', 'http', 'stks', 'co', '1qfg']
#
#
# ===Tokens:===
# ['finnish', 'food', 'industry', 'companies', 'hk', 'ruokatalo', 'atria', 'form', 'joint', 'venture', 'company', 'called', 'l', 'nsi', 'kalkkuna', 'produce', 'turkey', 'meat']
#
#
# ===Tokens:===
# ['sales', 'climbed', '19', '2', 'pct', '1', '002', 'bln', 'eur', 'surpassing', '953', 'mln', 'eur', 'consensus', 'figure']
#
#
# ===Tokens:===
# ['continuing', 'operations', 'turned', 'operating', 'loss', 'eur', '0', '1', 'mn', 'slight', 'improvement', 'loss', 'eur', '0', '2', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'leap', 'ftse', '100', 'marks', 'spencer', 'drops']
#
#
# ===Tokens:===
# ['basware', 'corporation', 'stock', 'exchange', 'release', 'august', '31', '2010', '16', '25', 'basware', 'signed', 'large', 'deal', 'international', 'industrial', 'group', 'basware', 'deliver', 'invoice', 'automation', 'solution', 'connectivity', 'services', 'international', 'industrial', 'group']
#
#
# ===Tokens:===
# ['also', 'turned', 'earnings', 'per', 'share', 'eps', 'eur', '0', '08', 'versus', 'loss', 'per', 'share', 'eur', '0', '04']
#
#
# ===Tokens:===
# ['company', 'consolidated', 'operating', 'profit', 'amounted', 'eur', '15', '86', 'mn', 'eur', '4', '14', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['aapl', 'right', 'back', 'buy', 'dips', 'brought', 'cnbc', 'lol']
#
#
# ===Tokens:===
# ['capman', 'partner', 'able', 'develop', 'business', 'continue', 'focus', 'providing', 'quality', 'restaurant', 'services', 'customers', 'says', 'christopher', 'wynne', 'ceo', 'papa', 'john', 'russia']
#
#
# ===Tokens:===
# ['technical', 'indicators', 'stock', 'bullish', 'p', 'gives', 'nok', 'positive', '4', 'stars', '5', 'buy', 'ranking']
#
#
# ===Tokens:===
# ['upm', 'deliveries', 'increased', 'third', 'quarter', '4', 'percent', 'efficiency', 'operations', 'improved', 'chief', 'executive', 'jussi', 'pesonen', 'said']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'maker', 'amer', 'sports', 'oyj', 'hel', 'ameas', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '16', '9', 'million', 'usd', '22', '3', 'second', 'quarter', '2010', 'eur', '23', '2', 'million', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['outokumpu', 'chief', 'executive', 'juha', 'rantanen', 'expressed', 'confidence', 'china', 'market']
#
#
# ===Tokens:===
# ['nflx', 'vision', 'short', 'term', 'consolidation', 'movement', 'higher', 'http', 'stks', 'co', 'j05uu']
#
#
# ===Tokens:===
# ['elcoteq', 'elcoteq', 'se', 'leading', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'communications', 'technology', 'field']
#
#
# ===Tokens:===
# ['renovation', 'biggest', 'moulding', 'line', 'orhangazi', 'foundry', 'modern', 'line', 'europe']
#
#
# ===Tokens:===
# ['company', 'established', '3g', 'base', 'station', '17', '000', 'feet', 'foot', 'mount', 'everest', 'enable', 'mountain', 'climbers', '29', '035', 'foot', 'summit', 'surf', 'internet', 'even', 'send', 'videos', 'exploits']
#
#
# ===Tokens:===
# ['spy', 'hang', 'bull', 'hat', 'yet', 'next', 'week', 'pop', 'higher', 'qe3', 'hope', 'back', 'fed', '2', 'day', 'meeting']
#
#
# ===Tokens:===
# ['return', 'investment', '16', '6', 'compared', '15', '8', '2004']
#
#
# ===Tokens:===
# ['finnish', 'investment', 'group', 'panostaja', 'oyj', 'said', 'net', 'profit', 'went', '8', '6', 'mln', 'euro', '11', '4', 'mln', 'fiscal', '2005', '06', 'ended', 'october', '31', '2006', '2', '8', 'mln', 'euro', '3', '7', 'mln', 'period', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['analysts', 'impressed', 'progress', 'tesla', 'flagship', 'factory', 'co', 'spent', '1', '6b', 'upgrades', '15', 'https', 'co', 'sabxcsn8cd', 'tsrandall', 'tsla']
#
#
# ===Tokens:===
# ['london', 'afx', 'shares', 'rautaruukki', 'corp', 'upgraded', 'hold', 'sell', 'abn', 'amro', 'price', 'target', 'raised', '25', '75', 'eur', '14', '5', 'said', 'dealers']
#
#
# ===Tokens:===
# ['narrows', 'eur2', '8', '9', 'mo', '09', '29', 'october', '2009', 'finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'net', 'loss', 'narrowed', 'eur2', '8', 'first', 'nine', 'months', '2009', 'eur35', '6', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['adp', 'news', 'nov', '18', '2008', 'finnish', 'ac', 'drives', 'manufacturer', 'vacon', 'oyj', 'omx', 'vac1v', 'said', 'today', 'set', 'new', 'representative', 'offices', 'romania', 'ukraine', 'serve', 'growing', 'markets', 'eastern', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['finnish', 'aktia', 'group', 'operating', 'profit', 'rose', 'eur', '17', '5', 'mn', 'first', 'quarter', '2010', 'eur', '8', '2', 'mn', 'first', 'quarter', '2009']
#
#
# ===Tokens:===
# ['first', 'nine', 'months', '2010', 'talvivaara', 'net', 'loss', 'narrowed', 'eur', '8', '3', 'million', 'eur', '21', '9', 'million', 'period', '2009']
#
#
# ===Tokens:===
# ['wpp', 'boosts', 'sales', 'despite', 'cautious', 'clients']
#
#
# ===Tokens:===
# ['fb', 'small', 'long', '109', '25', 'via', 'calls']
#
#
# ===Tokens:===
# ['altia', 'operating', 'profit', 'jumped', 'eur', '47', 'million', 'eur', '6', '6', 'million']
#
#
# ===Tokens:===
# ['lnt', 'increases', 'annual', 'dividend', 'target', '1', '80', 'share', '1', '70', 'share']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'kci', 'konecranes', 'said', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'ltd']
#
#
# ===Tokens:===
# ['vaahto', 'pulp', 'paper', 'finnish', 'vaahto', 'group', 'awarded', 'order', 'renovate', 'finnish', 'swedish', 'forest', 'industry', 'company', 'stora', 'enso', 'paperboard', 'machine', 'ingerois', 'board', 'mill', 'finland']
#
#
# ===Tokens:===
# ['buy', 'recommendation', 'reiterated']
#
#
# ===Tokens:===
# ['bristol', 'port', 'company', 'sealed', 'one', 'million', 'pound', 'contract', 'cooper', 'specialised', 'handling', 'supply', 'four', '45', 'tonne', 'customised', 'reach', 'stackers', 'konecranes']
#
#
# ===Tokens:===
# ['h', 'move', 'enhance', 'growth']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'period', 'eur0', '9', 'eur0', '01', 'last', 'year']
#
#
# ===Tokens:===
# ['subscriptions', 'increase', 'cargotec', 'share', 'capital', '36', '780', 'euros']
#
#
# ===Tokens:===
# ['new', 'representation', 'extends', 'comptel', 'global', 'presence', 'total', '18', 'countries', 'serving', '250', 'customers', '80', 'countries', 'worldwide']
#
#
# ===Tokens:===
# ['china', 'finnish', 'kone', 'provides', 'elevators', 'escalators', 'solutions', 'modernisation', 'maintenance', 'build', '342', 'escalators', 'installed', 'high', 'speed', 'railway', 'section', 'beijing', 'shanghai', '1', '5', 'years', 'time']
#
#
# ===Tokens:===
# ['shares', 'standard', 'chartered', 'stan', 'rose', '1', '2', 'ftse', '100', 'royal', 'bank', 'scotland', 'rbs', 'shares', 'rose', '2', 'barclays', 'shares', 'barc', 'bcs', '1', '7']
#
#
# ===Tokens:===
# ['cargo', 'volume', 'increased', 'approximately', '5']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'retail', 'wholesale', 'group', 'kesko', 'reported', 'net', 'sales', '659', '4', 'mln', 'eur', 'february', 'increase', '10', '8', 'pct', 'year', 'year']
#
#
# ===Tokens:===
# ['lule', 'municipality', 'awarded', 'yit', '2', 'year', 'contract', 'property', 'management', 'one', 'third', 'municipality', 'properties', 'total', 'area', '140', '000', 'sq', 'metres']
#
#
# ===Tokens:===
# ['pre', 'tax', 'profit', 'totaled', 'eur', '397', '4', 'mn', 'eur', '164', '7', 'mn']
#
#
# ===Tokens:===
# ['yhoo', 'break', '5', 'min']
#
#
# ===Tokens:===
# ['today', 'bought', 'mu', 'yhoo', 'vale', 'nbl', 'twtr', 'axp', 'znga', 'https', 'co', 'vt6t5zp2is']
#
#
# ===Tokens:===
# ['kalnapilio', 'tauro', 'grupe', 'kalnapilis', 'tauras', 'group', 'owned', 'denmark', 'royal', 'unibrew', 'raised', 'market', 'share', '25', '2', 'percent', '23', '91', 'percent', 'beer', 'sales', 'nine', 'months', 'jumped', '11', '4', 'percent', '52', '99', 'million', 'liters']
#
#
# ===Tokens:===
# ['mos', 'looking', 'good', '58', '65', 'calls', 'active', 'month', 'weekly']
#
#
# ===Tokens:===
# ['nokian', 'tyre', 'proves', 'high', 'safety', 'excellently', 'important', 'driving', 'qualities', 'stability', 'mark', '1', '4', 'handling', '1', '5', 'braking', 'wet', 'road', '1', '9']
#
#
# ===Tokens:===
# ['several', 'growth', 'initiatives', 'chosen', 'geographic', 'areas', 'already', 'ongoing', 'continued', 'noting', 'lindex', 'opened', 'first', 'store', 'czech', 'republic', 'autumn', 'brno']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'totalled', 'eur', '2', '71', 'mn', 'compared', 'negative', 'eur', '0', '83', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['sppi', 'building', 'rs', 'sweet', 'want', 'break', 'new', '52week', 'earnings', 'growth', 'justifies', 'way', 'higher']
#
#
# ===Tokens:===
# ['according', 'finnish', 'metso', 'minerals', 'value', 'company', 'orders', 'gone', 'eur', '1', '9', 'bn', '12', 'months']
#
#
# ===Tokens:===
# ['return', 'equity', 'stood', '18', '3', 'compared', '15', '4', 'third', 'quarter', '2005']
#
#
# ===Tokens:===
# ['fio', 'stay']
#
#
# ===Tokens:===
# ['intuitiv', 'clne', 'gasoline', 'prices', 'spike', 'california', 'http', 'stks', 'co', 't1boi']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '6', '2009', 'finnish', 'fishing', 'tackle', 'company', 'rapala', 'vmc', 'corp', 'hel', 'rap1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '19', '2', 'million', 'usd', '24', '6', '2008', 'eur', '17', '5', 'million', '2007']
#
#
# ===Tokens:===
# ['warmly', 'welcome', 'michael', 'frei', 'outotec']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'group', 'share', 'price', 'climbs', '1', '5bn', 'special', 'dividend']
#
#
# ===Tokens:===
# ['stora', 'enso', 'third', 'quarter', 'pre', 'tax', 'profit', 'doubled', 'eur', '197mn']
#
#
# ===Tokens:===
# ['kesko', 'agro', 'lietuva', 'agricultural', 'machinery', 'grain', 'trader', 'another', 'member', 'kesko', 'group', 'boosted', 'sales', '42', '9', 'percent', '13', '4', 'million', 'euros', 'vat', 'inclusive']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur13', '6', 'net', 'sales', 'increased', 'eur394', '7', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['compass', 'group', 'says', 'positive', 'year', 'ahead']
#
#
# ===Tokens:===
# ['shire', 'ceo', 'steps', 'drive', 'get', 'baxalta', 'board', 'talking']
#
#
# ===Tokens:===
# ['astrazeneca', 'acquires', 'zs', 'pharma', '2', '7', 'billion', 'deal']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '11', '4', 'mn', 'eur', '7', '5', 'mn']
#
#
# ===Tokens:===
# ['net', 'interest', 'income', 'eur', '152', '2', 'mn', 'eur', '101', '0', 'mn', '2008']
#
#
# ===Tokens:===
# ['president', 'ceo', 'mika', 'vehvil', 'inen', 'says', 'positive', 'signs', 'first', 'foremost', 'emerging', 'outside', 'finland']
#
#
# ===Tokens:===
# ['fb', 'slight', 'green', 'may', 'runner', 'later']
#
#
# ===Tokens:===
# ['contract', 'signed', 'august', 'papua', 'new', 'guinea', 'based', 'lihir', 'gold', 'ltd', 'asx', 'lgl']
#
#
# ===Tokens:===
# ['stora', 'enso', 'norske', 'skog', 'real', 'upm', 'kymmene', 'credit', 'suisse', 'first', 'boston', 'cfsb', 'raised', 'fair', 'value', 'shares', 'four', 'largest', 'nordic', 'forestry', 'groups']
#
#
# ===Tokens:===
# ['pleased', 'welcome', 'tapeks', 'noma', 'cramo', 'group']
#
#
# ===Tokens:===
# ['berkshire', 'applies', 'boost', 'wells', 'fargo', 'stake', '10', 'percent']
#
#
# ===Tokens:===
# ['outotec', 'oyj', 'press', 'release', 'december', '4', '2009', '10', '30', 'outotec', 'establishes', 'new', 'subsidiary', 'kolkata', 'outotec', 'established', 'subsidiary', 'india', 'order', 'better', 'serve', 'indian', 'customers', 'increase', 'business', 'growing', 'indian', 'market']
#
#
# ===Tokens:===
# ['amending', 'proposal', 'simplifies', 'proposed', 'plan', 'increases', 'incentive', 'key', 'employees', 'stay', 'company']
#
#
# ===Tokens:===
# ['honored', 'acknowledged', 'commitment', 'industry', 'especially', 'asia', 'pacific']
#
#
# ===Tokens:===
# ['navteq', 'commanding', 'lead', 'installed', 'map', 'data', 'systems', 'north', 'american', 'vehicles', 'may', 'leader', 'turn', 'turn', 'navigation', 'data', 'offered', 'services', 'onstar', 'north', 'america', 'said', 'analyst', 'phil', 'magney', 'telematics', 'research', 'group', 'minnetonka', 'minn']
#
#
# ===Tokens:===
# ['gsk', 'joins', 'china', 'trade', 'push', 'uk', 'trumpets', 'healthcare', 'deals']
#
#
# ===Tokens:===
# ['value', 'firm', 'forestry', 'holdings', 'increased', 'sek', '3', '6', 'bn']
#
#
# ===Tokens:===
# ['hammerson', 'jv', 'partner', 'secure', 'ownership', 'ireland', 'dundrum', 'quick', 'facts']
#
#
# ===Tokens:===
# ['2009', 'fiskars', 'cash', 'flow', 'operating', 'activities', 'amounted', 'eur121m', 'eur97m', 'previous', 'year']
#
#
# ===Tokens:===
# ['long', 'vvus', 'shares', 'call', 'option', 'w', 'expiration', 'umm', 'today', 'hitting', 'hod']
#
#
# ===Tokens:===
# ['chime', 'communications', 'set', 'acquired', 'wpp', 'providence']
#
#
# ===Tokens:===
# ['asdfllc', 'nice', 'pop', 'today', 'told', 'ya', 'would', 'green', 'haha', 'funny', 'bring', 'actually', 'working', 'story', 'nok', 'moment']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'company', 'elcoteq', 'signing', 'cooperation', 'agreement', 'japanese', 'mobile', 'phone', 'manufacturer', 'bypasses', 'elcoteq', 'tallinn', 'says', 'jan', 'kotka', 'ceo', 'elcoteq', 'tallinn']
#
#
# ===Tokens:===
# ['based', 'upon', 'unique', 'fiber', 'expertise', 'innovative', 'approach', 'company', 'strong', 'market', 'position', 'several', 'business', 'areas', 'operates']
#
#
# ===Tokens:===
# ['company', 'said', 'started', 'investigate', 'streamlining', 'operations', 'order', 'meet', 'tightening', 'competition', 'mobile', 'phone', 'charger', 'market']
#
#
# ===Tokens:===
# ['developers', 'project', 'predict', 'completed', 'april', '2009', 'skanssi', 'attract', '4', '5', 'million', 'visitors', 'annually']
#
#
# ===Tokens:===
# ['ftse', '100', 'flat', 'standard', 'chartered', 'leads', 'risers']
#
#
# ===Tokens:===
# ['manavigator', 'september', '7', '2010', 'kemira', 'unveils', 'indian', 'jv', 'ivrcl', 'finnish', 'chemicals', 'group', 'kemira', 'hel', 'kra1v', 'tuesday', 'announced', 'inked', 'deal', 'form', 'joint', 'venture', 'india', 'local', 'construction', 'firm', 'ivrcl', 'infrastructure', 'projects', 'ltd', 'bom', '530773']
#
#
# ===Tokens:===
# ['according', 'finnish', 'aktia', 'bank', 'managing', 'director', 'jussi', 'laitinen', 'bank', 'aim', 'triple', 'number', 'customers', 'finland', 'next', 'five', 'years']
#
#
# ===Tokens:===
# ['finland', 'nokian', 'tyres', 'kazakhstan', 'ordabasy', 'corporation', 'signed', 'agreement', 'build', 'plant', 'astana', 'produce', 'car', 'tires', 'ordabasy', 'chairman', 'dinmukhamet', 'idrisov', 'said', 'press', 'conference']
#
#
# ===Tokens:===
# ['danske', 'bank', 'danske', 'dc', 'jumped', '3', '7', 'percent', '133', '4', 'kroner', 'rebounding', 'yesterday', '3', '5', 'percent', 'slide']
#
#
# ===Tokens:===
# ['vessel', 'order', 'help', 'aspo', 'secure', 'long', 'term', 'competitiveness', 'fleet', 'terms', 'technology', 'pricing']
#
#
# ===Tokens:===
# ['enb', 'ca', 'head', 'shoulders', 'bullish', 'reversal', 'setup', 'breakout', 'oil', 'gas', 'pipleline', 'stock', 'uso']
#
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastic', 'products', 'maker', 'suominen', 'corporation', 'said', 'net', 'loss', 'narrowed', '1', '6', 'mln', 'euro', '2', '0', 'mln', 'first', 'nine', 'months', '2006', '2', '16', 'mln', 'euro', '2', '7', 'mln', 'period', '2005']
#
#
# ===Tokens:===
# ['upside', 'moves', 'volatile', 'mining', 'sector', 'sending', 'anglo', 'american', 'plc', 'aal', '6', '8', '4', '30', 'pm', 'london', 'time']
#
#
# ===Tokens:===
# ['rad', 'would', 'consider', 'opportunity', 'add', 'position', 'company', 'right', 'track', 'still', 'improving', 'sales']
#
#
# ===Tokens:===
# ['ocn', 'stuff', 'looking', 'add', 'shares', 'get', 'new', 'high', 'breakout']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'net', 'profit', 'rose', '26', '1', 'mln', 'euro', '35', '9', 'mln', 'first', 'quarter', '2007', '5', '3', 'mln', 'euro', '7', '3', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['rapala', 'estimates', 'net', 'sales', '2008', 'increase', '8', '0', 'pct', '12', 'pct', 'assuming', '2007', 'exchange', 'rates']
#
#
# ===Tokens:===
# ['free', 'ha', 'heeeeeere', 'comes', 'pump', 'glad', 'picked', '9k', 'end', 'day', 'get', 'ready', 'bull', 'ride']
#
#
# ===Tokens:===
# ['eps', 'grew', '0', '04', 'eur', '0', '02', 'eur']
#
#
# ===Tokens:===
# ['held', 'recent', 'double', 'bottom', 'buy', 'point', '56', '57', 'almost', 'penny', 'today', 'wmt', 'http', 'chart', 'ly', '6nosp5q']
#
#
# ===Tokens:===
# ['astrazeneca', 'shares', 'climb', '3', 'drug', 'maker', 'ups', 'profits', 'forecasts']
#
#
# ===Tokens:===
# ['group', 'business', 'balanced', 'broad', 'portfolio', 'sports', 'presence', 'major', 'markets']
#
#
# ===Tokens:===
# ['companiescar', 'insurer', 'hastings', 'group', 'driving', '180m', 'ipo']
#
#
# ===Tokens:===
# ['vrtx', 'early', 'technical', 'buy', 'signal', 'confirmation', '86', 'needs', 'fundam', 'incentive', 'https', 'co', 'quysrqfo2x']
#
#
# ===Tokens:===
# ['systeemitiimi', 'sales', 'project', 'resources', 'also', 'strengthened', 'director', 'paul', 'skogberg', 'said']
#
#
# ===Tokens:===
# ['accordance', 'strategy', 'strengthened', 'local', 'presence', 'establishing', 'representative', 'office', 'south', 'africa', 'october']
#
#
# ===Tokens:===
# ['metso', 'said', 'order', 'worth', 'around', '40', 'mln', 'eur', 'supply', 'kraftliner', 'board', 'machine', 'china', 'lee', 'man', 'paper', 'co']
#
#
# ===Tokens:===
# ['poyry', 'recognized', 'one', 'world', 'leading', 'advisors', 'global', 'forestry', 'industry']
#
#
# ===Tokens:===
# ['skf', '6', 'april', '2010', 'alandsbanken', 'given', 'buy', 'recommendation', 'swedish', 'industrial', 'company', 'skf', 'ab', 'sto', 'skf', 'b', 'share', 'price', 'target', 'sek150']
#
#
# ===Tokens:===
# ['investments', 'operational', 'changes', 'enable', 'additional', 'optimisation', 'working', 'hours', 'thereby', 'cost', 'savings', '7', '9']
#
#
# ===Tokens:===
# ['finnish', 'software', 'developer', 'basware', 'oyj', 'said', 'november', '30', '2006', 'u', 'subsidiary', 'basware', 'inc', 'order', 'provide', 'software', 'contract', 'lifecycle', 'management', 'unnamed', 'u', 'medical', 'technology', 'company']
#
#
# ===Tokens:===
# ['repair', 'maintenance', 'business', 'accounted', 'net', 'sales', 'eur', '645', '3', 'mn', 'eur', '563', '6', 'mn']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'increased', '2', 'eur', '1', '050', '7', 'mn', 'eur', '1', '027', '0', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['stock', 'trading', 'maps', '50', 'day', 'map', 'sek72', '983', 'higher', '200', 'day', 'map', 'sek70', '283', 'bullish', 'indicator']
#
#
# ===Tokens:===
# ['luv', 'continues', 'consolidate', 'previous', 'break', 'area']
#
#
# ===Tokens:===
# ['recommendable', 'nokian', 'z', 'g2', 'according', 'adac', 'judgement', 'latest', 'summer', 'tyre', 'test', 'german', 'automobile', 'association', 'adac']
#
#
# ===Tokens:===
# ['economic', 'occupancy', 'rate', 'sponda', 'property', 'portfolio', 'rose', '91', '2', '88', '8', '2006']
#
#
# ===Tokens:===
# ['leipurin', 'growing', 'rapidly', 'internationalizing', 'group']
#
#
# ===Tokens:===
# ['2008', 'deal', 'likely', 'bring', 'savings', 'eur', '20mn', '25mn']
#
#
# ===Tokens:===
# ['cargotec', 'germany', 'gmbh', 'awarded', 'contract', 'stadtverwaltung', 'mainz', 'chassis', 'bodies', 'open', 'procedure']
#
#
# ===Tokens:===
# ['exports', 'accounted', '65', '4', 'net', 'sales', 'representing', 'time', 'record', 'company']
#
#
# ===Tokens:===
# ['previously', 'eb', 'delivered', 'custom', 'solution', 'lg', 'electronics', 'making', 'commercially', 'available', 'mobile', 'terminal', 'vendors', 'well', 'wireless', 'operators']
#
#
# ===Tokens:===
# ['marimekko', 'group', 'full', 'year', 'net', 'sales', 'estimated', 'increase', '10']
#
#
# ===Tokens:===
# ['terms', 'profitability', 'earnings', '2007', 'best', 'year', 'history', 'chief', 'executive', 'veli', 'matti', 'mattila', 'said']
#
#
# ===Tokens:===
# ['profit', 'taking', 'aapl', 'morning', 'pressure', 'stock', 'still', 'bullish', 'aapl']
#
#
# ===Tokens:===
# ['passenger', 'related', 'revenue', 'rose', '5', '1', 'eur', '460', '8', 'mn', 'eur', '438', '5', 'mn', '2009']
#
#
# ===Tokens:===
# ['end', 'review', 'period', 'nordic', 'aluminium', 'order', 'book', 'stood', 'eur', '8', '77', 'mn', 'compared', 'eur', '7', '04', '2005']
#
#
# ===Tokens:===
# ['tesco', 'closes', 'new', 'chairman', 'dixons', 'carphone', 'john', 'allan', 'frame']
#
#
# ===Tokens:===
# ['takeover', 'cramo', 'become', 'second', 'largest', 'rental', 'services', 'provider', 'latvian', 'market']
#
#
# ===Tokens:===
# ['cencorp', 'estimates', 'net', 'sales', 'last', 'quarter', 'earlier', 'stated', 'eur4', '3', 'eur5', '0', 'operating', 'profit', 'ebit', 'estimated', 'positive']
#
#
# ===Tokens:===
# ['teliasonera', 'said', '100', 'million', 'invested', 'next', 'year', 'region', 'bring', 'mobile', 'coverage', '90', 'nepal', 'population']
#
#
# ===Tokens:===
# ['amazon', 'declares', 'best', 'ever', 'black', 'friday', 'cyber', 'monday', 'kindle', 'family', 'http', 'stks', 'co', 'cetw', 'via', 'engadget', 'amzn']
#
#
# ===Tokens:===
# ['rdc', 'rowan', 'expands', 'share', 'repurchase', 'program', '150', 'million']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', '2010', 'seen', 'grown', 'eur598', '3', 'eur582', '3', '2009']
#
#
# ===Tokens:===
# ['clothing', 'chain', 'sepp', 'l', 'net', 'sales', 'increased', '7', '0', 'eur', '30', '8', 'mn']
#
#
# ===Tokens:===
# ['ilmn', 'piper', 'jeffries', 'raises', 'pt', 'remain', 'long']
#
#
# ===Tokens:===
# ['dxcm', 'making', 'higher', 'highs', 'higher', 'lows', 'consolidates', 'past', 'several', 'weeks', '26', '70', 'time', 'high', '2006']
#
#
# ===Tokens:===
# ['mr', 'lee', 'said', 'hoped', 'neste', 'move', 'pave', 'way', 'collaboration', 'projects', 'two', 'countries']
#
#
# ===Tokens:===
# ['addition', 'fireplace', 'exports', 'demand', 'lining', 'stone', 'exceeded', 'level', 'earlier', 'part', 'year', 'continue', 'clearly', 'brisker', 'remainder', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'sales', 'three', 'month', 'period', 'increased', 'respectively', 'eur0', '3', 'eur13', '1', 'compared', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['also', 'bringing', 'right', 'kind', 'people', 'upgrade', 'human', 'resources']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '27', '8', 'mn', 'eur', '17', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['endp', 'saw', 'large', 'order', 'one', 'last', 'week', 'someone', 'also', 'accumulating', 'may', 'jun', '35', 'calls', 'today']
#
#
# ===Tokens:===
# ['commencing', 'construction', 'works', 'pearl', 'plaza', 'significant', 'step', 'russian', 'projects']
#
#
# ===Tokens:===
# ['raisio', 'divisions', 'recorded', 'operating', 'profit']
#
#
# ===Tokens:===
# ['meanwhile', 'nokia', 'said', 'able', 'deliver', 'complete', 'range', 'services', 'deployment', 'operations', 'consulting', 'integration', 'managed', 'services', 'result', 'buyout']
#
#
# ===Tokens:===
# ['glaxo', 'viiv', 'healthcare', 'signs', 'china', 'manufacturing', 'deal', 'desano']
#
#
# ===Tokens:===
# ['bot', 'amzn', '600', 'weekly', 'calls', '5', '93']
#
#
# ===Tokens:===
# ['finnish', 'lifting', 'equipment', 'maker', 'kone', 'oyj', 'said', 'october', '4', '2007', 'order', 'worth', '15', 'mln', 'euro', '21', '2', 'mln', 'deliver', 'total', '53', 'custom', 'designed', 'elevators', 'norwegian', 'shipbuilder', 'aker', 'yards', 'asa']
#
#
# ===Tokens:===
# ['standardised', 'services', 'met', 'positive', 'reception', 'among', 'customers', 'well', 'itella']
#
#
# ===Tokens:===
# ['refining', 'margin', 'year', '13', '39', 'bbl', 'compared', '10', '46', 'bbl', 'prior', 'year']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '103', '4', 'mn', 'eur', '23', '2', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['kraft', 'heinz', 'merger', 'came', 'together', 'speedy', '10', 'weeks']
#
#
# ===Tokens:===
# ['net', 'sales', 'vegetable', 'oil', 'business', 'rose', 'eur', '10', '6', 'mn', 'eur', '10', '1', 'mn']
#
#
# ===Tokens:===
# ['company', 'anticipates', 'turnover', 'whole', '2010', 'surpass', 'previous', 'year', 'eur', '67', '1', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'surged', 'eur21m', 'eur106', '000']
#
#
# ===Tokens:===
# ['bilfinger', 'industrial', 'services', 'win', '100m', 'bp', 'contract', 'extension']
#
#
# ===Tokens:===
# ['would', 'invest', 'physical', 'infrastructure', 'would', 'also', 'provide', 'know', 'managing', 'developing', 'science', 'technology', 'parks', 'said', 'sunrise', 'valley', 'director', 'andrius', 'bagdonas']
#
#
# ===Tokens:===
# ['rationalization', 'operations', 'seeks', 'achieve', 'eur', '1', 'million', 'yearly', 'savings', 'second', 'quarter', 'current', 'financial', 'year']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'outperforms', 'europe', 'royal', 'mail', 'tesco', 'rise']
#
#
# ===Tokens:===
# ['profit', 'period', 'eur', '5', '9', 'mn', 'eur', '1', '3', 'mn']
#
#
# ===Tokens:===
# ['cision', 'says', 'sale', 'return', 'u', 'k', 'operation', 'profitability']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'higher', '0', '48', '0', '37', 'year', 'ahead', 'market', 'consensus', '0', '40', 'eur']
#
#
# ===Tokens:===
# ['ebit', 'margin', '1', '4', '5', '1']
#
#
# ===Tokens:===
# ['ruukki', 'forecast', '15', '20', 'annual', 'sales', 'growth', 'positive', 'pretax', 'result', '2010']
#
#
# ===Tokens:===
# ['acquiring', 'rcp', 'combine', 'strong', 'knowhow', 'expertise', 'solid', 'local', 'company']
#
#
# ===Tokens:===
# ['4', 'beaten', 'internet', 'companies', 'may', 'ripe', 'takeover', 'target', 'twitter', 'twtr', 'linkedin', 'lnkd', 'yahoo', 'yhoo', 'groupon', 'grpn']
#
#
# ===Tokens:===
# ['sonc', 'amazing', 'run', 'since', 'middle', 'march', 'obvious', 'quality', 'tastiness', 'burgers', 'factored', 'price', 'advance']
#
#
# ===Tokens:===
# ['activision', 'blizzard', 'media', 'networks', 'announces', 'record', 'esports', 'viewership', 'https', 'co', '729biqlbtk', 'atvi', 'partnered', 'hdsi', '9', 'tournament']
#
#
# ===Tokens:===
# ['dara', 'breaking']
#
#
# ===Tokens:===
# ['supermarket', 'stocks', 'rally', 'tesco', 'plans', 'axe', 'non', 'core', 'uk', 'assets', 'tsco', 'https', 'co', 'bmvhcrwrea']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '4', '7', 'mn', 'eur', '4', '6', 'mn']
#
#
# ===Tokens:===
# ['strategic', 'cooperation', 'rentakran', 'brings', 'us', 'new', 'customers', 'already', 'working', 'relationships', 'authorities', 'new', 'territories', 'said', 'jarmo', 'laasanen', 'senior', 'manager', 'cramo']
#
#
# ===Tokens:===
# ['kitd', 'looking', 'oversold', 'bounce']
#
#
# ===Tokens:===
# ['wft', 'closng', 'higher']
#
#
# ===Tokens:===
# ['kauko', 'telko', 'ltd', 'press', 'release', '19', '06', '2007', '14', '00', '1', '1', 'telko', 'group', 'kauko', 'telko', 'expanding', 'strategic', 'partnership', 'bp', 'industrial', 'lubricants', 'services', 'bp', 'ils', 'acquiring', 'total', 'ownership', 'bp', 'swedish', 'retail', 'company', 'molub', 'alloy', 'ab']
#
#
# ===Tokens:===
# ['eln', 'longs', 'congrats', 'another', 'hod']
#
#
# ===Tokens:===
# ['solutions', 'used', 'upgrading', 'networks', 'russian', 'mso', '37', 'different', 'cities', 'russia']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '9', '2009', 'finnish', 'computer', 'services', 'company', 'proha', 'oyj', 'hel', 'art1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '113', '000', 'usd', '146', '000', '2008', 'eur', '1', '2', 'million', '2007']
#
#
# ===Tokens:===
# ['major', 'breweries', 'increased', 'domestic', 'beer', 'sales', '4', '5', 'per', 'cent', 'last', 'year', '256', '88', 'million', 'litres', '245', '92', 'million', 'litres', '2004']
#
#
# ===Tokens:===
# ['shopping', 'center', 'opened', 'st', 'petersburg', 'russia', 'november', '2010', 'turn', 'cash', 'flow', 'finnish', 'department', 'store', 'chain', 'stockmann', 'russian', 'operations', 'positive', 'first', 'time', '2011']
#
#
# ===Tokens:===
# ['company', 'also', 'estimates', 'already', 'carried', 'investments', 'lead', 'increase', 'net', 'sales', '2010', '2009', 'reached', 'eur', '141', '7', 'million']
#
#
# ===Tokens:===
# ['poyry', 'good', 'track', 'record', 'major', 'transportation', 'projects', 'latin', 'america']
#
#
# ===Tokens:===
# ['stx', 'long', 'play', 'another', 'consistent', 'profit', 'zone', 'check', 'https', 'co', 'dqfuzozylh', 'https', 'co', 'ggne4ayzqn']
#
#
# ===Tokens:===
# ['combine', 'renew', 'contents', 'functionality', 'current', 'systems', 'funding', 'online', 'service', 'well', 'maintenance']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '6', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['daily', 'mail', 'owner', 'considering', 'yahoo', 'bid', 'yhoo', '2', '05', 'https', 'co', 'extzr1riyp']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'seen', 'eur', '0', '56', 'eur', '0', '38']
#
#
# ===Tokens:===
# ['went', 'long', 'ilmn']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'awarded', 'contract', 'rebuild', 'sabah', 'forest', 'industries', 'sfi', 'pulp', 'mill', 'sabah', 'malaysia']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '1', '2008', 'finnish', 'consulting', 'engineering', 'company', 'poyry', 'oyj', 'omx', 'poy1v', 'said', 'today', 'awarded', 'eur', '5', '2', 'million', 'usd', '7', '4', 'extension', 'existing', 'consultancy', 'engineering', 'contract', 'venezuel']
#
#
# ===Tokens:===
# ['finnish', 'kci', 'konecranes', 'awarded', 'order', 'four', 'hot', 'metal', 'ladle', 'cranes', 'indian', 'steel', 'producer', 'bhushan', 'steel', 'strips', 'delivered', '2007']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'release', 'february', '11', '2011', 'at8', '45', 'esl', 'shipping', 'ltd', 'part', 'aspo', 'group', 'signed', 'new', 'long', 'term', 'contract', 'rautaruukki', 'corporation', 'marine', 'transport', 'raw', 'materials', 'baltic', 'sea']
#
#
# ===Tokens:===
# ['long', 'pcln']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'management', 'software', 'solutions', 'provider', 'ixonos', 'oyj', 'hel', 'xns1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '3', '5', 'million', 'usd', '4', '5', '2008', 'eur', '3', '1', 'million', '2007']
#
#
# ===Tokens:===
# ['stock', 'rose', 'second', 'day', 'wednesday', 'bringing', 'two', 'day', 'rise', 'gbx12', '0', '2', '0']
#
#
# ===Tokens:===
# ['new', 'partnership', 'agreement', 'represents', 'significant', 'milestone', 'parties']
#
#
# ===Tokens:===
# ['handelsbanken', 'ranked', 'local', 'cooperative', 'banks', 'aktia', 'customer', 'loyalty', 'time', 'however']
#
#
# ===Tokens:===
# ['fedday', 'looking', 'sharp', 'move', 'equities', 'aapl', 'hd', 'low', 'fb', 'seeing', 'uvxy', 'tvix', 'getting', 'hammered', 'even', 'though', 'market']
#
#
# ===Tokens:===
# ['operating', 'profit', 'grain', 'trading', 'increased', 'eur', '2', '0', 'mn', 'eur', '1', '4', 'mn', '2005']
#
#
# ===Tokens:===
# ['section', 'regional', 'news', 'demand', 'finnair', 'asian', 'traffic', 'measured', 'passenger', 'kilometers', '34', '9', 'august', 'compare', 'last', 'year']
#
#
# ===Tokens:===
# ['nflx', '3', 'lows']
#
#
# ===Tokens:===
# ['geosolutions', 'technology', 'leverage', 'benefon', 'gps', 'solutions', 'providing', 'location', 'based', 'search', 'technology', 'communities', 'platform', 'location', 'relevant', 'multimedia', 'content', 'new', 'powerful', 'commercial', 'model']
#
#
# ===Tokens:===
# ['update', 'cib', 'legal', 'general', 'sell', 'egyptian', 'life', 'joint', 'venture', 'axa']
#
#
# ===Tokens:===
# ['15', 'december', '2010', 'finnish', 'german', 'telecoms', 'equipment', 'maker', 'nokia', 'siemens', 'networks', 'said', 'today', 'contract', 'upgrade', 'radio', 'network', 'home', 'based', 'telecommunications', 'company', 'elisa', 'oyj', 'hel', 'eli1v']
#
#
# ===Tokens:===
# ['zurich', 'insurance', 'considering', 'offer', 'uk', 'rival', 'rsa', 'insurance']
#
#
# ===Tokens:===
# ['full', '2010', 'company', 'expects', 'net', 'sales', 'operating', 'result', 'improve', 'previous', 'year', 'saying', 'positive', 'operating', 'result', 'amount', 'depend', 'order', 'intake', 'end', 'summer']
#
#
# ===Tokens:===
# ['looking', 'strong', 'bounce', 'spy', 'lunchtime', 'rally', 'coming', 'dia', 'iwm', 'qqq', 'aa', 'fb']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur', '36', 'million', 'eur', '27', 'million']
#
#
# ===Tokens:===
# ['company', 'intensifying', 'smelter', 'operations', 'increasing', 'annual', 'production', 'capacity', '230', '000', 'tonnes', 'copper']
#
#
# ===Tokens:===
# ['long', 'position', 'gol', 'updating', 'http', 'stks', 'co', 'fdmm']
#
#
# ===Tokens:===
# ['transaction', 'also', 'rationalize', 'pulp', 'paper', 'industry', 'related', 'solutions']
#
#
# ===Tokens:===
# ['neste', 'oil', 'corp', 'signed', 'long', 'term', 'procurement', 'contracts', 'honkajoki', 'oy', 'findest', 'protein', 'oy', 'owned', 'finnish', 'food', 'manufacturers', 'supply', 'animal', 'fat', 'biodiesel', 'production', 'neste', '200', '000', 'b', 'cd', 'porvoo', 'finland', 'refinery']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'increased', 'eur3', '1', 'net', 'sales', 'increased', 'eur61', '5', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['finnish', 'aldata', 'solution', 'signed', 'contract', 'supply', 'g', 'l', 'system', 'two', 'french', 'retail', 'chains']
#
#
# ===Tokens:===
# ['reached', 'agreement', 'union', 'flights', 'continue', 'normal', 'finnair', 'spokesman', 'usko', 'maatta', 'said']
#
#
# ===Tokens:===
# ['real', 'sales', 'expected', 'increased', '4', 'year', 'year', 'eur609m', 'second', 'quarter', '2010']
#
#
# ===Tokens:===
# ['australia', 'clears', 'ab', 'inbev', '100', 'billion', 'sabmiller', 'buyout', 'plan']
#
#
# ===Tokens:===
# ['far', 'mr', 'galvan', 'able', 'avoid', 'laying', 'workers']
#
#
# ===Tokens:===
# ['abb', 'deutsche', 'bank', 'upgraded', 'recommendation', 'swiss', 'swedish', 'engineering', 'group', 'abb', 'ltd', 'buy', 'hold']
#
#
# ===Tokens:===
# ['slowly', 'adding', 'fio', 'got', 'ta', 'careful', 'one', 'biggest', 'winners', '2012']
#
#
# ===Tokens:===
# ['see', '200', 'day', 'sma', 'big', 'hurdle', 'good', 'base', 'building', 'nflx', 'https', 'co', 'imkygo2cyc']
#
#
# ===Tokens:===
# ['news', 'feedschroders', 'books', 'solid', 'earnings', 'growth', 'several', 'board', 'changes']
#
#
# ===Tokens:===
# ['astrazeneca', 'weighing', 'acerta', 'bid', 'secure', 'blood', 'cancer', 'drug']
#
#
# ===Tokens:===
# ['thanks', 'wide', 'contact', 'network', 'good', 'knowledge', 'market', 'business', 'environment', 'give', 'great', 'contribution', 'development', 'indian', 'operations', 'tells', 'incap', 'president', 'ceo', 'juhani', 'hanninen']
#
#
# ===Tokens:===
# ['design', 'team', 'long', 'admired', 'marimekko', 'vivid', 'patterns', 'colors']
#
#
# ===Tokens:===
# ['much', 'better', 'process', 'using', 'virgin', 'paper', 'requires', 'less', 'transportation', 'wood', 'pulp', 'places', 'like', 'finland', 'canada']
#
#
# ===Tokens:===
# ['arm', 'royalties', 'accelerate', 'smartphone', 'market', 'regains', 'strength']
#
#
# ===Tokens:===
# ['following', 'transaction', 'lundbeck', 'worldwide', 'rights', 'nalmefene', 'excluding', 'north', 'america', 'mexico', 'turkey', 'south', 'korea']
#
#
# ===Tokens:===
# ['fb', '110', '20', 'starting', 'show', 'relative', 'strength', 'signs', 'potential', 'b', 'daily']
#
#
# ===Tokens:===
# ['piper', 'upgrades', 'symantec', 'improving', 'renewal', 'rates', 'enterprise', 'growth', 'symc']
#
#
# ===Tokens:===
# ['district', 'court', 'helsinki', 'dismissed', 'charges', 'court', 'first', 'instance', '2005']
#
#
# ===Tokens:===
# ['china', 'based', 'operation', 'enable', 'us', 'fully', 'leverage', 'resources', 'expertise', 'wireless', 'solutions', 'also', 'strengthen', 'capability', 'offer', 'industry', 'leading', 'products', 'customers', 'china']
#
#
# ===Tokens:===
# ['starbucks', 'digital', 'strategy', 'drive', 'significant', 'growth', 'customer', 'loyalty', 'sbux', 'https', 'co', 'xk6lz3ui3k']
#
#
# ===Tokens:===
# ['adobe', 'receives', 'new', 'rating', 'top', 'analyst', 'adbe', 'https', 'co', 'ljnxpevhzn']
#
#
# ===Tokens:===
# ['assignment', 'strengthens', 'poyry', 'position', 'international', 'provider', 'engineering', 'project', 'services', 'chemical', 'process', 'industry']
#
#
# ===Tokens:===
# ['finnish', 'outotec', 'awarded', 'contract', 'supply', 'new', 'zinc', 'roaster', 'gas', 'cleaning', 'sulphuric', 'acid', 'plant', 'ozk', 'kardzhali', 'zinc', 'smelter', 'bulgaria']
#
#
# ===Tokens:===
# ['london', 'open', 'taylor', 'wimpey', 'ashtead', 'drive', 'markets', 'higher', 'barclays', 'falls']
#
#
# ===Tokens:===
# ['es', 'f', 'nice', 'little', 'cup', 'handle', 'shaping', '15', 'minute', 'end', 'day', 'spy', 'spx', 'favours', 'good', 'day', 'index', 'see', 'gap', 'open']
#
#
# ===Tokens:===
# ['finland', 'insurance', 'company', 'pohjola', 'finnish', 'motorcyclist', 'association', 'signed', 'agreement', 'aim', 'improving', 'motorcyclists', 'traffic', 'safety']
#
#
# ===Tokens:===
# ['soapstone', 'deposits', 'medvezhyegorsk', 'area', 'expected', 'increase', 'tulikivi', 'current', 'reserves', 'considerably']
#
#
# ===Tokens:===
# ['q1', '10', '19', 'april', '2010', 'finnish', 'forest', 'machinery', 'equipment', 'maker', 'ponsse', 'oyj', 'hel', 'pon1v', 'said', 'today', 'expects', 'swing', 'net', 'profit', 'eur6', '3', 'first', 'quarter', '2010', 'eur9', '6', 'loss', 'year', 'earlier']
#
#
# ===Tokens:===
# ['isrg', 'pt', 'raised', '700', '640', 'leerink', 'keeps', 'outperform', 'rated']
#
#
# ===Tokens:===
# ['q1', '2010', '18', 'may', '2010', 'finnish', 'electrical', 'components', 'maker', 'salcomp', 'oy', 'hel', 'sal1v', 'said', 'today', 'turned', 'net', 'profit', 'eur1', '6', 'first', 'quarter', '2010', 'versus', 'loss', 'eur2m', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['purchase', 'agreement', '7', '200', 'tons', 'gasoline', 'delivery', 'hamina', 'terminal', 'finland', 'signed', 'neste', 'oil', 'oyj', 'average', 'platts', 'index', 'september', 'plus', 'eight', 'us', 'dollars', 'per', 'month']
#
#
# ===Tokens:===
# ['added', 'bbby', 'jimcramer', 'wrong', 'one', 'still', 'profitable', 'merchant', 'profitable', 'stores']
#
#
# ===Tokens:===
# ['reporting', 'period', 'biotie', 'north', 'american', 'licensing', 'partner', 'somaxon', 'pharmaceuticals', 'announced', 'positive', 'results', 'nalmefene', 'pilot', 'phase', '2', 'clinical', 'trial', 'smoking', 'cessation']
#
#
# ===Tokens:===
# ['production', 'capacity', 'increase', '36', '000', '85', '000', 'tonnes', 'per', 'year', 'raw', 'material', 'continue', 'recycled', 'paper', 'board']
#
#
# ===Tokens:===
# ['government', 'professional', 'approach', 'assessing', 'offer']
#
#
# ===Tokens:===
# ['onty', 'continues', 'base', 'debate', 'lingers', 'ont', '10', 'data', 'next', 'potential', 'catalyst', 'positive', 'stock', 'quickly', 'moves', '10', 'downside', 'limited']
#
#
# ===Tokens:===
# ['result', 'distribution', 'companies', 'start', 'distribute', 'addition', 'current', 'product', 'offering', 'shimano', 'reels', 'rods', 'shimano', 'fishing', 'tackle', 'products', 'exclusive', 'basis']
#
#
# ===Tokens:===
# ['gild', 'expanding', 'research', 'facilities', 'keeping', 'pace', 'innovation', 'https', 'co', 'uoe7fj4lop']
#
#
# ===Tokens:===
# ['finnish', 'pulp', 'paper', 'machinery', 'maker', 'vaahto', 'group', 'oyj', 'swung', '1', '1', 'mln', 'euro', '1', '4', 'mln', 'net', 'profit', 'fiscal', '2005', '06', 'ended', 'august', '31', '2006', '249', '000', 'euro', '319', '000', 'net', 'loss', 'fiscal', '2004', '05']
#
#
# ===Tokens:===
# ['drugmaker', 'shire', 'buy', 'baxalta', '32', 'billion', '6', 'month', 'pursuit']
#
#
# ===Tokens:===
# ['fda', 'approves', 'astrazeneca', 'iressa', 'lung', 'cancer', 'treatment']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '83', '0', 'mn', 'eur', '23', '5', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'supply', 'new', 'wood', 'handling', 'bleaching', 'lines', 'well', 'rebuild', 'kraft', 'liner', 'washing', 'line', 'klabin', 'tel', 'maco', 'borba', 'mill', 'brazilian', 'state', 'paran']
#
#
# ===Tokens:===
# ['barclays', 'bank', 'america', 'citigroup', 'blockchain', 'sight']
#
#
# ===Tokens:===
# ['savon', 'koulutuskuntayhtyma', 'finland', 'based', 'company', 'awarded', 'contract', 'specialist', 'agricultural', 'forestry', 'machinery']
#
#
# ===Tokens:===
# ['brazilian', 'unit', 'finnish', 'security', 'solutions', 'provider', 'f', 'secure', 'signed', '1', '500', 'new', 'clients', 'last', 'year', 'online', 'news', 'source', 'reseller', 'web', 'quoted', 'division', 'commercial', 'director', 'vladimir', 'brand', 'saying']
#
#
# ===Tokens:===
# ['company', 'make', 'marketing', 'sales', 'investments', 'initiated', '2009', 'even', 'efficient', '2010']
#
#
# ===Tokens:===
# ['amazon', 'grocery', 'deal', 'morrisons', 'beginning']
#
#
# ===Tokens:===
# ['axp', 'looking', 'continuation', 'volume', 'increase', 'http', 'stks', 'co', 'c8sr']
#
#
# ===Tokens:===
# ['total', 'operating', 'revenue', 'grew', '27', '6', 'year', 'year', 'eur61m']
#
#
# ===Tokens:===
# ['coh', 'gaining', 'momentum', 'nice', 'buy', 'signals', 'long', '35', '92', 'http', 'stks', 'co', 't0tah']
#
#
# ===Tokens:===
# ['md', 'henning', 'bahr', 'stockmann', 'gruppen', 'praises', 'trend', 'since', 'chains', 'become', 'stronger', 'decision', 'making', 'processes', 'clear']
#
#
# ===Tokens:===
# ['20', 'october', '2010', 'finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'yesterday', 'net', 'loss', 'narrowed', 'eur7m', 'first', 'nine', 'months', '2010', 'eur23', '3', 'period', '2009']
#
#
# ===Tokens:===
# ['svyturys', 'utenos', 'alus', 'controlled', 'nordic', 'group', 'baltic', 'beverages', 'holding', 'bbh', 'posted', '4', '7', 'per', 'cent', 'growth', 'beer', 'sales', 'january', 'may', '46', '22', 'million', 'litres']
#
#
# ===Tokens:===
# ['finnish', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'net', 'loss', 'contracted', 'eur', '49', 'million', 'usd', '68', '2', 'first', 'nine', 'months', '2010', 'eur', '229', 'million', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'consolidated', 'net', 'operating', 'profit', 'increased', 'eur', '4', '8', 'mn', 'first', 'quarter', '2005', 'eur', '6', '4', 'mn', 'first', 'quarter', '2006']
#
#
# ===Tokens:===
# ['real', 'corporation', 'press', 'release', '3', 'november', '10', '35', 'real', 'corporation', 'second', 'best', 'company', 'materials', 'sector', 'including', 'e', 'g', 'forest', 'industry', 'companies', 'carbon', 'disclosure', 'leadership', 'index', 'cdli', 'nordic', 'report', '2009']
#
#
# ===Tokens:===
# ['aapl', 'dips', 'bought', 'real', 'quick', 'higher', 'lows', 'fo', 'sho']
#
#
# ===Tokens:===
# ['lse', 'deutsche', 'boerse', 'merger', 'would', 'signal', 'end', 'exchange', 'mega', 'deals']
#
#
# ===Tokens:===
# ['save', 'breaking', 'downtrend', 'line', 'increasing', 'volume', 'move', '20', '57', 'could', 'see', 'upside', 'http', 'stks', 'co', 'l8y4']
#
#
# ===Tokens:===
# ['rcon', 'upside', 'today', 'thing', 'severe', 'low', 'float', 'catalyst', 'guy', 'run']
#
#
# ===Tokens:===
# ['eli', 'lilly', 'co', 'lly', 'broken', 'new', 'high', 'astrazeneca', 'collaboration']
#
#
# ===Tokens:===
# ['iaci', 'http', 'stks', 'co', 'tju', 'looks', 'good', 'weekly', 'chart']
#
#
# ===Tokens:===
# ['vmw', 'got', 'nice', 'push', 'today', 'following', 'small', 'sweepers', 'may', 'c', 'morning']
#
#
# ===Tokens:===
# ['teleste', 'acquisition', 'marks', 'entry', 'services', 'business', 'market', 'long', 'established', 'significant', 'supplier', 'products']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'products', 'company', 'componenta', 'oyj', 'hel', 'cth1v', 'said', 'today', 'net', 'loss', 'narrowed', 'eur', '500', '000', 'usd', '680', '000', 'last', 'quarter', '2010', 'eur', '5', '3', 'million', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'operating', 'profit', 'record', 'high', 'company', 'history']
#
#
# ===Tokens:===
# ['adp', 'news', 'oct', '29', '2008', 'finnish', 'lifting', 'equipment', 'maker', 'konecranes', 'oyj', 'omx', 'kcr1v', 'said', 'today', 'net', 'profit', 'rose', 'eur', '116', '6', 'million', 'usd', '149', '1', 'first', 'nine', 'months', '2008', 'eur', '73', '6', 'million']
#
#
# ===Tokens:===
# ['lemcon', 'signed', 'investment', 'cooperation', 'agreement', 'kaluga', 'regional', 'administration', 'last', 'november']
#
#
# ===Tokens:===
# ['operating', 'profit', 'asian', 'plants', 'grew', 'markedly']
#
#
# ===Tokens:===
# ['truly', 'takes', 'efficiency', 'new', 'heights', 'mr', 'metso', 'adds']
#
#
# ===Tokens:===
# ['january', 'september', '2007', 'group', 'net', 'sales', 'continuing', 'operations', 'rose', 'eur', '213', '1', 'mn', 'eur', '172', '6', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['transaction', 'strengthens', 'position', 'design', 'branded', 'goods', 'said', 'fiskars', 'president', 'ceo', 'heikki', 'allonen', 'pointing', 'two', 'groups', 'relatively', 'overlapping', 'operations']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '5', '5', 'mn', 'eur', '0', '7', 'mn']
#
#
# ===Tokens:===
# ['memorandum', 'understanding', 'mou', 'parties', 'collaborate', 'preparing', 'implementing', 'joint', 'projects', 'fields', 'combined', 'power', 'heat', 'generation', 'environmental', 'protection', 'energy', 'efficient', 'technologies']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['cern', 'consolidating', '50', '200', 'nice', 'long', 'entry', 'w', 'stop', '10', 'targeting', '70', 'area']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'gains', 'land', 'securities', 'dividend', 'hike']
#
#
# ===Tokens:===
# ['bbry', 'ready', 'take']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '5', '8', 'mn', 'loss', 'eur', '1', '7', 'mn', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['metso', 'supply', 'equipment', 'two', 'process', 'lines', 'northland', 'resources', 'new', 'kaunisvaara', 'iron', 'ore', 'project', 'sweden', 'exploits', 'tapuli', 'sahavaara', 'iron', 'ore', 'deposits']
#
#
# ===Tokens:===
# ['carnival', 'corporation', 'china', 'merchants', 'group', 'sign', 'memo', 'understanding']
#
#
# ===Tokens:===
# ['alma', 'media', 'expects', 'net', 'sales', 'increase', 'forecast', 'previously']
#
#
# ===Tokens:===
# ['finnish', 'metso', 'paper', 'order', 'supply', 'uncoated', 'fine', 'paper', 'machine', 'mcc', 'paper', 'yinhe', 'china']
#
#
# ===Tokens:===
# ['operating', 'profit', 'rose', 'eur', '1', '94', 'mn', 'eur', '2', '45', 'mn']
#
#
# ===Tokens:===
# ['diluted', 'loss', 'per', 'share', 'stood', 'eur', '0', '15', 'versus', 'eur', '0', '26']
#
#
# ===Tokens:===
# ['3', 'january', '2011', 'finnish', 'flag', 'carrier', 'finnair', 'oyj', 'hel', 'fia1s', 'said', 'today', 'sealed', 'nine', 'year', 'sale', 'leaseback', 'agreement', 'newest', 'airbus', 'a330', 'aircraft', 'syndication', 'japanese', 'operating', 'lease', 'market']
#
#
# ===Tokens:===
# ['auto', 'trader', 'share', 'price', 'surges', 'company', 'floats', 'lse']
#
#
# ===Tokens:===
# ['company', 'said', 'estimates', 'make', 'slight', 'profit', 'thanks', 'cost', 'cutting', 'measures']
#
#
# ===Tokens:===
# ['aapl', 'taking', 'shorts', 'punishing', 'reminder', 'spear', 'strongest', 'herd']
#
#
# ===Tokens:===
# ['raute', 'posted', 'net', 'profit', '1', '8', 'mln', 'euro', '2', '6', 'mln', 'third', 'quarter', '2007', 'compared', 'net', 'loss', '299', '000', 'euro', '430', '000', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['yahoo', 'stock', '36', '46', 'bidding', 'war', 'picks', 'company', 'https', 'co', 'jdnzxdcmkl', 'yhoo', 'https', 'co', 'hmoegfhgvn']
#
#
# ===Tokens:===
# ['company', 'still', 'expects', 'turnover', '2010', 'slightly', 'increase', 'level', '2009', 'adding', 'market', 'predictability', 'still', 'poor', 'trustworthy', 'forecasts', 'market', 'development', 'contract', 'manufacturing', 'business', 'current', 'year']
#
#
# ===Tokens:===
# ['goog', 'breakout', 'likely', 'medium', 'target', '700', 'http', 'stks', 'co', '1lpz', 'http', 'chart', 'ly', 'lgb94rr']
#
#
# ===Tokens:===
# ['singapore', 'icis', '1', 'kemira', 'indian', 'water', 'infrastructure', 'firm', '2', 'ivrcl', 'agreed', 'form', 'join', 'venture', 'includes', 'new', 'inorganic', 'coagulant', 'manufacturing', 'facility', 'andhra', 'pradesh', 'state', 'india', 'finnish', 'water', 'treatment', 'chemicals', 'maker', 'said', 'tuesday']
#
#
# ===Tokens:===
# ['goog', 'testing', '200', 'day', 'consolidation', 'http', 'stks', 'co', 'h0cpj']
#
#
# ===Tokens:===
# ['prlb', 'hanging', 'tough', 'market', 'due', 'analyst', 'upgrades', 'last', 'week', 'almost', '3']
#
#
# ===Tokens:===
# ['energy', 'efficient', 'data', 'center', 'built', 'combining', 'effective', 'energy', 'solution', 'state', 'art', 'technology']
#
#
# ===Tokens:===
# ['entering', 'long', 'lockheed', 'martin', 'lmt', 'thursday', 'open', 'http', 'stks', 'co', 'exta']
#
#
# ===Tokens:===
# ['company', 'order', 'book', 'stood', '1', '5', 'bln', 'euro', '2', '2', 'bln', 'september', '30', '2007', '24', '2', 'pct', 'year', 'international', 'orders', 'amounting', '365', 'mln', 'euro', '534', '3', 'mln']
#
#
# ===Tokens:===
# ['aim', 'ensure', 'vacon', 'good', 'shape', 'capital', 'expenditure', 'starts', 'pick', 'comments', 'vacon', 'plc', 'president', 'ceo', 'vesa', 'laisi']
#
#
# ===Tokens:===
# ['two', 'companies', 'also', 'partner', 'developing', 'raiso', 'cholesterol', 'lowering', 'brand', 'benecol']
#
#
# ===Tokens:===
# ['nyse', 'owner', 'ice', 'considers', 'offer', 'lse']
#
#
# ===Tokens:===
# ['astrazeneca', 'bags', 'another', 'cancer', 'drug', 'deal', 'time', 'inovio']
#
#
# ===Tokens:===
# ['adbe', 'technical', 'alerts', 'expansion', 'breakout', 'gilligan', 'island', 'sell', 'setup', 'volume', 'surge', 'new', '52', 'https', 'co', 'lxx66tknfh']
#
#
# ===Tokens:===
# ['change', 'optimize', 'operational', 'efficiencies', 'growing', 'business', 'said', 'julia', 'prohaska', 'director', 'marketing', 'communications', 'fiskars']
#
#
# ===Tokens:===
# ['ebit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '67', '8', 'mn', 'eur', '38', '1', 'mn']
#
#
# ===Tokens:===
# ['finland', 'national', 'carrier', 'finnair', 'plc', 'carried', 'record', '8', '5', 'million', 'passengers', '2005', 'increase', '4', '5', 'percent', 'previous', 'year', 'airline', 'reported', 'tuesday']
#
#
# ===Tokens:===
# ['fb', 'trending', 'nicely', 'intraday']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'group', 'life', 'insurance', 'business', 'increased', 'eur36m', 'eur27m']
#
#
# ===Tokens:===
# ['last', 'week', 'finnish', 'metals', 'technology', 'group', 'announced', 'plans', 'sell', '80', 'percent', 'technology', 'unit', 'company', 'strategic', 'goal', 'becoming', 'world', 'largest', 'stainless', 'steel', 'maker']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'raises', 'prospect', 'investor', 'payout']
#
#
# ===Tokens:===
# ['satama', 'earned', 'data', 'management', 'solutions', 'competency', 'business', 'intelligence', 'specialization', 'recentlyvia', 'acquisition', 'fimentor', 'oy']
#
#
# ===Tokens:===
# ['spain', 'caixabank', 'launches', 'new', 'takeover', 'bid', 'banco', 'bpi']
#
#
# ===Tokens:===
# ['gild', 'chart', 'ibb', 'back', 'support', 'https', 'co', 'gprz2ujfc4']
#
#
# ===Tokens:===
# ['ebit', 'totalled', 'eur', '14', '4', 'mn', 'compared', 'loss', 'eur', '0', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['stora', 'enso', 'r', 'shares', 'rose', '1', '20', 'pct', '11', '84', 'eur', 'upm', 'kymmene', 'also', 'dragged', 'higher', 'rising', '1', '68', 'pct', '17', '56', 'eur', 'real', 'b', 'added', '2', '38', 'pct', '4', '30', 'eur']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'amounted', 'ee', '55', '5', 'mn', '36', '2004']
#
#
# ===Tokens:===
# ['press', 'serco', 'set', 'appoint', 'roy', 'gardner', 'ex', 'centrica', 'chairman', 'ft']
#
#
# ===Tokens:===
# ['aapl', 'downgrade', 'bias', 'stock', 'buy']
#
#
# ===Tokens:===
# ['aapl', 'new', 'long', '110', '61', 'broken', 'targets', '112', '19', '119', '86', '123', '82', 'bears', 'must', 'retake', '102', '77', 'qqq', 'nq', 'f', 'ndx', 'https', 'co', '6l3m1wxchw']
#
#
# ===Tokens:===
# ['retailers', 'kingfisher', 'sports', 'direct', 'rise', 'britain', 'share', 'index']
#
#
# ===Tokens:===
# ['bought', 'celg', 'ready', 'bounce']
#
#
# ===Tokens:===
# ['aim', 'convert', 'plants', 'flexible', 'manufacturers', 'new', 'technologically', 'demanding', 'products']
#
#
# ===Tokens:===
# ['arm', 'profits', 'sales', 'shift', 'away', 'mobile', 'gains', 'pace']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'rose', 'eur', '1', '019', 'mn', 'eur', '1', '007', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['tesco', 'leads', 'ftse', 'higher', 'clubcard', 'bid', 'reports']
#
#
# ===Tokens:===
# ['update', '1', 'astrazeneca', 'sells', 'rare', 'cancer', 'drug', 'sanofi', '300', 'mln']
#
#
# ===Tokens:===
# ['mako', 'hanging', 'well', 'today', 'still', 'basing', 'pattern', 'eyes']
#
#
# ===Tokens:===
# ['helsinki', 'afx', 'metso', 'said', 'upgrade', 'one', 'upm', 'kymmene', 'four', 'paper', 'machines', 'latter', 'mill', 'jaemsaenkoski', 'new', 'coating', 'color', 'supply', 'system', 'machine', 'process', 'controls', 'quality', 'measurements']
#
#
# ===Tokens:===
# ['contract', 'demonstrates', 'ability', 'apply', 'minerals', 'metals', 'technologies', 'adjacent', 'industries', 'oil', 'shale', 'processing']
#
#
# ===Tokens:===
# ['brooklynbandit', 'simo', 'basing', 'nice', 'close', '24', '18', 'bullish', 'qqq', 'spy', 'study', 'watch', 'close', 'near', 'hod', 'currently', '3', '5']
#
#
# ===Tokens:===
# ['alert', 'new', 'macd', 'signal', 'created', 'ctxs', 'buy', '77', '09', 'time', '18', '23', 'strength', '10', 'powered', 'https', 'co', '4tdgjedllz']
#
#
# ===Tokens:===
# ['resulted', 'improved', 'sales', 'figures', 'sweden']
#
#
# ===Tokens:===
# ['tectia', 'corporation', 'hel', 'tec1v', 'provider', 'real', 'time', 'security', 'solutions', 'today', 'announced', 'appointed', 'lan2lan', 'provider', 'services', 'uk', 'distribute', 'data', 'security', 'manage', 'file', 'transfer', 'software']
#
#
# ===Tokens:===
# ['long', 'aapl']
#
#
# ===Tokens:===
# ['ino', 'back', 'small', 'post']
#
#
# ===Tokens:===
# ['helsinki', 'eliiv', 'today', 'reported', 'eps', 'eur1', '13', '2009', 'increase', 'eps', 'eur1', '12', '2008']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'oyj', 'said', 'november', '13', '2007', '70', 'mln', 'euro', '102', '8', 'mln', 'contract', 'construct', 'new', 'office', 'building', 'local', 'property', 'company', 'tapiola', 'real', 'estate', 'oy']
#
#
# ===Tokens:===
# ['shorts', 'altr', '38', '85', 'loss']
#
#
# ===Tokens:===
# ['2nd', 'raise', 'year', 'bvhealthcare', 'qcor', 'questcor', 'increases', 'quarterly', 'cash', 'dividend', '20', 'percent', 'http', 'stks', 'co', 'goan']
#
#
# ===Tokens:===
# ['combining', 'existing', 'solutions', 'single', 'platform', 'comptel', 'said', 'reduced', 'cost', 'deployment']
#
#
# ===Tokens:===
# ['neon', 'oversold']
#
#
# ===Tokens:===
# ['third', 'quarter', '2010', 'net', 'sales', 'increased', '5', '2', 'eur', '205', '5', 'mn', 'operating', 'profit', '34', '9', 'eur', '23', '5', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'long', '630', '91']
#
#
# ===Tokens:===
# ['pioneer', 'library', 'system', 'one', '127', 'libraries', 'municipalities', 'arts', 'culture', 'higher', 'education', 'science', 'organizations', 'awarded', 'grants', 'participate', 'big', 'read', 'largest', 'federal', 'reading', 'program', 'u', 'history']
#
#
# ===Tokens:===
# ['financing', 'arrangements', 'enable', 'company', 'ensure', 'line', 'treasury', 'policy', 'sufficient', 'financial', 'instruments', 'disposal', 'potential', 'capital', 'requirements']
#
#
# ===Tokens:===
# ['operating', 'income', 'rose', 'eur', '696', '4', 'mn', 'eur', '600', '3', 'mn', '2009']
#
#
# ===Tokens:===
# ['rt', 'andrewnyquist', 'chartology', 'yahoo', 'http', 'stks', 'co', '1itr', 'yhoo', 'crazy', 'looking', 'chart', 'nearing', 'breakout', 'resistance', 'line']
#
#
# ===Tokens:===
# ['sainsbury', 'sells', 'unit', 'lloydspharmacy']
#
#
# ===Tokens:===
# ['liking', 'price', 'action', 'swks', 'currently', '21', '80', 'target', '24', '00', 'year', 'end']
#
#
# ===Tokens:===
# ['group', 'expand', 'chain', 'include', '45', 'stores']
#
#
# ===Tokens:===
# ['finnish', 'consulting', 'engineering', 'group', 'poyry', 'plc', 'omx', 'helsinki', 'poy', 'said', 'wednesday', '1', 'october', 'awarded', 'contract', 'tanqia', 'dibba', 'fzc', 'owner', 'engineer', 'wastewater', 'system', 'dibba', 'emirate', 'fujairah', 'uae']
#
#
# ===Tokens:===
# ['trend', 'underpins', 'uk', 'sales', 'growth', 'kingfisher']
#
#
# ===Tokens:===
# ['lee', 'man', 'paper', 'metso', 'long', 'prosperous', 'co', 'operation', 'good', 'example', 'changshu', 'hongmei', 'kraftliner', 'machines', 'delivered', 'earlier']
#
#
# ===Tokens:===
# ['ibm', 'staying', 'strong']
#
#
# ===Tokens:===
# ['open', 'next', 'year', 'largest', 'facility', 'world', 'produce', 'diesel', 'fuel', 'renewable', 'feedstock', 'palm', 'oil', 'animal', 'fat']
#
#
# ===Tokens:===
# ['turun', 'kaupunkin', 'finland', 'based', 'company', 'awarded', 'contract', 'lemminkainen', 'talotekniikka', 'oy', 'electrical', 'installation', 'work']
#
#
# ===Tokens:===
# ['revenue', 'grew', '12', 'percent', 'x20ac', '3', '6', 'billion', 'us', '4', '5', 'billion']
#
#
# ===Tokens:===
# ['royal', 'dutch', 'shell', 'buy', 'bg', 'group', 'nearly', '70', 'billion']
#
#
# ===Tokens:===
# ['estonia', 'beer', 'market', 'overall', 'grew', 'three', 'percent', 'last', 'year', '130', 'million', 'liters']
#
#
# ===Tokens:===
# ['eps', 'continuing', 'operations', 'came', '0', '30', 'eur', '0', '17']
#
#
# ===Tokens:===
# ['stable', 'outlook', 'reflects', 'nokia', 'strong', 'market', 'position', 'global', 'mobile', 'handset', 'market', 'strong', 'cash', 'flow', 'generation', 'conservative', 'balance', 'sheet', 'said', 'raab']
#
#
# ===Tokens:===
# ['whitbread', 'share', 'price', 'climbs', 'q4', 'sales', 'growth']
#
#
# ===Tokens:===
# ['financial', 'impact', 'estimated', 'annual', 'improvement', 'eur2', '0', 'division', 'results', 'fiscal', 'year', '2008']
#
#
# ===Tokens:===
# ['kndi', 'let', 'see', 'higher', 'highs', 'higher', 'lows', 'rest', 'day', 'slow', 'steady']
#
#
# ===Tokens:===
# ['adp', 'news', 'finnish', 'handling', 'systems', 'provider', 'cargotec', 'oyj', 'hel', 'cgcbv', 'announced', 'friday', 'orders', 'worth', 'eur', '10', 'million', 'usd', '13', '2', 'deliver', 'linkspans', 'jordan', 'morocco', 'ireland']
#
#
# ===Tokens:===
# ['continued', 'actively', 'focus', 'r', 'position', 'offering', 'away', 'point', 'solutions', 'towards', 'dynamic', 'end', 'end', 'solutions', 'ervio', 'stated']
#
#
# ===Tokens:===
# ['sports', 'equipment', 'sales', 'also', 'progressed', 'well', 'owing', 'prolonged', 'winter', 'season']
#
#
# ===Tokens:===
# ['transaction', 'positive', 'impact', 'around', 'eur2m', 'earnings', 'ruukki', 'recognize', 'fourth', 'quarter', 'year']
#
#
# ===Tokens:===
# ['kesko', 'car', 'import', 'retailing', 'business', 'vv', 'auto', 'saw', 'sales', 'grow', '17', '1', 'pct']
#
#
# ===Tokens:===
# ['insight', 'hires', 'aviva', 'david', 'hillier', 'multi', 'asset', 'team']
#
#
# ===Tokens:===
# ['news', 'feedftse', '100', 'movers', 'ashtead', 'jumps', 'strong', 'interims', 'glencore', 'bp']
#
#
# ===Tokens:===
# ['main', 'strength', 'cooperation', 'project', 'lies', 'merging', 'know', 'two', 'large', 'companies']
#
#
# ===Tokens:===
# ['company', 'also', 'featured', 'ethibel', 'pioneer', 'investment', 'register', 'included', 'innovest', 'global', '100', 'list', 'world', 'sustainable', 'corporations']
#
#
# ===Tokens:===
# ['london', 'morning', 'briefing', 'hsbc', 'standard', 'chartered', 'shares', 'rise']
#
#
# ===Tokens:===
# ['company', 'net', 'profit', 'rose', '11', '4', 'year', '82', '2', 'million', 'euros', '2005', 'sales', '686', '5', 'million', 'euros', '13', '8', 'year', 'company', 'said', 'earlier']
#
#
# ===Tokens:===
# ['tsla', 'bad', 'day', 'short']
#
#
# ===Tokens:===
# ['objective', 'planned', 'measures', 'achieve', 'significant', 'savings', 'next', 'years']
#
#
# ===Tokens:===
# ['update', '3', 'auto', 'trader', 'shares', 'leap', 'uk', 'biggest', 'private', 'equity', 'backed', 'listing']
#
#
# ===Tokens:===
# ['besides', 'increased', 'share', 'meat', 'various', 'sausages', 'offering', 'number', 'new', 'tastes', 'grill', 'products', 'shish', 'kebabs', 'segment', 'paavel', 'said']
#
#
# ===Tokens:===
# ['ftse', 'rallies', 'three', 'month', 'low', 'boosted', 'stanchart', 'sainsbury']
#
#
# ===Tokens:===
# ['aria', 'bounce', 'player', 'long', '6', '17', 'http', 'stks', 'co', 'q0wff']
#
#
# ===Tokens:===
# ['consolidated', 'operating', 'profit', 'excluding', 'one', 'items', 'eur', '30', '6', 'mn', 'eur', '29', '6', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bullya', 'pollux654321', '50', 'kors', '80', 'calls', 'going', 'b', 'blessing', 'daughters', 'tuition']
#
#
# ===Tokens:===
# ['according', 'sepp', 'nen', 'new', 'technology', 'umts900', 'solution', 'network', 'building', 'costs', 'one', 'third', 'lower', 'building', '3', '5', 'g', 'networks', 'operating', '2', '100', 'mhz', 'frequency']
#
#
# ===Tokens:===
# ['crus', 'upgraded', 'buy', 'alpha', 'street', 'research']
#
#
# ===Tokens:===
# ['favourable', 'currency', 'rates', 'also', 'contributed', 'higher', 'net', 'sales', 'ceo', 'kari', 'kauniskangas', 'said']
#
#
# ===Tokens:===
# ['tesco', 'breaks', 'downward', 'slide', 'cutting', 'sales', 'decline', 'half']
#                              0   1
# 0                 http stks co  73
# 1      mn corresponding period  24
# 2              profit rose eur  23
# 3            first nine months  20
# 4        operating profit rose  19
# ...                        ...  ..
# 15271    breaks downward slide   1
# 15272   downward slide cutting   1
# 15273      slide cutting sales   1
# 15274    cutting sales decline   1
# 15275       sales decline half   1
#
# [15276 rows x 2 columns]

# %%
for text in train_set[train_set['Sentiment']=='negative']['Sentence']:
    for word in generate_ngrams(text, 3):
        negativeWords_tri[word]+=1
df_negative_tri = pd.DataFrame(sorted(negativeWords_tri.items(),key=lambda x:x[1],reverse=True))
df_negative_tri
# Out:
# ===Tokens:===
# ['tesco', 'asda', 'sales', 'fall', 'march', 'discounters', 'continues', 'kantar']
#
#
# ===Tokens:===
# ['stores', '16', 'march', '2010', 'finnish', 'stationery', 'gift', 'retailer', 'tiimari', 'hel', 'tii1v', 'said', 'yesterday', 'cut', 'total', '28', 'jobs', 'units', 'tiimari', 'retail', 'ltd', 'gallerix', 'finland', 'ltd', 'result', 'closure', 'shops']
#
#
# ===Tokens:===
# ['adpnews', 'feb', '5', '2010', 'finnish', 'real', 'estate', 'investor', 'sponda', 'oyj', 'hel', 'sda1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur', '81', '5', 'million', 'usd', '11', '8', '2009', 'profit', 'eur', '29', '3', 'million', '2008']
#
#
# ===Tokens:===
# ['reed', 'elsevier', 'share', 'price', 'slides', 'underwhelming', 'full', 'year', 'results']
#
#
# ===Tokens:===
# ['potential', 'defect', 'third', 'row', 'seat', 'belts', 'tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'yvydncdndi']
#
#
# ===Tokens:===
# ['making', 'matters', 'difficult', 'company', 'said', 'grappling', 'higher', 'oil', 'gas', 'prices', 'pushed', 'cost', 'energy', 'raw', 'materials', 'transportation']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '38', '1', 'mn', 'eur', '55', '3', 'mn', '2007']
#
#
# ===Tokens:===
# ['standard', 'chartered', 'lags', 'capital', 'worries']
#
#
# ===Tokens:===
# ['update', '1', 'bhp', 'billiton', 'credit', 'ratings', 'fragile', 'fy16', 'agencies', 'warn']
#
#
# ===Tokens:===
# ['qcor', 'little', 'pullback', 'fine', 'erases', 'todays', 'gains', 'believe', 'manipulation', 'capable']
#
#
# ===Tokens:===
# ['gmcr', 'way', 'acting', 'may', 'fall', '65', 'today', 'horrible', 'action', 'since', 'hit', '70', 'yesterday']
#
#
# ===Tokens:===
# ['asian', 'traffic', 'declined', '3', '4', 'per', 'cent']
#
#
# ===Tokens:===
# ['petrofac', 'books', '30m', 'cost', 'shetland', 'gas', 'terminal', 'delays']
#
#
# ===Tokens:===
# ['saudi', 'aramco', 'shell', 'plan', 'break', 'motiva', 'divide', 'assets']
#
#
# ===Tokens:===
# ['update', '3', 'bp', 'settles', 'oil', 'spill', 'related', 'claims', 'halliburton', 'transocean']
#
#
# ===Tokens:===
# ['locked', 'fb', 'puts', 'nice', 'gain']
#
#
# ===Tokens:===
# ['external', 'net', 'sales', 'printing', 'business', 'fell', '43', '7', 'partly', 'due', 'termination', 'printing', 'contract', 'ilkka', 'yhtyma', 'printing', 'house', 'print', 'oy', 'sector', 'player', 'hss', 'media', 'ab', 'december', '2009', 'fall', 'printing', 'prices']
#
#
# ===Tokens:===
# ['air', 'traffic', 'finland', 'stoppage', 'since']
#
#
# ===Tokens:===
# ['airline', 'estimated', 'cancellation', 'flights', 'due', 'closure', 'european', 'airspace', 'process', 'recommencing', 'traffic', 'caused', 'company', 'loss', 'eur20m', 'including', 'costs', 'stranded', 'passengers', 'accommodation']
#
#
# ===Tokens:===
# ['cargo', 'traffic', 'fell', '1', 'year', 'year', '8', '561', 'tonnes', 'september', '2009']
#
#
# ===Tokens:===
# ['however', 'net', 'sales', 'declined', 'eur', '803', '6', 'million', 'eur', '1', '2', 'billion']
#
#
# ===Tokens:===
# ['also', 'construction', 'expenses', 'gone', 'russia']
#
#
# ===Tokens:===
# ['raute', 'reported', 'loss', 'per', 'share', 'eur0', '86', 'first', 'half', '2009', 'eps', 'eur0', '74', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['glencore', 'slumps', '25', 'pct', 'debt', 'fears', 'grow']
#
#
# ===Tokens:===
# ['pharmaceuticals', 'group', 'orion', 'corp', 'reported', 'fall', 'third', 'quarter', 'earnings', 'hit', 'larger', 'expenditures', 'r', 'marketing']
#
#
# ===Tokens:===
# ['implementation', 'programs', 'negative', 'impacts', '2006', '2007', 'earnings', 'mr', 'meiklejohn', 'said']
#
#
# ===Tokens:===
# ['dismissed', 'staff', 'members', 'take', 'matter', 'court', 'unless', 'settled', 'outside']
#
#
# ===Tokens:===
# ['diageo', 'receives', 'reports', 'united', 'spirits', 'financial', 'irregularities', 'involving']
#
#
# ===Tokens:===
# ['small', 'investors', 'voiced', 'fears', 'shares', 'end', 'risk', 'investors']
#
#
# ===Tokens:===
# ['xlb', 'weakest', 'sector', 'year', 'possible', 'false', 'breakout', 'http', 'stks', 'co', 'dl1z']
#
#
# ===Tokens:===
# ['furthermore', 'sales', 'new', 'passenger', 'cars', 'light', 'commercial', 'vehicles', 'country', 'declined', '5', '4', 'year', 'year', 'last', 'month']
#
#
# ===Tokens:===
# ['british', 'american', 'tobacco', 'first', 'half', 'sales', 'hurt', 'currency', 'moves']
#
#
# ===Tokens:===
# ['measures', 'result', 'weak', 'demand', 'shipbuilding', 'industry']
#
#
# ===Tokens:===
# ['deutsche', 'bank', 'downgrades', 'starbucks', 'new', 'loyalty', 'program', 'https', 'co', 'iy4lcugabc', 'sbux']
#
#
# ===Tokens:===
# ['17', 'march', '2011', 'goldman', 'sachs', 'estimates', 'negative', 'prospects', 'norwegian', 'mobile', 'operations', 'norway', 'telenor', 'asa', 'osl', 'tel', 'sweden', 'teliasonera', 'ab', 'sto', 'tlsn', 'short', 'term']
#
#
# ===Tokens:===
# ['plug', 'bear', 'raid']
#
#
# ===Tokens:===
# ['scanfil', 'systems', 'supplier', 'contract', 'manufacturer', 'communications', 'sector', 'give', 'notice', '20', 'productional', 'employees', 'temporarily', 'lay', '15', 'employees', 'company', 'plant', 'sievi', 'finland']
#
#
# ===Tokens:===
# ['breaking', 'tesla', 'recalls', 'model', 'x', 'cars', 'details', 'show', 'tsla']
#
#
# ===Tokens:===
# ['2009', '3', 'february', '2010', 'finland', 'based', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'slipped', 'larger', 'expected', 'pretax', 'loss', 'eur46m', 'fourth', 'quarter', '2009', 'year', 'earlier', 'profit', 'eur45m']
#
#
# ===Tokens:===
# ['workforce', 'reduced', 'also', 'amsterdam', 'office', 'netherlands']
#
#
# ===Tokens:===
# ['fastenal', 'misses', '0', '01', 'misses', 'revenue', 'fast', 'nyse', 'https', 'co', '63jhq7pwmn']
#
#
# ===Tokens:===
# ['bbry', 'actually', 'lost', '03c', 'per', 'share', 'u', 'incl', 'vz', 'debt', '3', '1', 'cash']
#
#
# ===Tokens:===
# ['ramirent', 'made', '18', 'million', 'kroons', 'eur', '1', '15', 'mln', 'loss', 'last', 'year', 'year', 'company', '7', '3', 'million', 'kroons', 'black']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'recent', 'quarter', 'also', 'reached', 'eight', 'year', 'low']
#
#
# ===Tokens:===
# ['lloyds', 'cut', '945', 'jobs', 'part', 'three', 'year', 'restructuring', 'strategy']
#
#
# ===Tokens:===
# ['however', 'rapidly', 'increasing', 'costs', 'strengthening', 'euro', 'challenging', 'whole', 'industry', 'impacted', 'results']
#
#
# ===Tokens:===
# ['optimistic', 'amzn', 'fundementals', 'charts', 'look', 'like', 'poopoo', 'quarter']
#
#
# ===Tokens:===
# ['belarus', 'oao', 'lidskoe', 'pivo', 'brewery', 'based', 'grodno', 'region', 'reported', '1', '1', 'decrease', 'output', '1', '045', 'million', 'decaliters', 'january', 'march', '2010', 'representative', 'administration', 'company', 'told']
#
#
# ===Tokens:===
# ['profit', 'period', 'totalled', 'eur', '1', '1', 'mn', 'eur', '1', '6', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['finnish', 'forest', 'industry', 'group', 'stora', 'enso', 'oyj', 'issued', 'thursday', '20', 'march', 'profit', 'warning', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['pcln', 'back', 'back', 'intraday', 'reversals', 'look', 'shorts', 'moving']
#
#
# ===Tokens:===
# ['legal', 'general', 'share', 'price', 'finance', 'chief', 'step']
#
#
# ===Tokens:===
# ['tsla', 'wish', 'puts', 'back', 'see', 'find', 'support', 'around', '243', '39', 'pop', 'get', 'back', 'https', 'co', 'hfklq3wobv']
#
#
# ===Tokens:===
# ['23', 'april', '2010', 'finnish', 'construction', 'engineering', 'company', 'outotec', 'oyj', 'hel', 'ote1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur7', '3', 'first', 'quarter', '2010', 'net', 'profit', 'eur12', '5', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['sweden', 'oversupply', 'pharmacies']
#
#
# ===Tokens:===
# ['hk', 'jan', 'sinking', 'ship']
#
#
# ===Tokens:===
# ['micron', 'technology', 'inc', 'nasdaq', 'mu', '2', '3', 'today', '8', '9', 'since', 'put', 'short', 'https', 'co', 'eqqltfuiou']
#
#
# ===Tokens:===
# ['scanfil', 'execute', 'temporary', 'lay', 'offs', 'mid', 'october', '2009', 'job', 'cuts', 'march', '2010']
#
#
# ===Tokens:===
# ['berkshire', 'discloses', 'unit', 'ties', 'iran', 'opens', 'probe']
#
#
# ===Tokens:===
# ['rnn', 'bleeding', 'monday']
#
#
# ===Tokens:===
# ['british', 'american', 'tobacco', 'drops', 'sues', 'pwc', 'pollution', 'scandal']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'declined', 'eur', '0', '78', 'eur', '1', '76']
#
#
# ===Tokens:===
# ['3rd', 'red', 'day', 'row', 'tsla']
#
#
# ===Tokens:===
# ['result', 'taxes', 'decreased', 'nearly', 'eur', '14', '5', 'mn', 'compared', 'nearly', 'eur', '20mn', 'previous', 'accounting', 'period']
#
#
# ===Tokens:===
# ['l', 'g', 'still', 'paying', 'price', 'dividend', 'cut', 'crisis', 'chief', 'says']
#
#
# ===Tokens:===
# ['55', 'workers', 'l', 'affected', 'close']
#
#
# ===Tokens:===
# ['operating', 'profit', '12', 'month', 'period', 'decreased', 'eur17', '9', 'net', 'sales', 'increased', 'eur58', '3', 'compared', '2007']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '10', '5', 'january', 'sales', 'outside', 'finland', 'dropped', '17']
#
#
# ===Tokens:===
# ['finnish', 'sports', 'equipment', 'company', 'amer', 'sports', 'said', 'decided', 'lay', '370', 'workers', 'salomon', 'division', 'france']
#
#
# ===Tokens:===
# ['building', 'home', 'improvement', 'trade', 'sales', 'decreased', '6', '3', 'totalling', 'eur', '154', '1', 'mn']
#
#
# ===Tokens:===
# ['altogether', 'finnair', 'canceled', '500', 'flights', 'strike']
#
#
# ===Tokens:===
# ['contracts', 'employees', '96', 'blue', 'collar', 'workers', 'ended', 'march', 'august', '2011']
#
#
# ===Tokens:===
# ['liquidity', 'providing', 'interrupted', 'may', '11', '2007', 'aspocomp', 'group', 'oyj', 'shares', 'traded', '0', '50', 'cent', 'aspocomp', 'stock', 'exchange', 'release', '11', '5', '2007']
#
#
# ===Tokens:===
# ['net', 'cash', 'operating', 'activities', 'negative', 'eur', '0', '3', 'mn', 'compared', 'eur', '30', '9', 'mn', '2009']
#
#
# ===Tokens:===
# ['tsla', 'recall', '2', '700', 'model', 'x', 'suvs', 'seat', 'belt', 'fix']
#
#
# ===Tokens:===
# ['sales', 'mid', 'strength', 'beer', 'decreased', '40']
#
#
# ===Tokens:===
# ['situation', 'coated', 'magazine', 'printing', 'paper', 'continue', 'weak']
#
#
# ===Tokens:===
# ['intertek', 'swings', '347', 'mln', 'loss', 'oil', 'slump']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'decreased', 'eur', '6', '2', 'mn', 'eur', '16', '8', 'mn', '2007', 'representing', '2', '3', 'net', 'sales']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', '9', 'eur', '187', '8', 'mn', 'first', 'nine', 'months', '2008', 'compared', 'eur', '207', '1', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['bad', 'idea', 'make', '5', 'min', 'predictions', 'based', 'faith', 'rt', 'dandyduct', 'aapl', 'sell', 'signal', 'hit', '584', 'go', 'next', '5', 'min']
#
#
# ===Tokens:===
# ['operating', 'loss', 'increased', 'eur', '17mn', 'loss', 'eur', '10', '8', 'mn', '2005']
#
#
# ===Tokens:===
# ['finland', 'sampo', 'bank', 'part', 'danske', 'bank', 'group', 'lay', 'staff', 'administrative', 'support', 'functions']
#
#
# ===Tokens:===
# ['result', '12', 'people', 'made', 'redundant', 'total', '67', 'persons', 'laid', 'temporarily']
#
#
# ===Tokens:===
# ['apple', 'breaks', 'major', 'support', 'levels', 'watch', 'http', 'stks', 'co', 'jrmw', 'aapl', 'qqq']
#
#
# ===Tokens:===
# ['sainsbury', 'asda', 'tesco', 'morrisons', 'cut', 'petrol', 'prices', 'oil', 'falls']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '8', 'mn', 'compared', 'profit', 'eur', '3', '9', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operations', 'january', 'december', '2008', 'negative', 'eur', '18', '1', 'mn', 'compared', 'eur', '39', '0', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['july', 'september', '2009', 'konecranes', 'sales', 'decreased', 'eur', '368', '7', 'mn', 'eur', '520', '4', 'mn', 'july', 'september', '2008']
#
#
# ===Tokens:===
# ['nq', 'got', 'hit', 'hard', 'lower', 'looks', 'like', 'found', 'support', '18', '89', 'http', 'stks', 'co', 's052z']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'wood', 'products', 'technology', 'supplier', 'raute', 'oyj', 'hel', 'rutav', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '4', '7', 'million', 'usd', '6', '1', '2008', 'eur', '6', '6', 'million', '2007']
#
#
# ===Tokens:===
# ['micron', 'shares', 'pounded', 'fears', 'loss', 'business', 'apple', 'stifel', 'defends', 'aapl', 'mu', 'http', 'stks', 'co', 't1z8t', 'marjo']
#
#
# ===Tokens:===
# ['sainsbury', 'sales', 'slip', 'price', 'pressures', 'take', 'toll']
#
#
# ===Tokens:===
# ['renn', 'topping', 'tail', '5', 'min', 'chart', '7', '31', 'short']
#
#
# ===Tokens:===
# ['aapl', 'near', '3', 'drop', 'thats', 'lot', 'best', 'hold', 'er', 'lol']
#
#
# ===Tokens:===
# ['amzn', 'rejected', '604', 'penny', 'weak', 'open', 'goes', 'r', 'g', 'within', 'first', '30', 'mins', 'could', '8', '10', 'points', 'https', 'co', '58teaexxpe']
#
#
# ===Tokens:===
# ['diageo', 'sales', 'disappoint', 'currency', 'comparatives', 'leave', 'bitter', 'taste']
#
#
# ===Tokens:===
# ['royal', 'mail', 'chairman', 'donald', 'brydon', 'set', 'step']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '7', 'mn', 'compared', 'profit', 'eur', '0', '8', 'mn', 'second', 'quarter', '2005']
#
#
# ===Tokens:===
# ['cash', 'flow', 'investments', 'amounted', 'eur45m', 'eur46m']
#
#
# ===Tokens:===
# ['addition', '29', 'employees', 'laid', 'notice', 'whole', 'workforce', 'laid', 'short', 'periods', 'needed']
#
#
# ===Tokens:===
# ['nokia', 'siemens', 'networks', 'struggled', 'make', 'profit', 'past', 'two', 'years']
#
#
# ===Tokens:===
# ['aapl', 'aapl', 'gundlach', 'slams', 'ipad', 'mini', 'sees', 'downside', '425', 'http', 'stks', 'co', 'bdqv']
#
#
# ===Tokens:===
# ['tesco', 'criticised', 'disgraceful', 'advert', 'showing', 'domestic', 'worker', 'slapped']
#
#
# ===Tokens:===
# ['fb', 'rejecting', 'highs', 'shortable', '109']
#
#
# ===Tokens:===
# ['naturalgas', 'settles', '3', 'year', 'low', 'dbo', 'bno', 'http', 'stks', 'co', 'd27qx']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'eur1', '37', 'eur2', '30']
#
#
# ===Tokens:===
# ['fb', 'still', 'dog', 'going', 'much', 'lower', 'week']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'nearly', 'eur', '1', '7', 'mn', 'however']
#
#
# ===Tokens:===
# ['finnair', 'believes', 'strike', 'cause', 'daily', 'net', 'losses', 'excess', 'eur', '2mn', 'due', 'canceled', 'reservations', 'passenger', 'routing']
#
#
# ===Tokens:===
# ['operating', 'profit', '2009', 'lower', 'outlook', 'published', 'earlier']
#
#
# ===Tokens:===
# ['bobe', '2', '84', 'premarket']
#
#
# ===Tokens:===
# ['total', '140', 'jobs', 'reduced', 'raahe', 'steel', 'works']
#
#
# ===Tokens:===
# ['sales', 'tiimari', 'segment', 'fell', '4', '0', 'year', 'year', 'eur3', '3', 'june', '2010']
#
#
# ===Tokens:===
# ['stora', 'enso', 'oyj', 'said', 'second', 'quarter', 'result', 'would', 'fall', 'half', 'compared', 'period', '2007']
#
#
# ===Tokens:===
# ['update', '1', 'lloyds', 'cut', '945', 'jobs', 'part', '3', 'year', 'restructuring', 'plan']
#
#
# ===Tokens:===
# ['net', 'profit', 'three', 'months', 'march', '31', 'fell', 'x20ac', '103', 'million', 'us', '165', 'million', 'x20ac', '131', 'million', 'year', 'earlier', 'finnish', 'company', 'said']
#
#
# ===Tokens:===
# ['astrazeneca', 'patent', 'asthma', 'drug', 'invalidated', 'us', 'court']
#
#
# ===Tokens:===
# ['easyjet', 'dismisses', 'lufthansa', 'low', 'cost', 'plan', 'contest', 'germany']
#
#
# ===Tokens:===
# ['yit', 'baltic', 'sales', 'first', 'three', 'quarters', '2008', 'totaled', '106', '2', 'million', 'euros', 'representing', 'drop', '29', 'percent', 'year', 'year']
#
#
# ===Tokens:===
# ['net', 'sales', 'finnish', 'sanoma', 'learning', 'literature', 'finnish', 'media', 'group', 'sanoma', 'decreased', '3', '6', 'january', 'june', '2009', 'totalling', 'eur', '162', '8', 'mn', 'eur', '168', '8', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['rt', 'alphatrends', 'vmarkets', 'still', 'acting', 'weak', 'http', 'stks', 'co', '1agn', 'spy', 'qqq', 'xlf', 'smh', 'iwm']
#
#
# ===Tokens:===
# ['finland', 'hobby', 'hall', 'sales', 'decreased', '10', 'international', 'sales', 'fell', '19']
#
#
# ===Tokens:===
# ['rbs', 'chairman', 'admits', 'surprise', 'size', 'regulatory', 'penalties']
#
#
# ===Tokens:===
# ['hard', 'find', 'new', 'buyers', 'tsla', '250', 'shorts', 'continue', 'pile']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'totaled', 'eur', '9', '0', 'mn', 'eur', '36', '3', 'mn', '2007']
#
#
# ===Tokens:===
# ['operating', 'result', '12', 'month', 'period', 'decreased', 'profit', 'eur0', '4', 'turnover', 'decreased', 'eur5', '6', 'compared', '2004']
#
#
# ===Tokens:===
# ['kone', 'said', 'court', 'papers', 'union', 'action', 'delayed', 'repairs', 'elevators', 'federal', 'courthouse', 'jan', '21', 'saltonstall', 'state', 'office', 'building', 'jan', '23']
#
#
# ===Tokens:===
# ['operating', 'profit', 'non', 'recurring', 'items', 'eur', '8', '3', 'mn', 'first', 'nine', 'months', '2008', 'compared', 'eur', '8', '4', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', 'eur', '31', '6', 'mn', 'eur', '50', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['intc', 'finally', 'nice', 'downside', 'move', 'looking', '31', 'handle', 'break']
#
#
# ===Tokens:===
# ['refile', 'aviva', 'investors', 'move', '34', 'bln', 'euros', 'assets', 'axa', 'fund', 'arm']
#
#
# ===Tokens:===
# ['airline', 'share', 'price', 'closed', 'slightly', 'x20ac', '12', '51', '15us', '74', 'helsinki']
#
#
# ===Tokens:===
# ['also', 'upset', 'machinery', 'work', 'taken', 'poland']
#
#
# ===Tokens:===
# ['q1', '2009', 'company', 'operating', 'loss', 'totalled', 'eur', '0', '3', 'mn', 'compared', 'profit', 'eur', '3', '6', 'mn', 'q1', '2008']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'reports', 'operating', 'profit', 'eur', '2', '2', 'mn', 'first', 'quarter', '2010', 'eur', '6', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totaled', 'eur', '117mn', 'compared', 'loss', 'eur', '65mn', 'corresponding', 'period']
#
#
# ===Tokens:===
# ['low', 'capacity', 'utilisation', 'rate', 'steel', 'production', 'considerably', 'increases', 'fixed', 'costs', 'per', 'unit', 'steel', 'produced']
#
#
# ===Tokens:===
# ['fb', 'churning', 'high', 'volume', 'ipo', 'price', 'lot', 'sellers', 'trying', 'get', 'might', 'take', 'consolidate', 'moving', 'higher']
#
#
# ===Tokens:===
# ['trouble', 'brewing', 'legal', 'general', 'group', 'plc', 'aviva', 'plc']
#
#
# ===Tokens:===
# ['gps', 'gap', 'september', 'comparable', 'store', 'sales', '4']
#
#
# ===Tokens:===
# ['revenue', 'slightly', 'x20ac', '495', 'million', '634', 'million', 'compared', 'x20ac', '497', 'million', 'year', 'earlier']
#
#
# ===Tokens:===
# ['net', 'sales', 'financial', 'year', '2006', 'expected', 'amount', 'eur20m', 'operating', 'result', 'ebit', 'expected', 'loss', 'announced']
#
#
# ===Tokens:===
# ['several', 'large', 'stocks', 'tacked', 'lower', 'however']
#
#
# ===Tokens:===
# ['jan', '6', 'ford', 'struggling', 'face', 'slowing', 'truck', 'suv', 'sales', 'surfeit', 'date', 'got', 'ta', 'cars']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'quarter', 'decreased', 'eur510m', 'sales', 'increased', 'eur860m', 'compared', 'third', 'quarter', '2007']
#
#
# ===Tokens:===
# ['26', 'october', '2010', 'finnish', 'environmental', 'management', 'company', 'lassila', 'tikanoja', 'oyj', 'hel', 'lat1v', 'l', 'said', 'today', 'net', 'profit', 'declined', 'eur20', '9', 'first', 'nine', 'months', '2010', 'eur27', '6', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'xdgraexkkz']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '4', '2009', 'finnish', 'broadband', 'data', 'communication', 'systems', 'solutions', 'company', 'teleste', 'oyj', 'hel', 'tlt1v', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '5', '5', 'million', 'usd', '7', '2', '2008', 'eur', '9', '4', 'million', '200']
#
#
# ===Tokens:===
# ['repeats', 'sees', '2008', 'operating', 'profit', 'reporting', 'helsinki', 'newsroom', 'keywords', 'tecnomen', 'results']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur30', '6', 'eur38', '3', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['consolidated', 'pretax', 'profit', 'decreased', '69', '2', 'eur', '41', '0', 'mn', 'eur', '133', '1', 'mn', '2007']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'dips', 'blinkbox', 'books', 'closes', 'ending', 'supermarket', 'digital']
#
#
# ===Tokens:===
# ['glencore', 'cuts', '2015', 'budget', 'plans', 'divest', 'lonmin']
#
#
# ===Tokens:===
# ['endp', 'sued', 'ftc', 'nobody', 'buy', 'hanging', 'heads']
#
#
# ===Tokens:===
# ['tesla', 'voluntary', 'recall', '2', '700', 'model', 'x', 'vehicles', 'due', 'back', 'seat', 'issue', 'tsla', 'https', 'co', 'npakc3u6gs']
#
#
# ===Tokens:===
# ['result', 'company', 'temporarily', 'lay', '25', 'whole', 'personnel', 'approximately', '270', 'persons', 'kirkkonummi', 'nivala', 'factories']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'totaled', 'eur', '4', '9', 'mn', 'compared', 'eur', '5', '2', 'mn', 'first', 'quarter', '2005']
#
#
# ===Tokens:===
# ['grid', 'shows', 'dia', 'capped', 'long', 'term', 'range', '123', '40', '124', '77', 'rally', 'beyond', 'today', 'levels', 'range', 'leads', 'meltdown']
#
#
# ===Tokens:===
# ['first', 'half', '2008', 'bank', 'operating', 'profit', 'fell', 'eur', '11', '8', 'mn', 'eur', '18', '9', 'mn', 'net', 'interest', 'income', 'increased', 'eur', '20', '9', 'mn', 'eur', '18', '8', 'mn', 'first', 'half', '2007']
#
#
# ===Tokens:===
# ['gpro', '25', 'since', 'tue', 'morning']
#
#
# ===Tokens:===
# ['update', '1', 'nomura', 'rbs', 'must', 'pay', '806', 'mln', 'mortgage', 'bond', 'case', 'us', 'judge']
#
#
# ===Tokens:===
# ['dish', 'weakness', 'continues', '49', '43', 'area', 'resistance', 'last', 'week']
#
#
# ===Tokens:===
# ['10', '33', 'huhtamaki', 'market', 'biggest', 'faller', '8', '69', 'pct', 'lower', '11', '35', 'eur', 'omx', 'helsinki', '25', '0', '32', 'pct', 'higher', '3', '332', '41', 'omx', 'helsinki', '0', '47', 'pct', '11', '687', '32']
#
#
# ===Tokens:===
# ['operating', 'loss', 'amounted', 'eur', '0', '9', 'mn', 'first', 'half', '2006', 'compared', 'profit', 'eur', '0', '5', 'mn', 'first', 'half', '2005']
#
#
# ===Tokens:===
# ['eu', 'commission', 'said', 'earlier', 'fined', 'thyssenkrupp', 'united', 'technologies', 'corp', 'otis', 'schindler', 'ag', 'kone', 'oyj', 'total', '992', '3', 'mln', 'eur', 'alleged', 'cartel', 'activity', 'lift', 'market', 'going', 'back', 'twelve', 'years']
#
#
# ===Tokens:===
# ['srv', 'lowered', 'net', 'sales', 'estimate', 'whole', '2008', 'due', 'uncertainties', 'housing', 'sales']
#
#
# ===Tokens:===
# ['11', 'august', '2010', 'finnish', 'measuring', 'equipment', 'maker', 'vaisala', 'oyj', 'hel', 'vaias', 'said', 'today', 'net', 'loss', 'widened', 'eur4', '8', 'first', 'half', '2010', 'eur2', '3', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['glaxosmithkline', 'share', 'price', 'slips', 'fda', 'okays', 'asthma', 'therapy', 'adults']
#
#
# ===Tokens:===
# ['googl', 'short', '740', 'upper', 'bb', 'overbought']
#
#
# ===Tokens:===
# ['know', 'back', 'seat', 'sit', 'tsla', 'tesla', 'recalls', '2', '700', 'model', 'x', 'cars', 'https', 'co', '7j0gwz89zc']
#
#
# ===Tokens:===
# ['juniper', 'tumbles', 'q1', 'warning', 'cisco', 'also', 'lower', 'jnpr', 'csco', 'https', 'co', 'bgvintk43h']
#
#
# ===Tokens:===
# ['walter', 'investment', 'management', 'corp', 'receives', 'sell', 'compass', 'point', 'wac', 'http', 'stks', 'co', 'c1ivx']
#
#
# ===Tokens:===
# ['amrn', 'got', 'sell', 'signal', '7', '1', '14', 'still', 'force', 'target', '1', '50']
#
#
# ===Tokens:===
# ['mcd', 'looks', 'set', 'fall', 'http', 'stks', 'co', 'f2fgj']
#
#
# ===Tokens:===
# ['isolationism', 'another', 'sell', 'rating', 'sell', 'ratings', 'spy', 'qqq', 'iwm', 'several', 'companies', 'https', 'co', 'j35fnnx744', 'aapl', 'apple', 'axp', 'bac']
#
#
# ===Tokens:===
# ['spy', 'bull', 'move', 'ended', 'waiting', 'next', 'setup']
#
#
# ===Tokens:===
# ['finnish', 'plumbing', 'heating', 'systems', 'supplier', 'uponor', 'net', 'sales', 'continuing', 'business', 'operations', 'decreased', 'eur', '249', '1', 'mn', 'july', 'september', '2008', 'compared', 'eur', '262', '1', 'mn', 'third', 'quarter', '2007']
#
#
# ===Tokens:===
# ['majority', 'company', 'personnel', 'finland', 'temporarily', 'laid', 'one', 'six', 'weeks', 'period', 'february', 'june', '2009', 'period']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'contract', 'manufacturer', 'scanfil', 'reports', 'net', 'sales', 'eur', '58', '9', 'mn', 'second', 'quarter', '2007', 'eur', '62', '4', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['spy', 'mitk', 'fast', '56pc', 'dive', 'http', 'stks', 'co', '3ffn']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'flexible', 'packaging', 'cutting', '48', 'jobs', 'unit', 'tampere', 'two', 'nastola', 'finland']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totaled', 'eur', '0', '2', 'mn', 'eur', '0', '8', 'mn', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['earlier', 'today', 'geberit', 'finnish', 'rival', 'uponor', 'oyj', 'cut', 'full', 'year', 'sales', 'growth', 'forecast', '6', 'pct', '10', 'pct', 'blaming', 'tough', 'conditions', 'germany', 'us', 'well', 'currency', 'factors']
#
#
# ===Tokens:===
# ['rxii', 'tang', 'really', 'toxic', 'keep', 'bringing', 'share', 'price', 'least', 'could', 'let', 'climb', 'little', 'dragging']
#
#
# ===Tokens:===
# ['uncommonly', 'weak', 'snow', 'conditions', 'nearly', 'every', 'market', 'affected', 'first', 'quarter', 'result', 'chief', 'executive', 'roger', 'talermo', 'said']
#
#
# ===Tokens:===
# ['aapl', 'aapl', 'finally', 'breaking', '49', 'buybacks', 'week', 'look', 'aapl', 'test', '120', 'support', 'area']
#
#
# ===Tokens:===
# ['operating', 'profit', 'nine', 'month', 'period', 'decreased', 'eur19', '9', 'net', 'sales', 'increased', 'eur155', '7', 'compared', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['hobby', 'hall', 'sales', 'decrease', '26', 'pct', 'due', 'implementing', 'new', 'information', 'system', 'involved', 'changing', 'principal', 'posting', 'sales']
#
#
# ===Tokens:===
# ['steelmaker', 'said', 'drop', 'profit', 'explained', 'continuing', 'economic', 'uncertainty', 'mixed', 'current', 'drought', 'bank', 'lending', 'resulting', 'decline', 'demand', 'products', 'customers', 'find', 'increasingly', 'difficult', 'fund', 'operations']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '5', '2', 'mn', 'compared', 'loss', 'eur', '3', '4', 'mn', 'corresponding', 'period', '2008', '2009']
#
#
# ===Tokens:===
# ['result', 'transactions', 'aggregate', 'holdings', 'burrill', 'life', 'sciences', 'capital', 'fund', 'l', 'p', 'decreased', '5', 'per', 'cent', 'total', 'number', 'shares', 'votes', 'company']
#
#
# ===Tokens:===
# ['shell', '70', 'billion', 'bg', 'deal', 'meets', 'shareholder', 'skepticism']
#
#
# ===Tokens:===
# ['samsung', 'currently', 'occupies', 'third', 'place', 'lost', 'ground', 'quarter', 'dropping', '1', '8', '11', '1', 'share', 'overall']
#
#
# ===Tokens:===
# ['sale', 'result', 'capital', 'loss', 'eur5m', 'solidium', 'obtained', 'tikkurila', 'shares', 'march', '2010']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totalled', 'eur', '162', '3', 'mn', 'compared', 'profit', 'eur', '253', '5', 'mn', '2007']
#
#
# ===Tokens:===
# ['timberrrr', 'tsla', 'https', 'co', 'mrbgfdhhva']
#
#
# ===Tokens:===
# ['kone', 'shares', 'dropped', '4', '1', 'percent', 'x20ac', '43', 'us', '55', '77', 'helsinki']
#
#
# ===Tokens:===
# ['sbux', 'downgraded', 'neutral', 'deutsche', 'bank', 'price', 'target', 'reduced', '64', '70']
#
#
# ===Tokens:===
# ['elcoteq', 'group', 'recently', 'announced', 'last', 'three', 'months', 'previous', 'year', 'brought', 'major', 'loss', 'half', 'billion', 'kroons', 'eur', '32', 'mln', 'fifth', 'quarter', 'running']
#
#
# ===Tokens:===
# ['according', 'swedish', 'authorities', 'traces', 'toxic', 'osmium', 'tetroxide', 'found', 'coast', 'per', 'meri', 'northernmost', 'part', 'gulf', 'bothnia']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'tumbles', 'negative', 'broker', 'note']
#
#
# ===Tokens:===
# ['thanks', 'internet', 'consumers', 'compare', 'products', 'previously', 'finnish', 'companies', 'competitive']
#
#
# ===Tokens:===
# ['hsbc', 'says', 'unit', 'book', '585', 'million', 'charge', 'settlement']
#
#
# ===Tokens:===
# ['starbucks', 'shares', 'much', '4', '2', 'sbux', 'https', 'co', 'jlgrprr54k']
#
#
# ===Tokens:===
# ['fb', 'trend', 'hits', 'mid', '110', 'drops']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '12', '7', 'mn', 'compared', 'profit', 'eur', '17', '7', 'mn', 'first', 'half', '2008']
#
#
# ===Tokens:===
# ['company', 'said', 'sales', 'three', 'months', 'end', 'march', 'slid', 'eur86', '4', 'us', '113', '4', 'eur91', '2', 'last', 'year']
#
#
# ===Tokens:===
# ['adp', 'news', 'jan', '22', '2009', 'finnish', 'mobile', 'phones', 'maker', 'nokia', 'oyj', 'omx', 'nok1v', 'said', 'today', 'operating', 'profit', 'decreased', 'eur', '5', 'billion', 'usd', '6', '5', 'bn', '2008', 'eur', '8', 'billion', '2007']
#
#
# ===Tokens:===
# ['department', 'store', 'division', 'sales', 'fell', '8', '6', 'eur', '140', '2', 'mn']
#
#
# ===Tokens:===
# ['tesla', 'recalling', '2', '700', 'model', 'x', 'units', 'related', 'faulty', 'latch', 'third', 'row', 'seats', 'fall', '252', '50', 'level', 'recall', 'shares', '1', 'tsla']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'reports', 'operating', 'profit', 'fell', 'eur', '4', '9', 'mn', 'third', 'quarter', '2007', 'eur', '5', '6', 'mn', 'third', 'quarter', '2006']
#
#
# ===Tokens:===
# ['rt', 'cash', 'cow', 'tlt', 'still', 'rising', 'rsi', 'macd', 'bond', 'buying', 'signaling', 'bad', 'moves', 'market', 'spy', 'uup']
#
#
# ===Tokens:===
# ['investors', 'remain', 'skeptical', 'shell', 'bg', 'deal']
#
#
# ===Tokens:===
# ['temporary', 'lay', 'offs', 'affecting', 'entire', 'workforce', 'also', 'implemented']
#
#
# ===Tokens:===
# ['g4s', 'slides', 'balance', 'sheet', 'worries']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totaled', 'eur', '0', '8', 'mn', 'compared', 'profit', 'eur', '0', '5', 'mn']
#
#
# ===Tokens:===
# ['viking', 'line', 'canceled', 'services']
#
#
# ===Tokens:===
# ['copper', 'market', 'may', 'get', '2003', 'style', 'supply', 'shock', 'glencore', 'closures']
#
#
# ===Tokens:===
# ['however', 'increases', 'signaling', 'traffic', 'wastes', 'network', 'resources', 'allows', 'fewer', 'smartphones', 'connect']
#
#
# ===Tokens:===
# ['aapl', 'beaten', 'hated', 'etc', 'hhhmm', 'opposite', '700', 'happens', 'next']
#
#
# ===Tokens:===
# ['tsla', 'recalls', '2', '700', 'model', 'x', 'cars', 'stock', 'dropping', 'hard']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totaled', 'eur', '25mn', 'compared', 'profit', 'eur', '63mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['due', 'rapid', 'decrease', 'net', 'sales', 'personnel', 'reductions', 'carried', 'wider', 'scale', 'initially', 'expected']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '9', '6', 'mn', 'eur', '42', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['announcement', 'pushed', 'freenet', 'shares', '6', '3', 'eur0', '71', 'frankfurt', 'trade', 'eur10', '65', 'investors', 'gave', 'hope', 'united', 'internet', 'ag', 'drillisch', 'would', 'pursue', 'takeover', 'breakup', 'freenet']
#
#
# ===Tokens:===
# ['result', 'negotiations', 'company', 'decided', 'make', '45', 'people', 'redundant', 'financial', 'production', 'grounds']
#
#
# ===Tokens:===
# ['however', 'company', 'saw', 'net', 'profit', 'third', 'quarter', 'eur', '1', '4', 'million', 'eur', '1', '5', 'million', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['baltic', 'countries', 'development', 'operations', 'reorganisation', 'continued', 'non', 'recurring', 'items', 'related', 'takeover', 'process', 'lowered', 'earnings']
#
#
# ===Tokens:===
# ['lay', 'offs', 'affect', '240', 'people', 'total', '320', 'okmetic', 'employees', 'finland']
#
#
# ===Tokens:===
# ['baltic', 'countries', 'sales', 'fell', '42', '6']
#
#
# ===Tokens:===
# ['uvxy', 'put', 'chum', 'key', 'support', 'next', 'level', 'careful']
#
#
# ===Tokens:===
# ['acom', 'http', 'stks', 'co', '1g6x', 'downside', 'breakout', 'looks', 'coming', 'soon']
#
#
# ===Tokens:===
# ['addition', 'production', 'varpaisj', 'rvi', 'factory', 'stopped', 'beginning', 'april', '2009']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'eur', '4', '0', 'mn', 'eur', '4', '9', 'mn']
#
#
# ===Tokens:===
# ['scanfil', 'also', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['exports', 'goods', 'fell', '59', 'imports', '16', '7']
#
#
# ===Tokens:===
# ['tsla', 'recall', 'model', 'x', 'https', 'co', 'b7izya4bue']
#
#
# ===Tokens:===
# ['baltic', 'states', 'company', 'reports', 'net', 'sales', 'eur', '11', '9', 'mn', 'eur', '14', '2', 'mn', 'operative', 'ebit', 'eur', '2', '2', 'mn', 'eur', '1', '7', 'mn']
#
#
# ===Tokens:===
# ['aapl', 'short', 'term', 'fund', 'redemption', 'liquidations', 'channel', 'cleared', 'soon', 'solid', 'footing', '520', 'new', 'floor', 'come', 'july']
#
#
# ===Tokens:===
# ['net', 'sales', 'kyro', 'main', 'business', 'area', 'glaston', 'technologies', 'manufacturer', 'glass', 'processing', 'machines', 'decreased', 'eur', '161', '5', 'mn', 'eur', '164', '1', 'mn', 'january', 'september', '2005']
#
#
# ===Tokens:===
# ['finnish', 'scanfil', 'contract', 'manufacturer', 'systems', 'supplier', 'communication', 'industrial', 'electronics', 'reports', 'net', 'sales', 'eur', '108', '7', 'mn', 'first', 'half', '2008', 'eur', '111', '1', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['pretax', 'loss', 'totalled', 'eur', '49', '9', 'mn', 'compared', 'loss', 'eur', '15', '4', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['aapl', 'afternoon', 'selloff', 'usual', 'brutal', 'get', 'ready', 'lose', 'ton', 'money']
#
#
# ===Tokens:===
# ['however', 'growth', 'margin', 'slowed', 'due', 'financial', 'crisis']
#
#
# ===Tokens:===
# ['nokia', 'shares', 'hit', '13', '21', 'euros', 'friday', '50', 'percent', 'start', 'year', 'part', 'slow', 'introduction', 'touch', 'screen', 'models']
#
#
# ===Tokens:===
# ['reduction', 'notice', 'applied', '17', 'people']
#
#
# ===Tokens:===
# ['european', 'stocks', 'hover', 'near', '3', 'week', 'low', 'dialog', 'bhp', 'slump']
#
#
# ===Tokens:===
# ['ssh', 'communications', 'security', 'corp', 'stock', 'exchange', 'release', 'october', '14', '2008', '2', '45', 'pm', 'company', 'updates', 'full', 'year', 'outlook', 'estimates', 'results', 'remain', 'loss', 'full', 'year']
#
#
# ===Tokens:===
# ['survey', 'conducted', 'taloustutkimus', 'sampo', 'life', 'shows', 'companies', 'badly', 'prepared', 'losing', 'key', 'staff', 'members']
#
#
# ===Tokens:===
# ['september', 'alone', 'market', 'declined', '10', '2', 'percent', 'year', 'year', '19', '28', 'million', 'liters']
#
#
# ===Tokens:===
# ['espn', 'files', 'lawsuit', 'verizon', 'http', 'stks', 'co', 'i2cj1', 'vz']
#
#
# ===Tokens:===
# ['company', 'slipped', 'operating', 'loss', 'eur', '2', '6', 'million', 'profit', 'eur', '1', '3', 'million']
#
#
# ===Tokens:===
# ['cost', 'costco', 'less', 'stellar', 'day', 'held', '50', 'day', 'moving', 'average']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'fell', 'eur', '0', '63', 'eur', '1', '71']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'eur', '11', '2', 'mn', 'eur', '16', '6', 'mn']
#
#
# ===Tokens:===
# ['ftse', '100', 'drops', '2', '5', 'pct', 'glencore', 'metals', 'price', 'fears']
#
#
# ===Tokens:===
# ['fastjet', 'slams', 'easyjet', 'founder', 'stelios', 'going', 'public', 'taking', 'legal', 'advice', 'letter', 'contractual']
#
#
# ===Tokens:===
# ['spy', 'tomorrow', 'party', 'time', 'bears', 'goog', 'msft', '5', '5']
#
#
# ===Tokens:===
# ['device', 'volume', 'area', 'decreased', '21', '2', '7', 'mn', 'units']
#
#
# ===Tokens:===
# ['finnish', 'textiles', 'clothing', 'group', 'marimekko', 'oyj', 'posted', 'net', 'profit', '7', '99', 'mln', 'euro', '10', '4', 'mln', '2006', 'compared', '8', '4', 'mln', 'euro', '10', '9', 'mln', '2005']
#
#
# ===Tokens:===
# ['company', 'said', 'fall', 'turnover', 'planned']
#
#
# ===Tokens:===
# ['meggitt', 'share', 'price', 'tumbles', 'profit', 'falls', 'challenging', 'year']
#
#
# ===Tokens:===
# ['tietoenator', '1', '13', 'pct', '18', '38', 'extending', 'recent', 'lows', 'last', 'week', 'second', 'quarter', 'report', 'dealers', 'said']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '20', '3', 'mn', 'eur', '74', '2', 'mn', 'second', 'quarter', '2008']
#
#
# ===Tokens:===
# ['net', 'sales', 'fell', '33', 'third', 'quarter', '2008', 'eur', '130', '5', 'mn']
#
#
# ===Tokens:===
# ['small', 'firms', 'suffering', 'moment', 'likely', 'money', 'trouble', 'added']
#
#
# ===Tokens:===
# ['food', 'trade', 'sales', 'amounted', 'eur320', '1', 'decline', '1', '1']
#
#
# ===Tokens:===
# ['company', 'previous', 'estimate', 'lower', 'revenue', 'year', 'ago', 'eur', '93', '9', 'million']
#
#
# ===Tokens:===
# ['adpnews', 'may', '4', '2010', 'finnish', 'cutlery', 'hand', 'tools', 'maker', 'fiskars', 'oyj', 'abp', 'hel', 'fisas', 'said', 'today', 'net', 'profit', 'declined', 'eur', '12', '9', 'million', 'usd', '17m', 'first', 'quarter', '2010', 'eur', '17', 'million', 'correspond']
#
#
# ===Tokens:===
# ['finnish', 'retail', 'software', 'developer', 'aldata', 'solution', 'oyj', 'reported', 'net', 'loss', '11', '7', 'mln', 'euro', '17', '2', 'mln', '2007', 'versus', 'net', 'profit', '2', '5', 'mln', 'euro', '3', '7', 'mln', '2006']
#
#
# ===Tokens:===
# ['finnish', 'construction', 'company', 'yit', 'reducing', 'number', 'start', 'ups', 'market', 'financed', 'residential', 'units', '2007', '2', '300', 'previously', 'announced', '2', '700']
#
#
# ===Tokens:===
# ['cencorp', 'net', 'sales', 'first', 'quarter', 'estimated', 'eur0', '9', '1', '2', 'compared', 'eur4', '5', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['building', 'home', 'improvement', 'trade', 'net', 'sales', 'totalled', 'eur', '1', '173', 'mn', 'eur', '1', '566', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['hsbc', 'hit', 'fresh', 'details', 'tax', 'evasion', 'claims']
#
#
# ===Tokens:===
# ['shell', 'share', 'price', 'standard', 'life', 'announce', 'position', 'bg', 'acquisition']
#
#
# ===Tokens:===
# ['negotiation', 'resulted', 'reduction', '80', 'people', 'regular', 'employment', 'around', 'half', 'covered', 'pension', 'arrangements']
#
#
# ===Tokens:===
# ['royal', 'mail', 'johnson', 'matthey', 'lead', 'ftse', 'lower']
#
#
# ===Tokens:===
# ['adpnews', 'sep', '28', '2009', 'finnish', 'silicon', 'wafers', 'maker', 'okmetic', 'oyj', 'hel', 'okm1v', 'said', 'reduce', 'number', 'clerical', 'workers', '22', 'worldwide', 'result', 'personnel', 'negotiations', 'completed', 'today']
#
#
# ===Tokens:===
# ['helsinki', 'thomson', 'financial', 'shares', 'cargotec', 'fell', 'sharply', 'early', 'afternoon', 'trade', 'cargo', 'handling', 'group', 'posted', 'surprise', 'drop', 'april', 'june', 'profits', 'overshadowed', 'large', 'number', 'new', 'orders', 'received', 'three', 'months']
#
#
# ===Tokens:===
# ['generated', 'operating', 'loss', 'eur', '96', '3', 'mn', 'profit', 'eur', '43', '9', 'mn']
#
#
# ===Tokens:===
# ['cat', 'hangin', 'thread', '1click', 'away', 'cliff', 'drop', 'needs', 'follow', 'snap', 'back', 'vix']
#
#
# ===Tokens:===
# ['iff', 'technical', 'alerts', 'stochastic', 'sell', 'signal', '200', 'dma', 'support', '50', 'dma', 'support', 'http', 'stks', 'co', 'p12qy']
#
#
# ===Tokens:===
# ['supreme', 'court', 'upholds', '236', 'million', 'jury', 'award', 'exxonmobil']
#
#
# ===Tokens:===
# ['media', 'advisory', 'ntsb', 'said', 'subsequent', 'testing', 'train', 'detection', 'system', 'intermittently', 'failed']
#
#
# ===Tokens:===
# ['u', 'energy', 'executives', 'say', 'high', 'steel', 'prices', 'threatening', 'energy', 'exploration']
#
#
# ===Tokens:===
# ['spy', 'weak', 'close']
#
#
# ===Tokens:===
# ['result', 'negotiations', 'employment', '130', 'blue', 'white', 'collar', 'employees', 'oulu', 'plant', 'would', 'terminated']
#
#
# ===Tokens:===
# ['reuters', 'green', 'mountain', 'revenue', 'misses', 'shares', 'plunge', 'http', 'stks', 'co', '13mw', 'gmcr', 'prints', '43', '80', 'market', 'foul', 'mood', 'bad', 'day', 'disappoint']
#
#
# ===Tokens:===
# ['operating', 'loss', 'non', 'recurring', 'items', 'eur', '0', '9', 'mn', 'compared', 'profit', 'eur', '11', '5', 'mn', '2008']
#
#
# ===Tokens:===
# ['last', 'year', '8', '3', 'million', 'passengers', 'flew', 'airline', '4', 'percent', '2007']
#
#
# ===Tokens:===
# ['glaston', 'net', 'profit', 'third', 'quarter', '2007', 'dropped', '2', '4', 'mln', 'euro', '3', '5', 'mln', '3', '5', 'mln', 'euro', '5', '1', 'mln', 'corresponding', 'period', '2006']
#
#
# ===Tokens:===
# ['nokia', 'u', 'shares', '3', '3', 'percent', 'lower', '12', '73', '1750', 'gmt']
#
#
# ===Tokens:===
# ['paper', 'companies', 'negative', 'territories', 'stora', 'enso', 'r', 'shedding', '1', '62', 'pct', '12', '73', 'eur', 'upm', 'kymmene', '0', '80', 'pct', '18', '64', 'eur', 'real', 'b', '0', '18', 'pct', 'lower', '5', '57', 'eur']
#
#
# ===Tokens:===
# ['johnson', 'matthey', 'share', 'price', 'slumps', 'company', 'posts', 'full', 'year', 'results']
#
#
# ===Tokens:===
# ['hargreaves', 'lansdown', 'share', 'price', 'falls', 'costs', 'mount', 'although', 'pensions']
#
#
# ===Tokens:===
# ['googl', 'hit', 'lawsuit', 'russian', 'search', 'engine', 'yndx', 'http', 'stks', 'co', 'b1kd8']
#
#
# ===Tokens:===
# ['information', 'released', '5', 'september', '2008', 'nokia', 'american', 'depositary', 'shares', 'fell', '8']
#
#
# ===Tokens:===
# ['frost', 'sold', 'shares', '19', 'million', '6', '06', '7', '12', 'per', 'share', 'compared', 'friday', 'high', '11', '33', 'low', '10', '14']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '6', '7', 'mn', 'eur', '7', '2', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['cut', 'frequency', 'new', 'york', 'last', 'year', 'explains', 'fall', 'said']
#
#
# ===Tokens:===
# ['managing', 'director', 'comments', 'net', 'sales', 'first', 'quarter', 'notably', 'lower', 'year', 'especially', 'finland', 'russia', 'baltic', 'countries']
#
#
# ===Tokens:===
# ['netapp', 'downgraded', 'macquarie', 'underperform', '22', '00', 'pt', 'https', 'co', 'xcngws0t4q', 'ntap', 'ntap', 'via', 'ratingsnetwork']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'loss', 'eur0', '38']
#
#
# ===Tokens:===
# ['cndo', '21', 'short', 'float', 'shorts', 'likely', 'take', 'profits', 'close']
#
#
# ===Tokens:===
# ['european', 'shares', 'plunge', 'roiled', 'bhp', 'oil', 'hopes', 'turn', 'ecb']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '1', '0', 'mn', 'eur', '1', '6', 'mn']
#
#
# ===Tokens:===
# ['ftse', 'falls', '3', 'month', 'low', 'greek', 'debt', 'concerns', 'easyjet', 'skids']
#
#
# ===Tokens:===
# ['barclays', 'share', 'price', 'subdued', 'bank', 'faces', 'fresh', 'forex', 'probe']
#
#
# ===Tokens:===
# ['companieskingfisher', 'bid', 'mr', 'bricolage', 'runs', 'trouble']
#
#
# ===Tokens:===
# ['adpnews', 'feb', '3', '2010', 'finland', 'based', 'steel', 'maker', 'rautaruukki', 'oyj', 'hel', 'rtrks', 'ruukki', 'said', 'today', 'slipped', 'larger', 'expected', 'pretax', 'loss', 'eur', '46', 'million', 'usd', '64', '5', 'fourth', 'quarter', '2009']
#
#
# ===Tokens:===
# ['operating', 'profit', 'declined', 'mainly', 'due', 'increased', 'cost', 'wood', 'recycled', 'fiber', 'strengthened', 'euro']
#
#
# ===Tokens:===
# ['oil', 'majors', 'like', 'royal', 'dutch', 'shell', 'chevron', 'bp', 'fail', 'find', 'reserves', 'counter']
#
#
# ===Tokens:===
# ['profitability', 'ebit', '13', '6', 'compared', '14', '3', 'q2', '2009']
#
#
# ===Tokens:===
# ['kiosk', 'cinema', 'operations', 'suffered', 'particular']
#
#
# ===Tokens:===
# ['shares', 'royal', 'sun', 'alliance', 'continued', 'slide', 'back', '12', 'month', 'high', '172p', 'last', 'month', 'potential', 'suitor', 'ruled', 'takeover', 'bid']
#
#
# ===Tokens:===
# ['rio', 'tinto', 'swings', 'loss', 'drops', 'dividend', 'policy']
#
#
# ===Tokens:===
# ['finnish', 'bank', 'land', 'landsbanken', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'totalled', 'eur', '2', '2', 'mn', 'eur', '2', '7', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['antti', 'orkola', 'president', 'kemira', 'growhow', 'industrial', 'solutions', 'unit', 'told', 'thomson', 'financial', 'news', 'company', 'put', 'opening', 'mine', 'prices', 'phosphate', 'quite', 'depressed', 'long', 'time']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '3', '2', 'mn', 'compared', 'profit', 'eur', '7', '2', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2008', 'net', 'sales', 'decreased', 'eur', '121', '4', 'mn', 'eur', '165', '5', 'mn', 'fourth', 'quarter', '2007']
#
#
# ===Tokens:===
# ['finnish', 'national', 'carrier', 'said', 'net', 'loss', 'april', 'june', 'euro26', 'million', 'net', 'profit', 'euro13', 'million', 'year', 'earlier']
#
#
# ===Tokens:===
# ['scottrade', 'tsla', 'available', 'shorting', 'time', 'w']
#
#
# ===Tokens:===
# ['total', '16', '5', 'mn', 'passenger', 'ship', 'journeys', 'took', 'place', 'northern', 'baltic', 'sea', '2007', 'slightly', '16', '5', 'mn', '2006']
#
#
# ===Tokens:===
# ['finnish', 'solutions', 'provider', 'affecto', 'oyj', 'hel', 'afe1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur', '115', '000', 'usd', '152', '000', 'second', 'quarter', '2010', 'profit', 'eur', '845', '000', 'corresponding', 'period', 'year', 'earlier']
#
#
# ===Tokens:===
# ['astrazeneca', 'suffers', 'setback', 'drug', 'fails', 'treat', 'eye', 'cancer']
#
#
# ===Tokens:===
# ['omx', 'nordic', '40', 'omxn40', 'index', 'comprising', '40', 'traded', 'nordic', 'stocks', 'nasdaq', 'omx', 'exchange', 'closed', '0', '87', '1', '064', '14', 'points', 'thursday']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'corporation', 'makes', 'wipes', 'nonwovens', 'flexible', 'packaging', 'expects', 'changes', 'market', 'situation', 'reduce', 'sales', 'suominen', 'nonwovens', 'wet', 'wipes', 'previously', 'estimated', 'volumes']
#
#
# ===Tokens:===
# ['windows', '10', 'awful', 'force', 'upgrade', 'pc', 'without', 'consent', 'windows', 'microsoft', 'msft']
#
#
# ===Tokens:===
# ['twtr', 'best', 'scenario', 'going', 'forward', 'stock', 'slowly', 'falling', 'everyday', 'quite', 'probable']
#
#
# ===Tokens:===
# ['homebuilders', 'ryl', 'breaking', 'support', 'watch', 'one', 'spy']
#
#
# ===Tokens:===
# ['finnish', 'airline', 'finnair', 'starting', 'temporary', 'layoffs', 'cabin', 'crews', 'february', '2010']
#
#
# ===Tokens:===
# ['stock', 'hit', 'profit', 'warning', 'finnish', 'rival', 'rautaruukki', 'oyj', 'omx', 'rtrks']
#
#
# ===Tokens:===
# ['operating', 'cash', 'flow', 'investments', 'totalled', 'eur', '61', '3', 'mn', 'compared', 'eur', '75', '3', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['company', 'confirmed', 'estimate', 'lower', 'revenue', 'whole', '2009', 'year', 'ago', 'eur93', '9', 'given', 'interim', 'report', '5', 'august', '2009']
#
#
# ===Tokens:===
# ['tesco', 'share', 'price', 'grocer', 'faces', 'sfo', 'investigation', 'outcome']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'amounted', 'eur', '40', '6', 'mn', 'eur', '57', '3', 'mn', 'year', 'year']
#
#
# ===Tokens:===
# ['glencore', 'chief', 'blames', 'rivals', 'overproduction', 'share', 'price', 'fall']
#
#
# ===Tokens:===
# ['profit', 'period', 'totalled', 'eur', '0', '8', 'mn', 'eur', '1', '1', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['moment', 'valio', 'worried', 'ban', 'continues', 'long', 'may', 'become', 'quite', 'problem']
#
#
# ===Tokens:===
# ['bhp', 'billiton', 'drags', 'ftse', 'lower', 'slashing', 'dividend']
#
#
# ===Tokens:===
# ['acando', 'ab', 'acanb', 'ss', 'fell', '8', '9', 'percent', '13', '35', 'kronor', 'lowest', 'close', 'since', 'dec', '11']
#
#
# ===Tokens:===
# ['cost', 'short', 'finally', 'making', 'gains', 'take', 'half', 'gains', '147']
#
#
# ===Tokens:===
# ['quick', 'fio', '21', '35', 'market', 'tanking', 'scaling', 'longs']
#
#
# ===Tokens:===
# ['sales', 'seppala', 'diminished', '6', 'per', 'cent']
#
#
# ===Tokens:===
# ['tightened', 'competition', 'situation', 'production', 'automation', 'market', 'affected', 'net', 'sales', '2006', 'cencorp', 'said']
#
#
# ===Tokens:===
# ['dolce', 'gabbana', 'asked', 'european', 'union', 'declare', 'marimekko', 'corporation', 'unikko', 'floral', 'pattern', 'trademark', 'invalid', 'continuing', 'dispute', 'two', 'companies']
#
#
# ===Tokens:===
# ['net', 'sales', 'decreased', 'eur', '49', '8', 'million', 'eur', '59', '9', 'million']
#
#
# ===Tokens:===
# ['yelp', 'wayyy', 'overvalued', 'right', 'imo', 'trading', 'single', 'digits', 'may', 'take', 'short', 'pos', 'earnings', 'near', 'term', 'target', '18']
#
#
# ===Tokens:===
# ['according', 'scanfil', 'demand', 'telecommunications', 'network', 'products', 'fluctuated', 'significantly', 'third', 'quarter', '2006', 'situation', 'expected', 'remain', 'unstable', 'rest', 'year']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['uk', 'ftse', 'worst', 'day', 'far', '2015', 'bg', 'prudential', 'fall']
#
#
# ===Tokens:===
# ['amazon', 'selling', 'surveillance', 'cameras', 'infected', 'malware', 'amzn', 'amazon', 'https', 'co', 'tohleq8fk6', 'https', 'co', '5pr4cbtvvy']
#
#
# ===Tokens:===
# ['sales', 'volume', 'coca', 'cola', 'market', 'share', 'decreased', '2', '2', '24', '2']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '2', '0', 'international', 'sales', 'decreased', '9', '3', 'terms', 'euros', '15', '1', 'terms', 'local', 'currencies']
#
#
# ===Tokens:===
# ['hpq', 'says', 'breakup', 'cost', 'billions', 'sees', 'savings', 'http', 'stks', 'co', 'p27hz']
#
#
# ===Tokens:===
# ['britain', 'ftse', 'falls', 'back', 'ashtead', 'commodities', 'pressure']
#
#
# ===Tokens:===
# ['tesco', 'sales', 'pickup', 'enough']
#
#
# ===Tokens:===
# ['upm', 'stock', 'fell', '3', 'percent', 'euro', '12', '49', '17', '24', 'early', 'afternoon', 'trading', 'helsinki']
#
#
# ===Tokens:===
# ['finnish', 'power', 'supply', 'solutions', 'systems', 'provider', 'efore', 'oyj', 'said', 'net', 'loss', 'widened', '3', '2', 'mln', 'euro', '4', '2', 'mln', 'first', 'quarter', 'fiscal', '2006', '2007', 'ending', 'october', '31', '2007', '900', '000', 'euro', '1', '2', 'mln', 'period', 'fiscal', '2005', '06']
#
#
# ===Tokens:===
# ['operating', 'margin', 'came', '2', '4', '5', '7']
#
#
# ===Tokens:===
# ['rbi', 'surprises', 'street', 'sensex', 'pares', 'gains', 'hitting', 'mount', '30k']
#
#
# ===Tokens:===
# ['hack', 'extra', 'nefarious', 'tweets', 'activated', 'without', 'clicked', 'enough', 'web', 'surfers', 'move', 'mouse', 'cursors']
#
#
# ===Tokens:===
# ['casinos', 'red', 'bell', 'lvs', '0', '75', 'wynn', '0', '47', 'wynn', '0', '47', 'unusual', 'comibinations', 'running', 'red', 'bell']
#
#
# ===Tokens:===
# ['company', 'reported', 'today', 'operating', 'loss', 'eur0', '1', 'net', 'sales', 'eur4', '5', 'first', 'quarter', '2008']
#
#
# ===Tokens:===
# ['rimm', 'spx', 'nya', 'compq', 'djia', 'going']
#
#
# ===Tokens:===
# ['ferries', 'run', 'trouble', 'outside', 'stockholm', 'archipelago', 'made', '20', '000', 'islands']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '9', '0', 'mn', 'eur', '9', '7', 'mn', 'first', 'half', '2008']
#
#
# ===Tokens:===
# ['finnish', 'exel', 'composites', 'technology', 'company', 'designs', 'manufactures', 'markets', 'composite', 'profiles', 'tubes', 'various', 'industrial', 'applications', 'reports', 'net', 'sales', 'decreased', '0', '6', 'second', 'quarter', '2010', 'eur', '19', '2', 'mn', 'eur', '19', '3', 'mn', 'corresponding', 'period', '2009']
#
#
# ===Tokens:===
# ['soullor', 'regular', 'scrappy', 'q', 'swy', 'usually', 'presents', 'sales', 'weak', 'margins', 'debt', 'still', 'way']
#
#
# ===Tokens:===
# ['upm', 'kymmene', 'corp', 'world', 'largest', 'maker', 'magazine', 'paper', 'tuesday', 'reported', '19', 'percent', 'profit', 'drop', 'lower', 'paper', 'prices', 'higher', 'costs', 'strong', 'euro', 'hurt', 'revenue']
#
#
# ===Tokens:===
# ['hznp', 'havent', 'seen', 'vol', 'like', 'since', 'runup', 'lets', 'see', 'one', 'dip', '2', '0x']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'decreased', '37', 'eur', '193', '1', 'mn', 'eur', '305', '6', 'mn']
#
#
# ===Tokens:===
# ['miners', 'meltdown', 'bhp', 'rio', 'tinto', 'sink', 'commodities', 'rout']
#
#
# ===Tokens:===
# ['traceyryniec', 'energy', 'broad', 'see', 'wwg', 'kaman', 'well', 'short', 'fast']
#
#
# ===Tokens:===
# ['operating', 'profits', 'half', '0', '8', '0', '9', 'glisten', 'invested', 'brand', 'management', 'team']
#
#
# ===Tokens:===
# ['finnlines', 'estimated', 'annual', 'general', 'meeting', '2008', 'financially', 'tough', 'year', 'due', 'large', 'investments']
#
#
# ===Tokens:===
# ['salonen', 'added', 'data', 'shows', 'producers', 'pulp', 'inventories', 'north', 'america', 'declining']
#
#
# ===Tokens:===
# ['vnoto74', 'follow', 'sell', 'signal', 'ndx', 'internals', '06', '23', 'technical', 'sell', 'qqq', '06', '25']
#
#
# ===Tokens:===
# ['arcelormittal', 'chief', 'executive', 'officer', 'lakshmi', 'mittal', 'already', 'cut', 'output', 'furnaces']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '35', '4', 'mn', 'eur', '68', '8', 'mn', '2007', 'including', 'vessel', 'sales', 'gain', 'eur', '12', '3', 'mn']
#
#
# ===Tokens:===
# ['astrazeneca', 'diabetes', 'drug', 'combination', 'faces', 'delay', 'fda', 'rebuff']
#
#
# ===Tokens:===
# ['third', 'quarter', 'fiscal', '2008', 'efore', 'swung', 'net', 'loss', 'eur', '400', '000', 'versus', 'net', 'profit', 'eur', '200', '000', 'corresponding', 'period', 'fiscal', '2007']
#
#
# ===Tokens:===
# ['deutsche', 'bank', 'downgraded', 'starbucks', 'co', 'sbux', 'https', 'co', 'qqlevvwpmv', 'https', 'co', 'f2pdqjutha']
#
#
# ===Tokens:===
# ['adp', 'news', 'apr', '22', '2009', 'finnish', 'business', 'information', 'systems', 'developer', 'solteq', 'oyj', 'hel', 'stq1v', 'said', 'today', 'net', 'loss', 'widened', 'eur', '189', '000', 'usd', '245', '000', 'first', 'quarter', '2009', 'eur', '10', '000', 'peri']
#
#
# ===Tokens:===
# ['boeing', 'company', 'nyse', 'ba', 'bearish', 'trader', 'bets', '550k', 'stock', 'sell', '9', '79', 'july', 'expiry', 'ba', 'http', 'stks', 'co', 'tcse']
#
#
# ===Tokens:===
# ['gevo', 'plunging', 'back', '3', '55']
#
#
# ===Tokens:===
# ['finnish', 'developer', 'manufacturer', 'mobile', 'phone', 'chargers', 'salcomp', 'plc', 'omx', 'helsinki', 'sal1v', 'wednesday', '19', 'november', 'lowered', 'full', 'year', 'net', 'sales', 'estimate']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'stood', 'eur', '0', '25', 'versus', 'eur', '0', '42']
#
#
# ===Tokens:===
# ['net', 'sales', 'decreased', 'eur', '91', '6', 'mn', 'eur', '109mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['budapest', 'august', '10', 'mti', 'finnish', 'electronics', 'maker', 'elcoteq', 'lay', '700', 'workers', 'plants', 'pecs', 'hungary', 'end', 'september', 'falling', 'orders', 'communications', 'director', 'elcoteq', 'local', 'unit', 'zoltan', 'krippl', 'told', 'mti', 'monday']
#
#
# ===Tokens:===
# ['12', '01', 'pm', 'omx', 'helsinki', '25', '0', '66', 'pct', '3', '143', '57', 'omx', 'helsinki', '0', '67', 'pct', 'lower', '10', '530', '74', '253', 'mln', 'eur', 'turnover']
#
#
# ===Tokens:===
# ['finnair', 'total', 'traffic', 'decreased', '8', '7', 'terms', 'revenue', 'passenger', 'kilometres']
#
#
# ===Tokens:===
# ['iwm', 'conditions', 'sent', 'markets', 'tumble', 'hitting', 'week']
#
#
# ===Tokens:===
# ['finnish', 'meat', 'company', 'atria', 'longer', 'promise', 'sufficient', 'amount', 'domestic', 'beef', 'customers']
#
#
# ===Tokens:===
# ['company', 'profit', 'taxes', 'fell', 'eur', '21', '1', 'mn', 'third', 'quarter', '2008', 'compared', 'eur', '35', '8', 'mn', 'corresponding', 'period', '2007']
#
#
# ===Tokens:===
# ['academics', 'claim', 'google', 'android', 'two', 'factor', 'authentication', 'breakable', 'security', 'authentication', 'hacking', 'goog', 'https', 'co', 'njx4mnrglo']
#
#
# ===Tokens:===
# ['aapl', 'rejected', 'hod', 'head', 'lower', 'sitting', 'sidelines']
#
#
# ===Tokens:===
# ['also', 'cut', 'price', 'projections', 'paper', 'packaging', 'analyst', 'goldman', 'sachs', 'said', 'note', 'monday']
#
#
# ===Tokens:===
# ['morrisons', 'finance', 'chief', 'fill', 'gap', 'ceo', 'leaves', 'early']
#
#
# ===Tokens:===
# ['multi', 'top', 'mcd', 'chart', 'finally', 'leads', 'fall', 'price', 'stability', 'questioned', 'stock', 'coming', 'weeks', 'tell']
#
#
# ===Tokens:===
# ['zsl', 'looking', 'weak', 'could', 'good', 'short', 'setup']
#
#
# ===Tokens:===
# ['top', 'us', 'commerce', 'department', 'published', 'worse', 'expected', 'construction', 'spending', 'figures', 'november']
#
#
# ===Tokens:===
# ['finnish', 'glass', 'technology', 'company', 'glaston', 'oyj', 'abp', 'net', 'profit', 'decreased', '2', '6', 'mln', 'euro', '3', '8', 'mln', 'first', 'nine', 'months', '2007', '7', '8', 'mln', 'euro', '11', '4', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['fb', 'guess', 'want', 'look', 'sell', 'orders']
#
#
# ===Tokens:===
# ['vaisala', 'net', 'profit', 'third', 'quarter', '2007', 'dropped', '3', '0', 'mln', 'euro', '4', '3', 'mln', '6', '8', 'mln', 'euro', '9', '8', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['repurchases', 'shall', 'decrease', 'distributable', 'capital', 'reserves']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'contract', 'manufacturer', 'scanfil', 'reports', 'net', 'sales', 'eur', '241', '2', 'mn', '2006', 'eur', '321', '6', 'mn', '2005']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'dropped', 'eur', '0', '21', 'eur', '0', '31']
#
#
# ===Tokens:===
# ['operating', 'profit', 'eur', '1', '6', 'mn', '2005', 'compared', 'eur', '5', '9', 'mn', '2004']
#
#
# ===Tokens:===
# ['kingfisher', 'share', 'price', 'slides', 'cost', 'implement', 'new', 'strategy']
#
#
# ===Tokens:===
# ['cramo', 'slipped', 'pretax', 'loss', 'eur', '6', '7', 'million', 'pretax', 'profit', 'eur', '58', '9', 'million']
#
#
# ===Tokens:===
# ['rivals', 'say', 'qualcomm', 'fewer', 'patents', '3g', 'phones', 'earlier', 'versions', 'lower', 'rates']
#
#
# ===Tokens:===
# ['aviva', 'fined', '27', 'million', 'u', 'k', 'regulator', 'fee', 'failings']
#
#
# ===Tokens:===
# ['aspocomp', 'large', 'factory', 'china', 'factory', 'building', 'project', 'india', 'halted', 'due', 'financing', 'problems']
#
#
# ===Tokens:===
# ['tesco', 'abandons', 'video', 'streaming', 'ambitions', 'blinkbox', 'sale']
#
#
# ===Tokens:===
# ['tsla', 'recall']
#
#
# ===Tokens:===
# ['prices', 'delivery', 'volumes', 'broadband', 'products', 'decreased', 'significantly', '2005']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'decreased', 'eur', '13', '8', 'mn', 'eur', '17', '1', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['ftse', '100', 'falls', 'china', 'devaluation', 'hits', 'burberry', 'mining', 'stocks']
#
#
# ===Tokens:===
# ['finnish', 'communication', 'electronics', 'components', 'supplier', 'scanfil', 'oyj', 'tuesday', 'said', 'sales', 'first', 'half', '2006', '15', 'lower', 'period', 'year', 'ago']
#
#
# ===Tokens:===
# ['really', 'surprised', 'much', 'fb', 'fallen', 'thought', 'support', 'around', '50d', 'guess']
#
#
# ===Tokens:===
# ['sheryl', 'sandberg', 'sells', '109', '000', 'shares', 'facebook', 'inc', 'fb', 'stock', 'https', 'co', '3vxt7amnpk', 'via', 'ratingsnetwork']
#
#
# ===Tokens:===
# ['market', 'share', 'decreased', 'route', 'helsinki', 'finland', 'tallinn', 'estonia', '0', '1', 'percentage', 'points', '24', '8']
#
#
# ===Tokens:===
# ['finnair', 'passenger', 'load', 'factor', 'measures', 'number', 'sold', 'seats', 'share', 'available', 'seats', 'dropped', '1', '3', 'percentage', 'points', '76', '7', 'september']
#
#
# ===Tokens:===
# ['rapala', 'vmc', 'corporation', 'stock', 'exchange', 'release', 'october', '10', '2008', '11', '45', 'kaupthing', 'bank', 'oyj', 'kapthing', 'informed', 'rapala', 'vmc', 'corporation', 'rapala', 'interrupted', 'liquidity', 'providing', 'rapala', 'share', 'time']
#
#
# ===Tokens:===
# ['slv', '4', '44', '18', 'awful', '42', '50']
#
#
# ===Tokens:===
# ['orion', 'net', 'profit', 'third', 'quarter', '2007', 'decreased', '36', '5', 'mln', 'euro', '52', '1', 'mln', '40', '3', 'mln', 'euro', '57', '5', 'mln', 'year', 'earlier']
#
#
# ===Tokens:===
# ['omx', 'helsinki', 'index', '0', '34', 'pct', '8', '256', '02', 'turnover', '813', '191', 'mln', 'eur']
#
#
# ===Tokens:===
# ['uncertainties', 'cloud', 'long', 'term', 'outlook']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'first', 'half', '2007', 'amounted', 'eur0', '29', 'eur0', '40', 'year', 'ago']
#
#
# ===Tokens:===
# ['still', 'short', 'lng', '11', '70', 'area', 'next', 'stop', 'could', '9', '00', 'someone', 'slammed', 'hard', '230', '000', 'shs', 'follow']
#
#
# ===Tokens:===
# ['capacity', 'ease', 'seikku', 'sawmill', 'pori', 'alholma', 'sawmill', 'pietarsaari', 'result', '60', 'people', 'laid', 'around', 'six', 'weeks', 'starting', 'mid', 'may', 'said']
#
#
# ===Tokens:===
# ['starbucks', 'downgraded', 'day', 'new', 'downgraded', 'rewards', 'program', 'starts', 'sbux']
#
#
# ===Tokens:===
# ['tsla', 'recalls', '2', '700', 'model', 'x', 'vehicles', 'shares', 'volatile', 'https', 'co', 'tckqznmiqx', 'tsla', 'tech', 'stockmarket', 'https', 'co', 'femhjtamqj']
#
#
# ===Tokens:===
# ['iwm', 'relative', 'weakness', 'pretty', 'apparent', 'short', 'boat', 'getting', 'full', 'one', 'prefer', 'boat', 'closer', 'empty']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fell', 'eur', '15', '1', 'mn', 'eur', '24', '6', 'mn', '2006']
#
#
# ===Tokens:===
# ['ea', 'points', 'two', 'facebook', 'games', 'accuses', 'znga', 'copyright', 'infringement', 'http', 'stks', 'co', 'g3a1']
#
#
# ===Tokens:===
# ['finnish', 'media', 'group', 'talentum', 'issued', 'profit', 'warning']
#
#
# ===Tokens:===
# ['hlf', 'shorts', 'made', 'killing', 'last', 'couple', 'days', 'might', 'make', 'cover', 'buy', 'back']
#
#
# ===Tokens:===
# ['smh', 'got', 'sell', 'signal', '6', '4', 'needs', 'take', '39', '28', 'go', 'higher', 'otherwise', 'headed', 'lower', '37', '60', 'gap', '35', '38']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur', '30', '6', 'million', 'eur', '38', '3', 'million', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['far', 'norwegian', 'norske', 'skog', 'reduced', 'staff', 'levels', '1', '000', 'people', 'plans', 'reduce', 'production', '200', '000', 'tons', '2008', 'finnish', 'swedish', 'stora', 'enso', 'cut', 'staff', '1', '700', 'people', 'production', '500', '000', 'tons']
#
#
# ===Tokens:===
# ['gld', 'http', 'stks', 'co', '44ow', 'closer', 'inspection', 'resistance', '10', 'points', 'north', '200d', 'downward', 'trendline', 'chart', '2', '2']
#
#
# ===Tokens:===
# ['fb', 'tsla', 'cracking', 'lower', 'early', 'short', 'correction', 'stocks']
#
#
# ===Tokens:===
# ['stumbled', 'upon', 'amazing', 'chart', 'ofix', 'holy', 'guac', 'super', 'overbought', 'http', 'stks', 'co', 'e0px1']
#
#
# ===Tokens:===
# ['ab', 'inbev', 'attacks', 'sabmiller', 'bid', 'rebuffal']
#
#
# ===Tokens:===
# ['since', 'association', 'data', 'cover', 'sales', 'figures', '100', 'small', 'local', 'breweries', 'sales', 'imported', 'beer', 'products', 'actual', 'market', 'shares', 'members', 'smaller', 'given', 'report']
#
#
# ===Tokens:===
# ['sanoma', 'news', 'advertising', 'sales', 'decreased', '22', 'year']
#
#
# ===Tokens:===
# ['finnish', 'electronics', 'manufacturing', 'services', 'ems', 'company', 'elcoteq', 'se', 'posted', 'net', 'loss', '66', '4', 'mln', 'euro', '91', '2', 'mln', 'first', 'half', '2007', 'compared', 'net', 'profit', '7', '1', 'mln', 'euro', '9', '8', 'mln', 'period', '2006']
#
#
# ===Tokens:===
# ['operating', 'profit', 'fourth', 'quarter', 'went', 'eur3m', 'eur4', '2', 'corresponding', 'period', '2009', 'included', 'costs', 'growth', 'projects']
#
#
# ===Tokens:===
# ['finnish', 'waste', 'management', 'cleaning', 'group', 'lassila', 'tikanoja', 'oyj', 'l', 'net', 'profit', 'went', '32', '2', 'mln', 'euro', '47', '7', 'mln', '2007', '35', '3', 'mln', 'euro', '52', '3', 'mln', '2006']
#
#
# ===Tokens:===
# ['update', '1', 'dairy', 'crest', 'loses', 'third', 'morrisons', 'milk', 'contract']
#
#
# ===Tokens:===
# ['tullow', 'oil', 'suspends', 'dividend', 'amid', 'oil', 'price', 'fall']
#
#
# ===Tokens:===
# ['finnish', 'laboratory', 'liquid', 'handling', 'diagnostic', 'test', 'systems', 'developer', 'biohit', 'oyj', 'omx', 'helsinki', 'biobv', 'issued', 'tuesday', '3', 'june', 'profit', 'warning', 'financial', 'year', '2008']
#
#
# ===Tokens:===
# ['city', 'spirits', 'sink', 'diageo', 'comes', 'short', 'sales', 'slide']
#
#
# ===Tokens:===
# ['tesla', 'motors', 'recalls', '2', '700', 'model', 'x', 'suvs', 'tsla', 'https', 'co', 'f55dx4aegi']
#
#
# ===Tokens:===
# ['net', 'sales', 'dropped', '6', 'year', 'year', 'eur', '11', '9', 'million']
#
#
# ===Tokens:===
# ['operating', 'profit', 'excluding', 'non', 'recurring', 'items', 'eur', '7', '8', 'million', 'compared', 'eur', '11', '2', 'million']
#
#
# ===Tokens:===
# ['siga', 'bid', 'reargument', 'denied', 'judge']
#                             0   1
# 0                http stks co  27
# 1     mn corresponding period  18
# 2         compared profit eur  14
# 3            mn third quarter  10
# 4          earnings per share  10
# ...                       ...  ..
# 6809          compared eur 11   1
# 6810             11 2 million   1
# 6811      siga bid reargument   1
# 6812    bid reargument denied   1
# 6813  reargument denied judge   1
#
# [6814 rows x 2 columns]

# %%
# # Creating neutral trigrams

for text in train_set[train_set['Sentiment']=='neutral']['Sentence']:
    for word in generate_ngrams(text, 3):
        neutralWords_tri[word]+=1
df_neutral_tri = pd.DataFrame(sorted(neutralWords_tri.items(),key=lambda x:x[1],reverse=True))
df_neutral_tri
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ===Tokens:===
# ['finnish', 'fibers', 'plastics', 'producer', 'suominen', 'corporation', 'omx', 'helsinki', 'suy1v', 'reported', 'wednesday', '22', 'october', 'operating', 'loss', 'eur0', '8', 'net', 'sales', 'eur55', '2', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['uk', 'sarantel', 'outsource', 'part', 'processes', 'elcoteq', 'plant', 'estonia', 'london', 'oct', '13', 'bns', 'british', 'miniature', 'antennas', 'maker', 'sarantel', 'signed', 'agreement', 'outsource', 'assembly', 'test', 'supply', 'chain', 'processes', 'plant', 'elcoteq', 'estonian', 'capital', 'tallinn']
#
#
# ===Tokens:===
# ['12', '59', 'pm', 'omx', 'helsinki', '25', 'index', '0', '32', 'pct', 'lower', '2', '694', '81']
#
#
# ===Tokens:===
# ['finland', 'martela', 'offers', 'comprehensive', 'service', 'cover', 'entire', 'process', 'change', 'initial', 'inventory', 'design', 'removal', 'maintenance']
#
#
# ===Tokens:===
# ['move', 'carried', 'transferring', 'hkscan', 'production', 'related', 'property', 'plant', 'equipment', 'well', 'holdings', 'subsidiaries', 'associate', 'companies', 'country', 'hkscan', 'finland']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '9', '4', 'mn', 'eur', '11', '7', 'mn', '2004']
#
#
# ===Tokens:===
# ['marimekko', 'operates', 'industry', 'changes', 'business', 'climate', 'reflected', 'consumer', 'demand']
#
#
# ===Tokens:===
# ['offer', 'clients', 'integrated', 'management', 'consulting', 'total', 'solutions', 'complex', 'projects', 'efficient', 'best', 'class', 'design', 'supervision']
#
#
# ===Tokens:===
# ['group', 'business', 'sectors', 'building', 'construction', 'infrastructure', 'construction', 'technical', 'building', 'services', 'building', 'products']
#
#
# ===Tokens:===
# ['company', 'expects', 'sales', 'revenue', 'rmb8', '0', 'billion', '2009']
#
#
# ===Tokens:===
# ['according', 'statistics', 'finnish', 'maritime', 'administration', 'shipping', 'increase', 'much', 'january', 'august', '2009', 'however']
#
#
# ===Tokens:===
# ['cranes', 'would', 'installed', 'onboard', 'two', 'freighters', 'ordered', 'singaporean', 'ship', 'owner', 'masterbulk']
#
#
# ===Tokens:===
# ['acquisition', 'avc', 'systemhaus', 'majority', 'stake', 'cableway', 'increase', 'number', 'teleste', 'personnel', '250']
#
#
# ===Tokens:===
# ['proposal', 'board', 'directors', 'issuance', 'option', 'rights', 'otherwise', 'correspond', 'proposal', 'board', 'directors', 'notice', 'general', 'meeting']
#
#
# ===Tokens:===
# ['plant', 'collect', 'raw', 'material', 'baltic', 'sea', 'region']
#
#
# ===Tokens:===
# ['jvc', 'stop', 'producing', 'dvd', 'players', 'brazil', 'jvc', 'brazil', 'subsidiary', 'japan', 'jvc', 'group', 'announced', 'stop', 'production', 'dvd', 'players', 'brazil']
#
#
# ===Tokens:===
# ['efore', 'ceo', 'reijo', 'maihaniemi', 'said', 'company', 'developed', 'already', 'delivered', 'power', 'supply', 'units', 'respective', 'systems', 'based', 'technology', 'chinese', 'sector', 'company', 'zte', 'corp', '000063']
#
#
# ===Tokens:===
# ['secondary', 'antenna', 'also', 'used', 'reception', 'high', 'power', 'signal', 'radar', 'calibrate', 'transmission', 'channels', 'radar']
#
#
# ===Tokens:===
# ['altogether', 'capman', 'employs', 'approximately', '150', 'people', 'helsinki', 'stockholm', 'copenhagen', 'oslo', 'moscow', 'luxembourg']
#
#
# ===Tokens:===
# ['underground', 'parking', 'facilities', 'also', 'built', 'basement', 'floor']
#
#
# ===Tokens:===
# ['fixed', 'acquisition', 'price', 'amounts', 'nok', '70', 'approximately', 'eur', '8', '7', 'million', 'additional', 'price', 'nok', '15', 'eur', '1', '8', 'million', 'maximum']
#
#
# ===Tokens:===
# ['operating', 'profits', 'half', '0', '8', '0', '9', 'glisten', 'invested', 'brand', 'management', 'team']
#
#
# ===Tokens:===
# ['mr', 'clausen', 'however', 'refused', 'comment', 'option', 'nordea', 'would', 'consider', 'buying', 'citadele', 'bank']
#
#
# ===Tokens:===
# ['finnish', 'plumbing', 'heating', 'systems', 'supplier', 'uponor', 'net', 'sales', 'continuing', 'operations', 'decreased', '9', '4', '2008', 'eur', '949', '2', 'mn', 'eur', '1', '047', '4', 'mn', '2007']
#
#
# ===Tokens:===
# ['sales', 'seppala', 'diminished', '6', 'per', 'cent']
#
#
# ===Tokens:===
# ['performance', 'based', 'values', 'sustainability']
#
#
# ===Tokens:===
# ['rosen', 'cautious', 'optimistic', 'inregard', 'second', 'half', 'year']
#
#
# ===Tokens:===
# ['winner', 'present', 'win']
#
#
# ===Tokens:===
# ['group', 'cumulative', 'sales', 'review', 'period', 'eur', '48', '2', 'million', 'eur', '53', '1', 'million', '1', '9', '2007', 'profit', 'taxes', 'eur', '1', '2', '1', '4', 'million']
#
#
# ===Tokens:===
# ['exel', 'wants', 'serve', 'industrial', 'customers', 'individual', 'products']
#
#
# ===Tokens:===
# ['export', 'declined', '6', 'percent', '16', '4', 'million', 'liters']
#
#
# ===Tokens:===
# ['revenue', 'quarter', 'totaled', '27', '4', 'billion', '2', 'percent', '28', '1', 'billion', 'fourth', 'quarter', '2008']
#
#
# ===Tokens:===
# ['total', 'project', 'duration', 'three', 'years', 'valued', 'eur11', '5']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'eur0', '01']
#
#
# ===Tokens:===
# ['mall', 'financed', 'parity', 'basis', 'pearl', 'plaza', 'llc', 'joint', 'venture', 'company', 'established', 'chinese', 'investor', 'shanghai', 'industrial', 'investment', 'holdings', 'co', 'ltd', 'srv', 'group']
#
#
# ===Tokens:===
# ['huhtamaki', 'rigid', 'plastic', 'consumer', 'goods', 'operations', 'mainly', 'europe', 'separated', 'new', 'reporting', 'segment', '1', 'january', '2009']
#
#
# ===Tokens:===
# ['financial', 'details', 'disclosed']
#
#
# ===Tokens:===
# ['den', 'bosch', 'based', 'tomtom', 'europe', 'largest', 'maker', 'automotive', 'navigation', 'devices', 'cayman', 'islands', 'based', 'garmin', 'larger', 'u', 'overall']
#
#
# ===Tokens:===
# ['company', 'said', 'results', 'third', 'quarter', 'include', 'non', 'recurring', 'items']
#
#
# ===Tokens:===
# ['23', 'april', '2010', 'finnish', 'construction', 'engineering', 'company', 'outotec', 'oyj', 'hel', 'ote1v', 'said', 'today', 'slipped', 'net', 'loss', 'eur7', '3', 'first', 'quarter', '2010', 'net', 'profit', 'eur12', '5', 'corresponding', 'period', 'last', 'year']
#
#
# ===Tokens:===
# ['following', 'demerger', 'vice', 'president', 'group', 'pharmaceutical', 'trade', 'finland', 'jukka', 'niemi', 'appointed', 'managing', 'director', 'oriola', 'addition', 'current', 'responsibilities']
#
#
# ===Tokens:===
# ['full', 'midnighttrader', 'extended', 'hours', 'trading', 'analysis', 'news', 'service', 'available', 'real', 'time', 'comtex']
#
#
# ===Tokens:===
# ['value', 'contract', 'eur', '25mn']
#
#
# ===Tokens:===
# ['aviation', 'systems', 'maintenance', 'based', 'kansas', 'generated', 'net', 'sales', 'usd', '2', '6', 'million', '2008']
#
#
# ===Tokens:===
# ['proposal', 'board', 'directors', 'make', 'annual', 'general', 'meeting', 'attached', 'whole', 'release']
#
#
# ===Tokens:===
# ['nordea', 'bank', 'estonia', 'part', 'largest', 'financial', 'group', 'nordic', 'countries']
#
#
# ===Tokens:===
# ['product', 'front', 'edge', 'folding', 'maximizes', 'weather', 'resilience', 'enables', 'seamless', 'roof', 'finish']
#
#
# ===Tokens:===
# ['capman', 'asset', 'manager', 'eur', '3bn', 'worth', 'assets', 'management', 'nordic', 'region']
#
#
# ===Tokens:===
# ['member', 'hk', 'ruokatalo', 'group', 'finland', 'scan', 'launching', 'joint', 'venture', 'slaughterhouse', 'team', 'ugglarp', 'sk', 'ne', 'southern', 'sweden']
#
#
# ===Tokens:===
# ['l', 'net', 'profit', 'whole', '2010', 'dropped', 'eur', '36', 'million', 'eur', '45', 'million', '2009']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'flexible', 'packaging', 'cutting', '48', 'jobs', 'unit', 'tampere', 'two', 'nastola', 'finland']
#
#
# ===Tokens:===
# ['total', 'number', 'shares', 'company', '585', '236', '987', 'innofactor', 'group', 'innofactor', 'offers', 'customers', 'comprehensive', 'solutions', 'microsoft', 'environment']
#
#
# ===Tokens:===
# ['markets', 'expect', 'heineken', 'sell', 'hartwall', 'whole', 'parts']
#
#
# ===Tokens:===
# ['asian', 'traffic', 'declined', '3', '4', 'per', 'cent']
#
#
# ===Tokens:===
# ['swot', 'analysis', 'one', 'method', 'categorization', 'weaknesses']
#
#
# ===Tokens:===
# ['risk', 'exposure', 'non', 'life', 'insurance', 'moving', '12', 'month', 'expenses', 'function', 'non', 'life', 'insurance', 'excluding', 'expenses', 'investment', 'management', 'expenses', 'services', 'rendered', 'non', 'life', 'insurance', 'investment', 'portfolio', 'allocation']
#
#
# ===Tokens:===
# ['private', 'equity', 'investor', 'capman', 'owner', 'finnish', 'lumene', 'cosmetics', 'company', 'planning', 'list', 'lumene']
#
#
# ===Tokens:===
# ['sales', 'finland', 'decreased', '10', '5', 'january', 'sales', 'outside', 'finland', 'dropped', '17']
#
#
# ===Tokens:===
# ['project', 'expected', 'completed', '2009']
#
#
# ===Tokens:===
# ['capman', 'stockholm', 'headquartered', 'private', 'equity', 'firm', 'held', 'first', 'close', 'second', 'private', 'equity', 'real', 'estate', 'fund', 'continues', 'push', 'property', 'sector']
#
#
# ===Tokens:===
# ['24', 'hour', 'news', 'try', 'icis', 'news', 'www', 'icis', 'com', 'click', 'trial', 'icis', 'news']
#
#
# ===Tokens:===
# ['lifted', 'veil', 'various', 'types', 'customer', 'designs', 'phones', 'result', 'social', 'stereotyping', 'taken', 'fine', 'art']
#
#
# ===Tokens:===
# ['finnish', 'holding', 'company', 'panostaja', 'oyj', 'said', 'june', '12', '2007', 'signed', 'letter', 'intent', 'acquire', 'local', 'lahden', 'lampokasittely', 'oy', 'heatmasters', 'oy', 'active', 'heat', 'treatment', 'metals', 'total', '3', '1', 'mln', 'euro', '4', '1', 'mln']
#
#
# ===Tokens:===
# ['company', 'net', 'sales', '2009', 'totalled', 'meur', '307', '8', 'operating', 'margin', '13', '5', 'per', 'cent']
#
#
# ===Tokens:===
# ['barclays', 'poised', 'replace', 'sir', 'mike', 'rake', 'heads', 'exit']
#
#
# ===Tokens:===
# ['previously', 'company', 'expected', '2008', 'financial', 'performance', 'remain', 'level', '2008']
#
#
# ===Tokens:===
# ['currently', '100', 'global', 'fortune', '500', 'companies', 'using', 'ssh', 'security', 'solutions']
#
#
# ===Tokens:===
# ['business', 'units', 'investlesprom', 'group', 'cover', 'full', 'forest', 'industry', 'chain', 'group', 'owns', 'forests', 'sawmills', 'paper', 'pulp', 'mills', 'processing', 'plants']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '0', '9', 'mn', 'profit', 'eur', '2', '7', 'mn']
#
#
# ===Tokens:===
# ['reductions', 'implemented', 'mainly', 'course', 'first', 'half', '2009']
#
#
# ===Tokens:===
# ['growth', 'beer', 'consumption', 'took', 'place', 'far', 'east', 'latin', 'america', 'africa']
#
#
# ===Tokens:===
# ['tekla', 'structures', 'product', 'box', 'needed', 'made', 'recycled', 'material']
#
#
# ===Tokens:===
# ['merisatama', 'far', 'corners', 'world', 'asfaltti', 'osakeyhti', 'lemmink', 'inen', 'established', '1910', 'group', 'master', 'builders', 'helsinki', 'specialist', 'business', 'subcontractor']
#
#
# ===Tokens:===
# ['forecast', '2012', '3', '3']
#
#
# ===Tokens:===
# ['company', 'set', 'services', 'include', 'digital', 'printing', 'printing', 'preparation', 'offset', 'printing', 'treatment', 'services', 'send', 'services']
#
#
# ===Tokens:===
# ['seventy', 'three', 'also', 'extensive', 'training', 'products', 'built', 'latest', 'archestra', 'technologies', 'wonderware', 'system', 'platform']
#
#
# ===Tokens:===
# ['company', 'continuous', 'need', 'alloys', 'nickel', 'ferro', 'chrome', 'molybdenum', 'manganese', 'production', 'said', 'talvivaara']
#
#
# ===Tokens:===
# ['fish', 'content', 'nuggets', '85', 'fish', 'comes', 'canada', 'finland']
#
#
# ===Tokens:===
# ['adpnews', 'may', '4', '2010', 'finnish', 'cutlery', 'hand', 'tools', 'maker', 'fiskars', 'oyj', 'abp', 'hel', 'fisas', 'said', 'today', 'net', 'profit', 'declined', 'eur', '12', '9', 'million', 'usd', '17m', 'first', 'quarter', '2010', 'eur', '17', 'million', 'correspond']
#
#
# ===Tokens:===
# ['copper', 'lead', 'nickel', 'also', 'dropped', 'hbos', 'hbos', 'plummeted', '20', '70', '3', 'pence', 'saying', 'year']
#
#
# ===Tokens:===
# ['exel', 'board', 'directors', 'propose', 'dividend', '0', '2', 'euro', '0', '3', 'per', 'share', '2006', 'annual', 'general', 'meeting', 'april', '19', '2007']
#
#
# ===Tokens:===
# ['result', 'merger', 'largest', 'professional', 'electronics', 'telecommunications', 'technology', 'contract', 'manufacturing', 'center', 'finland', 'formed', 'sievi']
#
#
# ===Tokens:===
# ['aktia', 'forecasts', 'finland', 'inflation', '1', '1', '2010']
#
#
# ===Tokens:===
# ['russia', 'wants', 'utilise', 'huge', 'forest', 'reserves', 'different', 'way', 'done', 'far']
#
#
# ===Tokens:===
# ['decision', 'made', 'whether', 'group', 'agrees', 'import', 'estonian', 'meat', 'meat', 'products', 'finland', 'paper', 'added']
#
#
# ===Tokens:===
# ['financing', 'project', 'come', 'mainly', 'china']
#
#
# ===Tokens:===
# ['financial', 'statements', 'include', 'consolidated', 'financial', 'statements', 'group', 'board', 'directors', 'report', 'auditors', 'report', 'corporate', 'governance', 'statement']
#
#
# ===Tokens:===
# ['according', 'company', 'lay', 'offs', 'temporary']
#
#
# ===Tokens:===
# ['rsa', 'shares', 'closed', '156', '9', 'p', 'time', 'going', 'press']
#
#
# ===Tokens:===
# ['recruitment', 'related', 'relocation', 'stora', 'enso', 'research', 'operations', 'karlstad', 'central', 'sweden']
#
#
# ===Tokens:===
# ['aspo', 'plc', 'stock', 'exchange', 'bulletin', 'october', '24', '2006', '2', '00', 'p', 'aspo', 'systems', 'division', 'completed', 'statutory', 'negotiations', 'required', 'act', 'co', 'operation', 'within', 'undertakings', 'conducted', 'part', 'action', 'plan', 'launched', 'august']
#
#
# ===Tokens:===
# ['agreement', 'pfizer', 'funding', 'biotie', 'research', 'activities', 'pde10', 'phosphodiesterase', '10', 'inhibitor', 'program', 'since', 'start', 'late', '2006', 'sole', 'authority', 'develop', 'discovered', 'compounds']
#
#
# ===Tokens:===
# ['however', 'brokers', 'ratings', 'stock', 'differ']
#
#
# ===Tokens:===
# ['extraordinary', 'general', 'meeting', 'expected', 'take', 'place', 'later', '18', 'february', '2011']
#
#
# ===Tokens:===
# ['new', 'shares', 'entitle', 'holders', 'dividends', 'fiscal', '2006']
#
#
# ===Tokens:===
# ['swedish', 'telco', 'teliasonera', 'teaming', 'friends', 'swedish', 'organization', 'bullying', 'fight', 'bullying', 'children', 'teenagers', 'via', 'electronic', 'channels']
#
#
# ===Tokens:===
# ['purchase', 'price', 'disclosed']
#
#
# ===Tokens:===
# ['expanded', 'company', 'continue', 'called', 'newpage']
#
#
# ===Tokens:===
# ['mr', 'mcdonald', 'started', 'evening', 'set', 'featuring', 'hits', 'solo', 'career', 'doobie', 'brothers', 'years', 'selection', 'r', 'b', 'cover', 'songs', 'met', 'mixed', 'results']
#
#
# ===Tokens:===
# ['comparable', 'operating', 'profit', 'decreased', 'eur', '13', '8', 'mn', 'eur', '17', '1', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['department', 'store', 'division', 'sales', 'fell', '8', '6', 'eur', '140', '2', 'mn']
#
#
# ===Tokens:===
# ['scanfil', 'issued', 'profit', 'warning', '10', 'april', '2006']
#
#
# ===Tokens:===
# ['expansion', 'delivered', 'fourth', 'quarter', '2006']
#
#
# ===Tokens:===
# ['finnish', 'forestry', 'company', 'upm', 'kymmene', 'waste', 'management', 'company', 'lassila', 'tikanoja', 'said', 'jan', '30', 'planning', 'produce', 'ethanol', 'energy', 'commercial', 'industrial', 'waste']
#
#
# ===Tokens:===
# ['proline', 'plus', 'available', 'adjustable', 'single', 'multichannel', 'models', 'fixed', 'volume', 'single', 'channel', 'models', 'volume', 'ranges', '0', '1', 'micro', 'litres', '10', 'ml']
#
#
# ===Tokens:===
# ['year', 'personal', 'entertainment', 'plays', 'significant', 'role', 'determining', 'whether', 'fitness', 'facility', 'workout', 'experience', 'pleasurable', 'chore', 'said', 'brian', 'wilson', 'director', 'marketing', 'precor', 'entertainment', 'services', 'division']
#
#
# ===Tokens:===
# ['thanks', 'internet', 'consumers', 'compare', 'products', 'previously', 'finnish', 'companies', 'competitive']
#
#
# ===Tokens:===
# ['sold', 'tsla', 'puts', 'morning', 'closed', 'close', 'helps', 'pay', 'monthly', 'expenses']
#
#
# ===Tokens:===
# ['union', 'company', 'officials', 'return', 'calls', 'yesterday']
#
#
# ===Tokens:===
# ['company', 'give', 'palm', 'oil', 'altogether', 'however']
#
#
# ===Tokens:===
# ['according', 'honka', 'japan', 'managing', 'director', 'marko', 'saarelainen', 'honkarakenne', 'exports', '200', 'ready', 'made', 'log', 'houses', 'japan', 'year']
#
#
# ===Tokens:===
# ['production', 'liquidated', 'june', '2009', '325', 'employees', 'loose', 'jobs']
#
#
# ===Tokens:===
# ['use', 'case', 'dramatically', 'narrows', 'go', 'hot', 'ltd']
#
#
# ===Tokens:===
# ['currently', 'company', 'uses', 'eight', 'similar', 'reach', 'stackers', 'four', 'empty', 'container', 'handlers', 'konecranes']
#
#
# ===Tokens:===
# ['pretax', 'profit', 'decreased', 'eur', '33', '8', 'mn', 'eur', '40', '8', 'mn', 'fourth', 'quarter', '2005']
#
#
# ===Tokens:===
# ['comprehensive', 'range', 'cut', 'length', 'slitting', 'services', 'allow', 'ruukki', 'particular', 'serve', 'light', 'engineering', 'customers', 'relocate', 'production', 'st', 'petersburg', 'area']
#
#
# ===Tokens:===
# ['natural', 'source', 'isoprene', 'tree', 'species', 'hevea', 'brasiliensis', 'also', 'known', 'rubber', 'tree']
#
#
# ===Tokens:===
# ['aspocomp', 'group', 'headquartered', 'helsinki', 'finland', 'develops', 'interconnection', 'solutions', 'electronics', 'industry']
#
#
# ===Tokens:===
# ['frost', 'sold', 'shares', '19', 'million', '6', '06', '7', '12', 'per', 'share', 'compared', 'friday', 'high', '11', '33', 'low', '10', '14']
#
#
# ===Tokens:===
# ['transaction', 'tikkurila', 'powder', 'coatings', 'related', 'operations']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'march', '15', 'jaakko', 'vilo', 'turku', 'finland', 'developed', 'panel', 'press']
#
#
# ===Tokens:===
# ['total', 'value', 'contract', 'eur', '8', 'million']
#
#
# ===Tokens:===
# ['elisa', 'commissioned', 'finland', 'poyry', 'telecom', 'oy', 'conduct', 'study', 'reception', 'estonia', 'largest', 'cities', 'besides', 'tallinn']
#
#
# ===Tokens:===
# ['solidium', 'holds', '5', '0', 'per', 'cent', 'shares', 'solidium', 'oy', 'acquired', '5', '0', 'per', 'cent', 'shares', 'tieto', 'corporation', 'approximately', 'eur', '58', 'million']
#
#
# ===Tokens:===
# ['september', 'alone', 'market', 'declined', '10', '2', 'percent', 'year', 'year', '19', '28', 'million', 'liters']
#
#
# ===Tokens:===
# ['potential', 'clients', 'include', 'public', 'administration', 'organizations', 'investing', 'utility', 'networks', 'services']
#
#
# ===Tokens:===
# ['last', 'july', 'group', 'said', 'intended', 'relocate', 'warehouse', 'office', 'space', 'loudeac', 'saint', 'marcel', 'morvillars', 'east', 'france', 'already', 'operates', 'hook', 'manufacturing', 'distribution', 'unit']
#
#
# ===Tokens:===
# ['would', 'premature', 'talk', 'dates', 'volume', 'investment', 'procedure', 'said']
#
#
# ===Tokens:===
# ['diluted', 'earnings', 'per', 'share', 'eps', 'fell', 'eur', '0', '63', 'eur', '1', '71']
#
#
# ===Tokens:===
# ['duration', 'contract', '37', 'months']
#
#
# ===Tokens:===
# ['negotiations', 'concern', '246', 'salaried', 'senior', 'salaried', 'employees', 'scheduled', 'completed', 'six', 'weeks']
#
#
# ===Tokens:===
# ['following', 'divestment', 'fiskars', 'outdoor', 'unit', 'comprise', 'brands', 'gerber', 'silva', 'buster', 'focus', 'multi', 'tools', 'knives', 'compasses', 'mobile', 'lighting', 'pedometers', 'aluminium', 'boats']
#
#
# ===Tokens:===
# ['2009', 'kone', 'annual', 'net', 'sales', 'eur', '4', '7', 'billion', 'approximately', '34', '000', 'employees']
#
#
# ===Tokens:===
# ['objective', 'trading', 'shares', 'commence', 'may', '2', '2007']
#
#
# ===Tokens:===
# ['need', 'ready', 'window', 'opens', 'rosberg', 'said']
#
#
# ===Tokens:===
# ['group', 'revenue', '2009', 'amounted', 'eur', '70', 'million', 'company', 'currently', 'employs', 'approximately', '780', 'people']
#
#
# ===Tokens:===
# ['said', 'comptel', 'delivers', 'reliable', 'provisioning', 'activation', 'solutions', 'improve', 'fulfilment', 'processes', 'operators']
#
#
# ===Tokens:===
# ['strike', 'finnair', 'estimates', 'incur', 'net', 'loss', 'eur2m', 'eur2', '5', 'per', 'day']
#
#
# ===Tokens:===
# ['measures', 'result', 'weak', 'demand', 'shipbuilding', 'industry']
#
#
# ===Tokens:===
# ['share', 'transactions', 'part', 'company', 'strategy', 'relinquishing', 'assets', 'part', 'core', 'business']
#
#
# ===Tokens:===
# ['decision', 'french', 'court', 'relates', 'claims', 'raised', 'twenty', 'one', 'former', 'aspocomp', 'employees', 'company', 'said']
#
#
# ===Tokens:===
# ['report', 'oriola', 'kd', 'chief', 'executive', 'officer', 'eero', 'hautaniemi']
#
#
# ===Tokens:===
# ['swedish', 'subsidiary', 'holds', '1', '0', 'net', 'smelter', 'return', 'nsr', 'royalties', 'two', 'advanced', 'copper', 'projects', 'northern', 'sweden', 'viscaria', 'adak', 'projects', 'developed', 'avalon', 'minerals', 'ltd', 'asx', 'avi']
#
#
# ===Tokens:===
# ['atria', 'chose', 'delight', 'attract', 'consumers', '25', '45', 'age', 'group', 'atria', 'fresh', 'range', 'microwaveable', 'meals']
#
#
# ===Tokens:===
# ['according', 'swedish', 'authorities', 'traces', 'toxic', 'osmium', 'tetroxide', 'found', 'coast', 'per', 'meri', 'northernmost', 'part', 'gulf', 'bothnia']
#
#
# ===Tokens:===
# ['group', 'net', 'sales', '2007', 'eur683', '6']
#
#
# ===Tokens:===
# ['l', 'nnen', 'tehtaat', 'showed', 'loss', 'recently', 'started', 'streamlining', 'measures']
#
#
# ===Tokens:===
# ['basic', 'banking', 'activities', 'continued', 'normal']
#
#
# ===Tokens:===
# ['inventors', 'bylander', 'johan', 'ponten', 'fredrik', 'lundberg', 'jorgen']
#
#
# ===Tokens:===
# ['finnish', 'l', 'recoil', 'company', 'specialising', 'used', 'oil', 'regeneration', 'building', 'facility', 'hamina', 'finland', '2008']
#
#
# ===Tokens:===
# ['swedish', 'engineering', 'consultant', 'firm', 'etteplan', 'establish', 'unit', 'town', 'borl', 'nge', 'turn', 'month', 'march', 'april', '2008']
#
#
# ===Tokens:===
# ['city', 'cu', 'welcomes', 'dart', 'members', 'dallas', 'city', 'cu', 'welcomes', 'members', 'dart', 'fcu', 'merge', 'city', 'cu']
#
#
# ===Tokens:===
# ['germany', 'innovational', 'centers', 'united', 'focusing', 'companies', 'aim', 'use', 'technologies', 'development', 'new', 'kinds', 'activity', 'supporting', 'beginner', 'companies', 'entire', 'spectrum', 'services']
#
#
# ===Tokens:===
# ['mentioned', 'shareholders', 'suggest', 'monthly', 'salary', 'eur', '1', '400', 'would', 'paid', 'board', 'members', 'outside', 'company']
#
#
# ===Tokens:===
# ['mformation', 'provides', 'enhanced', 'management', 'applications', 'enabling', 'configuration', 'control', 'throughout', 'lifecycle']
#
#
# ===Tokens:===
# ['fourth', 'quarter', '2006', 'oko', 'banks', 'expects', 'operating', 'environment', 'banking', 'investment', 'services', 'remain', 'similar', 'january', 'september', '2006']
#
#
# ===Tokens:===
# ['roshan', 'net', 'sales', '2006', '191', 'million', 'ebitda', '66', '5', 'million']
#
#
# ===Tokens:===
# ['westend', 'ict', 'plc', 'new', '409', '665', '891', 'shares', 'increase', 'share', 'capital', 'eur', '2', '000', '000', 'based', 'resolutions', 'extraordinary', 'shareholders', 'meeting', '27', 'december', '2010', 'today', 'registered', 'trade', 'register']
#
#
# ===Tokens:===
# ['reduction', 'notice', 'applied', '17', 'people']
#
#
# ===Tokens:===
# ['aapl', '620', 'resistance', 'area']
#
#
# ===Tokens:===
# ['sweden', 'gallerix', 'accumulated', 'sek', 'denominated', 'sales', '1', 'eur', 'denominated', 'sales', '11']
#
#
# ===Tokens:===
# ['u', 'based', 'corp', 'talks', 'scandinavian', 'telecoms', 'company', 'teliasonera', 'sell', 'stake', 'uzbek', 'cellular', 'operator', 'coscom', 'executive', 'coscom', 'told', 'interfax']
#
#
# ===Tokens:===
# ['17', 'march', '2011', 'goldman', 'sachs', 'estimates', 'negative', 'prospects', 'norwegian', 'mobile', 'operations', 'norway', 'telenor', 'asa', 'osl', 'tel', 'sweden', 'teliasonera', 'ab', 'sto', 'tlsn', 'short', 'term']
#
#
# ===Tokens:===
# ['4', 'complete', 'name', 'shareholder', 'otto', 'henrik', 'bernhard', 'nyberg', '5', 'information', 'amount', 'shares', 'transferred', 'corresponds', '5', '68', 'total', 'number', 'shares', 'aspo', 'plc']
#
#
# ===Tokens:===
# ['altogether', 'finnair', 'canceled', '500', 'flights', 'strike']
#
#
# ===Tokens:===
# ['tikkurila', 'powder', 'coatings', '50', 'employees', 'four', 'paint', 'plants', 'generated', 'revenues', 'eur2', '4', 'usd3', '3', '2010']
#
#
# ===Tokens:===
# ['result', 'total', '82', 'employees', 'would', 'given', 'notice']
#
#
# ===Tokens:===
# ['barclays', 'plc', 'lse', 'barc', 'nyse', 'bcs', 'credit', 'agricole', 'sa', 'epa', 'aca', 'cagr']
#
#
# ===Tokens:===
# ['contract', 'comprises', 'log', 'handling', 'line', 'peeling', 'line', 'veneer', 'drying', 'grading', 'line']
#
#
# ===Tokens:===
# ['flurry', 'analytics', 'spokesperson', 'said', 'measuring', 'windows', 'phone', '7', 'data', 'weeks', 'firm', 'double', 'checked', 'data', 'make', 'sure', '66', 'per', 'cent', 'rise', 'aberration']
#
#
# ===Tokens:===
# ['expenditures', 'must', 'justified', 'pass', 'budget', 'approval', 'hurdles', 'believe', 'rop', 'model', 'help', 'make', 'easier', 'security', 'practitioners', 'make', 'business', 'case', 'acquiring', 'enabling', 'security', 'technologies', 'related', 'control', 'activities']
#
#
# ===Tokens:===
# ['ramirent', 'made', '18', 'million', 'kroons', 'eur', '1', '15', 'mln', 'loss', 'last', 'year', 'year', 'company', '7', '3', 'million', 'kroons', 'black']
#
#
# ===Tokens:===
# ['mercator', 'use', 'software', 'logistic', 'retail', 'wholesale', 'operations', 'slovenia', 'markets', 'southeastern', 'europe']
#
#
# ===Tokens:===
# ['full', 'function', 'pc', 'weighs', '1', '25', 'kilograms', 'measures', 'slightly', 'two', 'centimeters', 'thin']
#
#
# ===Tokens:===
# ['okmetic', 'board', 'directors', 'also', 'decided', 'new', 'share', 'ownership', 'program', 'directed', 'company', 'top', 'management']
#
#
# ===Tokens:===
# ['estonia', 'agriculture', 'minister', 'helir', 'valdor', 'seeder', 'finland', 'two', 'day', 'visit', 'course', 'meet', 'finnish', 'counterpart', 'sirkka', 'liisa', 'anttila']
#
#
# ===Tokens:===
# ['company', 'said', 'currently', 'french', 'distribution', 'unit', 'ragot', 'located', 'loudeac', 'normandy', 'distribution', 'unit', 'waterqueen', 'line', 'supplier', 'tortue', 'saint', 'marcel', 'mid', 'france', 'hook', 'manufacturing', 'unit', 'vmc', 'hook', 'distribution', 'unit', 'vmc', 'europe', 'morvillars']
#
#
# ===Tokens:===
# ['finnish', 'component', 'supplier', 'componenta', 'corporation', 'omx', 'helsinki', 'cth1v', 'said', 'monday', '16', 'june', 'changing', 'pricing', 'cycle', 'due', 'increase', 'raw', 'material', 'prices']
#
#
# ===Tokens:===
# ['profit', 'accounting', 'period', 'eur', '0', '3', 'mn']
#
#
# ===Tokens:===
# ['benefon', 'turn', 'salo', 'unit', 'b2b', 'business', 'unit', 'establish', 'b2c', 'business', 'unit', 'uk']
#
#
# ===Tokens:===
# ['indexes', 'include', 'top', 'companies', 'committed', 'sustainable', 'development']
#
#
# ===Tokens:===
# ['agreement', 'includes', 'entire', 'process', 'managing', 'mercator', 'supply', 'chain', 'regions', 'company', 'currently', 'present']
#
#
# ===Tokens:===
# ['corrensponds', '4', '628', 'percent', 'okmetic', 'share', 'capital', 'voting', 'rights']
#
#
# ===Tokens:===
# ['part', 'agreement', '10', 'employees', 'john', 'deere', 'forestry', 'documentation', 'functions', 'transfer', 'dokumentori', 'oy']
#
#
# ===Tokens:===
# ['zip', 'experts', 'warned', 'tuesday']
#
#
# ===Tokens:===
# ['sanoma', 'magazines', 'international', 'invite', 'shareholders', 'holding', 'approximately', '15', 'shares', 'sell', 'shares']
#
#
# ===Tokens:===
# ['stora', 'enso', 'oyj', 'said', 'second', 'quarter', 'result', 'would', 'fall', 'half', 'compared', 'period', '2007']
#
#
# ===Tokens:===
# ['upm', 'kymmene', 'www', 'upm', 'kymmene', 'com', 'produces', 'magazine', 'papers', 'newsprint', 'well', 'fine', 'specialty', 'papers', 'converting', 'materials', 'wood', 'products']
#
#
# ===Tokens:===
# ['rivals', 'say', 'qualcomm', 'fewer', 'patents', '3g', 'phones', 'earlier', 'versions', 'lower', 'rates']
#
#
# ===Tokens:===
# ['digia', 'also', 'set', 'two', 'subsidiaries', 'digia', 'norway', 'digia', 'usa', 'inc']
#
#
# ===Tokens:===
# ['according', 'shipping', 'company', 'viking', 'line', 'eu', 'decision', 'significant', 'financial', 'impact']
#
#
# ===Tokens:===
# ['total', 'value', 'project', 'eur53m', 'including', 'plots', 'transferred', 'atria']
#
#
# ===Tokens:===
# ['718', '430', 'new', 'series', 'shares', 'become', 'subject', 'trading', 'helsinki', 'stock', 'exchange', 'main', 'list', 'together', 'old', 'series', 'shares', 'july', '3', '2006']
#
#
# ===Tokens:===
# ['development', 'technological', 'park', 'specialize', 'telecommunications', 'information', 'technologies', 'part', 'state', 'program', 'formation', 'technoparks', 'hi', 'tech', 'sectors', 'russia']
#
#
# ===Tokens:===
# ['rad', 'charts', 'flashing', 'oversold']
#
#
# ===Tokens:===
# ['poyry', 'plccompany', 'announcement', '10', 'december', '2010', '4', '10', 'p', 'pursuant', 'poyry', 'plc', 'stock', 'option', 'program', '2004', '63', '792', 'new', 'shares', 'company', 'subscribed', 'since', '27', 'october', '2010', 'stock', 'options', '2004b']
#
#
# ===Tokens:===
# ['markets', 'almost', 'completely', 'controlled', 'three', 'banks', 'nordea', 'op', 'bank', 'group', 'sampo']
#
#
# ===Tokens:===
# ['offers', 'advanced', 'machinery', 'maintenance', 'process', 'development', 'services', 'pulp', 'paper', 'industry', 'northern', 'china']
#
#
# ===Tokens:===
# ['financialwire', 'tm', 'press', 'release', 'service', 'receives', 'compensation', 'news', 'opinions', 'distributions']
#
#
# ===Tokens:===
# ['total', 'headcount', 'reduction', '50', 'persons', 'company', 'said']
#
#
# ===Tokens:===
# ['order', 'valued', 'usd12', '2']
#
#
# ===Tokens:===
# ['elite', 'residence', 'tower', 'new', 'development', 'tameer', 'located', 'heart', 'dubai', 'marina']
#
#
# ===Tokens:===
# ['cut', 'bring', 'outdoors', 'birch', 'branch', 'coasters']
#
#
# ===Tokens:===
# ['country', 'switzerland', 'sector', 'pharmaceuticals', 'target', 'synosia', 'therapeutics', 'holding', 'ag', 'buyer', 'biotie', 'therapies', 'corp', 'deal', 'size', 'usd', '129', '4', 'type', 'corporate', 'acquisition', 'financing', 'stock', 'status', 'closed']
#
#
# ===Tokens:===
# ['timo', 'penttila', 'appointed', 'new', 'manager', 'responsible', 'asset', 'management', 'nordea', 'institutional', 'customers', 'finland']
#
#
# ===Tokens:===
# ['order', 'comprises', 'production', 'lines', 'plywood', 'mill', 'company', 'said', 'statement', 'received', 'lesprom', 'network']
#
#
# ===Tokens:===
# ['operating', 'profit', 'decreased', 'nearly', 'eur', '1', '7', 'mn', 'however']
#
#
# ===Tokens:===
# ['met', 'located', 'central', 'business', 'district', 'cbd', 'bangkok']
#
#
# ===Tokens:===
# ['teollisuuden', 'voima', 'oyj', 'finnish', 'utility', 'known', 'tvo', 'said', 'shortlisted', 'mitsubishi', 'heavy', 'eu', 'apwr', 'model', 'along', 'reactors', 'areva', 'toshiba', 'corp', 'ge', 'hitachi', 'nuclear', 'energy', 'korea', 'hydro', 'nuclear', 'power', 'co']
#
#
# ===Tokens:===
# ['pharmaceuticals', 'belgium', 'brand', 'new', 'market', 'analysis', 'gives', 'clear', 'overview', 'actual', 'situation', 'future', 'outlook', 'pharmaceutical', 'market', 'belgium']
#
#
# ===Tokens:===
# ['2003', 'emphasis', 'kyro', 'strategy', 'glaston', 'growth']
#
#
# ===Tokens:===
# ['according', 'original', 'merger', 'plan', 'scanfil', 'would', 'get', '79', 'stake', 'combined', 'business']
#
#
# ===Tokens:===
# ['profitability', 'ebit', '13', '6', 'compared', '14', '3', 'q2', '2009']
#
#
# ===Tokens:===
# ['arena', 'partners', 'oy', 'development', 'company', 'electronic', 'business']
#
#
# ===Tokens:===
# ['curators', 'divided', 'material', 'eight', 'themes']
#
#
# ===Tokens:===
# ['new', 'production', 'lines', 'novator', 'mill', 'veliky', 'ustjug', 'vologda', 'oblast', 'sveza', 'change', 'current', '1', '5', '1', '5', 'birch', 'plywood', 'production', 'targeting', 'domestic', 'market', 'produce', '1', '5', '3', '0', 'overlaid', 'birch', 'plywood', 'global', 'market']
#
#
# ===Tokens:===
# ['1411', 'cet', 'arcelormittal', 'lost', '7', '26', 'eur', '17', '38', 'euronext', 'paris', 'coming', 'lead', 'blue', 'chip', 'fallers']
#
#
# ===Tokens:===
# ['rights', 'reserved']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '6', '7', 'mn', 'eur', '7', '2', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['operating', 'loss', 'pulp', 'paper', 'machinery', 'unit', 'eur', '3mn', 'september', '2007', 'august', '2008', 'compared', 'profit', 'eur', '3', '7', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['ruukki', 'group', 'calculates', 'lost', 'eur', '4mn', 'failed', 'project']
#
#
# ===Tokens:===
# ['proha', 'plc', 'euronext', '7327', 'announced', 'today', '19', 'may', 'fully', 'owned', 'subsidiary', 'safran', 'software', 'solutions', 'agreed', 'sell', '49', 'share', 'safran', 'north', 'america', 'llc', 'sna', 'holding', 'investment', 'group', 'based', 'norway']
#
#
# ===Tokens:===
# ['made', 'long', 'term', 'investments', 'developing', 'system', 'implementation', 'model']
#
#
# ===Tokens:===
# ['unit', 'planned', 'operational', 'second', 'half', '2007', 'full', 'stream', '2008']
#
#
# ===Tokens:===
# ['trip', 'maintains', 'neutral', 'rating', 'jp', 'morgan', 'pt', 'cut', '61', '66']
#
#
# ===Tokens:===
# ['sales', 'mid', 'strength', 'beer', 'decreased', '40']
#
#
# ===Tokens:===
# ['marimekko', 'aims', 'expand', 'distribution', 'network', 'primarily', 'increasing', 'number', 'concept', 'stores', 'shop', 'shops']
#
#
# ===Tokens:===
# ['return', 'capital', 'employed', 'roce', 'negative', '2', '3', 'compared', '11', '3', '2007']
#
#
# ===Tokens:===
# ['hkscan', 'headquartered', 'turku', 'finland', 'leading', 'northern', 'european', 'food', 'group', '10', '000', 'employees', 'nine', 'countries']
#
#
# ===Tokens:===
# ['maximum', '666', '104', 'new', 'shares', 'subscribed', 'exercising', 'b', 'options', '2004', 'stock', 'option', 'plan']
#
#
# ===Tokens:===
# ['two', 'contracts', 'turntable', 'anode', 'vibrocompactors', 'delivered', 'gansu', 'hualu', 'aluminum', 'co', 'ltd', 'another', 'unnamed', 'costumer']
#
#
# ===Tokens:===
# ['addus', 'services', 'include', 'personal', 'care', 'assistance', 'activities', 'daily', 'living', 'skilled', 'nursing', 'rehabilitative', 'therapies', 'adult', 'day', 'care']
#
#
# ===Tokens:===
# ['mr', 'koistinen', 'joins', 'nokia', 'siemens', 'networks', 'held', 'various', 'senior', 'sales', 'management', 'business', 'development', 'positions', 'since', '1997']
#
#
# ===Tokens:===
# ['pentik', 'inen', 'emphasises', 'internet', 'contents', 'media', 'houses', 'provide', 'free', 'forever']
#
#
# ===Tokens:===
# ['update', '1', 'meggitt', 'reiterates', 'annual', 'outlook', 'tough', '2014']
#
#
# ===Tokens:===
# ['new', 'chairman', 'board', 'directors', 'mr', 'chaim', 'katzman', 'give', 'presentation', 'answer', 'questions']
#
#
# ===Tokens:===
# ['transaction', 'herttaassa', 'holding', 'alma', 'media', 'fallen', 'flagging', 'limit', '5']
#
#
# ===Tokens:===
# ['april', '2010', 'olvi', 'range', 'ciders', 'expand', 'strawberry', 'rhubarb', 'apple', 'pear', 'cider', 'green', 'bottles', 'new', 'shape']
#
#
# ===Tokens:===
# ['kemira', 'headquartered', 'helsinki', 'finland', 'international', 'chemicals', 'group', 'comprising', 'business', 'areas', 'kemira', 'pulp', 'paper', 'kemira', 'water', 'kemira', 'specialty', 'kemira', 'coatings']
#
#
# ===Tokens:===
# ['according', 'gallup', 'food', 'farm', 'facts', 'beef', 'consumption', 'totaled', '99mn', 'kilos', 'finland', '2007']
#
#
# ===Tokens:===
# ['nokia', 'inaugurated', 'manufacturing', 'plant', 'near', 'chennai', '11', 'mar', '2006']
#
#
# ===Tokens:===
# ['intercontinental', 'hotels', 'denies', 'reports', 'starwood', 'merger', 'talks']
#
#
# ===Tokens:===
# ['sales', 'fell', 'abroad', 'increased', 'finland']
#
#
# ===Tokens:===
# ['sanoma', 'corporation', 'wants', 'new', 'better', 'frequency', 'helsinki', 'metropolitan', 'area']
#
#
# ===Tokens:===
# ['economic', 'development', 'trade', 'ministry', 'industry', 'energy', 'ministry', 'along', 'kostroma', 'regional', 'administration', 'russian', 'lumberman', 'timber', 'exporters', 'union', 'carrying', 'work', 'acquire', 'investment', 'construction', 'pulp', 'paper', 'mill', 'neya', 'since', '2003']
#
#
# ===Tokens:===
# ['period', 'sales', 'dropped', 'eur', '30', '6', 'million', 'eur', '38', '3', 'million', 'according', 'interim', 'report', 'released', 'today']
#
#
# ===Tokens:===
# ['said', 'losing', 'five', 'families', 'month', 'economy', 'many', 'make', 'alternative', 'arrangements', 'save', 'money']
#
#
# ===Tokens:===
# ['honkarakenne', 'starts', 'production', 'need', 'partner', 'sawmill', 'operations']
#
#
# ===Tokens:===
# ['acquisition', 'teliasonera', 'would', 'france', 'telecom', 'biggest', 'since', '2000', 'purchase', 'orange', 'plc', '27', '8', 'billion', '55', '1', 'billion', 'would', 'create', 'world', 'fourth', 'largest', 'telecom', 'company', 'behind', 'inc', 'verizon', 'communications', 'inc', 'ntt', 'corp', 'japan']
#
#
# ===Tokens:===
# ['finnish', 'developer', 'manufacturer', 'mobile', 'phone', 'chargers', 'salcomp', 'plc', 'omx', 'helsinki', 'sal1v', 'wednesday', '19', 'november', 'lowered', 'full', 'year', 'net', 'sales', 'estimate']
#
#
# ===Tokens:===
# ['meantime', 'ceo', 'duties', 'assumed', 'outotec', 'deputy', 'ceo', 'seppo', 'rantakari']
#
#
# ===Tokens:===
# ['way', 'industry', 'starting', 'point', 'consumers', 'needs']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'amounted', 'loss', 'eur0', '06']
#
#
# ===Tokens:===
# ['loss', 'financial', 'items', 'totalled', 'eur', '9', '7', 'mn', 'compared', 'profit', 'eur', '1', '3', 'mn', 'corresponding', 'period', '2008']
#
#
# ===Tokens:===
# ['building', 'house', 'example', 'respecta', 'oy', 'jyvaskyla', 'premises', 'well', 'companies', 'announced', 'later', 'says', 'samuel', 'koivisto', 'director', 'technopolis', 'operations', 'jyvaskyla']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'dec', '19', 'united', 'states', 'patent', '7', '853', '620', 'issued', 'dec', '14', 'assigned', 'nokia', 'corp', 'espoo', 'finland']
#
#
# ===Tokens:===
# ['north', 'rhine', 'westphalia', 'issue', 'benchmark', '5', 'year', 'fixed', 'rate', 'deal', 'euros']
#
#
# ===Tokens:===
# ['report', 'full', 'year', 'results', 'august', '22']
#
#
# ===Tokens:===
# ['pge', 'belchatow', 'runs', '4', '44', 'gw', 'belchatow', 'coal', 'fired', 'power', 'plant', 'fortum', 'intentions', 'start', 'ccs', 'demonstration', 'project', 'jointly', 'teollisuuden', 'voima', 'oyj', 'tvo', 'another', 'finnish', 'utility', 'jointly', 'owned', '565mw', 'meri', 'pori', 'coal', 'fired', 'facility']
#
#
# ===Tokens:===
# ['share', 'issue', 'derogating', 'pre', 'emptive', 'right', 'shareholders', 'comprising', 'six', 'million', 'new', 'shares', 'market', 'price', 'offered', 'subscription', 'shareholders', 'holders', 'capital', 'notes', 'professional', 'clients']
#
#
# ===Tokens:===
# ['german', 'commerzbank', 'ag', 'hamburg', 'branch', 'us', 'jp', 'morgan', 'nyse', 'jpm', 'participated', 'arrangers', 'dutch', 'ing', 'ams', 'inga', 'co', 'arranger']
#
#
# ===Tokens:===
# ['process', 'products', 'orders', 'installation', 'separation', 'filtration', 'equipment', 'three', 'natural', 'gas', 'pipeline', 'projects', 'china', 'south', 'america', 'saudi', 'arabia']
#
#
# ===Tokens:===
# ['report', 'examines', 'medical', 'equipment', 'business', 'structure', 'operations', 'history', 'products', 'provides', 'analysis', 'key', 'medical', 'equipment', 'revenue', 'lines']
#
#
# ===Tokens:===
# ['net', 'profit', 'three', 'months', 'march', '31', 'fell', 'x20ac', '103', 'million', 'us', '165', 'million', 'x20ac', '131', 'million', 'year', 'earlier', 'finnish', 'company', 'said']
#
#
# ===Tokens:===
# ['honkarakenne', 'oyj', 'world', 'leading', 'manufacturer', 'genuine', 'wooden', 'homes', 'sponsoring', 'finnish', 'crosscountry', 'skier', 'virpi', 'kuitunen', 'next', 'three', 'years']
#
#
# ===Tokens:===
# ['reported', 'operating', 'margin', 'negative', '5', '9']
#
#
# ===Tokens:===
# ['ahlstrom', 'corporation', 'seppo', 'parvi', 'cfo', 'distribution', 'main', 'media', 'www', 'ahlstrom', 'com', 'ahlstrom', 'brief', 'ahlstrom', 'global', 'leader', 'development', 'manufacture', 'marketing', 'high', 'performance', 'nonwovens', 'specialty', 'papers']
#
#
# ===Tokens:===
# ['finland', 'alma', 'media', 'focus', 'quality', 'developing', 'chain', 'operations']
#
#
# ===Tokens:===
# ['company', 'share', 'quoted', 'nasdaq', 'omx', 'helsinki', 'rautaruukki', 'oyj', 'rtrks']
#
#
# ===Tokens:===
# ['warmly', 'welcome']
#
#
# ===Tokens:===
# ['sale', 'price', 'disclosed']
#
#
# ===Tokens:===
# ['site', 'cover', 'six', 'hectares']
#
#
# ===Tokens:===
# ['details', 'provided']
#
#
# ===Tokens:===
# ['technology', 'park', 'built', 'near', 'st', 'petersburg', 'based', 'pulkovo', 'airport']
#
#
# ===Tokens:===
# ['route', 'helsinki', 'finland', 'tallinn', 'estonia', 'cargo', 'volumes', 'increased', '36', 'cargo', 'volumes', 'finland', 'sweden', 'fell', '9']
#
#
# ===Tokens:===
# ['mylan', 'appoints', 'ranjan', 'ray', 'chaudhuri', 'global', 'commercial', 'lead', 'mylan']
#
#
# ===Tokens:===
# ['parties', 'also', 'agreed', 'l', 'nnen', 'tehtaat', 'right', 'sell', 'remaining', 'shares', 'suomen', 'rehu', 'hankkija', 'maatalous', '15', 'months', 'purchase', 'majority', 'holding', 'earliest']
#
#
# ===Tokens:===
# ['adp', 'news', 'feb', '11', '2009', 'finnish', 'wood', 'products', 'technology', 'supplier', 'raute', 'oyj', 'hel', 'rutav', 'said', 'today', 'net', 'profit', 'decreased', 'eur', '4', '7', 'million', 'usd', '6', '1', '2008', 'eur', '6', '6', 'million', '2007']
#
#
# ===Tokens:===
# ['metso', 'global', 'supplier', 'sustainable', 'technology', 'services', 'mining', 'construction', 'power', 'generation', 'automation', 'recycling', 'pulp', 'paper', 'industries']
#
#
# ===Tokens:===
# ['financial', 'terms', 'disclosed']
#
#
# ===Tokens:===
# ['first', 'two', 'project', 'phases', 'expected', 'completed', 'end', '2012']
#
#
# ===Tokens:===
# ['stora', 'enso', 'global', 'paper', 'packaging', 'wood', 'products', 'company', 'neste', 'oil', 'finnish', 'company', 'engaged', 'refining', 'marketing', 'oil', 'inaugurated', 'demonstration', 'plant', 'varkaus', 'finland', 'biomass', 'liquids', 'production', 'utilizing', 'forestry', 'residues']
#
#
# ===Tokens:===
# ['implementation', 'important', 'operator', 'since', 'launch', 'fixed', 'mobile', 'convergence', 'service', 'brazil', 'see', 'brazil', '8', 'may', '2006']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'eur', '4', '0', 'mn', 'eur', '4', '9', 'mn']
#
#
# ===Tokens:===
# ['construction', 'scheduled', 'start', 'april', 'june', '2007', 'completed', 'early', '2008']
#
#
# ===Tokens:===
# ['group', 'revenue', 'amounts', 'eur', '80', 'million', 'half', 'accounted', 'exports']
#
#
# ===Tokens:===
# ['layoff', 'talks', 'first', 'announced', 'august']
#
#
# ===Tokens:===
# ['beers', 'olvi', 'retained', 'market', 'position']
#
#
# ===Tokens:===
# ['eps', 'dropped', 'eur0', '2', 'eur0', '3']
#
#
# ===Tokens:===
# ['finland', 'based', 'company', 'says', 'move', 'existing', '260', '000', 'square', 'foot', 'facility', 'september']
#
#
# ===Tokens:===
# ['seem', 'enough', 'hours', 'day', 'pekkarinen']
#
#
# ===Tokens:===
# ['according', 'arokarhu', 'purchases', 'scanned', 'cash', 'register', 'computer', 'disappeared', 'total', 'sum', 'key', 'pressed']
#
#
# ===Tokens:===
# ['nordstjernan', 'make', 'offer', 'approximately', 'one', 'month', 'september', '2007']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '3', '2', 'mn', 'compared', 'profit', 'eur', '7', '2', 'mn', 'third', 'quarter', '2008']
#
#
# ===Tokens:===
# ['opportunity', 'available', 'employees', 'however']
#
#
# ===Tokens:===
# ['according', 'heikkil', 'refreshment', 'energy', 'soon', 'found', 'soft', 'drinks', 'also', 'finland']
#
#
# ===Tokens:===
# ['dividend', 'come', 'top', '0', '45', 'eur', 'shares', '0', '43', 'k', 'shares', 'already', 'paid', 'last', 'year', 'accounts']
#
#
# ===Tokens:===
# ['finnish', 'software', 'hardware', 'developer', 'elektrobit', 'oyj', 'hel', 'ebg1v', 'eb', 'said', 'today', 'temporarily', 'lay', '200', 'people', 'maximum', '90', 'day', 'finland', 'aiming', 'achieve', 'cost', 'savings', 'eur', '1', '7', 'million', 'usd', '2m', 'second', 'half', '2010']
#
#
# ===Tokens:===
# ['testament', 'quality', 'lte', 'solution', 'commitment', 'japanese', 'market', 'added']
#
#
# ===Tokens:===
# ['according', 'notification', 'holdings', 'ameriprice', 'inc', 'group', 'companies', 'total', '808', '973', 'shares', 'represent', '3', '582', 'tekla', 'shares', 'voting', 'rights']
#
#
# ===Tokens:===
# ['marketing', 'use', 'tikkurila', 'existing', 'infra', 'structure', 'local', 'knowledge', 'russia']
#
#
# ===Tokens:===
# ['authorisation', 'force', 'end', 'next', 'annual', 'general', 'meeting', 'repeals', 'authorisation', 'acquire', 'shares', 'given', 'general', 'meeting', 'held', 'april', '4', '2007']
#
#
# ===Tokens:===
# ['tulikivi', 'manufactures', 'heat', 'retaining', 'soapstone', 'ceramic', 'fireplaces', 'well', 'natural', 'stone', 'products', 'utility', 'ceramics']
#
#
# ===Tokens:===
# ['choose', 'giant', 'countdown', 'red', 'head', 'rainbow', 'trout', 'giant', 'shad', 'rap', 'perch', 'color']
#
#
# ===Tokens:===
# ['whats', 'lulu', 'numbers', 'looked', 'good', 'great', 'good', 'think', 'conference', 'call', 'instill', 'confidence']
#
#
# ===Tokens:===
# ['finnish', 'suominen', 'corporation', 'makes', 'wipes', 'nonwovens', 'flexible', 'packaging', 'plant', 'near', 'warsaw', 'poland', 'makes', 'flexible', 'packaging']
#
#
# ===Tokens:===
# ['finnish', 'retail', 'software', 'developer', 'aldata', 'solution', 'oyj', 'reported', 'net', 'loss', '11', '7', 'mln', 'euro', '17', '2', 'mln', '2007', 'versus', 'net', 'profit', '2', '5', 'mln', 'euro', '3', '7', 'mln', '2006']
#
#
# ===Tokens:===
# ['f', 'secure', 'internet', 'security', '2010', 'security', 'service', 'surfing', 'web', 'online', 'banking', 'shopping', 'e', 'mail', 'online', 'activities']
#
#
# ===Tokens:===
# ['order', 'included', 'metso', 'fourth', 'quarter', '2007', 'order', 'backlog']
#
#
# ===Tokens:===
# ['latin', 'america', 'currently', 'accounts', 'approximately', '40', 'sales', 'tecnotree', 'company', 'president', 'ceo', 'eero', 'mertano', 'recently', 'told', 'bnamericas']
#
#
# ===Tokens:===
# ['effect', 'may', 'remain', 'short', 'lived', 'however']
#
#
# ===Tokens:===
# ['ebrd', 'using', 'funds', 'provide', '21', '6', 'mln', 'loan', 'b', 'portion', '10', 'mln', 'euros', 'syndicated', 'two', 'finnish', 'commercial', 'banks', 'nordea', 'bank', 'finland', 'plc', '7', '7', 'mln', 'euros', 'pohjola', 'bank', 'plc', '2', '3', 'mln', 'euros']
#
#
# ===Tokens:===
# ['parties', 'therefore', 'agreed', 'leave', 'avena', 'deal']
#
#
# ===Tokens:===
# ['april', '2005', 'neste', 'separated', 'parent', 'company', 'finnish', 'energy', 'company', 'fortum', 'became', 'listed', 'helsinki', 'stock', 'exchange']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', '2005', 'amounted', 'loss', 'eur1', '26']
#
#
# ===Tokens:===
# ['result', 'transactions', 'aggregate', 'holdings', 'burrill', 'life', 'sciences', 'capital', 'fund', 'l', 'p', 'decreased', '5', 'per', 'cent', 'total', 'number', 'shares', 'votes', 'company']
#
#
# ===Tokens:===
# ['1', 'april', '2007', 'cencorp', 'employees', 'territory']
#
#
# ===Tokens:===
# ['however', 'offering', 'probably', 'made', 'current', 'valuation', 'partly', 'derives', 'deal', 'company', 'merged', 'stock', 'market', 'shell']
#
#
# ===Tokens:===
# ['electricity', 'consumption', 'grows', 'higher', 'frequencies']
#
#
# ===Tokens:===
# ['contract', 'value', 'amounts', 'eur11m', 'company', 'added']
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '5', '2', 'mn', 'compared', 'loss', 'eur', '3', '4', 'mn', 'corresponding', 'period', '2008', '2009']
#
#
# ===Tokens:===
# ['neste', 'shipping', 'likely', 'remain', 'finnish', 'oil', 'sector', 'transports', 'significant', 'emergency', 'supply']
#
#
# ===Tokens:===
# ['vehvilainen', 'currently', 'chief', 'operating', 'officer', 'nokia', 'siemens', 'networks', 'join', 'finnair', '5', 'january', '2010', 'take', 'ceo', 'effective', '1', 'february', '2010']
#
#
# ===Tokens:===
# ['emsa', 'deputy', 'chairman', 'board', 'juri', 'lember', 'told', 'bns', 'wednesday', 'first', 'time', 'heard', 'strike', 'swedish', 'side', 'informed', 'estonian', 'union', 'yet']
#
#
# ===Tokens:===
# ['bridge', 'part', 'highway', '14', 'development', 'project']
#
#
# ===Tokens:===
# ['potential', 'acquirer', 'cencorp', 'corporation', 'related', 'entity', 'sav', 'owing', 'sav', 'cencorp', 'subsidiary', 'finnish', 'savcor', 'group', 'oy']
#
#
# ===Tokens:===
# ['elcoteq', 'global', 'service', 'offering', 'covers', 'entire', 'lifecycle', 'products', 'product', 'development', 'market', 'services']
#
#
# ===Tokens:===
# ['financial', 'details', 'n', 'disclosed']
#
#
# ===Tokens:===
# ['counter', 'competitor', 'strengths', 'target', 'weaknesses']
#
#
# ===Tokens:===
# ['amendment', 'incur', 'additional', 'costs']
#
#
# ===Tokens:===
# ['project', '2', 'x', '600', 'mw', 'coal', 'fired', 'power', 'plant', 'located', '420', 'km', 'south', 'hanoi', 'company', 'said']
#
#
# ===Tokens:===
# ...
#
#
# ===Tokens:===
# ['operating', 'loss', 'totalled', 'eur', '4', '0', 'mn', 'compared', 'profit', 'eur', '8', '6', 'mn', 'second', 'quarter', '2008']
#
#
# ===Tokens:===
# ['stora', 'enso', 'target', 'cut', 'eur', '4', '85', 'eur', '5', '55', 'holmen', 'target', 'sek', '135', 'sek', '150']
#
#
# ===Tokens:===
# ['finnish', 'investor', 'scanfil', 'oyj', 'hel', 'scf1v', 'said', 'last', 'friday', 'bought', '57', 'million', 'shares', '32', '96', 'norwegian', 'contract', 'electronics', 'manufacturer', 'kitron', 'asa', 'osl', 'kit', 'nok', '143', '9', 'million', 'usd', '24', '4', 'eur', '18', '1']
#
#
# ===Tokens:===
# ['annual', 'report', 'contains', 'financial', 'statements', 'consolidated', 'financial', 'statements', 'report', 'board', 'directors', 'auditor', 'report']
#
#
# ===Tokens:===
# ['sales', 'volume', 'coca', 'cola', 'market', 'share', 'decreased', '2', '2', '24', '2']
#
#
# ===Tokens:===
# ['based', 'negotiations', 'personnel', '20', 'indicated', 'willingness', 'move', 'new', 'location']
#
#
# ===Tokens:===
# ['company', 'transportation', 'business', 'conducted', 'florida', 'rock', 'tank', 'lines', 'southeastern', 'transportation', 'company', 'concentrating', 'hauling', 'motor', 'carrier', 'liquid', 'dry', 'bulk', 'commodities']
#
#
# ===Tokens:===
# ['according', 'hk', 'ruokatalo', 'almost', 'meat', 'used', 'company', 'comes', 'finland']
#
#
# ===Tokens:===
# ['order', 'consists', 'capacity', 'expansion', 'maintenance', 'services', 'new', 'charging', 'functionality', 'company', 'said']
#
#
# ===Tokens:===
# ['paper', 'company', 'real', 'calculated', '100', '000', 'biscuit', 'cartons', 'made', 'using', '25gsm', 'lighter', 'board', 'co2', 'saved', 'course', '12', 'months', 'would', 'equal', 'generated', 'driving', '1', '000', 'km', 'car']
#
#
# ===Tokens:===
# ['key', 'level', 'watch', 'fb', 'today', '25', '53', 'watching', 'see', 'hold', 'support', 'http', 'stks', 'co', 'boh4']
#
#
# ===Tokens:===
# ['part', 'agreement', 'aspocomp', 'also', 'give', 'meadville', '10', 'pct', 'slice', 'subsidiary', 'operating', 'oulu', 'finland']
#
#
# ===Tokens:===
# ['original', 'contract', 'signed', 'last', 'summer']
#
#
# ===Tokens:===
# ['finnish', 'metal', 'components', 'supplier', 'componenta', 'december', '26', '2006', 'applied', 'approval', 'turkish', 'capital', 'markets', 'board', 'launch', 'mandatory', 'offer', 'remaining', 'shares', 'iron', 'aluminium', 'castings', 'producer', 'doktas', 'dokumculuk']
#
#
# ===Tokens:===
# ['cargo', 'traffic', 'fell', '1', 'year', 'year', '8', '561', 'tonnes', 'september', '2009']
#
#
# ===Tokens:===
# ['net', 'sales', 'kyro', 'main', 'business', 'area', 'glaston', 'technologies', 'manufacturer', 'glass', 'processing', 'machines', 'decreased', 'eur', '161', '5', 'mn', 'eur', '164', '1', 'mn', 'january', 'september', '2005']
#
#
# ===Tokens:===
# ['ab', 'inbev', 'sell', 'sab', 'assets', 'seeks', 'eu', 'deal', 'approval']
#
#
# ===Tokens:===
# ['market', 'share', '6', 'percent', 'according', 'ac', 'nielsen', '2008', 'data']
#
#
# ===Tokens:===
# ['salcomp', 'charger', 'manufacturing', 'plant', 'india', 'located', 'nokia', 'telecom', 'park', 'state', 'tamil', 'nadu', 'eastern', 'part', 'india']
#
#
# ===Tokens:===
# ['profit', 'taxes', 'decreased', 'eur', '31', '6', 'mn', 'eur', '50', '0', 'mn', 'year']
#
#
# ===Tokens:===
# ['veidekke', 'headquartered', 'oslo', 'norway', 'scandinavian', 'construction', 'property', 'development', 'group', '6', '350', 'employees', 'norway', 'sweden', 'denmark', 'annual', 'turnover', 'nok16', '4', 'bn']
#
#
# ===Tokens:===
# ['shares', 'subscribed', 'eligible', 'trade', 'following', 'day', 'registration']
#
#
# ===Tokens:===
# ['erkki', 'jarvinen', 'president', 'rautakirja', 'head', 'sanoma', 'trade', 'division', 'leave', 'current', 'tasks', 'spring', '2009', 'similar', 'position', 'outside', 'sanoma', 'group']
#
#
# ===Tokens:===
# ['agreement', 'larox', 'transfer', '10', 'employees', 'within', 'engineering', 'documentation', 'related', 'delivery', 'projects', 'product', 'maintenance', 'finland', 'etteplan', 'january', '1', '2007']
#
#
# ===Tokens:===
# ['2007', 'etteplan', 'reported', 'turnover', 'eur125', '2']
#
#
# ===Tokens:===
# ['eu', 'commission', 'said', 'earlier', 'fined', 'thyssenkrupp', 'united', 'technologies', 'corp', 'otis', 'schindler', 'ag', 'kone', 'oyj', 'total', '992', '3', 'mln', 'eur', 'alleged', 'cartel', 'activity', 'lift', 'market', 'going', 'back', 'twelve', 'years']
#
#
# ===Tokens:===
# ['ruukki', 'delivery', 'includes', 'steel', 'structures', 'including', 'installation', 'krakeroy', 'bascule', 'bridge', 'steel', 'piles', 'bridge', 'foundations']
#
#
# ===Tokens:===
# ['based', 'design', 'previous', 'handsets', 'nokia', 'e72', 'nokia', 'e63', 'symbian', 'based', 'model', 'promised', 'offer', 'direct', 'access', '90', 'per', 'cent', 'world', 'corporate', 'email', 'mail', 'exchange', 'ibm', 'lotus', 'notes', 'traveler']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'oct', '6', 'united', 'states', 'patent', '7', '804', '288', 'issued', 'sept', '28', 'assigned', 'vacon', 'oyj', 'vaasa', 'finland']
#
#
# ===Tokens:===
# ['reason', 'st', 'petersburg', 'status', 'capital', 'one', 'participants', 'meeting', 'quoted', 'chikunov', 'saying']
#
#
# ===Tokens:===
# ['negotiations', 'started', 'neste', 'oil', 'anticipated', '450', 'people', 'would', 'affected']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totalled', 'eur', '30', '2', 'mn', 'eur', '43', '8', 'mn', 'year', 'earlier']
#
#
# ===Tokens:===
# ['total', 'investment', 'necessary', 'eur40m', 'company', 'estimated']
#
#
# ===Tokens:===
# ['helsinki', 'based', 'componenta', 'bought', 'turkish', 'listed', 'company', 'doktas', 'october', '2006', '89', 'million', 'euros', 'making', 'largest', 'finnish', 'investment', 'turkey', 'date']
#
#
# ===Tokens:===
# ['operating', 'profit', 'totaled', 'eur', '3', '8', 'mn', 'eur', '4', '5', 'mn', 'corresponding', 'period', '2005']
#
#
# ===Tokens:===
# ['deliveries', 'start', 'second', 'half', '2007', 'start', 'mill', 'scheduled', '2008']
#
#
# ===Tokens:===
# ['even', 'little', 'bit', 'higher', 'yara', 'multiples', 'analyst', 'helsinki', 'said']
#
#
# ===Tokens:===
# ['size', 'cider', 'bottle', 'remain', 'unchanged']
#
#
# ===Tokens:===
# ['ferries', 'run', 'trouble', 'outside', 'stockholm', 'archipelago', 'made', '20', '000', 'islands']
#
#
# ===Tokens:===
# ['motorola', 'inc', 'united', 'states', 'came', 'second', 'shipments', '217', '4', 'million', 'units', '21', '3', 'percent', 'market', 'share', 'followed', 'south', 'korea', 'samsung', 'electronics', 'co', 'shipments', '118', '0', 'million', 'units', '11', '6', 'percent', 'share']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'nov', '19', 'erkki', 'aho', 'elimaki', 'finland', 'developed', 'method', 'apparatus', 'conjunction', 'shoe', 'press']
#
#
# ===Tokens:===
# ['alexandria', 'va', 'may', '23', 'matti', 'harkonen', 'pentti', 'sipponen', 'espoo', 'finland', 'osmo', 'suovaniemi', 'helsinki', 'finland', 'tapani', 'tiusanen', 'vantaa', 'finland', 'developed', 'paper', 'web', 'press', 'device']
#
#
# ===Tokens:===
# ['survey', 'conducted', 'taloustutkimus', 'sampo', 'life', 'shows', 'companies', 'badly', 'prepared', 'losing', 'key', 'staff', 'members']
#
#
# ===Tokens:===
# ['deal', 'includes', 'entire', 'personnel', 'planmill', 'oy', 'transfer', 'new', 'company', 'called', 'old', 'employees']
#
#
# ===Tokens:===
# ['metso', 'oyj', 'said', 'sold', 'spreader', 'roll', 'manufacturing', 'business', 'related', 'assets', 'town', 'nokia', 'southern', 'finland', 'group', 'finnish', 'investors', 'operate', 'business', 'name', 'finbow', 'oy']
#
#
# ===Tokens:===
# ['hu', 'offer', 'discount', '25', '50', 'selected', 'books']
#
#
# ===Tokens:===
# ['fiscal', 'year', 'ending', 'september', '30', '2009', 'revenue', 'customers', '10', '012', 'million', 'around', '11', '0', 'transportation', 'group', 'revenue']
#
#
# ===Tokens:===
# ['yit', 'lodged', 'counter', 'claims', 'neste', 'oil', 'totaling', 'eur25m', 'primarily', 'based', 'work', 'carried', 'contract', 'additional', 'costs', 'incurred', 'due', 'prolongation', 'project']
#
#
# ===Tokens:===
# ['fortum', 'also', 'blocking', 'stake', 'northwestern', 'tgk', '1']
#
#
# ===Tokens:===
# ['one', 'opportunities', 'would', 'bring', 'baltic', 'meat', 'processing', 'rakvere', 'like', 'processing', 'concentrated', 'vantaa', 'meat', 'packing', 'unit', 'finland', 'paper', 'wrote']
#
#
# ===Tokens:===
# ['tanks', 'delivered', 'company', 'currently', 'building', 'chemical', 'tank', 'farm', 'antwerp', 'northern', 'belgium']
#
#
# ===Tokens:===
# ['lemmink', 'inen', 'started', 'manufacture', 'roofing', 'felt', '1920', 'production', 'asphalt', '1930s']
#
#
# ===Tokens:===
# ['metso', 'foundries', 'jyvaskyla', 'oy', 'discontinue', 'production', 'line', '30', 'september', '2008']
#
#
# ===Tokens:===
# ['tightened', 'competition', 'situation', 'production', 'automation', 'market', 'affected', 'net', 'sales', '2006', 'cencorp', 'said']
#
#
# ===Tokens:===
# ['jon', 'risfelt', '49', 'years', 'old', 'holds', 'master', 'science', 'chemical', 'engineering', 'swedish', 'royal', 'institute', 'technology']
#
#
# ===Tokens:===
# ['2009', 'comptel', 'slipped', 'net', 'loss', 'eur2', '1', 'profit', 'eur6', '6', 'previous', 'year']
#
#
# ===Tokens:===
# ['abn', 'amro', 'capital', 'agreed', 'sell', 'helsinki', 'based', 'designer', 'homeware', 'producer', 'iittala', 'oyj', 'crosstown', 'consumer', 'products', 'group', 'fiskars', 'corp', 'eur230', 'million', 'eur235', 'million', '310', 'million', '316', 'million']
#
#
# ===Tokens:===
# ['europe', 'however', 'remains', 'important', 'strong', 'market', 'us']
#
#
# ===Tokens:===
# ['westpac', 'banking', 'corp', 'issue', 'benchmark', '3', 'year', 'frn', 'deal', 'euros']
#
#
# ===Tokens:===
# ['past', '10', 'years', 'factory', 'produced', 'many', 'nokia', 'popular', 'models', 'including', 'nokia', '2760', 'nokia', '6300', 'well', 'nokia', 'latest', 'music', 'device', 'nokia', '5800', 'express', 'music']
#
#
# ===Tokens:===
# ['cargotec', 'share', 'capital', 'increase', 'totals', '64', '046', '460', 'euros']
#
#
# ===Tokens:===
# ['incap', 'corporation', 'stock', 'exchange', 'announcement', '29', 'april', '2010', '1', 'p', 'invitation', 'news', 'conference', 'incap', 'interim', 'report', 'q1', '2010', 'incap', 'publish', 'interim', 'report', 'january', 'march', '2010', 'wednesday', '5', 'may', '2010']
#
#
# ===Tokens:===
# ['pa', 'jpmorgan', 'chase', 'co', 'nyse', 'jpm', 'pohjoa', 'bank', 'joint', 'lead', 'managers', 'senior', 'unsecured', 'deal']
#
#
# ===Tokens:===
# ['ruukki', 'included', 'djsi', 'world', 'second', 'year', 'running', 'european', 'djsi', 'stoxx', 'third', 'year', 'running']
#
#
# ===Tokens:===
# ['shares', 'shall', 'repurchased', 'public', 'trading', 'reason', 'shares', 'repurchased', 'otherwise', 'proportion', 'holdings', 'shareholders']
#
#
# ===Tokens:===
# ['okhta', 'center', 'area', 'expected', '700', '000', 'square', 'metres', 'office', 'premises', '2016']
#
#
# ===Tokens:===
# ['company', 'decided', 'stop', 'operations', 'ruukki', 'construction', 'division', 'latvia', 'lithuania', 'concentrate', 'production', 'logistics', 'parnu', 'estonia', '2009']
#
#
# ===Tokens:===
# ['uranium', 'found', 'locally', 'naturally', 'occurring', 'makes', 'sense', 'extract', 'way', 'metals']
#
#
# ===Tokens:===
# ['company', 'operates', 'u', 'division', 'lisle', 'ill']
#
#
# ===Tokens:===
# ['guidance', 'set', '90', 'basis', 'points', 'mid', 'swaps', 'report', 'said']
#
#
# ===Tokens:===
# ['finnish', 'media', 'company', 'talentum', 'oyj', 'net', 'profit', 'decreased', '2', '5', 'mln', 'euro', '4', '0', 'mln', 'first', 'quarter', '2008', '3', '0', 'mln', 'euro', '4', '7', 'mln', 'period', '2007']
#
#
# ===Tokens:===
# ['total', 'need', 'staff', 'cuts', 'corresponds', '300', 'man', 'years']
#
#
# ===Tokens:===
# ['country', 'finland', 'sector', 'construction', 'real', 'estate', 'target', 'pohjolan', 'design', 'talo', 'oy', 'buyer', 'capman', 'oyj', 'vendor', 'ruukki', 'group', 'oyj', 'deal', 'size', 'usd', '102', '6', 'type', 'divestment', 'status', 'agreed']
#
#
# ===Tokens:===
# ['program', 'started', 'summer', '2007', 'originally', 'estimated', 'last', 'approximately', 'two', 'years']
#
#
# ===Tokens:===
# ['company', 'reiterates', 'outlook', '2009']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operating', 'activities', 'investments', 'eur', '7', '6', 'million', 'eur', '2', '5', 'million']
#
#
# ===Tokens:===
# ['lsc', '30', 'employees', 'move', 'ixonos', 'existing', 'status', 'benefits']
#
#
# ===Tokens:===
# ['sampo', 'group', 'become', 'major', 'shareholder', 'nordea', 'owns', 'trygvesta', 'main', 'competitor', 'p', 'c', 'insurance']
#
#
# ===Tokens:===
# ['increase', 'number', 'shares', 'based', 'option', 'rights', 'granted', 'management', 'company', 'stock', 'option', 'plan', '2006']
#
#
# ===Tokens:===
# ['third', 'quarter', 'result', 'also', 'includes', '400', '000', 'euro', '575', '000', 'provision', 'sizing', 'lure', 'manufacturing', 'ireland']
#
#
# ===Tokens:===
# ['company', 'board', 'directors', 'would', 'propose', 'dividend', 'eur1', '00', 'per', 'share', '2005']
#
#
# ===Tokens:===
# ['cash', 'flow', 'operating', 'activities', 'investments', 'eur', '0', '8', '1', '2', 'million']
#
#
# ===Tokens:===
# ['believe', 'however', 'hkscan', 'atria', 'start', 'use', 'imported', 'meat', 'finnish', 'consumers', 'prefer', 'domestic', 'products']
#
#
# ===Tokens:===
# ['net', 'sales', 'dropped', '6', 'year', 'year', 'eur', '11', '9', 'million']
#
#
# ===Tokens:===
# ['finnish', 'food', 'workers', 'union', 'sel', 'plans', 'hasten', 'collective', 'bargaining', 'two', 'day', 'strike', 'would', 'begin', '7', 'april', '2010', 'finland']
#
#
# ===Tokens:===
# ['neste', 'oil', 'refineries', 'combined', 'crude', 'oil', 'refining', 'capacity', 'approximately', '260', '000', 'barrels', 'day']
#
#
# ===Tokens:===
# ['incap', 'estimates', 'generate', 'revenue', '10', 'mln', 'euro', '13', '2', 'mln', 'indian', 'operations', '2007']
#
#
# ===Tokens:===
# ['target', 'company', 'tieto', 'corporation', 'business', 'identity', 'code', '0101138', '5', 'date', 'change', 'holding', '22', 'january', '2010', 'portion', 'shares', 'votes', 'current', 'group', 'holding', 'op', 'pohjola', 'group', 'central', 'cooperative', 'opk', '2982', '587', 'shares', 'represents', '4', '14', 'shares', 'voting', 'rights']
#
#
# ===Tokens:===
# ['alma', 'media', 'corporation', 'press', 'release', '15', 'march', '2010', 'tyrvaan', 'sanomat', 'paikallissanomat', 'bought', 'suomen', 'paikallissanomat', 'two', 'local', 'papers', 'tyrvaan', 'sanomat', 'paikallissanomat', 'appearing', 'sastamala', 'neighbouring', 'municipalities', 'bought', 'suomen', 'paikallissanomat', 'oy']
#
#
# ===Tokens:===
# ['rohwedder', 'group', 'automotive', 'supplies', 'telecommunications', 'electronics', 'industry', 'provider', 'customers', 'europe', 'north', 'america', 'asia']
#
#
# ===Tokens:===
# ['group', 'loyal', 'customer', 'magazine', 'yhteishyv', 'came', 'second', '1', '629', '000', 'readers', 'sanoma', 'corporation', 'daily', 'newspaper', 'helsingin', 'sanomat', 'third', '1', '097', '000', 'readers']
#
#
# ===Tokens:===
# ['olli', 'pekka', 'kallasvuo', 'elected', 'vice', 'chairman', 'board']
#
#
# ===Tokens:===
# ['steelmaker', 'said', 'drop', 'profit', 'explained', 'continuing', 'economic', 'uncertainty', 'mixed', 'current', 'drought', 'bank', 'lending', 'resulting', 'decline', 'demand', 'products', 'customers', 'find', 'increasingly', 'difficult', 'fund', 'operations']
#
#
# ===Tokens:===
# ['earnings', 'per', 'share', 'eps', 'dropped', 'eur', '0', '21', 'eur', '0', '31']
#
#
# ===Tokens:===
# ['company', 'also', 'appointed', 'leif', 'rosen', 'head', 'special', 'plate', 'unit', 'includes', 'quarto', 'plate', 'units', 'degerfors', 'sweden', 'new', 'castle', 'usa', 'unit', 'willich', 'germany', 'well', 'pressplate', 'prefab', 'avesta', 'plate', 'service', 'centre', 'nordic', 'degerfors']
#                              0   1
# 0      mn corresponding period  20
# 1                net sales eur  16
# 2          compared profit eur  14
# 3           earnings per share  12
# 4         operating profit eur  12
# ...                        ...  ..
# 26066      prefab avesta plate   1
# 26067     avesta plate service   1
# 26068     plate service centre   1
# 26069    service centre nordic   1
# 26070  centre nordic degerfors   1
#
# [26071 rows x 2 columns]

# %%
x_positive_tri = df_positive_tri[0][:10]
y_positive_tri = df_positive_tri[1][:10]

x_negative_tri = df_negative_tri[0][:10]
y_negative_tri = df_negative_tri[1][:10]

x_neutral_tri = df_neutral_tri[0][:10]
y_neutral_tri = df_neutral_tri[1][:10]


fig, ax = plt.subplots(3, 1, figsize=(20, 8), dpi=110)

ax[0].bar(x_positive_tri, y_positive_tri, color='g', width= 0.6)
ax[0].set_title('Top 10 words with positive sentiment(Trigrams)')
ax[0].set_xlabel('Words in the positive df')
ax[0].set_ylabel('Count')

ax[1].bar(x_negative_tri, y_negative_tri, color='r', width= 0.6)
ax[1].set_title('Top 10 words with negative sentiment(Trigrams)')
ax[1].set_xlabel('Words in the negative df')
ax[1].set_ylabel('Count')

ax[2].bar(x_neutral_tri, y_neutral_tri, color='gray', width= 0.6)
ax[2].set_title('Top 10 words with neutral sentiment(Trigrams)')
ax[2].set_xlabel('Words in the neutral df')
ax[2].set_ylabel('Count')
plt.tight_layout()
